# %%
import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count
import numpy as np

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
'''Dynamic Programming, FCFS Simulated result'''
dp = 61135
fcfs = 45564

# %%
'''Establish an aircraft'''
class aircraft:

    # Initialize aircraft
    def __init__(self):
        self.seat_capacity = 100
        self.seat_type = ['Y', 'M', 'K']
        self.seat_price = {'f': 0, 'Y': 800, 'M': 500, 'K': 450}

# %%
''' Demand model from Balaiyan et al.'''
class demandmodel:
    
    # Initialize demand model
    def __init__(self):
        
        # inherent attributes from aircraft class
        self.aircraft = aircraft()
        self.seat_set = self.aircraft.seat_type
        self.seat_price = self.aircraft.seat_price
        
        # demand model parameters
        self.total_booking = 105
        self.market_share = 0.25
        self.gamma = 0.08426
        self.alpha = 0.001251
        self.beta = {'DFARE':-0.006, 'LOT3':-0.944}
        self.a = {'Y':{'DFARE':800, 'LOT3':1},
                  'M':{'DFARE':500, 'LOT3':1},
                  'K':{'DFARE':450, 'LOT3':1},
                 }
        self.fare_diff_avg = sum(self.seat_price.values()) / len(self.seat_price)
        for seat_type in self.a:
            self.a[seat_type]['DFARE'] = round(self.a[seat_type]['DFARE'] - self.fare_diff_avg, 2)

    # Calculate dm
    def dm(self):
        dm = self.total_booking/self.market_share
        return dm

    # Calcilate booking curve
    def booking_curve(self, RD2, RD1):
        booking_curve = math.exp(-self.gamma*RD2)-math.exp(-self.gamma*RD1)
        return booking_curve

    # find pj+1
    def find_pj1(self, seat):
        smaller_keys = [key for key in self.seat_price.keys() if key < seat]
        if smaller_keys:
            max_smaller_key = max(smaller_keys)
            pj1 = self.seat_price[max_smaller_key]
        else:
            pj1 = min(self.seat_price.values())
        return pj1

    # Multinomial logit model
    def mnl(self):
        choose_prob = {}
        value_dict = {}
        for seat in self.seat_set:
            result = {key: self.beta[key] * value for key, value in self.a[seat].items()}
            total = sum(result.values())
            value = math.exp(total)
            value_dict[seat] = value
        for seat in value_dict:
            exp_value = math.exp(value_dict[seat])
            choose_prob[seat] = exp_value / sum(math.exp(value) for value in value_dict.values())
        # print("mnl: ", choose_prob)
        return choose_prob

    # Calculate customer choice
    def customer_choice(self, seat_type):
        total_sum = 0
        choose_prob = self.mnl()
        min_key = min(self.seat_price, key=self.seat_price.get)
        p0 = self.seat_price[min_key]
        for seat in self.seat_set:
            pj = self.seat_price['Y'] # 暫時寫這樣
            pj1 = self.seat_price['M'] # 暫時寫這樣
            # print('p0: ',p0 , 'p1: ', pj, 'pj1: ', pj1)
            sum_of_set = (math.exp(-self.alpha*(pj-p0))-math.exp(-self.alpha*(pj1-p0))) * choose_prob[seat_type] 
            # print('sum of set: ', sum_of_set)
            total_sum += sum_of_set
        return total_sum

    # Calculate demand
    def formulation(self, RD2, RD1):
        dm = self.dm()
        # print('dm',dm)
        booking_curve = self.booking_curve(RD2, RD1)
        # print('booking curve: ',booking_curve)
        BR_dict = {}
        
        for seat in self.seat_set:
            # print("calculate", seat, " ing...")
            customer_choice = self.customer_choice(seat)
            # print('customer choice', customer_choice)
            BR = dm * booking_curve * customer_choice
            BR_dict[seat] = BR
            # print(' seat: ', seat, ' predicted demand model from ', RD2,' to ', RD1, 'is', BR)
        print("total demand: ", sum(BR_dict.values()))
        return BR_dict
    
    # Plot demand result
    def plot_demand(self):
        
        # Store calculated result
        every_rd = {seat: [] for seat in model.seat_set}  
        cumulative_demand = {seat: [] for seat in model.seat_set}  
        total_demand = {seat: 0 for seat in model.seat_set}  
        cumulative_total_demand_per_rd = []  # Store each RD cumulative demand

        # Calculate all RD demand
        cumulative_total_demand = 0  # Initialize cumulative demand
        for i in range(2, max_rd+1):
            # print('i: ', i)
            BR_results = model.formulation(i, i-1)  
            total_demand_rd = sum(BR_results.values())  # Calculate demand form all rd
            cumulative_total_demand += total_demand_rd  # update cumulative total deamnd
            cumulative_total_demand_per_rd.append(cumulative_total_demand)  # append cumulative total demand
            for seat, demand in BR_results.items():  
                every_rd[seat].append(demand) 
                total_demand[seat] += demand  
                cumulative_demand[seat].append(total_demand[seat])  
        
        plt.figure(figsize=(10, 6))
        plt.plot(range(1, max_rd), cumulative_total_demand_per_rd, label='Total Demand')
        plt.xlabel('RD')
        plt.ylabel('Total Demand')
        plt.title('Total Demand Model')
        plt.legend()
        plt.xticks(range(0, max_rd, int(max_rd/10)))
        plt.grid(True)
        plt.show()

# %%
class AgentActionSpace:
    def __init__(self):
        self.action_list = [0, 1, 2, 3, 4, 5, 6, 7]
        self.n = len(action_list)  # 動作的數量

    def sample(self):
        return np.random.choice(self.action_list)

    def contains(self, action):
        return action in self.action_list

# 創建一個列表動作空間
action_list = [0, 1, 2, 3, 4, 5, 6, 7]
action_space = AgentActionSpace()
print(type(action_space))
# Out:
# <class '__main__.AgentActionSpace'>

# %%
'''Uniform distribution'''
class uniform_distribution:

    # Initialize parameters
    def __init__(self, total_demand, total_lambda):
        self.total_demand = total_demand
        self.total_lambda = total_lambda
        self.num_period = int(total_demand/total_lambda)
        self.prob = {'Bus1': 0.1, 'Bus2': 0.2, 'Leis1': 0.2, 'Leis2': 0.2, 'Leis3': 0.3}
    
    # Calculate lambda for each type of customer
    def calculate_lambda(self):
        lambda_list = []
        lambda_list.append(round(1-self.total_lambda, 2))
        for customer in self.prob:
            lambda_list.append(round(self.prob[customer] * self.total_lambda, 2)) 
        print("lambda_list: ", lambda_list)
        return lambda_list

# %%
'''Establish Customer class'''
class Customer:

    ''' Initialization '''
    def __init__(self, total_demand, total_lambda):
        self.customer_type = {0: 'f', 1: 'Bus1', 2:'Bus2', 3:'Leis1', 4: 'Leis2', 5: 'Leis3'}
        self.num_customer_type = len(self.customer_type)
        self.customer_preference = {
            'f':{'Y': False, 'M': False, 'K': False},
            'Bus1': {'Y': True, 'M': False, 'K': False},
            'Bus2': {'Y': True, 'M': True, 'K': False},
            'Leis1': {'Y': False, 'M': True, 'K': False},
            'Leis2': {'Y': False, 'M': True, 'K': True},
            'Leis3': {'Y': False, 'M': False, 'K': True},
        }

        # inherent from uniform distribution class
        self.uniform_distribution = uniform_distribution(total_demand, total_lambda)
        self.arrival_rates = self.uniform_distribution.calculate_lambda() # calculate arrival rates for each customer type

        # inherent from aircraft class
        self.aircraft = aircraft()
        self.seat_price = self.aircraft.seat_price

    '''Customer generation'''
    def generate_customer(self):
        random_number = np.random.rand() # generate random number
        probabilities = self.arrival_rates # arrival rates list
        cumulative_probability = 0 # Use cumulative probability decide customer type
        customer_index = 0
        for probability in probabilities:
            cumulative_probability += probability
            if random_number <= cumulative_probability:
                break
            customer_index += 1
        customer_type = self.customer_type[customer_index] # return customer will buy what kind of seat   
        print(f"random_number: {random_number}, customer_index: {customer_index}, customer_type: {customer_type}")
        return customer_type

    '''customer's preference seat under control'''
    def preference_seat(self, customer_type, seat_open):
        preferred_seats = []  
        preferences = self.customer_preference[customer_type]  
        for seat_type, preference in preferences.items():
            if preference and seat_type in seat_open:
                preferred_seats.append(seat_type)
        # print("preference seats: ", preferred_seats)
        return preferred_seats  
    
    '''customer make decision'''
    def make_decision(self, customer_type, seat_open):
        preferred_seats = self.preference_seat(customer_type, seat_open)  
        if preferred_seats:
            cheapest_seat = min(preferred_seats, key=lambda x: self.seat_price[x])
            return cheapest_seat
        else:
            return 'f'

# %%
'''Establish env with Single Cabin mulitiple fare classes'''
class AirlineEnvironmentv2:
    
    '''Initialize env parameters'''
    def __init__(self, name):
        
        # name of env
        self.name = name
        
        # inherent aircraft
        self.aircraft = aircraft()
        self.seat_capacity = self.aircraft.seat_capacity # seat limitation
        self.seat_type = self.aircraft.seat_type # seat type
        
        # environment parameters
        self.seat_remain = self.seat_capacity # seat limitation
        self.state = (self.seat_capacity, 1) # Initialize state : (num seat sold, period)
        self.a_s_ref = {0: 'f', 1: 'Y', 2: 'M', 3: 'K', 4: 'YM', 5: 'YK', 6: 'MK', 7: 'YMK'} # action reference to seat open combination
        self.seat_combination = {
            'f': {'f': 0.0, 'Y': 0.0, 'M': 0.0, 'K': 0.0},
            'Y': {'f': 0.0, 'Y': 800, 'M': 0.0, 'K': 0.0},
            'M': {'f': 0.0, 'Y': 0.0, 'M': 500, 'K': 0.0},
            'K': {'f': 0.0, 'Y': 0.0, 'M': 0.0, 'K': 450},
            'YM': {'f': 0.0, 'Y': 800, 'M': 500, 'K': 0.0},
            'YK': {'f': 0.0, 'Y': 800, 'M': 0.0, 'K': 450},
            'MK': {'f': 0.0, 'Y': 0.0, 'M': 500, 'K': 450},
            'YMK': {'f': 0.0, 'Y': 800, 'M': 500, 'K': 450}
        } # Seat combination & seat open
        
        # inherent action space class
        self.action_space = AgentActionSpace() 
        
        # inherent attributes from demand model
        self.max_rd = 20 # total selling RDs
        self.demand_model = demandmodel()
        self.total_demand = sum(self.demand_model.formulation(self.max_rd, 1).values()) # total demand from demand model
        self.total_lambda = 0.8 # total lambda from test
        self.max_period = self.total_demand/self.total_lambda # total period
        
        # inherent attributes from uniform distribution class
        self.uniform_distribution = uniform_distribution(self.total_demand, self.total_lambda)
        self.arrival_rates = self.uniform_distribution.calculate_lambda() # calculate arrival rates for each customer type

        # inherent attributes from Customer class
        self.customer = Customer(self.total_demand, self.total_lambda) 
        
    '''reset env'''
    def reset(self):
        self.seat_remain = self.seat_capacity # Initialize total seat 
        self.state = (self.seat_remain, 1)  # Initialize state
        return self.state

    '''Step'''
    def step_v2(self, state, action):

        # total reward this RD
        total_reward = 0
        
        # Agent choose a seat combination
        seat_open = self.a_s_ref[action]   
        # print("seat_open: ", seat_open)

        # calculate reward this period
        for period in range(1, int(self.max_period/self.max_rd)):
            
            # With remaining seat
            if self.seat_remain > 0:
                
                # Customer generation
                customer_type = self.customer.generate_customer()
                # print("customer type: ", customer_type)
    
                # Customer choose seat
                chosen_seat = self.customer.make_decision(customer_type, seat_open) 
                # print("chosen seat: ", chosen_seat)
    
                # Decide immediate revenue
                reward = self.aircraft.seat_price[chosen_seat] 
    
                # Update seat remain
                if reward > 0:
                    self.seat_remain = self.seat_remain-1
            
            # Without remaining seat
            else:
                # print("No remaining seat.")
                reward = 0

            # add reward to total reward this period
            # print("reward: ", reward)
            total_reward += reward
            # print("total reward: ", total_reward)
    
        # Update rd
        next_rd = state[0, 1].item() + 1
            
        # Check departure or not 
        departure = (next_rd >= self.max_rd+1)
    
        # update state
        state[0, 0] = self.seat_remain
        state[0, 1] = next_rd            
        # print(f"state[0, 0]: {state[0, 0]}, state[0, 1]: {state[0, 1]}")    
        return state.cpu().detach().numpy(), total_reward, departure

# %%
# if GPU is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Define tuple structure, use tuple structure to store info
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))

''' Establish Memory Replay Buffer '''
class ReplayMemory(object):

    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)

    def push(self, *args):
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
''' 建構 DQN '''
class DQN(nn.Module):

    def __init__(self, n_observations, n_actions):
        super(DQN, self).__init__()
        self.layer1 = nn.Linear(n_observations, 128)
        self.layer2 = nn.Linear(128, 128)
        self.layer3 = nn.Linear(128, n_actions)

    # Called with either one element to determine next action, or a batch
    # during optimization. Returns tensor([[left0exp,right0exp]...]).
    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        return self.layer3(x)

# %%
'''Establish environment from Airline env'''
env = AirlineEnvironmentv2("Single route parallel flight.v0")

''' Reinforcement Learning Hyparameter '''
BATCH_SIZE = 128  # Batch size from experience replay buffer
GAMMA = 0.99  # Reward discount rate Gamma
EPS_START = 0.9  # Epilson-Greedy strategy's hyparameter eplison
EPS_END = 0.05 # Final value of eplison 
EPS_DECAY = 1000 # Control eplison decay，higher represent slower decay
TAU = 0.005 # Update rate of target network
LR = 1e-4 # Learning rate of optimizer

''' Simulated Environment Parameter '''
n_actions = env.action_space.n # num action
state = env.reset() # initialize env
n_observations = len(state) # num state

''' Establish Policy Network, Target Network '''
policy_net = DQN(n_observations, n_actions).to(device) # Policy Network
target_net = DQN(n_observations, n_actions).to(device) # Target Network
target_net.load_state_dict(policy_net.state_dict())
memory = ReplayMemory(10000) # Memory size of Replay Buffer
optimizer = optim.AdamW(policy_net.parameters(), lr=LR, amsgrad=True) # AdamW optimizer

''' Agent Select Action'''
steps_done = 0
def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        # Exploit：Select Max Value action
        with torch.no_grad():
            # t.max(1) return max expected value column
            return policy_net(state).max(1).indices.view(1, 1)
    else:
        # Explore：Randomly select action
        return torch.tensor([[env.action_space.sample()]], device=device, dtype=torch.long)
# Out:
# total demand:  154.78080374954658

# %%
''' Optimize Network '''
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    batch = Transition(*zip(*transitions)) # Converts batch-array of Transitions to Transition of batch-arrays.

    # Compute a mask of non-final states and concatenate the batch elements
    # (a final state would've been the one after which simulation ended)
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
    # columns of actions taken. These are the actions which would've been taken
    # for each batch state according to policy_net
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Compute V(s_{t+1}) for all next states.
    # Expected values of actions for non_final_next_states are computed based
    # on the "older" target_net; selecting their best reward with max(1).values
    # This is merged based on the mask, such that we'll have either the expected
    # state value or 0 in case the state was final.
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    with torch.no_grad():
        next_state_values[non_final_mask] = target_net(non_final_next_states).max(1).values
    # Compute the expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Compute Huber loss
    criterion = nn.SmoothL1Loss()
    loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    
    # In-place gradient clipping
    torch.nn.utils.clip_grad_value_(policy_net.parameters(), 100)
    optimizer.step()

# %%
# Initialize Training parameters
num_episodes = 3000
DQN_total_revenues = []
DQN_cumulative_average = []
DQN_per_50_avg = []

# Start Training
for episode in range(num_episodes):
    
    # Initialize environment
    print("---------- Episode ", episode, "-----------")
    state = env.reset()
    state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
    total_revenue = 0 # Initialize total revenue
    
    for step in count():
        
        # print("------- step " ,step + 1 ," ---------")
        
        # agent 選擇動作
        action = select_action(state)
        # print("action: ", action)

        observation, reward, departure = env.step_v2(state, action.item())
        # print("observation: ", observation, "reward: ",  reward, "departure: ", departure)
        reward = torch.tensor([reward], device=device)
        done = departure

        if departure:
            break
        else:
            observation = observation.flatten()
            next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)

        # Update total revenue
        total_revenue += reward

        # Store the transition in memory
        memory.push(state, action, next_state, reward)

        # Move on to the next state
        state = next_state

        # Perform one step of the optimization (on the policy network)
        optimize_model()

        # Soft update of the target network's weights
        # θ′ ← τ θ + (1 −τ )θ′
        target_net_state_dict = target_net.state_dict()
        policy_net_state_dict = policy_net.state_dict()
        for key in policy_net_state_dict:
            target_net_state_dict[key] = policy_net_state_dict[key]*TAU + target_net_state_dict[key]*(1-TAU)
        target_net.load_state_dict(target_net_state_dict)
    
    # 將每個 episode 的 total reward 加入列表中  
    DQN_total_revenues.append(total_revenue.cpu().numpy()) 
    
    # 計算每50個 episode 的平均總獎勵
    if episode % 50 == 0 and episode != 0:
        DQN_per_50_avg.append(np.mean(DQN_total_revenues[-50:]))
    
    # 累積平均獎勵
    DQN_cumulative_avg = sum(DQN_total_revenues) / (episode + 1)
    DQN_cumulative_average.append(DQN_cumulative_avg)
    print(f"Episode: {episode}, Total Revenue: {total_revenue}, Cumulative average: {DQN_cumulative_avg}")
# Out:
# ---------- Episode  0 -----------
# random_number: 0.8238954069314383, customer_index: 5, customer_type: Leis3
# random_number: 0.8196351087954457, customer_index: 5, customer_type: Leis3
# random_number: 0.7657942122987607, customer_index: 5, customer_type: Leis3
# random_number: 0.16050645580785639, customer_index: 0, customer_type: f
# random_number: 0.8209688373361232, customer_index: 5, customer_type: Leis3
# random_number: 0.42784320716937574, customer_index: 2, customer_type: Bus2
# random_number: 0.029654768811477772, customer_index: 0, customer_type: f
# random_number: 0.7233882082538822, customer_index: 4, customer_type: Leis2
# random_number: 0.4546889620828959, customer_index: 3, customer_type: Leis1
# random_number: 0.626216824783058, customer_index: 4, customer_type: Leis2
# random_number: 0.23486875583386835, customer_index: 1, customer_type: Bus1
# random_number: 0.7931103270374509, customer_index: 5, customer_type: Leis3
# random_number: 0.6256654840893386, customer_index: 4, customer_type: Leis2
# random_number: 0.8156626555074967, customer_index: 5, customer_type: Leis3
# random_number: 0.8496714980546433, customer_index: 5, customer_type: Leis3
# random_number: 0.26066696546689017, customer_index: 1, customer_type: Bus1
# random_number: 0.5846644066147506, customer_index: 3, customer_type: Leis1
# random_number: 0.7244120278440203, customer_index: 4, customer_type: Leis2
# random_number: 0.5429489491148881, customer_index: 3, customer_type: Leis1
# random_number: 0.9345644947311573, customer_index: 5, customer_type: Leis3
# random_number: 0.133331706928267, customer_index: 0, customer_type: f
# random_number: 0.7773512897496775, customer_index: 5, customer_type: Leis3
# random_number: 0.4115482187068913, customer_index: 2, customer_type: Bus2
# random_number: 0.33281020155331187, customer_index: 2, customer_type: Bus2
# random_number: 0.74303830119165, customer_index: 4, customer_type: Leis2
# random_number: 0.9137728290110039, customer_index: 5, customer_type: Leis3
# random_number: 0.07062583484697393, customer_index: 0, customer_type: f
# random_number: 0.14111046255188797, customer_index: 0, customer_type: f
# random_number: 0.7613767877928956, customer_index: 5, customer_type: Leis3
# random_number: 0.9875545576514889, customer_index: 5, customer_type: Leis3
# random_number: 0.7817083009058706, customer_index: 5, customer_type: Leis3
# random_number: 0.36192184068923006, customer_index: 2, customer_type: Bus2
# random_number: 0.06518419721400837, customer_index: 0, customer_type: f
# random_number: 0.7726374127354438, customer_index: 5, customer_type: Leis3
# random_number: 0.35146474291714747, customer_index: 2, customer_type: Bus2
# random_number: 0.6883351230445642, customer_index: 4, customer_type: Leis2
# random_number: 0.060079893479991986, customer_index: 0, customer_type: f
# random_number: 0.15431736629713988, customer_index: 0, customer_type: f
# random_number: 0.12427466981147606, customer_index: 0, customer_type: f
# random_number: 0.10391452418274649, customer_index: 0, customer_type: f
# random_number: 0.5171386283332136, customer_index: 3, customer_type: Leis1
# random_number: 0.5797506149991258, customer_index: 3, customer_type: Leis1
# random_number: 0.11396247077777599, customer_index: 0, customer_type: f
# random_number: 0.338392568215649, customer_index: 2, customer_type: Bus2
# random_number: 0.8067033970321564, customer_index: 5, customer_type: Leis3
# random_number: 0.7470029583058385, customer_index: 4, customer_type: Leis2
# random_number: 0.004845039452983757, customer_index: 0, customer_type: f
# random_number: 0.8333116537000949, customer_index: 5, customer_type: Leis3
# random_number: 0.06587762573643574, customer_index: 0, customer_type: f
# random_number: 0.40444460152641093, customer_index: 2, customer_type: Bus2
# random_number: 0.6658160787882625, customer_index: 4, customer_type: Leis2
# random_number: 0.14201846135778373, customer_index: 0, customer_type: f
# random_number: 0.28183957863837683, customer_index: 2, customer_type: Bus2
# random_number: 0.6976923175164782, customer_index: 4, customer_type: Leis2
# random_number: 0.16286944463938358, customer_index: 0, customer_type: f
# random_number: 0.11417962428923467, customer_index: 0, customer_type: f
# random_number: 0.6671771730630243, customer_index: 4, customer_type: Leis2
# random_number: 0.4512708962671569, customer_index: 3, customer_type: Leis1
# random_number: 0.9248358773667126, customer_index: 5, customer_type: Leis3
# random_number: 0.11925490421845852, customer_index: 0, customer_type: f
# random_number: 0.1564389510408415, customer_index: 0, customer_type: f
# random_number: 0.2890644914358502, customer_index: 2, customer_type: Bus2
# random_number: 0.9999078688987639, customer_index: 5, customer_type: Leis3
# random_number: 0.19729751167828435, customer_index: 0, customer_type: f
# random_number: 0.1776189276177932, customer_index: 0, customer_type: f
# random_number: 0.3303851280601573, customer_index: 2, customer_type: Bus2
# random_number: 0.8379422960080479, customer_index: 5, customer_type: Leis3
# random_number: 0.8349172489837248, customer_index: 5, customer_type: Leis3
# random_number: 0.9086666977048574, customer_index: 5, customer_type: Leis3
# random_number: 0.7028474025791619, customer_index: 4, customer_type: Leis2
# random_number: 0.2476535454398039, customer_index: 1, customer_type: Bus1
# random_number: 0.9753702682465663, customer_index: 5, customer_type: Leis3
# random_number: 0.33923607347792584, customer_index: 2, customer_type: Bus2
# random_number: 0.4907146773483062, customer_index: 3, customer_type: Leis1
# random_number: 0.2788512352192275, customer_index: 1, customer_type: Bus1
# random_number: 0.1722147373762768, customer_index: 0, customer_type: f
# random_number: 0.9298788610980746, customer_index: 5, customer_type: Leis3
# random_number: 0.8282489973438663, customer_index: 5, customer_type: Leis3
# random_number: 0.19726565828440035, customer_index: 0, customer_type: f
# random_number: 0.7548233933625884, customer_index: 4, customer_type: Leis2
# random_number: 0.2626627887448708, customer_index: 1, customer_type: Bus1
# random_number: 0.6648839800219324, customer_index: 4, customer_type: Leis2
# random_number: 0.30550107936152615, customer_index: 2, customer_type: Bus2
# random_number: 0.06857128373002075, customer_index: 0, customer_type: f
# random_number: 0.7431063118639727, customer_index: 4, customer_type: Leis2
# random_number: 0.7933965903491214, customer_index: 5, customer_type: Leis3
# random_number: 0.02111147099061883, customer_index: 0, customer_type: f
# random_number: 0.8092075160195347, customer_index: 5, customer_type: Leis3
# random_number: 0.19257390937469698, customer_index: 0, customer_type: f
# random_number: 0.4192200967947495, customer_index: 2, customer_type: Bus2
# random_number: 0.006895882982597246, customer_index: 0, customer_type: f
# random_number: 0.620090952647836, customer_index: 4, customer_type: Leis2
# random_number: 0.8135383377082078, customer_index: 5, customer_type: Leis3
# random_number: 0.7681280795800655, customer_index: 5, customer_type: Leis3
# random_number: 0.12522563883989346, customer_index: 0, customer_type: f
# random_number: 0.9191908231852414, customer_index: 5, customer_type: Leis3
# random_number: 0.8415726438225332, customer_index: 5, customer_type: Leis3
# random_number: 0.3510760074094722, customer_index: 2, customer_type: Bus2
# random_number: 0.7388505384201138, customer_index: 4, customer_type: Leis2
# random_number: 0.007286324629578234, customer_index: 0, customer_type: f
# random_number: 0.9239955162553531, customer_index: 5, customer_type: Leis3
# random_number: 0.18843872403169515, customer_index: 0, customer_type: f
# random_number: 0.21240554961275804, customer_index: 1, customer_type: Bus1
# random_number: 0.2969597111365522, customer_index: 2, customer_type: Bus2
# random_number: 0.3476175167773361, customer_index: 2, customer_type: Bus2
# random_number: 0.31020133524580806, customer_index: 2, customer_type: Bus2
# random_number: 0.5937858810296798, customer_index: 3, customer_type: Leis1
# random_number: 0.1542733460031025, customer_index: 0, customer_type: f
# random_number: 0.21714701740231113, customer_index: 1, customer_type: Bus1
# random_number: 0.2680707735994421, customer_index: 1, customer_type: Bus1
# random_number: 0.8215952120250777, customer_index: 5, customer_type: Leis3
# random_number: 0.5285063234222561, customer_index: 3, customer_type: Leis1
# random_number: 0.7735113020495822, customer_index: 5, customer_type: Leis3
# random_number: 0.3189712770541634, customer_index: 2, customer_type: Bus2
# random_number: 0.798236575071623, customer_index: 5, customer_type: Leis3
# random_number: 0.7467889438799806, customer_index: 4, customer_type: Leis2
# random_number: 0.1656955499898629, customer_index: 0, customer_type: f
# random_number: 0.4158363157732262, customer_index: 2, customer_type: Bus2
# random_number: 0.6472107032168404, customer_index: 4, customer_type: Leis2
# random_number: 0.767101785954034, customer_index: 5, customer_type: Leis3
# random_number: 0.8123719436888847, customer_index: 5, customer_type: Leis3
# random_number: 0.60338904611081, customer_index: 4, customer_type: Leis2
# random_number: 0.4617152419176419, customer_index: 3, customer_type: Leis1
# random_number: 0.16988884023560902, customer_index: 0, customer_type: f
# random_number: 0.17345349463112247, customer_index: 0, customer_type: f
# random_number: 0.39954735332573743, customer_index: 2, customer_type: Bus2
# random_number: 0.24619151419011032, customer_index: 1, customer_type: Bus1
# random_number: 0.9424479045022488, customer_index: 5, customer_type: Leis3
# random_number: 0.1956591663836631, customer_index: 0, customer_type: f
# random_number: 0.6057750631641854, customer_index: 4, customer_type: Leis2
# random_number: 0.15710527360619952, customer_index: 0, customer_type: f
# random_number: 0.7066968759887009, customer_index: 4, customer_type: Leis2
# random_number: 0.5165431393297176, customer_index: 3, customer_type: Leis1
# random_number: 0.41334187342472906, customer_index: 2, customer_type: Bus2
# random_number: 0.12684755677989712, customer_index: 0, customer_type: f
# random_number: 0.8666499350244479, customer_index: 5, customer_type: Leis3
# random_number: 0.8391786685804499, customer_index: 5, customer_type: Leis3
# random_number: 0.2636295765609097, customer_index: 1, customer_type: Bus1
# random_number: 0.14914877533630744, customer_index: 0, customer_type: f
# random_number: 0.49455285308015784, customer_index: 3, customer_type: Leis1
# random_number: 0.7899557936731767, customer_index: 5, customer_type: Leis3
# random_number: 0.3594736412992092, customer_index: 2, customer_type: Bus2
# random_number: 0.6765237616945279, customer_index: 4, customer_type: Leis2
# random_number: 0.2719396131703954, customer_index: 1, customer_type: Bus1
# random_number: 0.364407204983204, customer_index: 2, customer_type: Bus2
# random_number: 0.7727063690256482, customer_index: 5, customer_type: Leis3
# random_number: 0.4715788163113449, customer_index: 3, customer_type: Leis1
# random_number: 0.4732127114904653, customer_index: 3, customer_type: Leis1
# random_number: 0.08166563638513702, customer_index: 0, customer_type: f
# random_number: 0.9194504203970725, customer_index: 5, customer_type: Leis3
# random_number: 0.4841088350274977, customer_index: 3, customer_type: Leis1
# random_number: 0.7406584752031757, customer_index: 4, customer_type: Leis2
# random_number: 0.419665211522641, customer_index: 2, customer_type: Bus2
# random_number: 0.4930764130755999, customer_index: 3, customer_type: Leis1
# random_number: 0.9552306343731847, customer_index: 5, customer_type: Leis3
# random_number: 0.7871369045927855, customer_index: 5, customer_type: Leis3
# random_number: 0.6131345714097662, customer_index: 4, customer_type: Leis2
# random_number: 0.008646674834390744, customer_index: 0, customer_type: f
# random_number: 0.09349335758613408, customer_index: 0, customer_type: f
# random_number: 0.2346603722615116, customer_index: 1, customer_type: Bus1
# Episode: 0, Total Revenue: tensor([37050], device='cuda:0'), Cumulative average: [37050.]
# ---------- Episode  1 -----------
# random_number: 0.4365970466025576, customer_index: 2, customer_type: Bus2
# random_number: 0.34905142667297673, customer_index: 2, customer_type: Bus2
# random_number: 0.32521968569478177, customer_index: 2, customer_type: Bus2
# random_number: 0.42682396749955964, customer_index: 2, customer_type: Bus2
# random_number: 0.04369690085346678, customer_index: 0, customer_type: f
# random_number: 0.5538679479249392, customer_index: 3, customer_type: Leis1
# random_number: 0.41250272630321916, customer_index: 2, customer_type: Bus2
# random_number: 0.9078758606881997, customer_index: 5, customer_type: Leis3
# random_number: 0.7010853501384805, customer_index: 4, customer_type: Leis2
# random_number: 0.09133892242169594, customer_index: 0, customer_type: f
# random_number: 0.9205520329875058, customer_index: 5, customer_type: Leis3
# random_number: 0.23718076404891608, customer_index: 1, customer_type: Bus1
# random_number: 0.49196056375114516, customer_index: 3, customer_type: Leis1
# random_number: 0.7222651373112934, customer_index: 4, customer_type: Leis2
# random_number: 0.27085363743317237, customer_index: 1, customer_type: Bus1
# random_number: 0.6658222403977383, customer_index: 4, customer_type: Leis2
# random_number: 0.8615488157344035, customer_index: 5, customer_type: Leis3
# random_number: 0.5930374395415193, customer_index: 3, customer_type: Leis1
# random_number: 0.05956364544282888, customer_index: 0, customer_type: f
# random_number: 0.2884462821257078, customer_index: 2, customer_type: Bus2
# random_number: 0.6727204900440236, customer_index: 4, customer_type: Leis2
# random_number: 0.12221948787086856, customer_index: 0, customer_type: f
# random_number: 0.09735997177499944, customer_index: 0, customer_type: f
# random_number: 0.4829054325515857, customer_index: 3, customer_type: Leis1
# random_number: 0.36494411342713917, customer_index: 2, customer_type: Bus2
# random_number: 0.9760483269309339, customer_index: 5, customer_type: Leis3
# random_number: 0.23266488042564248, customer_index: 1, customer_type: Bus1
# random_number: 0.5819833273659871, customer_index: 3, customer_type: Leis1
# random_number: 0.7195112747682184, customer_index: 4, customer_type: Leis2
# random_number: 0.1833506502255139, customer_index: 0, customer_type: f
# random_number: 0.26668434659322837, customer_index: 1, customer_type: Bus1
# random_number: 0.6127795950433912, customer_index: 4, customer_type: Leis2
# random_number: 0.2072976639295976, customer_index: 1, customer_type: Bus1
# random_number: 0.213539364935317, customer_index: 1, customer_type: Bus1
# random_number: 0.32259374394329887, customer_index: 2, customer_type: Bus2
# random_number: 0.4725546870398132, customer_index: 3, customer_type: Leis1
# random_number: 0.01784462419329924, customer_index: 0, customer_type: f
# random_number: 0.20473335717060404, customer_index: 1, customer_type: Bus1
# random_number: 0.9138244617759241, customer_index: 5, customer_type: Leis3
# random_number: 0.9383491261747295, customer_index: 5, customer_type: Leis3
# random_number: 0.7282163874210217, customer_index: 4, customer_type: Leis2
# random_number: 0.6871352549335706, customer_index: 4, customer_type: Leis2
# random_number: 0.33701730436036315, customer_index: 2, customer_type: Bus2
# random_number: 0.048670831953907756, customer_index: 0, customer_type: f
# random_number: 0.28724387098110926, customer_index: 2, customer_type: Bus2
# random_number: 0.6559725940806732, customer_index: 4, customer_type: Leis2
# random_number: 0.10968511060952135, customer_index: 0, customer_type: f
# random_number: 0.01929866161362437, customer_index: 0, customer_type: f
# random_number: 0.9244022729102548, customer_index: 5, customer_type: Leis3
# random_number: 0.4622738284998954, customer_index: 3, customer_type: Leis1
# random_number: 0.06922587994396612, customer_index: 0, customer_type: f
# random_number: 0.404879324483569, customer_index: 2, customer_type: Bus2
# random_number: 0.7461708227717383, customer_index: 4, customer_type: Leis2
# random_number: 0.6776948446680437, customer_index: 4, customer_type: Leis2
# random_number: 0.2801144122510305, customer_index: 2, customer_type: Bus2
# random_number: 0.4245011708858083, customer_index: 2, customer_type: Bus2
# random_number: 0.5809799755354736, customer_index: 3, customer_type: Leis1
# random_number: 0.14124174678533463, customer_index: 0, customer_type: f
# random_number: 0.06552858923445115, customer_index: 0, customer_type: f
# random_number: 0.21618811283109363, customer_index: 1, customer_type: Bus1
# random_number: 0.40193110441329205, customer_index: 2, customer_type: Bus2
# random_number: 0.7502444708078675, customer_index: 4, customer_type: Leis2
# random_number: 0.7584012892680589, customer_index: 4, customer_type: Leis2
# random_number: 0.31051004242070634, customer_index: 2, customer_type: Bus2
# random_number: 0.34932170726892886, customer_index: 2, customer_type: Bus2
# random_number: 0.4509216588034054, customer_index: 3, customer_type: Leis1
# random_number: 0.28577163706902653, customer_index: 2, customer_type: Bus2
# random_number: 0.8541916690943437, customer_index: 5, customer_type: Leis3
# random_number: 0.6688747668138406, customer_index: 4, customer_type: Leis2
# random_number: 0.27493548402690116, customer_index: 1, customer_type: Bus1
# random_number: 0.1260379403360543, customer_index: 0, customer_type: f
# random_number: 0.0339158434978466, customer_index: 0, customer_type: f
# random_number: 0.4272104416036885, customer_index: 2, customer_type: Bus2
# random_number: 0.46795270869962524, customer_index: 3, customer_type: Leis1
# random_number: 0.3904282445303562, customer_index: 2, customer_type: Bus2
# random_number: 0.0818312466804143, customer_index: 0, customer_type: f
# random_number: 0.04303537431219795, customer_index: 0, customer_type: f
# random_number: 0.35017479286845277, customer_index: 2, customer_type: Bus2
# random_number: 0.4173339572339554, customer_index: 2, customer_type: Bus2
# random_number: 0.25180114830342215, customer_index: 1, customer_type: Bus1
# random_number: 0.6768504465383324, customer_index: 4, customer_type: Leis2
# random_number: 0.2907825774088988, customer_index: 2, customer_type: Bus2
# random_number: 0.052283955771416424, customer_index: 0, customer_type: f
# random_number: 0.74083997668661, customer_index: 4, customer_type: Leis2
# random_number: 0.3792827944368341, customer_index: 2, customer_type: Bus2
# random_number: 0.12086365905009089, customer_index: 0, customer_type: f
# random_number: 0.7614550301613421, customer_index: 5, customer_type: Leis3
# random_number: 0.7110049820539319, customer_index: 4, customer_type: Leis2
# random_number: 0.21254912690821726, customer_index: 1, customer_type: Bus1
# random_number: 0.1689957088220354, customer_index: 0, customer_type: f
# random_number: 0.7516067993599554, customer_index: 4, customer_type: Leis2
# random_number: 0.5070862198331757, customer_index: 3, customer_type: Leis1
# random_number: 0.20841658242679784, customer_index: 1, customer_type: Bus1
# random_number: 0.7134586611689333, customer_index: 4, customer_type: Leis2
# random_number: 0.24770813722593932, customer_index: 1, customer_type: Bus1
# random_number: 0.6374254904456093, customer_index: 4, customer_type: Leis2
# random_number: 0.9862284573618434, customer_index: 5, customer_type: Leis3
# random_number: 0.31326704075427636, customer_index: 2, customer_type: Bus2
# random_number: 0.21203550710496255, customer_index: 1, customer_type: Bus1
# random_number: 0.8202269494940303, customer_index: 5, customer_type: Leis3
# random_number: 0.6921524137466721, customer_index: 4, customer_type: Leis2
# random_number: 0.6170958708535588, customer_index: 4, customer_type: Leis2
# random_number: 0.5863161727037287, customer_index: 3, customer_type: Leis1
# random_number: 0.3178492182806445, customer_index: 2, customer_type: Bus2
# random_number: 0.10663460798570035, customer_index: 0, customer_type: f
# random_number: 0.2774659971968173, customer_index: 1, customer_type: Bus1
# random_number: 0.8519232271940811, customer_index: 5, customer_type: Leis3
# random_number: 0.24035278730594833, customer_index: 1, customer_type: Bus1
# random_number: 0.8458679758043528, customer_index: 5, customer_type: Leis3
# random_number: 0.6051612735145563, customer_index: 4, customer_type: Leis2
# random_number: 0.03498867484821333, customer_index: 0, customer_type: f
# random_number: 0.13746604968049203, customer_index: 0, customer_type: f
# random_number: 0.5453849823414021, customer_index: 3, customer_type: Leis1
# random_number: 0.3997237930628944, customer_index: 2, customer_type: Bus2
# random_number: 0.1395668036958152, customer_index: 0, customer_type: f
# random_number: 0.5609528766582548, customer_index: 3, customer_type: Leis1
# random_number: 0.9685821191050439, customer_index: 5, customer_type: Leis3
# random_number: 0.8116257430373953, customer_index: 5, customer_type: Leis3
# random_number: 0.7586207323538299, customer_index: 4, customer_type: Leis2
# random_number: 0.54298224850723, customer_index: 3, customer_type: Leis1
# random_number: 0.9854102620311758, customer_index: 5, customer_type: Leis3
# random_number: 0.7287103946771573, customer_index: 4, customer_type: Leis2
# random_number: 0.4236794115073499, customer_index: 2, customer_type: Bus2
# random_number: 0.4420334059578005, customer_index: 3, customer_type: Leis1
# random_number: 0.7843516818103738, customer_index: 5, customer_type: Leis3
# random_number: 0.393251638309581, customer_index: 2, customer_type: Bus2
# random_number: 0.7343719213068624, customer_index: 4, customer_type: Leis2
# random_number: 0.22622320794069362, customer_index: 1, customer_type: Bus1
# random_number: 0.33802602369466683, customer_index: 2, customer_type: Bus2
# random_number: 0.8891751563918913, customer_index: 5, customer_type: Leis3
# random_number: 0.6228202055710674, customer_index: 4, customer_type: Leis2
# random_number: 0.04583458540982399, customer_index: 0, customer_type: f
# random_number: 0.2796652810603115, customer_index: 1, customer_type: Bus1
# random_number: 0.7231384250678032, customer_index: 4, customer_type: Leis2
# random_number: 0.2202582723560872, customer_index: 1, customer_type: Bus1
# random_number: 0.6387955874386924, customer_index: 4, customer_type: Leis2
# random_number: 0.2538715010521715, customer_index: 1, customer_type: Bus1
# random_number: 0.9925194869294296, customer_index: 5, customer_type: Leis3
# random_number: 0.8933744163115845, customer_index: 5, customer_type: Leis3
# random_number: 0.7671985622661499, customer_index: 5, customer_type: Leis3
# random_number: 0.47220886575499277, customer_index: 3, customer_type: Leis1
# random_number: 0.6682793256891905, customer_index: 4, customer_type: Leis2
# random_number: 0.8018427954973161, customer_index: 5, customer_type: Leis3
# random_number: 0.6295374151946682, customer_index: 4, customer_type: Leis2
# random_number: 0.2902703761863339, customer_index: 2, customer_type: Bus2
# random_number: 0.9251045943337479, customer_index: 5, customer_type: Leis3
# random_number: 0.7454421854128459, customer_index: 4, customer_type: Leis2
# random_number: 0.9953513363237144, customer_index: 5, customer_type: Leis3
# random_number: 0.2587857070723588, customer_index: 1, customer_type: Bus1
# random_number: 0.20143180547969575, customer_index: 1, customer_type: Bus1
# random_number: 0.11908706521659473, customer_index: 0, customer_type: f
# random_number: 0.6673324160011112, customer_index: 4, customer_type: Leis2
# random_number: 0.22640223993213715, customer_index: 1, customer_type: Bus1
# random_number: 0.7113179384425472, customer_index: 4, customer_type: Leis2
# random_number: 0.09420154540070269, customer_index: 0, customer_type: f
# random_number: 0.9458860417063254, customer_index: 5, customer_type: Leis3
# random_number: 0.28766338052088924, customer_index: 2, customer_type: Bus2
# random_number: 0.04863301308917156, customer_index: 0, customer_type: f
# random_number: 0.12421002091047417, customer_index: 0, customer_type: f
# random_number: 0.9445492074346218, customer_index: 5, customer_type: Leis3
# Episode: 1, Total Revenue: tensor([29000], device='cuda:0'), Cumulative average: [33025.]
# ---------- Episode  2 -----------
# random_number: 0.7249936834155197, customer_index: 4, customer_type: Leis2
# random_number: 0.4486604729802742, customer_index: 3, customer_type: Leis1
# random_number: 0.5106769918329969, customer_index: 3, customer_type: Leis1
# random_number: 0.47174921697136907, customer_index: 3, customer_type: Leis1
# random_number: 0.3688997225003958, customer_index: 2, customer_type: Bus2
# random_number: 0.48179758152558994, customer_index: 3, customer_type: Leis1
# random_number: 0.40180862204657786, customer_index: 2, customer_type: Bus2
# random_number: 0.22950879926934586, customer_index: 1, customer_type: Bus1
# random_number: 0.6315518901276299, customer_index: 4, customer_type: Leis2
# random_number: 0.8459268407181213, customer_index: 5, customer_type: Leis3
# random_number: 0.5287189170202549, customer_index: 3, customer_type: Leis1
# random_number: 0.3350418783044631, customer_index: 2, customer_type: Bus2
# random_number: 0.23528070190413386, customer_index: 1, customer_type: Bus1
# random_number: 0.05139081654697242, customer_index: 0, customer_type: f
# random_number: 0.31365942505432387, customer_index: 2, customer_type: Bus2
# random_number: 0.024604631080934025, customer_index: 0, customer_type: f
# random_number: 0.2755896661343058, customer_index: 1, customer_type: Bus1
# random_number: 0.8951252190368163, customer_index: 5, customer_type: Leis3
# random_number: 0.29565995207702134, customer_index: 2, customer_type: Bus2
# random_number: 0.5629571023755149, customer_index: 3, customer_type: Leis1
# random_number: 0.5639746390814837, customer_index: 3, customer_type: Leis1
# random_number: 0.6520614457425746, customer_index: 4, customer_type: Leis2
# random_number: 0.13294673565796888, customer_index: 0, customer_type: f
# random_number: 0.13185261979155638, customer_index: 0, customer_type: f
# random_number: 0.5214766773029509, customer_index: 3, customer_type: Leis1
# random_number: 0.2598568419456393, customer_index: 1, customer_type: Bus1
# random_number: 0.5244568753638413, customer_index: 3, customer_type: Leis1
# random_number: 0.6688012703215855, customer_index: 4, customer_type: Leis2
# random_number: 0.7546017909467998, customer_index: 4, customer_type: Leis2
# random_number: 0.9912288512057993, customer_index: 5, customer_type: Leis3
# random_number: 0.6470847466414031, customer_index: 4, customer_type: Leis2
# random_number: 0.9825140873042092, customer_index: 5, customer_type: Leis3
# random_number: 0.749499721788952, customer_index: 4, customer_type: Leis2
# random_number: 0.03182539235699455, customer_index: 0, customer_type: f
# random_number: 0.542131755498402, customer_index: 3, customer_type: Leis1
# random_number: 0.5907967454042795, customer_index: 3, customer_type: Leis1
# random_number: 0.5420109875575863, customer_index: 3, customer_type: Leis1
# random_number: 0.5521110583747513, customer_index: 3, customer_type: Leis1
# random_number: 0.3404017921798441, customer_index: 2, customer_type: Bus2
# random_number: 0.1478852057454042, customer_index: 0, customer_type: f
# random_number: 0.06301236465701843, customer_index: 0, customer_type: f
# random_number: 0.35746812025809205, customer_index: 2, customer_type: Bus2
# random_number: 0.05035135545606284, customer_index: 0, customer_type: f
# random_number: 0.9062504540476264, customer_index: 5, customer_type: Leis3
# random_number: 0.1651113018343322, customer_index: 0, customer_type: f
# random_number: 0.11648488170042626, customer_index: 0, customer_type: f
# random_number: 0.7279214594742704, customer_index: 4, customer_type: Leis2
# random_number: 0.6050947739342436, customer_index: 4, customer_type: Leis2
# random_number: 0.7195432715325139, customer_index: 4, customer_type: Leis2
# random_number: 0.5589183480655554, customer_index: 3, customer_type: Leis1
# random_number: 0.8843005168401464, customer_index: 5, customer_type: Leis3
# random_number: 0.9422103870546034, customer_index: 5, customer_type: Leis3
# random_number: 0.26341892822920876, customer_index: 1, customer_type: Bus1
# random_number: 0.725808586415533, customer_index: 4, customer_type: Leis2
# random_number: 0.5041139118750103, customer_index: 3, customer_type: Leis1
# random_number: 0.9816069255941671, customer_index: 5, customer_type: Leis3
# random_number: 0.4866761741788904, customer_index: 3, customer_type: Leis1
# random_number: 0.8397368523605512, customer_index: 5, customer_type: Leis3
# random_number: 0.003525987458501856, customer_index: 0, customer_type: f
# random_number: 0.5975392457944717, customer_index: 3, customer_type: Leis1
# random_number: 0.4704700471163167, customer_index: 3, customer_type: Leis1
# random_number: 0.09106164850143261, customer_index: 0, customer_type: f
# random_number: 0.32436498658656765, customer_index: 2, customer_type: Bus2
# random_number: 0.0076051854592215085, customer_index: 0, customer_type: f
# random_number: 0.33731044212036565, customer_index: 2, customer_type: Bus2
# random_number: 0.44815659758950044, customer_index: 3, customer_type: Leis1
# random_number: 0.41022324123407927, customer_index: 2, customer_type: Bus2
# random_number: 0.3483527417633212, customer_index: 2, customer_type: Bus2
# random_number: 0.5095181117511335, customer_index: 3, customer_type: Leis1
# random_number: 0.10619208836699645, customer_index: 0, customer_type: f
# random_number: 0.8503003383738641, customer_index: 5, customer_type: Leis3
# random_number: 0.8867312924522157, customer_index: 5, customer_type: Leis3
# random_number: 0.7109792304096308, customer_index: 4, customer_type: Leis2
# random_number: 0.3472414230364693, customer_index: 2, customer_type: Bus2
# random_number: 0.22225470893207266, customer_index: 1, customer_type: Bus1
# random_number: 0.6115376115905012, customer_index: 4, customer_type: Leis2
# random_number: 0.38180699502510407, customer_index: 2, customer_type: Bus2
# random_number: 0.6416426914617814, customer_index: 4, customer_type: Leis2
# random_number: 0.07835480000836426, customer_index: 0, customer_type: f
# random_number: 0.15835941642052143, customer_index: 0, customer_type: f
# random_number: 0.726301869808106, customer_index: 4, customer_type: Leis2
# random_number: 0.45523880615471257, customer_index: 3, customer_type: Leis1
# random_number: 0.9528086516613414, customer_index: 5, customer_type: Leis3
# random_number: 0.3546203874340639, customer_index: 2, customer_type: Bus2
# random_number: 0.4041515528720645, customer_index: 2, customer_type: Bus2
# random_number: 0.7162389784853403, customer_index: 4, customer_type: Leis2
# random_number: 0.47158333511084916, customer_index: 3, customer_type: Leis1
# random_number: 0.5593588860488321, customer_index: 3, customer_type: Leis1
# random_number: 0.8613362844670145, customer_index: 5, customer_type: Leis3
# random_number: 0.9239907118703757, customer_index: 5, customer_type: Leis3
# random_number: 0.36839290702263694, customer_index: 2, customer_type: Bus2
# random_number: 0.7735896247331369, customer_index: 5, customer_type: Leis3
# random_number: 0.5544284030585213, customer_index: 3, customer_type: Leis1
# random_number: 0.39059470464084967, customer_index: 2, customer_type: Bus2
# random_number: 0.050069028890949774, customer_index: 0, customer_type: f
# random_number: 0.08428273258621388, customer_index: 0, customer_type: f
# random_number: 0.25691010188875096, customer_index: 1, customer_type: Bus1
# random_number: 0.3460629723817681, customer_index: 2, customer_type: Bus2
# random_number: 0.9584727495483029, customer_index: 5, customer_type: Leis3
# random_number: 0.7991780054597897, customer_index: 5, customer_type: Leis3
# random_number: 0.5808162761032354, customer_index: 3, customer_type: Leis1
# random_number: 0.7065901900438957, customer_index: 4, customer_type: Leis2
# random_number: 0.10501322845819305, customer_index: 0, customer_type: f
# random_number: 0.9680031043342341, customer_index: 5, customer_type: Leis3
# random_number: 0.4618456103954143, customer_index: 3, customer_type: Leis1
# random_number: 0.11975885245894369, customer_index: 0, customer_type: f
# random_number: 0.2533808815394576, customer_index: 1, customer_type: Bus1
# random_number: 0.09373207881471846, customer_index: 0, customer_type: f
# random_number: 0.6347623652065041, customer_index: 4, customer_type: Leis2
# random_number: 0.4360276412421997, customer_index: 2, customer_type: Bus2
# random_number: 0.04954323278078976, customer_index: 0, customer_type: f
# random_number: 0.009663244508803182, customer_index: 0, customer_type: f
# random_number: 0.11882388531439614, customer_index: 0, customer_type: f
# random_number: 0.05879813217590679, customer_index: 0, customer_type: f
# random_number: 0.27584422708402456, customer_index: 1, customer_type: Bus1
# random_number: 0.2513419321781314, customer_index: 1, customer_type: Bus1
# random_number: 0.07313996903492404, customer_index: 0, customer_type: f
# random_number: 0.5867509443962058, customer_index: 3, customer_type: Leis1
# random_number: 0.10818934609377684, customer_index: 0, customer_type: f
# random_number: 0.3565610594860851, customer_index: 2, customer_type: Bus2
# random_number: 0.22342921981937147, customer_index: 1, customer_type: Bus1
# random_number: 0.05218859351503857, customer_index: 0, customer_type: f
# random_number: 0.15999399233145983, customer_index: 0, customer_type: f
# random_number: 0.1504533510167434, customer_index: 0, customer_type: f
# random_number: 0.6170226669576498, customer_index: 4, customer_type: Leis2
# random_number: 0.3183219114372968, customer_index: 2, customer_type: Bus2
# random_number: 0.4967725542673951, customer_index: 3, customer_type: Leis1
# random_number: 0.04285697518339182, customer_index: 0, customer_type: f
# random_number: 0.3242839329205024, customer_index: 2, customer_type: Bus2
# random_number: 0.908098065665069, customer_index: 5, customer_type: Leis3
# random_number: 0.2631126808089732, customer_index: 1, customer_type: Bus1
# random_number: 0.9139266458270027, customer_index: 5, customer_type: Leis3
# random_number: 0.3625882965864258, customer_index: 2, customer_type: Bus2
# random_number: 0.1851493729776329, customer_index: 0, customer_type: f
# random_number: 0.6087048117261683, customer_index: 4, customer_type: Leis2
# random_number: 0.5565498660817225, customer_index: 3, customer_type: Leis1
# random_number: 0.8304285563084186, customer_index: 5, customer_type: Leis3
# random_number: 0.9290416044926939, customer_index: 5, customer_type: Leis3
# random_number: 0.7550780270238219, customer_index: 4, customer_type: Leis2
# random_number: 0.07222159219376001, customer_index: 0, customer_type: f
# random_number: 0.1769496261647885, customer_index: 0, customer_type: f
# random_number: 0.48411798998095057, customer_index: 3, customer_type: Leis1
# random_number: 0.7383790214427493, customer_index: 4, customer_type: Leis2
# random_number: 0.14065270388979367, customer_index: 0, customer_type: f
# random_number: 0.7971197743367247, customer_index: 5, customer_type: Leis3
# random_number: 0.5446306129527122, customer_index: 3, customer_type: Leis1
# random_number: 0.37868647521171295, customer_index: 2, customer_type: Bus2
# random_number: 0.865164816655413, customer_index: 5, customer_type: Leis3
# random_number: 0.21197061439607712, customer_index: 1, customer_type: Bus1
# random_number: 0.7315375260118894, customer_index: 4, customer_type: Leis2
# random_number: 0.6791013305659287, customer_index: 4, customer_type: Leis2
# random_number: 0.4682162308237666, customer_index: 3, customer_type: Leis1
# random_number: 0.4214697256134192, customer_index: 2, customer_type: Bus2
# random_number: 0.5947314910602163, customer_index: 3, customer_type: Leis1
# random_number: 0.8652044495402202, customer_index: 5, customer_type: Leis3
# random_number: 0.9418710201579583, customer_index: 5, customer_type: Leis3
# random_number: 0.45597115265032595, customer_index: 3, customer_type: Leis1
# random_number: 0.5269775408760395, customer_index: 3, customer_type: Leis1
# random_number: 0.5085848870066517, customer_index: 3, customer_type: Leis1
# random_number: 0.7678276753658344, customer_index: 5, customer_type: Leis3
# Episode: 2, Total Revenue: tensor([24400], device='cuda:0'), Cumulative average: [30150.]
# ---------- Episode  3 -----------
# random_number: 0.4796540516271064, customer_index: 3, customer_type: Leis1
# random_number: 0.4629034810918199, customer_index: 3, customer_type: Leis1
# random_number: 0.4299058916220574, customer_index: 2, customer_type: Bus2
# random_number: 0.8719909128574265, customer_index: 5, customer_type: Leis3
# random_number: 0.9531676030531425, customer_index: 5, customer_type: Leis3
# random_number: 0.8343886143636574, customer_index: 5, customer_type: Leis3
# random_number: 0.9322027194456803, customer_index: 5, customer_type: Leis3
# random_number: 0.4971156030459488, customer_index: 3, customer_type: Leis1
# random_number: 0.27665502737495884, customer_index: 1, customer_type: Bus1
# random_number: 0.4099321428752535, customer_index: 2, customer_type: Bus2
# random_number: 0.20477551718537845, customer_index: 1, customer_type: Bus1
# random_number: 0.7170337003591888, customer_index: 4, customer_type: Leis2
# random_number: 0.9724410884724835, customer_index: 5, customer_type: Leis3
# random_number: 0.8658812206829484, customer_index: 5, customer_type: Leis3
# random_number: 0.8765687383623498, customer_index: 5, customer_type: Leis3
# random_number: 0.6513824357363175, customer_index: 4, customer_type: Leis2
# random_number: 0.6940896083279285, customer_index: 4, customer_type: Leis2
# random_number: 0.5900951337531433, customer_index: 3, customer_type: Leis1
# random_number: 0.038642845011441995, customer_index: 0, customer_type: f
# random_number: 0.7429225195281438, customer_index: 4, customer_type: Leis2
# random_number: 0.7339308299153205, customer_index: 4, customer_type: Leis2
# random_number: 0.6331944329896868, customer_index: 4, customer_type: Leis2
# random_number: 0.03016290947607103, customer_index: 0, customer_type: f
# random_number: 0.3602335653951595, customer_index: 2, customer_type: Bus2
# random_number: 0.5137089096386798, customer_index: 3, customer_type: Leis1
# random_number: 0.9475887226732699, customer_index: 5, customer_type: Leis3
# random_number: 0.57354811829031, customer_index: 3, customer_type: Leis1
# random_number: 0.16563769450566035, customer_index: 0, customer_type: f
# random_number: 0.415349816064991, customer_index: 2, customer_type: Bus2
# random_number: 0.40075740905855917, customer_index: 2, customer_type: Bus2
# random_number: 0.13826377145796398, customer_index: 0, customer_type: f
# random_number: 0.12333137596051247, customer_index: 0, customer_type: f
# random_number: 0.20438318737030792, customer_index: 1, customer_type: Bus1
# random_number: 0.07050841920151596, customer_index: 0, customer_type: f
# random_number: 0.34005070655155056, customer_index: 2, customer_type: Bus2
# random_number: 0.6425957198518527, customer_index: 4, customer_type: Leis2
# random_number: 0.0029521876790989943, customer_index: 0, customer_type: f
# random_number: 0.20920315713328752, customer_index: 1, customer_type: Bus1
# random_number: 0.20817930945172902, customer_index: 1, customer_type: Bus1
# random_number: 0.36307513920847245, customer_index: 2, customer_type: Bus2
# random_number: 0.3236843106723689, customer_index: 2, customer_type: Bus2
# random_number: 0.4934139408579057, customer_index: 3, customer_type: Leis1
# random_number: 0.05628026403614805, customer_index: 0, customer_type: f
# random_number: 0.9152803019614392, customer_index: 5, customer_type: Leis3
# random_number: 0.3620424656216903, customer_index: 2, customer_type: Bus2
# random_number: 0.6840892475420253, customer_index: 4, customer_type: Leis2
# random_number: 0.8132275786535993, customer_index: 5, customer_type: Leis3
# random_number: 0.9329245393393312, customer_index: 5, customer_type: Leis3
# random_number: 0.8808000465197275, customer_index: 5, customer_type: Leis3
# random_number: 0.003989586152761904, customer_index: 0, customer_type: f
# random_number: 0.9989914224845533, customer_index: 5, customer_type: Leis3
# random_number: 0.38138038476363134, customer_index: 2, customer_type: Bus2
# random_number: 0.37339790431214437, customer_index: 2, customer_type: Bus2
# random_number: 0.7374640313935528, customer_index: 4, customer_type: Leis2
# random_number: 0.5258646832538234, customer_index: 3, customer_type: Leis1
# random_number: 0.21093406718395125, customer_index: 1, customer_type: Bus1
# random_number: 0.4771443344911507, customer_index: 3, customer_type: Leis1
# random_number: 0.20425427546536712, customer_index: 1, customer_type: Bus1
# random_number: 0.7474026266341374, customer_index: 4, customer_type: Leis2
# random_number: 0.3516295836047896, customer_index: 2, customer_type: Bus2
# random_number: 0.17973094904261122, customer_index: 0, customer_type: f
# random_number: 0.8491152846413617, customer_index: 5, customer_type: Leis3
# random_number: 0.6889427454198545, customer_index: 4, customer_type: Leis2
# random_number: 0.06948103951276852, customer_index: 0, customer_type: f
# random_number: 0.07272801223198133, customer_index: 0, customer_type: f
# random_number: 0.2762091662196178, customer_index: 1, customer_type: Bus1
# random_number: 0.28680772305256275, customer_index: 2, customer_type: Bus2
# random_number: 0.5546366467552556, customer_index: 3, customer_type: Leis1
# random_number: 0.5759818500349998, customer_index: 3, customer_type: Leis1
# random_number: 0.20970265181042325, customer_index: 1, customer_type: Bus1
# random_number: 0.08015013801549764, customer_index: 0, customer_type: f
# random_number: 0.17290132315814966, customer_index: 0, customer_type: f
# random_number: 0.11871074643846513, customer_index: 0, customer_type: f
# random_number: 0.5946278579817981, customer_index: 3, customer_type: Leis1
# random_number: 0.8058780133682417, customer_index: 5, customer_type: Leis3
# random_number: 0.00697585104760845, customer_index: 0, customer_type: f
# random_number: 0.6915896559924861, customer_index: 4, customer_type: Leis2
# random_number: 0.8036536001785352, customer_index: 5, customer_type: Leis3
# random_number: 0.6889492062039276, customer_index: 4, customer_type: Leis2
# random_number: 0.06846174448845288, customer_index: 0, customer_type: f
# random_number: 0.5826110294484635, customer_index: 3, customer_type: Leis1
# random_number: 0.5310782403907548, customer_index: 3, customer_type: Leis1
# random_number: 0.31089166139621915, customer_index: 2, customer_type: Bus2
# random_number: 0.030912187443700723, customer_index: 0, customer_type: f
# random_number: 0.7464227334588881, customer_index: 4, customer_type: Leis2
# random_number: 0.9395515292529811, customer_index: 5, customer_type: Leis3
# random_number: 0.4208639219051876, customer_index: 2, customer_type: Bus2
# random_number: 0.5371527358884546, customer_index: 3, customer_type: Leis1
# random_number: 0.7709384203104511, customer_index: 5, customer_type: Leis3
# random_number: 0.27925800965648373, customer_index: 1, customer_type: Bus1
# random_number: 0.1612408101360555, customer_index: 0, customer_type: f
# random_number: 0.4438014910510336, customer_index: 3, customer_type: Leis1
# random_number: 0.7975795792700251, customer_index: 5, customer_type: Leis3
# random_number: 0.8214531286169526, customer_index: 5, customer_type: Leis3
# random_number: 0.39521719358741825, customer_index: 2, customer_type: Bus2
# random_number: 0.4204416871542731, customer_index: 2, customer_type: Bus2
# random_number: 0.13852630125292187, customer_index: 0, customer_type: f
# random_number: 0.2530123160737353, customer_index: 1, customer_type: Bus1
# random_number: 0.6501299258235629, customer_index: 4, customer_type: Leis2
# random_number: 0.6640723968467809, customer_index: 4, customer_type: Leis2
# random_number: 0.9845367191364138, customer_index: 5, customer_type: Leis3
# random_number: 0.11521406375249299, customer_index: 0, customer_type: f
# random_number: 0.5286762884634861, customer_index: 3, customer_type: Leis1
# random_number: 0.8187943275884345, customer_index: 5, customer_type: Leis3
# random_number: 0.8311544929387907, customer_index: 5, customer_type: Leis3
# random_number: 0.16123351075858516, customer_index: 0, customer_type: f
# random_number: 0.9028923928671572, customer_index: 5, customer_type: Leis3
# random_number: 0.472777307965908, customer_index: 3, customer_type: Leis1
# random_number: 0.25700102434441097, customer_index: 1, customer_type: Bus1
# random_number: 0.24355740284926686, customer_index: 1, customer_type: Bus1
# random_number: 0.9847320292034101, customer_index: 5, customer_type: Leis3
# random_number: 0.50777822940011, customer_index: 3, customer_type: Leis1
# random_number: 0.84524620540132, customer_index: 5, customer_type: Leis3
# random_number: 0.701681439619296, customer_index: 4, customer_type: Leis2
# random_number: 0.46085417614015967, customer_index: 3, customer_type: Leis1
# random_number: 0.6535232695554501, customer_index: 4, customer_type: Leis2
# random_number: 0.18720811113285674, customer_index: 0, customer_type: f
# random_number: 0.3484083202534687, customer_index: 2, customer_type: Bus2
# random_number: 0.9769001977833945, customer_index: 5, customer_type: Leis3
# random_number: 0.4917026591845186, customer_index: 3, customer_type: Leis1
# random_number: 0.5588720949978265, customer_index: 3, customer_type: Leis1
# random_number: 0.08304594207645333, customer_index: 0, customer_type: f
# random_number: 0.15986933223714284, customer_index: 0, customer_type: f
# random_number: 0.5376685927883962, customer_index: 3, customer_type: Leis1
# random_number: 0.7291765730726522, customer_index: 4, customer_type: Leis2
# random_number: 0.6439595479721016, customer_index: 4, customer_type: Leis2
# random_number: 0.6658300853058841, customer_index: 4, customer_type: Leis2
# random_number: 0.8108119532409048, customer_index: 5, customer_type: Leis3
# random_number: 0.16156156189858817, customer_index: 0, customer_type: f
# random_number: 0.8813080613415185, customer_index: 5, customer_type: Leis3
# random_number: 0.17860647014890407, customer_index: 0, customer_type: f
# random_number: 0.9677801594904027, customer_index: 5, customer_type: Leis3
# random_number: 0.588033841102752, customer_index: 3, customer_type: Leis1
# random_number: 0.5639251794887842, customer_index: 3, customer_type: Leis1
# random_number: 0.402632393725765, customer_index: 2, customer_type: Bus2
# random_number: 0.9291468178117603, customer_index: 5, customer_type: Leis3
# random_number: 0.9672304735754652, customer_index: 5, customer_type: Leis3
# random_number: 0.5010853154256658, customer_index: 3, customer_type: Leis1
# random_number: 0.5142237768537564, customer_index: 3, customer_type: Leis1
# random_number: 0.625292723421415, customer_index: 4, customer_type: Leis2
# random_number: 0.24061692829618841, customer_index: 1, customer_type: Bus1
# random_number: 0.904800996702362, customer_index: 5, customer_type: Leis3
# random_number: 0.6285067710993204, customer_index: 4, customer_type: Leis2
# random_number: 0.8807739350844297, customer_index: 5, customer_type: Leis3
# random_number: 0.07538321294709116, customer_index: 0, customer_type: f
# random_number: 0.8303022944626424, customer_index: 5, customer_type: Leis3
# random_number: 0.4413665632880479, customer_index: 3, customer_type: Leis1
# random_number: 0.4920299709679442, customer_index: 3, customer_type: Leis1
# random_number: 0.01547665505839757, customer_index: 0, customer_type: f
# random_number: 0.9644948067701749, customer_index: 5, customer_type: Leis3
# random_number: 0.43716190622096573, customer_index: 2, customer_type: Bus2
# random_number: 0.8049026903936031, customer_index: 5, customer_type: Leis3
# random_number: 0.589949248307367, customer_index: 3, customer_type: Leis1
# random_number: 0.08902788354204938, customer_index: 0, customer_type: f
# random_number: 0.4977014813261136, customer_index: 3, customer_type: Leis1
# random_number: 0.7565637005690116, customer_index: 4, customer_type: Leis2
# random_number: 0.44653137812717325, customer_index: 3, customer_type: Leis1
# random_number: 0.9972160428105994, customer_index: 5, customer_type: Leis3
# random_number: 0.9799279965949386, customer_index: 5, customer_type: Leis3
# random_number: 0.472401432866013, customer_index: 3, customer_type: Leis1
# Episode: 3, Total Revenue: tensor([28300], device='cuda:0'), Cumulative average: [29687.5]
# ...
# random_number: 0.4637705323358271, customer_index: 3, customer_type: Leis1
# random_number: 0.8920680120188673, customer_index: 5, customer_type: Leis3
# random_number: 0.21177750260750683, customer_index: 1, customer_type: Bus1
# random_number: 0.6431214248917289, customer_index: 4, customer_type: Leis2
# random_number: 0.6909915967988133, customer_index: 4, customer_type: Leis2
# random_number: 0.17943653143637406, customer_index: 0, customer_type: f
# random_number: 0.3987269188395953, customer_index: 2, customer_type: Bus2
# random_number: 0.9881166040717666, customer_index: 5, customer_type: Leis3
# random_number: 0.2719206606906207, customer_index: 1, customer_type: Bus1
# random_number: 0.14098089494255772, customer_index: 0, customer_type: f
# random_number: 0.21302250821816682, customer_index: 1, customer_type: Bus1
# random_number: 0.36446014971383045, customer_index: 2, customer_type: Bus2
# random_number: 0.2965594520835707, customer_index: 2, customer_type: Bus2
# random_number: 0.7426688895211251, customer_index: 4, customer_type: Leis2
# random_number: 0.4282531171212961, customer_index: 2, customer_type: Bus2
# random_number: 0.30058783484733453, customer_index: 2, customer_type: Bus2
# random_number: 0.38597852460504434, customer_index: 2, customer_type: Bus2
# random_number: 0.24706951515111242, customer_index: 1, customer_type: Bus1
# random_number: 0.5115441464607942, customer_index: 3, customer_type: Leis1
# random_number: 0.8089676947201081, customer_index: 5, customer_type: Leis3
# random_number: 0.1154190605379316, customer_index: 0, customer_type: f
# random_number: 0.5544384838062542, customer_index: 3, customer_type: Leis1
# random_number: 0.6964113281901252, customer_index: 4, customer_type: Leis2
# random_number: 0.5277297034060974, customer_index: 3, customer_type: Leis1
# random_number: 0.9431956110081492, customer_index: 5, customer_type: Leis3
# random_number: 0.32611215871896126, customer_index: 2, customer_type: Bus2
# random_number: 0.7515337873082097, customer_index: 4, customer_type: Leis2
# random_number: 0.48442113468925396, customer_index: 3, customer_type: Leis1
# random_number: 0.42693084737836107, customer_index: 2, customer_type: Bus2
# random_number: 0.7958038159910313, customer_index: 5, customer_type: Leis3
# random_number: 0.8301491687629899, customer_index: 5, customer_type: Leis3
# random_number: 0.7915274935936896, customer_index: 5, customer_type: Leis3
# random_number: 0.8188715190098215, customer_index: 5, customer_type: Leis3
# random_number: 0.021375798644923005, customer_index: 0, customer_type: f
# random_number: 0.8323900765380668, customer_index: 5, customer_type: Leis3
# random_number: 0.542117656664117, customer_index: 3, customer_type: Leis1
# random_number: 0.7542562172651827, customer_index: 4, customer_type: Leis2
# random_number: 0.00399213907674667, customer_index: 0, customer_type: f
# random_number: 0.5401069902467487, customer_index: 3, customer_type: Leis1
# random_number: 0.1258156936787156, customer_index: 0, customer_type: f
# random_number: 0.03931917281186559, customer_index: 0, customer_type: f
# random_number: 0.2420485095800975, customer_index: 1, customer_type: Bus1
# random_number: 0.6232851848396085, customer_index: 4, customer_type: Leis2
# random_number: 0.6260576344976649, customer_index: 4, customer_type: Leis2
# random_number: 0.9823544480353502, customer_index: 5, customer_type: Leis3
# random_number: 0.057853866019274336, customer_index: 0, customer_type: f
# random_number: 0.784715745923463, customer_index: 5, customer_type: Leis3
# random_number: 0.035595827688938764, customer_index: 0, customer_type: f
# random_number: 0.8168747954190244, customer_index: 5, customer_type: Leis3
# random_number: 0.5060402911726838, customer_index: 3, customer_type: Leis1
# random_number: 0.5416957822767092, customer_index: 3, customer_type: Leis1
# random_number: 0.14305714849665274, customer_index: 0, customer_type: f
# random_number: 0.9160156698684463, customer_index: 5, customer_type: Leis3
# random_number: 0.8966438973722378, customer_index: 5, customer_type: Leis3
# random_number: 0.13687175863354573, customer_index: 0, customer_type: f
# random_number: 0.1768422673869301, customer_index: 0, customer_type: f
# random_number: 0.4629841268121143, customer_index: 3, customer_type: Leis1
# random_number: 0.34652535232953563, customer_index: 2, customer_type: Bus2
# random_number: 0.7799126015934453, customer_index: 5, customer_type: Leis3
# random_number: 0.13364589017729545, customer_index: 0, customer_type: f
# random_number: 0.21230267525728364, customer_index: 1, customer_type: Bus1
# random_number: 0.698678035913437, customer_index: 4, customer_type: Leis2
# random_number: 0.8996802804905333, customer_index: 5, customer_type: Leis3
# random_number: 0.5736735319098453, customer_index: 3, customer_type: Leis1
# random_number: 0.05542272360227429, customer_index: 0, customer_type: f
# random_number: 0.10438825034047616, customer_index: 0, customer_type: f
# random_number: 0.39531583214889343, customer_index: 2, customer_type: Bus2
# random_number: 0.16319533042452206, customer_index: 0, customer_type: f
# random_number: 0.685835422293425, customer_index: 4, customer_type: Leis2
# random_number: 0.7153330102491321, customer_index: 4, customer_type: Leis2
# random_number: 0.8850609935987062, customer_index: 5, customer_type: Leis3
# random_number: 0.4067526720610123, customer_index: 2, customer_type: Bus2
# random_number: 0.9400291763804873, customer_index: 5, customer_type: Leis3
# random_number: 0.7308558649245559, customer_index: 4, customer_type: Leis2
# random_number: 0.7811676722559399, customer_index: 5, customer_type: Leis3
# random_number: 0.3867893104631589, customer_index: 2, customer_type: Bus2
# random_number: 0.6201185779580644, customer_index: 4, customer_type: Leis2
# random_number: 0.369034534600711, customer_index: 2, customer_type: Bus2
# random_number: 0.848623969941421, customer_index: 5, customer_type: Leis3
# random_number: 0.7793451144201415, customer_index: 5, customer_type: Leis3
# random_number: 0.7455544854416124, customer_index: 4, customer_type: Leis2
# random_number: 0.4778067165366262, customer_index: 3, customer_type: Leis1
# random_number: 0.9136064914836688, customer_index: 5, customer_type: Leis3
# random_number: 0.15127103254453445, customer_index: 0, customer_type: f
# random_number: 0.8151082005942151, customer_index: 5, customer_type: Leis3
# random_number: 0.5494202007242681, customer_index: 3, customer_type: Leis1
# random_number: 0.8354768211944641, customer_index: 5, customer_type: Leis3
# random_number: 0.16480008198204088, customer_index: 0, customer_type: f
# random_number: 0.18764396517807524, customer_index: 0, customer_type: f
# random_number: 0.37383531100648937, customer_index: 2, customer_type: Bus2
# random_number: 0.8288807307000963, customer_index: 5, customer_type: Leis3
# random_number: 0.14489193422782132, customer_index: 0, customer_type: f
# random_number: 0.9484799855029997, customer_index: 5, customer_type: Leis3
# random_number: 0.7039585139022776, customer_index: 4, customer_type: Leis2
# random_number: 0.3596913980786931, customer_index: 2, customer_type: Bus2
# random_number: 0.7255607301973632, customer_index: 4, customer_type: Leis2
# random_number: 0.6190297426519357, customer_index: 4, customer_type: Leis2
# random_number: 0.1843063676080846, customer_index: 0, customer_type: f
# random_number: 0.625559430244062, customer_index: 4, customer_type: Leis2
# random_number: 0.4532861729308335, customer_index: 3, customer_type: Leis1
# random_number: 0.5609105438780246, customer_index: 3, customer_type: Leis1
# random_number: 0.3555278740447121, customer_index: 2, customer_type: Bus2
# random_number: 0.6108095840999169, customer_index: 4, customer_type: Leis2
# random_number: 0.1140004959080606, customer_index: 0, customer_type: f
# random_number: 0.8692158661261116, customer_index: 5, customer_type: Leis3
# random_number: 0.18365726086670742, customer_index: 0, customer_type: f
# random_number: 0.1330845814915067, customer_index: 0, customer_type: f
# random_number: 0.7448498280078629, customer_index: 4, customer_type: Leis2
# random_number: 0.3508934283298203, customer_index: 2, customer_type: Bus2
# random_number: 0.01774112416173712, customer_index: 0, customer_type: f
# random_number: 0.027067503403004678, customer_index: 0, customer_type: f
# random_number: 0.5606082741292663, customer_index: 3, customer_type: Leis1
# random_number: 0.8632896979615082, customer_index: 5, customer_type: Leis3
# random_number: 0.06686077393189827, customer_index: 0, customer_type: f
# random_number: 0.4520897160752966, customer_index: 3, customer_type: Leis1
# random_number: 0.17951722254584113, customer_index: 0, customer_type: f
# random_number: 0.4216207226403522, customer_index: 2, customer_type: Bus2
# random_number: 0.4062930367254143, customer_index: 2, customer_type: Bus2
# random_number: 0.8185112441415597, customer_index: 5, customer_type: Leis3
# random_number: 0.30549101460057004, customer_index: 2, customer_type: Bus2
# random_number: 0.25494509326108816, customer_index: 1, customer_type: Bus1
# random_number: 0.8455003591745883, customer_index: 5, customer_type: Leis3
# random_number: 0.3720494792840082, customer_index: 2, customer_type: Bus2
# random_number: 0.4436864346495406, customer_index: 3, customer_type: Leis1
# random_number: 0.79510073448562, customer_index: 5, customer_type: Leis3
# random_number: 0.44907444159511556, customer_index: 3, customer_type: Leis1
# random_number: 0.7064532084018396, customer_index: 4, customer_type: Leis2
# random_number: 0.8079224001905414, customer_index: 5, customer_type: Leis3
# random_number: 0.46753005777931833, customer_index: 3, customer_type: Leis1
# random_number: 0.33689532944073375, customer_index: 2, customer_type: Bus2
# random_number: 0.8466210364258654, customer_index: 5, customer_type: Leis3
# random_number: 0.5687290490154772, customer_index: 3, customer_type: Leis1
# random_number: 0.6966770229982285, customer_index: 4, customer_type: Leis2
# random_number: 0.7890503311837234, customer_index: 5, customer_type: Leis3
# random_number: 0.158856271594082, customer_index: 0, customer_type: f
# random_number: 0.37924569000467145, customer_index: 2, customer_type: Bus2
# random_number: 0.08812936622348844, customer_index: 0, customer_type: f
# random_number: 0.8106927441788745, customer_index: 5, customer_type: Leis3
# random_number: 0.5069958488967294, customer_index: 3, customer_type: Leis1
# random_number: 0.6672051908164229, customer_index: 4, customer_type: Leis2
# random_number: 0.5774765112324732, customer_index: 3, customer_type: Leis1
# random_number: 0.6513432265923633, customer_index: 4, customer_type: Leis2
# random_number: 0.7104496007176492, customer_index: 4, customer_type: Leis2
# random_number: 0.8034221023353898, customer_index: 5, customer_type: Leis3
# random_number: 0.8773339709425003, customer_index: 5, customer_type: Leis3
# random_number: 0.7940435566553469, customer_index: 5, customer_type: Leis3
# random_number: 0.06743497539453525, customer_index: 0, customer_type: f
# random_number: 0.5903267949709307, customer_index: 3, customer_type: Leis1
# random_number: 0.2293703400457855, customer_index: 1, customer_type: Bus1
# random_number: 0.5341153740866241, customer_index: 3, customer_type: Leis1
# random_number: 0.09447665059422261, customer_index: 0, customer_type: f
# random_number: 0.6078886792939978, customer_index: 4, customer_type: Leis2
# random_number: 0.4229516488056174, customer_index: 2, customer_type: Bus2
# random_number: 0.044246427214970185, customer_index: 0, customer_type: f
# random_number: 0.6045537855078148, customer_index: 4, customer_type: Leis2
# random_number: 0.20572360613536855, customer_index: 1, customer_type: Bus1
# random_number: 0.9617023509855879, customer_index: 5, customer_type: Leis3
# random_number: 0.16958302140606496, customer_index: 0, customer_type: f
# random_number: 0.9129088195613652, customer_index: 5, customer_type: Leis3
# random_number: 0.884311942383247, customer_index: 5, customer_type: Leis3
# Episode: 57, Total Revenue: tensor([43000], device='cuda:0'), Cumulative average: [40836.20689655]
# ---------- Episode  58 -----------
# random_number: 0.5479831839621502, customer_index: 3, customer_type: Leis1
# random_number: 0.5449518993716745, customer_index: 3, customer_type: Leis1
# random_number: 0.11311792367795126, customer_index: 0, customer_type: f
# random_number: 0.6434386009713235, customer_index: 4, customer_type: Leis2
# random_number: 0.936057154534604, customer_index: 5, customer_type: Leis3
# random_number: 0.44626111204725405, customer_index: 3, customer_type: Leis1
# random_number: 0.6213869559384843, customer_index: 4, customer_type: Leis2
# random_number: 0.1982699230937669, customer_index: 0, customer_type: f
# random_number: 0.9907235258154832, customer_index: 5, customer_type: Leis3
# random_number: 0.9551872317183875, customer_index: 5, customer_type: Leis3
# random_number: 0.43948414201382724, customer_index: 2, customer_type: Bus2
# random_number: 0.5665699436219525, customer_index: 3, customer_type: Leis1
# random_number: 0.55726910867355, customer_index: 3, customer_type: Leis1
# random_number: 0.1376399569554756, customer_index: 0, customer_type: f
# random_number: 0.5004683941383848, customer_index: 3, customer_type: Leis1
# random_number: 0.6905051589872169, customer_index: 4, customer_type: Leis2
# random_number: 0.6129859590365101, customer_index: 4, customer_type: Leis2
# random_number: 0.4562948942521159, customer_index: 3, customer_type: Leis1
# random_number: 0.8546519463607336, customer_index: 5, customer_type: Leis3
# random_number: 0.2876932574875508, customer_index: 2, customer_type: Bus2
# random_number: 0.3210306587242424, customer_index: 2, customer_type: Bus2
# random_number: 0.08917648900051256, customer_index: 0, customer_type: f
# random_number: 0.49741871580682917, customer_index: 3, customer_type: Leis1
# random_number: 0.6018737676448348, customer_index: 4, customer_type: Leis2
# random_number: 0.02776536128107987, customer_index: 0, customer_type: f
# random_number: 0.8092259680092341, customer_index: 5, customer_type: Leis3
# random_number: 0.40005194908179864, customer_index: 2, customer_type: Bus2
# random_number: 0.2976162041061846, customer_index: 2, customer_type: Bus2
# random_number: 0.9223931935060851, customer_index: 5, customer_type: Leis3
# random_number: 0.22587245841649795, customer_index: 1, customer_type: Bus1
# random_number: 0.8797407432351593, customer_index: 5, customer_type: Leis3
# random_number: 0.9772099159381191, customer_index: 5, customer_type: Leis3
# random_number: 0.3615738515074395, customer_index: 2, customer_type: Bus2
# random_number: 0.201245662828476, customer_index: 1, customer_type: Bus1
# random_number: 0.4329377915063495, customer_index: 2, customer_type: Bus2
# random_number: 0.04496212836850533, customer_index: 0, customer_type: f
# random_number: 0.958822432769961, customer_index: 5, customer_type: Leis3
# random_number: 0.3664328567953554, customer_index: 2, customer_type: Bus2
# random_number: 0.6563950589439973, customer_index: 4, customer_type: Leis2
# random_number: 0.6757856064959653, customer_index: 4, customer_type: Leis2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 45
#      42 state = next_state
#      44 # Perform one step of the optimization (on the policy network)
# ---> 45 optimize_model()
#      47 # Soft update of the target network's weights
#      48 # θ′ ← τ θ + (1 −τ )θ′
#      49 target_net_state_dict = target_net.state_dict()
#
# Cell In[14], line 15, in optimize_model()
#      12 non_final_next_states = torch.cat([s for s in batch.next_state
#      13                                             if s is not None])
#      14 state_batch = torch.cat(batch.state)
# ---> 15 action_batch = torch.cat(batch.action)
#      16 reward_batch = torch.cat(batch.reward)
#      18 # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
#      19 # columns of actions taken. These are the actions which would've been taken
#      20 # for each batch state according to policy_net
#
# KeyboardInterrupt:

# %%
# Plot results
plt.figure(figsize=(10, 6))  
plt.plot(range(num_episodes), DQN_total_revenues, label='DQN each episode', alpha=0.5, color='b')
plt.plot(range(50, num_episodes, 50), DQN_per_50_avg, label='DQN per 50 episode', alpha=0.5, color='green')
plt.plot(range(num_episodes), DQN_cumulative_average, label='DQN Cumulative')
plt.axhline(y=dp, color='r', label='DP')
plt.axhline(y=fcfs, color='orange', label='FCFS')
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('Total Reward per Episode')
plt.legend()  
plt.grid(True)
plt.show()
