# %%
import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count
import numpy as np

# %%
import torch as T
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
'''Dynamic Programming, FCFS Simulated result'''
dp = 60940
fcfs = 45276

# %%
'''Establish an aircraft'''
class aircraft:

    # Initialize aircraft
    def __init__(self):
        self.seat_capacity = 100
        self.seat_type = ['Y', 'M', 'K']
        self.seat_price = {'f': 0, 'Y': 800, 'M': 500, 'K': 450}

# %%
''' Demand model from Balaiyan et al.'''
class demandmodel:
    
    # Initialize demand model
    def __init__(self):
        
        # inherent attributes from aircraft class
        self.aircraft = aircraft()
        self.seat_set = self.aircraft.seat_type
        self.seat_price = self.aircraft.seat_price
        
        # demand model parameters
        self.total_booking = 105
        self.market_share = 0.25
        self.gamma = 0.08426
        self.alpha = 0.001251
        self.beta = {'DFARE':-0.006, 'LOT3':-0.944}
        self.a = {'Y':{'DFARE':800, 'LOT3':1},
                  'M':{'DFARE':500, 'LOT3':1},
                  'K':{'DFARE':450, 'LOT3':1},
                 }
        self.fare_diff_avg = sum(self.seat_price.values()) / len(self.seat_price)
        for seat_type in self.a:
            self.a[seat_type]['DFARE'] = round(self.a[seat_type]['DFARE'] - self.fare_diff_avg, 2)

    # Calculate dm
    def dm(self):
        dm = self.total_booking/self.market_share
        return dm

    # Calcilate booking curve
    def booking_curve(self, RD2, RD1):
        booking_curve = math.exp(-self.gamma*RD2)-math.exp(-self.gamma*RD1)
        return booking_curve

    # find pj+1
    def find_pj1(self, seat):
        smaller_keys = [key for key in self.seat_price.keys() if key < seat]
        if smaller_keys:
            max_smaller_key = max(smaller_keys)
            pj1 = self.seat_price[max_smaller_key]
        else:
            pj1 = min(self.seat_price.values())
        return pj1

    # Multinomial logit model
    def mnl(self):
        choose_prob = {}
        value_dict = {}
        for seat in self.seat_set:
            result = {key: self.beta[key] * value for key, value in self.a[seat].items()}
            total = sum(result.values())
            value = math.exp(total)
            value_dict[seat] = value
        for seat in value_dict:
            exp_value = math.exp(value_dict[seat])
            choose_prob[seat] = exp_value / sum(math.exp(value) for value in value_dict.values())
        # print("mnl: ", choose_prob)
        return choose_prob

    # Calculate customer choice
    def customer_choice(self, seat_type):
        total_sum = 0
        choose_prob = self.mnl()
        min_key = min(self.seat_price, key=self.seat_price.get)
        p0 = self.seat_price[min_key]
        for seat in self.seat_set:
            pj = self.seat_price['Y'] # 暫時寫這樣
            pj1 = self.seat_price['M'] # 暫時寫這樣
            # print('p0: ',p0 , 'p1: ', pj, 'pj1: ', pj1)
            sum_of_set = (math.exp(-self.alpha*(pj-p0))-math.exp(-self.alpha*(pj1-p0))) * choose_prob[seat_type] 
            # print('sum of set: ', sum_of_set)
            total_sum += sum_of_set
        return total_sum

    # Calculate demand
    def formulation(self, RD2, RD1):
        dm = self.dm()
        # print('dm',dm)
        booking_curve = self.booking_curve(RD2, RD1)
        # print('booking curve: ',booking_curve)
        BR_dict = {}
        
        for seat in self.seat_set:
            # print("calculate", seat, " ing...")
            customer_choice = self.customer_choice(seat)
            # print('customer choice', customer_choice)
            BR = dm * booking_curve * customer_choice
            BR_dict[seat] = BR
            # print(' seat: ', seat, ' predicted demand model from ', RD2,' to ', RD1, 'is', BR)
        # print("total demand: ", sum(BR_dict.values()))
        return BR_dict
    
    # Plot demand result
    def plot_demand(self):
        
        # Store calculated result
        every_rd = {seat: [] for seat in model.seat_set}  
        cumulative_demand = {seat: [] for seat in model.seat_set}  
        total_demand = {seat: 0 for seat in model.seat_set}  
        cumulative_total_demand_per_rd = []  # Store each RD cumulative demand

        # Calculate all RD demand
        cumulative_total_demand = 0  # Initialize cumulative demand
        for i in range(2, max_rd+1):
            # print('i: ', i)
            BR_results = model.formulation(i, i-1)  
            total_demand_rd = sum(BR_results.values())  # Calculate demand form all rd
            cumulative_total_demand += total_demand_rd  # update cumulative total deamnd
            cumulative_total_demand_per_rd.append(cumulative_total_demand)  # append cumulative total demand
            for seat, demand in BR_results.items():  
                every_rd[seat].append(demand) 
                total_demand[seat] += demand  
                cumulative_demand[seat].append(total_demand[seat])  
        
        plt.figure(figsize=(10, 6))
        plt.plot(range(1, max_rd), cumulative_total_demand_per_rd, label='Total Demand')
        plt.xlabel('RD')
        plt.ylabel('Total Demand')
        plt.title('Total Demand Model')
        plt.legend()
        plt.xticks(range(0, max_rd, int(max_rd/10)))
        plt.grid(True)
        plt.show()

# %%
'''Action space'''
class AgentActionSpace:
    def __init__(self):
        # self.action_list = [0, 1, 2, 3, 4, 5, 6, 7]
        self.action_list = [0, 1, 2, 3]
        self.n = len(self.action_list)  

    def sample(self):
        return np.random.choice(self.action_list)

    def contains(self, action):
        return action in self.action_list

# %%
'''Uniform distribution'''
class uniform_distribution:

    # Initialize parameters
    def __init__(self, total_demand, total_lambda):
        self.total_demand = total_demand
        self.total_lambda = total_lambda
        self.num_period = int(total_demand/total_lambda)
        self.prob = {'Bus1': 0.1, 'Bus2': 0.2, 'Leis1': 0.2, 'Leis2': 0.2, 'Leis3': 0.3}
    
    # Calculate lambda for each type of customer
    def calculate_lambda(self):
        lambda_list = []
        lambda_list.append(round(1-self.total_lambda, 2))
        for customer in self.prob:
            lambda_list.append(round(self.prob[customer] * self.total_lambda, 2)) 
        # print("lambda_list: ", lambda_list)
        return lambda_list

# %%
'''Establish Customer class'''
class Customer:

    ''' Initialization '''
    def __init__(self, total_demand, total_lambda):
        self.customer_type = {0: 'f', 1: 'Bus1', 2:'Bus2', 3:'Leis1', 4: 'Leis2', 5: 'Leis3'}
        self.num_customer_type = len(self.customer_type)
        self.customer_preference = {
            'f':{'Y': False, 'M': False, 'K': False},
            'Bus1': {'Y': True, 'M': False, 'K': False},
            'Bus2': {'Y': True, 'M': True, 'K': False},
            'Leis1': {'Y': False, 'M': True, 'K': False},
            'Leis2': {'Y': False, 'M': True, 'K': True},
            'Leis3': {'Y': False, 'M': False, 'K': True},
        }

        # inherent from uniform distribution class
        self.uniform_distribution = uniform_distribution(total_demand, total_lambda)
        self.arrival_rates = self.uniform_distribution.calculate_lambda() # calculate arrival rates for each customer type
        
        # inherent from aircraft class
        self.aircraft = aircraft()
        self.seat_price = self.aircraft.seat_price

    '''Customer generation'''
    def generate_customer(self):
        random_number = np.random.rand() # generate random number
        probabilities = self.arrival_rates # arrival rates list
        cumulative_probability = 0 # Use cumulative probability decide customer type
        customer_index = 0
        for probability in probabilities:
            cumulative_probability += probability
            if random_number <= cumulative_probability:
                break
            customer_index += 1
        customer_type = self.customer_type[customer_index] # return customer will buy what kind of seat   
        # print(f"random_number: {random_number}, customer_index: {customer_index}, customer_type: {customer_type}")
        return customer_type

    '''customer's preference seat under control'''
    def preference_seat(self, customer_type, seat_open):
        preferred_seats = []  
        preferences = self.customer_preference[customer_type]  
        for seat_type, preference in preferences.items():
            if preference and seat_type in seat_open:
                preferred_seats.append(seat_type)
        # print("preference seats: ", preferred_seats)
        return preferred_seats  
    
    '''customer make decision'''
    def make_decision(self, customer_type, seat_open):
        preferred_seats = self.preference_seat(customer_type, seat_open)  
        if preferred_seats:
            cheapest_seat = min(preferred_seats, key=lambda x: self.seat_price[x])
            return cheapest_seat
        else:
            return 'f'

# %%
'''Establish env with Single Cabin mulitiple fare classes'''
class AirlineEnvironment:
    
    '''Initialize env parameters'''
    def __init__(self, name):
        
        # name of env
        self.name = name
        
        # inherent aircraft
        self.aircraft = aircraft()
        self.seat_capacity = self.aircraft.seat_capacity # seat limitation
        self.seat_type = self.aircraft.seat_type # seat type
        
        # inherent action space class
        self.action_space = AgentActionSpace() 
        
        # inherent attributes from demand model
        self.max_rd = 20 # total selling RDs
        self.demand_model = demandmodel()
        self.total_demand = sum(self.demand_model.formulation(self.max_rd, 1).values()) # total demand from demand model
        self.total_lambda = 0.8 # total lambda from test
        self.max_period = int(self.total_demand/self.total_lambda) # total period
        
        # inherent attributes from uniform distribution class
        self.uniform_distribution = uniform_distribution(self.total_demand, self.total_lambda)
        self.arrival_rates = self.uniform_distribution.calculate_lambda() # calculate arrival rates for each customer type

        # inherent attributes from Customer class
        self.customer = Customer(self.total_demand, self.total_lambda) 
        
        # environment parameters
        self.seat_remain = self.seat_capacity # seat limitation
        self.state = np.array([self.seat_capacity, self.max_period]) # Initialize state : (num seat sold, period)
        # self.a_s_ref = {0: 'f', 1: 'Y', 2: 'M', 3: 'K', 4: 'YM', 5: 'YK', 6: 'MK', 7: 'YMK'} # action reference to seat open combination
        self.a_s_ref = {0: 'f', 1: 'Y', 2: 'YK', 3: 'YMK'}
        
    '''reset env'''
    def reset(self):
        self.seat_remain = self.seat_capacity # Initialize total seat 
        self.state = np.array([self.seat_remain, self.max_period])  # Initialize state
        return self.state
    
    '''Step'''
    def step(self, state, action):

        # print(f"Action: {action}, state: {state}")
        
        # With remaining seat
        if self.seat_remain > 0:

            # Agent choose a seat combination
            seat_open = self.a_s_ref[action]   
            # print("seat_open: ", seat_open)
            
            # Customer generation
            customer_type = self.customer.generate_customer()
            # print("customer type: ", customer_type)

            # Customer choose seat
            chosen_seat = self.customer.make_decision(customer_type, seat_open) 
            # print("chosen seat: ", chosen_seat)

            # Decide immediate revenue
            reward = self.aircraft.seat_price[chosen_seat] 

            # Update seat remain
            if reward > 0:
                self.seat_remain = self.seat_remain-1
        
        # Without remaining seat 
        else:
            # print("No remaining seat.")
            reward = 0

        # Update period
        next_time = state[1].item() - 1
        
        # Check departure or not 
        departure = (next_time <= 0)

        # update state
        state[0] = self.seat_remain
        state[1] = next_time
        return state, reward, departure

# %%
'''Deep Q Network'''
class DeepQNetwork(nn.Module):
    def __init__(self, lr, n_actions, input_dims):
        super(DeepQNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dims, 512)
        self.fc2 = nn.Linear(512, n_actions)

        self.optimizer = optim.RMSprop(self.parameters(), lr=lr)

        self.loss = nn.MSELoss()
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)

    def forward(self, state):
        x = F.relu(self.fc1(state))
        actions = self.fc2(x)

        return actions

# %%
'''Define replay buffer'''
class ReplayBuffer(object):
    def __init__(self, max_size, input_shape, n_actions):
        self.mem_size = max_size
        self.mem_cntr = 0
        self.state_memory = np.zeros((self.mem_size, *input_shape),
                                     dtype=np.float32)
        self.new_state_memory = np.zeros((self.mem_size, *input_shape),
                                         dtype=np.float32)

        self.action_memory = np.zeros(self.mem_size, dtype=np.int64)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool_)

    # store transition to buffer
    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.terminal_memory[index] = done
        self.mem_cntr += 1

    # sample transition from buffer
    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)
        batch = np.random.choice(max_mem, batch_size, replace=False)

        states = self.state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        states_ = self.new_state_memory[batch]
        terminal = self.terminal_memory[batch]

        return states, actions, rewards, states_, terminal

# %%
'''DDQN Agent'''
class DDQNAgent(object):
    def __init__(self, gamma, epsilon, lr, n_actions, input_dims,
                 mem_size, batch_size, eps_min, eps_dec, replace):
        self.gamma = gamma # time discount gamma
        self.epsilon = epsilon # epilson-greedy hyperparameter eplison
        self.lr = lr # learning rate
        self.n_actions = n_actions # number of action
        self.input_dims = input_dims # number of state
        self.batch_size = batch_size # batch size of sample memory
        self.eps_min = eps_min # minimum of hyperparameter epilson
        self.eps_dec = eps_dec # epilson decay rate, higher represent slower decay
        self.replace_target_cnt = replace # frequence of replace target network 
        self.action_space = [i for i in range(n_actions)]
        self.learn_step_counter = 0
        self.memory = ReplayBuffer(mem_size, (input_dims,), n_actions) # Replay buffer
        self.q_eval = DeepQNetwork(self.lr, self.n_actions,
                                    input_dims=self.input_dims) # Target network
        self.q_next = DeepQNetwork(self.lr, self.n_actions,
                                    input_dims=self.input_dims) # Policy network

    # store transition
    def store_transition(self, state, action, reward, state_, done):
        self.memory.store_transition(state, action, reward, state_, done)

    # sample memory
    def sample_memory(self):
        state, action, reward, new_state, done = \
                                self.memory.sample_buffer(self.batch_size)

        states = T.tensor(state).to(self.q_eval.device)
        rewards = T.tensor(reward).to(self.q_eval.device)
        dones = T.tensor(done).to(self.q_eval.device)
        actions = T.tensor(action).to(self.q_eval.device)
        states_ = T.tensor(new_state).to(self.q_eval.device)

        return states, actions, rewards, states_, dones

    # agent choose action
    def choose_action(self, observation):
        if np.random.random() > self.epsilon:
            state = T.tensor([observation],dtype=T.float).to(self.q_eval.device)
            actions = self.q_eval.forward(state)
            action = T.argmax(actions).item()
        else:
            action = np.random.choice(self.action_space)

        return action

    # update parameter of target network
    def replace_target_network(self):
        if self.replace_target_cnt is not None and \
           self.learn_step_counter % self.replace_target_cnt == 0:
            self.q_next.load_state_dict(self.q_eval.state_dict())

    # decrease value of epilson
    def decrement_epsilon(self):
        self.epsilon = self.epsilon - self.eps_dec \
                           if self.epsilon > self.eps_min else self.eps_min

    # optimizer model
    def learn(self):
        if self.memory.mem_cntr < self.batch_size: # check whether have enough memory
            return

        self.q_eval.optimizer.zero_grad() # diminish previous gradient

        self.replace_target_network()

        states, actions, rewards, states_, dones = self.sample_memory()

        indices = np.arange(self.batch_size)

        q_pred = self.q_eval.forward(states)[indices, actions]
        q_next = self.q_next.forward(states_)
        q_eval = self.q_eval.forward(states_)

        max_actions = T.argmax(q_eval, dim=1)
        q_next[dones] = 0.0

        q_target = rewards + self.gamma*q_next[indices, max_actions]
        loss = self.q_eval.loss(q_target, q_pred).to(self.q_eval.device)
        loss.backward()

        self.q_eval.optimizer.step()
        self.learn_step_counter += 1

        self.decrement_epsilon()

# %%
# Initialize Training parameters
num_episodes = 3000
DDQN_total_revenues = []
DDQN_cumulative_average = []
DDQN_per_50_avg = []

env = AirlineEnvironment("Single route parallel flight.v0")
agent = DDQNAgent(gamma=0.99, epsilon=1, lr=0.001,
                 input_dims=len(env.state),
                 n_actions=env.action_space.n, mem_size=100000, eps_min=0.1,
                 batch_size=512, replace=1000, eps_dec=5e-6)

n_step = 0
best_score = 0

# Start Training
for episode in range(1, num_episodes+1):
    
    # Initialize environment
    # print("---------- Episode ", episode, "-----------")
    observation = env.reset()
    total_revenue = 0 # Initialize total revenue
    departure = None
    
    while not departure:
        
        # print("------- step " , env.max_period - n_step," ---------")
        
        # agent select action
        action = agent.choose_action(observation)
        # print("action", action)

        # env return observation
        observation_, reward, departure = env.step(observation, action)
        # print("observation_: ", observation, "reward: ",  reward, "departure: ", departure)
        total_revenue += reward # Update total revenue

        # agent memorize transition
        agent.store_transition(observation, action, reward, observation_, departure)
        agent.learn()

        # Move on to the next state
        observation = observation_ 
        n_step += 1

    if total_revenue > best_score:
        best_score = total_revenue
        
    DDQN_total_revenues.append(total_revenue) 
    DDQN_per_50_avg.append(np.mean(DDQN_total_revenues[-50:])) 
    DDQN_cumulative_avg = sum(DDQN_total_revenues) / (episode)
    DDQN_cumulative_average.append(DDQN_cumulative_avg)
    # print(f"Episode: {episode}, Total Revenue: {total_revenue}, Cumulative average: {DDQN_cumulative_avg}")
    print('Episode:',episode ,'Total Revenue:', total_revenue,
             ' Cumulative average %.1f' % DDQN_cumulative_avg, 'best score:', best_score,
            'epsilon %.2f' % agent.epsilon, 'steps', n_step)
# Out:
# Episode: 1 Total Revenue: 45900  Cumulative average 45900.0 best score: 45900 epsilon 1.00 steps 193
# Episode: 2 Total Revenue: 49400  Cumulative average 47650.0 best score: 49400 epsilon 1.00 steps 386
# Episode: 3 Total Revenue: 45200  Cumulative average 46833.3 best score: 49400 epsilon 1.00 steps 579
# Episode: 4 Total Revenue: 52500  Cumulative average 48250.0 best score: 52500 epsilon 1.00 steps 772
# Episode: 5 Total Revenue: 49150  Cumulative average 48430.0 best score: 52500 epsilon 1.00 steps 965
# Episode: 6 Total Revenue: 42750  Cumulative average 47483.3 best score: 52500 epsilon 1.00 steps 1158
# Episode: 7 Total Revenue: 46200  Cumulative average 47300.0 best score: 52500 epsilon 1.00 steps 1351
# Episode: 8 Total Revenue: 50500  Cumulative average 47700.0 best score: 52500 epsilon 0.99 steps 1544
# C:\Users\User\AppData\Local\Temp\ipykernel_76388\4213426725.py:42: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:264.)
#   state = T.tensor([observation],dtype=T.float).to(self.q_eval.device)
# Episode: 9 Total Revenue: 54500  Cumulative average 48455.6 best score: 54500 epsilon 0.99 steps 1737
# Episode: 10 Total Revenue: 50850  Cumulative average 48695.0 best score: 54500 epsilon 0.99 steps 1930
# Episode: 11 Total Revenue: 43050  Cumulative average 48181.8 best score: 54500 epsilon 0.99 steps 2123
# Episode: 12 Total Revenue: 50450  Cumulative average 48370.8 best score: 54500 epsilon 0.99 steps 2316
# Episode: 13 Total Revenue: 44950  Cumulative average 48107.7 best score: 54500 epsilon 0.99 steps 2509
# Episode: 14 Total Revenue: 50100  Cumulative average 48250.0 best score: 54500 epsilon 0.99 steps 2702
# Episode: 15 Total Revenue: 51900  Cumulative average 48493.3 best score: 54500 epsilon 0.99 steps 2895
# Episode: 16 Total Revenue: 48900  Cumulative average 48518.8 best score: 54500 epsilon 0.99 steps 3088
# Episode: 17 Total Revenue: 53400  Cumulative average 48805.9 best score: 54500 epsilon 0.99 steps 3281
# Episode: 18 Total Revenue: 47450  Cumulative average 48730.6 best score: 54500 epsilon 0.99 steps 3474
# Episode: 19 Total Revenue: 48200  Cumulative average 48702.6 best score: 54500 epsilon 0.98 steps 3667
# Episode: 20 Total Revenue: 47050  Cumulative average 48620.0 best score: 54500 epsilon 0.98 steps 3860
# Episode: 21 Total Revenue: 47400  Cumulative average 48561.9 best score: 54500 epsilon 0.98 steps 4053
# Episode: 22 Total Revenue: 50500  Cumulative average 48650.0 best score: 54500 epsilon 0.98 steps 4246
# Episode: 23 Total Revenue: 39700  Cumulative average 48260.9 best score: 54500 epsilon 0.98 steps 4439
# Episode: 24 Total Revenue: 50250  Cumulative average 48343.8 best score: 54500 epsilon 0.98 steps 4632
# Episode: 25 Total Revenue: 54050  Cumulative average 48572.0 best score: 54500 epsilon 0.98 steps 4825
# Episode: 26 Total Revenue: 49850  Cumulative average 48621.2 best score: 54500 epsilon 0.98 steps 5018
# Episode: 27 Total Revenue: 52700  Cumulative average 48772.2 best score: 54500 epsilon 0.98 steps 5211
# Episode: 28 Total Revenue: 47150  Cumulative average 48714.3 best score: 54500 epsilon 0.98 steps 5404
# Episode: 29 Total Revenue: 47550  Cumulative average 48674.1 best score: 54500 epsilon 0.97 steps 5597
# Episode: 30 Total Revenue: 48200  Cumulative average 48658.3 best score: 54500 epsilon 0.97 steps 5790
# Episode: 31 Total Revenue: 50150  Cumulative average 48706.5 best score: 54500 epsilon 0.97 steps 5983
# Episode: 32 Total Revenue: 53700  Cumulative average 48862.5 best score: 54500 epsilon 0.97 steps 6176
# Episode: 33 Total Revenue: 46000  Cumulative average 48775.8 best score: 54500 epsilon 0.97 steps 6369
# Episode: 34 Total Revenue: 49550  Cumulative average 48798.5 best score: 54500 epsilon 0.97 steps 6562
# Episode: 35 Total Revenue: 47050  Cumulative average 48748.6 best score: 54500 epsilon 0.97 steps 6755
# Episode: 36 Total Revenue: 53900  Cumulative average 48891.7 best score: 54500 epsilon 0.97 steps 6948
# Episode: 37 Total Revenue: 52900  Cumulative average 49000.0 best score: 54500 epsilon 0.97 steps 7141
# Episode: 38 Total Revenue: 50600  Cumulative average 49042.1 best score: 54500 epsilon 0.97 steps 7334
# Episode: 39 Total Revenue: 51900  Cumulative average 49115.4 best score: 54500 epsilon 0.96 steps 7527
# Episode: 40 Total Revenue: 48400  Cumulative average 49097.5 best score: 54500 epsilon 0.96 steps 7720
# Episode: 41 Total Revenue: 48150  Cumulative average 49074.4 best score: 54500 epsilon 0.96 steps 7913
# Episode: 42 Total Revenue: 40250  Cumulative average 48864.3 best score: 54500 epsilon 0.96 steps 8106
# Episode: 43 Total Revenue: 49750  Cumulative average 48884.9 best score: 54500 epsilon 0.96 steps 8299
# Episode: 44 Total Revenue: 52300  Cumulative average 48962.5 best score: 54500 epsilon 0.96 steps 8492
# Episode: 45 Total Revenue: 48650  Cumulative average 48955.6 best score: 54500 epsilon 0.96 steps 8685
# Episode: 46 Total Revenue: 47500  Cumulative average 48923.9 best score: 54500 epsilon 0.96 steps 8878
# Episode: 47 Total Revenue: 50250  Cumulative average 48952.1 best score: 54500 epsilon 0.96 steps 9071
# Episode: 48 Total Revenue: 48000  Cumulative average 48932.3 best score: 54500 epsilon 0.96 steps 9264
# Episode: 49 Total Revenue: 53500  Cumulative average 49025.5 best score: 54500 epsilon 0.96 steps 9457
# Episode: 50 Total Revenue: 51500  Cumulative average 49075.0 best score: 54500 epsilon 0.95 steps 9650
# Episode: 51 Total Revenue: 52500  Cumulative average 49142.2 best score: 54500 epsilon 0.95 steps 9843
# Episode: 52 Total Revenue: 48100  Cumulative average 49122.1 best score: 54500 epsilon 0.95 steps 10036
# Episode: 53 Total Revenue: 53800  Cumulative average 49210.4 best score: 54500 epsilon 0.95 steps 10229
# Episode: 54 Total Revenue: 48050  Cumulative average 49188.9 best score: 54500 epsilon 0.95 steps 10422
# Episode: 55 Total Revenue: 42900  Cumulative average 49074.5 best score: 54500 epsilon 0.95 steps 10615
# Episode: 56 Total Revenue: 49850  Cumulative average 49088.4 best score: 54500 epsilon 0.95 steps 10808
# Episode: 57 Total Revenue: 46550  Cumulative average 49043.9 best score: 54500 epsilon 0.95 steps 11001
# Episode: 58 Total Revenue: 52000  Cumulative average 49094.8 best score: 54500 epsilon 0.95 steps 11194
# Episode: 59 Total Revenue: 51200  Cumulative average 49130.5 best score: 54500 epsilon 0.95 steps 11387
# Episode: 60 Total Revenue: 49000  Cumulative average 49128.3 best score: 54500 epsilon 0.94 steps 11580
# Episode: 61 Total Revenue: 46550  Cumulative average 49086.1 best score: 54500 epsilon 0.94 steps 11773
# Episode: 62 Total Revenue: 52850  Cumulative average 49146.8 best score: 54500 epsilon 0.94 steps 11966
# Episode: 63 Total Revenue: 52650  Cumulative average 49202.4 best score: 54500 epsilon 0.94 steps 12159
# Episode: 64 Total Revenue: 47700  Cumulative average 49178.9 best score: 54500 epsilon 0.94 steps 12352
# Episode: 65 Total Revenue: 50750  Cumulative average 49203.1 best score: 54500 epsilon 0.94 steps 12545
# Episode: 66 Total Revenue: 53350  Cumulative average 49265.9 best score: 54500 epsilon 0.94 steps 12738
# Episode: 67 Total Revenue: 53700  Cumulative average 49332.1 best score: 54500 epsilon 0.94 steps 12931
# Episode: 68 Total Revenue: 47950  Cumulative average 49311.8 best score: 54500 epsilon 0.94 steps 13124
# Episode: 69 Total Revenue: 51800  Cumulative average 49347.8 best score: 54500 epsilon 0.94 steps 13317
# Episode: 70 Total Revenue: 50000  Cumulative average 49357.1 best score: 54500 epsilon 0.94 steps 13510
# Episode: 71 Total Revenue: 49450  Cumulative average 49358.5 best score: 54500 epsilon 0.93 steps 13703
# Episode: 72 Total Revenue: 45800  Cumulative average 49309.0 best score: 54500 epsilon 0.93 steps 13896
# Episode: 73 Total Revenue: 53250  Cumulative average 49363.0 best score: 54500 epsilon 0.93 steps 14089
# Episode: 74 Total Revenue: 50550  Cumulative average 49379.1 best score: 54500 epsilon 0.93 steps 14282
# Episode: 75 Total Revenue: 46200  Cumulative average 49336.7 best score: 54500 epsilon 0.93 steps 14475
# Episode: 76 Total Revenue: 50200  Cumulative average 49348.0 best score: 54500 epsilon 0.93 steps 14668
# Episode: 77 Total Revenue: 53350  Cumulative average 49400.0 best score: 54500 epsilon 0.93 steps 14861
# Episode: 78 Total Revenue: 54250  Cumulative average 49462.2 best score: 54500 epsilon 0.93 steps 15054
# Episode: 79 Total Revenue: 48900  Cumulative average 49455.1 best score: 54500 epsilon 0.93 steps 15247
# Episode: 80 Total Revenue: 53350  Cumulative average 49503.8 best score: 54500 epsilon 0.93 steps 15440
# Episode: 81 Total Revenue: 47800  Cumulative average 49482.7 best score: 54500 epsilon 0.92 steps 15633
# Episode: 82 Total Revenue: 51300  Cumulative average 49504.9 best score: 54500 epsilon 0.92 steps 15826
# Episode: 83 Total Revenue: 48050  Cumulative average 49487.3 best score: 54500 epsilon 0.92 steps 16019
# Episode: 84 Total Revenue: 52900  Cumulative average 49528.0 best score: 54500 epsilon 0.92 steps 16212
# Episode: 85 Total Revenue: 51000  Cumulative average 49545.3 best score: 54500 epsilon 0.92 steps 16405
# Episode: 86 Total Revenue: 46250  Cumulative average 49507.0 best score: 54500 epsilon 0.92 steps 16598
# Episode: 87 Total Revenue: 49650  Cumulative average 49508.6 best score: 54500 epsilon 0.92 steps 16791
# Episode: 88 Total Revenue: 50400  Cumulative average 49518.8 best score: 54500 epsilon 0.92 steps 16984
# Episode: 89 Total Revenue: 53150  Cumulative average 49559.6 best score: 54500 epsilon 0.92 steps 17177
# Episode: 90 Total Revenue: 52200  Cumulative average 49588.9 best score: 54500 epsilon 0.92 steps 17370
# Episode: 91 Total Revenue: 51500  Cumulative average 49609.9 best score: 54500 epsilon 0.91 steps 17563
# Episode: 92 Total Revenue: 50450  Cumulative average 49619.0 best score: 54500 epsilon 0.91 steps 17756
# Episode: 93 Total Revenue: 52350  Cumulative average 49648.4 best score: 54500 epsilon 0.91 steps 17949
# Episode: 94 Total Revenue: 54900  Cumulative average 49704.3 best score: 54900 epsilon 0.91 steps 18142
# Episode: 95 Total Revenue: 52050  Cumulative average 49728.9 best score: 54900 epsilon 0.91 steps 18335
# Episode: 96 Total Revenue: 51300  Cumulative average 49745.3 best score: 54900 epsilon 0.91 steps 18528
# Episode: 97 Total Revenue: 50950  Cumulative average 49757.7 best score: 54900 epsilon 0.91 steps 18721
# Episode: 98 Total Revenue: 48500  Cumulative average 49744.9 best score: 54900 epsilon 0.91 steps 18914
# Episode: 99 Total Revenue: 48000  Cumulative average 49727.3 best score: 54900 epsilon 0.91 steps 19107
# Episode: 100 Total Revenue: 46750  Cumulative average 49697.5 best score: 54900 epsilon 0.91 steps 19300
# Episode: 101 Total Revenue: 52600  Cumulative average 49726.2 best score: 54900 epsilon 0.91 steps 19493
# Episode: 102 Total Revenue: 47350  Cumulative average 49702.9 best score: 54900 epsilon 0.90 steps 19686
# Episode: 103 Total Revenue: 50600  Cumulative average 49711.7 best score: 54900 epsilon 0.90 steps 19879
# Episode: 104 Total Revenue: 49750  Cumulative average 49712.0 best score: 54900 epsilon 0.90 steps 20072
# Episode: 105 Total Revenue: 48750  Cumulative average 49702.9 best score: 54900 epsilon 0.90 steps 20265
# Episode: 106 Total Revenue: 49600  Cumulative average 49701.9 best score: 54900 epsilon 0.90 steps 20458
# Episode: 107 Total Revenue: 52550  Cumulative average 49728.5 best score: 54900 epsilon 0.90 steps 20651
# Episode: 108 Total Revenue: 48350  Cumulative average 49715.7 best score: 54900 epsilon 0.90 steps 20844
# Episode: 109 Total Revenue: 52400  Cumulative average 49740.4 best score: 54900 epsilon 0.90 steps 21037
# Episode: 110 Total Revenue: 52500  Cumulative average 49765.5 best score: 54900 epsilon 0.90 steps 21230
# Episode: 111 Total Revenue: 54850  Cumulative average 49811.3 best score: 54900 epsilon 0.90 steps 21423
# Episode: 112 Total Revenue: 50900  Cumulative average 49821.0 best score: 54900 epsilon 0.89 steps 21616
# Episode: 113 Total Revenue: 51650  Cumulative average 49837.2 best score: 54900 epsilon 0.89 steps 21809
# Episode: 114 Total Revenue: 53850  Cumulative average 49872.4 best score: 54900 epsilon 0.89 steps 22002
# Episode: 115 Total Revenue: 49900  Cumulative average 49872.6 best score: 54900 epsilon 0.89 steps 22195
# Episode: 116 Total Revenue: 49400  Cumulative average 49868.5 best score: 54900 epsilon 0.89 steps 22388
# Episode: 117 Total Revenue: 49250  Cumulative average 49863.2 best score: 54900 epsilon 0.89 steps 22581
# Episode: 118 Total Revenue: 51100  Cumulative average 49873.7 best score: 54900 epsilon 0.89 steps 22774
# Episode: 119 Total Revenue: 51000  Cumulative average 49883.2 best score: 54900 epsilon 0.89 steps 22967
# Episode: 120 Total Revenue: 52750  Cumulative average 49907.1 best score: 54900 epsilon 0.89 steps 23160
# Episode: 121 Total Revenue: 49700  Cumulative average 49905.4 best score: 54900 epsilon 0.89 steps 23353
# Episode: 122 Total Revenue: 54100  Cumulative average 49939.8 best score: 54900 epsilon 0.88 steps 23546
# Episode: 123 Total Revenue: 50600  Cumulative average 49945.1 best score: 54900 epsilon 0.88 steps 23739
# Episode: 124 Total Revenue: 51250  Cumulative average 49955.6 best score: 54900 epsilon 0.88 steps 23932
# Episode: 125 Total Revenue: 46350  Cumulative average 49926.8 best score: 54900 epsilon 0.88 steps 24125
# Episode: 126 Total Revenue: 52450  Cumulative average 49946.8 best score: 54900 epsilon 0.88 steps 24318
# Episode: 127 Total Revenue: 50700  Cumulative average 49952.8 best score: 54900 epsilon 0.88 steps 24511
# Episode: 128 Total Revenue: 53500  Cumulative average 49980.5 best score: 54900 epsilon 0.88 steps 24704
# Episode: 129 Total Revenue: 52500  Cumulative average 50000.0 best score: 54900 epsilon 0.88 steps 24897
# Episode: 130 Total Revenue: 48050  Cumulative average 49985.0 best score: 54900 epsilon 0.88 steps 25090
# Episode: 131 Total Revenue: 51700  Cumulative average 49998.1 best score: 54900 epsilon 0.88 steps 25283
# Episode: 132 Total Revenue: 52900  Cumulative average 50020.1 best score: 54900 epsilon 0.88 steps 25476
# Episode: 133 Total Revenue: 51150  Cumulative average 50028.6 best score: 54900 epsilon 0.87 steps 25669
# Episode: 134 Total Revenue: 48050  Cumulative average 50013.8 best score: 54900 epsilon 0.87 steps 25862
# Episode: 135 Total Revenue: 52100  Cumulative average 50029.3 best score: 54900 epsilon 0.87 steps 26055
# Episode: 136 Total Revenue: 51200  Cumulative average 50037.9 best score: 54900 epsilon 0.87 steps 26248
# Episode: 137 Total Revenue: 51800  Cumulative average 50050.7 best score: 54900 epsilon 0.87 steps 26441
# Episode: 138 Total Revenue: 51850  Cumulative average 50063.8 best score: 54900 epsilon 0.87 steps 26634
# Episode: 139 Total Revenue: 54650  Cumulative average 50096.8 best score: 54900 epsilon 0.87 steps 26827
# Episode: 140 Total Revenue: 48900  Cumulative average 50088.2 best score: 54900 epsilon 0.87 steps 27020
# Episode: 141 Total Revenue: 52900  Cumulative average 50108.2 best score: 54900 epsilon 0.87 steps 27213
# Episode: 142 Total Revenue: 52450  Cumulative average 50124.6 best score: 54900 epsilon 0.87 steps 27406
# Episode: 143 Total Revenue: 51900  Cumulative average 50137.1 best score: 54900 epsilon 0.86 steps 27599
# Episode: 144 Total Revenue: 52600  Cumulative average 50154.2 best score: 54900 epsilon 0.86 steps 27792
# Episode: 145 Total Revenue: 53400  Cumulative average 50176.6 best score: 54900 epsilon 0.86 steps 27985
# Episode: 146 Total Revenue: 46000  Cumulative average 50147.9 best score: 54900 epsilon 0.86 steps 28178
# Episode: 147 Total Revenue: 53000  Cumulative average 50167.3 best score: 54900 epsilon 0.86 steps 28371
# Episode: 148 Total Revenue: 48950  Cumulative average 50159.1 best score: 54900 epsilon 0.86 steps 28564
# Episode: 149 Total Revenue: 50250  Cumulative average 50159.7 best score: 54900 epsilon 0.86 steps 28757
# Episode: 150 Total Revenue: 54050  Cumulative average 50185.7 best score: 54900 epsilon 0.86 steps 28950
# Episode: 151 Total Revenue: 50800  Cumulative average 50189.7 best score: 54900 epsilon 0.86 steps 29143
# Episode: 152 Total Revenue: 51900  Cumulative average 50201.0 best score: 54900 epsilon 0.86 steps 29336
# Episode: 153 Total Revenue: 53950  Cumulative average 50225.5 best score: 54900 epsilon 0.85 steps 29529
# Episode: 154 Total Revenue: 53300  Cumulative average 50245.5 best score: 54900 epsilon 0.85 steps 29722
# Episode: 155 Total Revenue: 50750  Cumulative average 50248.7 best score: 54900 epsilon 0.85 steps 29915
# Episode: 156 Total Revenue: 50700  Cumulative average 50251.6 best score: 54900 epsilon 0.85 steps 30108
# Episode: 157 Total Revenue: 50450  Cumulative average 50252.9 best score: 54900 epsilon 0.85 steps 30301
# Episode: 158 Total Revenue: 53100  Cumulative average 50270.9 best score: 54900 epsilon 0.85 steps 30494
# Episode: 159 Total Revenue: 51550  Cumulative average 50278.9 best score: 54900 epsilon 0.85 steps 30687
# Episode: 160 Total Revenue: 54100  Cumulative average 50302.8 best score: 54900 epsilon 0.85 steps 30880
# Episode: 161 Total Revenue: 47350  Cumulative average 50284.5 best score: 54900 epsilon 0.85 steps 31073
# Episode: 162 Total Revenue: 53100  Cumulative average 50301.9 best score: 54900 epsilon 0.85 steps 31266
# Episode: 163 Total Revenue: 51550  Cumulative average 50309.5 best score: 54900 epsilon 0.85 steps 31459
# Episode: 164 Total Revenue: 47450  Cumulative average 50292.1 best score: 54900 epsilon 0.84 steps 31652
# Episode: 165 Total Revenue: 47000  Cumulative average 50272.1 best score: 54900 epsilon 0.84 steps 31845
# Episode: 166 Total Revenue: 52650  Cumulative average 50286.4 best score: 54900 epsilon 0.84 steps 32038
# Episode: 167 Total Revenue: 52600  Cumulative average 50300.3 best score: 54900 epsilon 0.84 steps 32231
# Episode: 168 Total Revenue: 51450  Cumulative average 50307.1 best score: 54900 epsilon 0.84 steps 32424
# Episode: 169 Total Revenue: 51350  Cumulative average 50313.3 best score: 54900 epsilon 0.84 steps 32617
# Episode: 170 Total Revenue: 53000  Cumulative average 50329.1 best score: 54900 epsilon 0.84 steps 32810
# Episode: 171 Total Revenue: 51800  Cumulative average 50337.7 best score: 54900 epsilon 0.84 steps 33003
# Episode: 172 Total Revenue: 46350  Cumulative average 50314.5 best score: 54900 epsilon 0.84 steps 33196
# Episode: 173 Total Revenue: 51700  Cumulative average 50322.5 best score: 54900 epsilon 0.84 steps 33389
# Episode: 174 Total Revenue: 52850  Cumulative average 50337.1 best score: 54900 epsilon 0.83 steps 33582
# Episode: 175 Total Revenue: 54050  Cumulative average 50358.3 best score: 54900 epsilon 0.83 steps 33775
# Episode: 176 Total Revenue: 51050  Cumulative average 50362.2 best score: 54900 epsilon 0.83 steps 33968
# Episode: 177 Total Revenue: 54600  Cumulative average 50386.2 best score: 54900 epsilon 0.83 steps 34161
# Episode: 178 Total Revenue: 51650  Cumulative average 50393.3 best score: 54900 epsilon 0.83 steps 34354
# Episode: 179 Total Revenue: 54150  Cumulative average 50414.2 best score: 54900 epsilon 0.83 steps 34547
# Episode: 180 Total Revenue: 51550  Cumulative average 50420.6 best score: 54900 epsilon 0.83 steps 34740
# Episode: 181 Total Revenue: 50700  Cumulative average 50422.1 best score: 54900 epsilon 0.83 steps 34933
# Episode: 182 Total Revenue: 51300  Cumulative average 50426.9 best score: 54900 epsilon 0.83 steps 35126
# Episode: 183 Total Revenue: 54550  Cumulative average 50449.5 best score: 54900 epsilon 0.83 steps 35319
# Episode: 184 Total Revenue: 53500  Cumulative average 50466.0 best score: 54900 epsilon 0.82 steps 35512
# Episode: 185 Total Revenue: 54000  Cumulative average 50485.1 best score: 54900 epsilon 0.82 steps 35705
# Episode: 186 Total Revenue: 51300  Cumulative average 50489.5 best score: 54900 epsilon 0.82 steps 35898
# Episode: 187 Total Revenue: 50100  Cumulative average 50487.4 best score: 54900 epsilon 0.82 steps 36091
# Episode: 188 Total Revenue: 52600  Cumulative average 50498.7 best score: 54900 epsilon 0.82 steps 36284
# Episode: 189 Total Revenue: 51550  Cumulative average 50504.2 best score: 54900 epsilon 0.82 steps 36477
# Episode: 190 Total Revenue: 51900  Cumulative average 50511.6 best score: 54900 epsilon 0.82 steps 36670
# Episode: 191 Total Revenue: 50650  Cumulative average 50512.3 best score: 54900 epsilon 0.82 steps 36863
# Episode: 192 Total Revenue: 54750  Cumulative average 50534.4 best score: 54900 epsilon 0.82 steps 37056
# Episode: 193 Total Revenue: 54200  Cumulative average 50553.4 best score: 54900 epsilon 0.82 steps 37249
# Episode: 194 Total Revenue: 52500  Cumulative average 50563.4 best score: 54900 epsilon 0.82 steps 37442
# Episode: 195 Total Revenue: 51550  Cumulative average 50568.5 best score: 54900 epsilon 0.81 steps 37635
# Episode: 196 Total Revenue: 51350  Cumulative average 50572.4 best score: 54900 epsilon 0.81 steps 37828
# Episode: 197 Total Revenue: 52700  Cumulative average 50583.2 best score: 54900 epsilon 0.81 steps 38021
# Episode: 198 Total Revenue: 52950  Cumulative average 50595.2 best score: 54900 epsilon 0.81 steps 38214
# Episode: 199 Total Revenue: 50950  Cumulative average 50597.0 best score: 54900 epsilon 0.81 steps 38407
# Episode: 200 Total Revenue: 53200  Cumulative average 50610.0 best score: 54900 epsilon 0.81 steps 38600
# Episode: 201 Total Revenue: 50300  Cumulative average 50608.5 best score: 54900 epsilon 0.81 steps 38793
# Episode: 202 Total Revenue: 52650  Cumulative average 50618.6 best score: 54900 epsilon 0.81 steps 38986
# Episode: 203 Total Revenue: 52050  Cumulative average 50625.6 best score: 54900 epsilon 0.81 steps 39179
# Episode: 204 Total Revenue: 50750  Cumulative average 50626.2 best score: 54900 epsilon 0.81 steps 39372
# Episode: 205 Total Revenue: 51900  Cumulative average 50632.4 best score: 54900 epsilon 0.80 steps 39565
# Episode: 206 Total Revenue: 52300  Cumulative average 50640.5 best score: 54900 epsilon 0.80 steps 39758
# Episode: 207 Total Revenue: 54200  Cumulative average 50657.7 best score: 54900 epsilon 0.80 steps 39951
# Episode: 208 Total Revenue: 50150  Cumulative average 50655.3 best score: 54900 epsilon 0.80 steps 40144
# Episode: 209 Total Revenue: 52250  Cumulative average 50662.9 best score: 54900 epsilon 0.80 steps 40337
# Episode: 210 Total Revenue: 53400  Cumulative average 50676.0 best score: 54900 epsilon 0.80 steps 40530
# Episode: 211 Total Revenue: 50250  Cumulative average 50673.9 best score: 54900 epsilon 0.80 steps 40723
# Episode: 212 Total Revenue: 51300  Cumulative average 50676.9 best score: 54900 epsilon 0.80 steps 40916
# Episode: 213 Total Revenue: 51550  Cumulative average 50681.0 best score: 54900 epsilon 0.80 steps 41109
# Episode: 214 Total Revenue: 52550  Cumulative average 50689.7 best score: 54900 epsilon 0.80 steps 41302
# Episode: 215 Total Revenue: 53400  Cumulative average 50702.3 best score: 54900 epsilon 0.80 steps 41495
# Episode: 216 Total Revenue: 51600  Cumulative average 50706.5 best score: 54900 epsilon 0.79 steps 41688
# Episode: 217 Total Revenue: 50800  Cumulative average 50706.9 best score: 54900 epsilon 0.79 steps 41881
# Episode: 218 Total Revenue: 53850  Cumulative average 50721.3 best score: 54900 epsilon 0.79 steps 42074
# Episode: 219 Total Revenue: 54200  Cumulative average 50737.2 best score: 54900 epsilon 0.79 steps 42267
# Episode: 220 Total Revenue: 51150  Cumulative average 50739.1 best score: 54900 epsilon 0.79 steps 42460
# Episode: 221 Total Revenue: 52900  Cumulative average 50748.9 best score: 54900 epsilon 0.79 steps 42653
# Episode: 222 Total Revenue: 52200  Cumulative average 50755.4 best score: 54900 epsilon 0.79 steps 42846
# Episode: 223 Total Revenue: 51450  Cumulative average 50758.5 best score: 54900 epsilon 0.79 steps 43039
# Episode: 224 Total Revenue: 52050  Cumulative average 50764.3 best score: 54900 epsilon 0.79 steps 43232
# Episode: 225 Total Revenue: 52450  Cumulative average 50771.8 best score: 54900 epsilon 0.79 steps 43425
# Episode: 226 Total Revenue: 52200  Cumulative average 50778.1 best score: 54900 epsilon 0.78 steps 43618
# Episode: 227 Total Revenue: 50900  Cumulative average 50778.6 best score: 54900 epsilon 0.78 steps 43811
# Episode: 228 Total Revenue: 51350  Cumulative average 50781.1 best score: 54900 epsilon 0.78 steps 44004
# Episode: 229 Total Revenue: 52250  Cumulative average 50787.6 best score: 54900 epsilon 0.78 steps 44197
# Episode: 230 Total Revenue: 49200  Cumulative average 50780.7 best score: 54900 epsilon 0.78 steps 44390
# Episode: 231 Total Revenue: 52250  Cumulative average 50787.0 best score: 54900 epsilon 0.78 steps 44583
# Episode: 232 Total Revenue: 53700  Cumulative average 50799.6 best score: 54900 epsilon 0.78 steps 44776
# Episode: 233 Total Revenue: 50700  Cumulative average 50799.1 best score: 54900 epsilon 0.78 steps 44969
# Episode: 234 Total Revenue: 52250  Cumulative average 50805.3 best score: 54900 epsilon 0.78 steps 45162
# Episode: 235 Total Revenue: 52000  Cumulative average 50810.4 best score: 54900 epsilon 0.78 steps 45355
# Episode: 236 Total Revenue: 51750  Cumulative average 50814.4 best score: 54900 epsilon 0.77 steps 45548
# Episode: 237 Total Revenue: 52800  Cumulative average 50822.8 best score: 54900 epsilon 0.77 steps 45741
# Episode: 238 Total Revenue: 46900  Cumulative average 50806.3 best score: 54900 epsilon 0.77 steps 45934
# Episode: 239 Total Revenue: 51700  Cumulative average 50810.0 best score: 54900 epsilon 0.77 steps 46127
# Episode: 240 Total Revenue: 54100  Cumulative average 50823.8 best score: 54900 epsilon 0.77 steps 46320
# Episode: 241 Total Revenue: 51850  Cumulative average 50828.0 best score: 54900 epsilon 0.77 steps 46513
# Episode: 242 Total Revenue: 49900  Cumulative average 50824.2 best score: 54900 epsilon 0.77 steps 46706
# Episode: 243 Total Revenue: 52350  Cumulative average 50830.5 best score: 54900 epsilon 0.77 steps 46899
# Episode: 244 Total Revenue: 49800  Cumulative average 50826.2 best score: 54900 epsilon 0.77 steps 47092
# Episode: 245 Total Revenue: 52550  Cumulative average 50833.3 best score: 54900 epsilon 0.77 steps 47285
# Episode: 246 Total Revenue: 52800  Cumulative average 50841.3 best score: 54900 epsilon 0.77 steps 47478
# Episode: 247 Total Revenue: 50000  Cumulative average 50837.9 best score: 54900 epsilon 0.76 steps 47671
# Episode: 248 Total Revenue: 53300  Cumulative average 50847.8 best score: 54900 epsilon 0.76 steps 47864
# Episode: 249 Total Revenue: 51850  Cumulative average 50851.8 best score: 54900 epsilon 0.76 steps 48057
# Episode: 250 Total Revenue: 54400  Cumulative average 50866.0 best score: 54900 epsilon 0.76 steps 48250
# Episode: 251 Total Revenue: 50950  Cumulative average 50866.3 best score: 54900 epsilon 0.76 steps 48443
# Episode: 252 Total Revenue: 53450  Cumulative average 50876.6 best score: 54900 epsilon 0.76 steps 48636
# Episode: 253 Total Revenue: 51150  Cumulative average 50877.7 best score: 54900 epsilon 0.76 steps 48829
# Episode: 254 Total Revenue: 53200  Cumulative average 50886.8 best score: 54900 epsilon 0.76 steps 49022
# Episode: 255 Total Revenue: 51950  Cumulative average 50891.0 best score: 54900 epsilon 0.76 steps 49215
# Episode: 256 Total Revenue: 52050  Cumulative average 50895.5 best score: 54900 epsilon 0.76 steps 49408
# Episode: 257 Total Revenue: 49100  Cumulative average 50888.5 best score: 54900 epsilon 0.75 steps 49601
# Episode: 258 Total Revenue: 51550  Cumulative average 50891.1 best score: 54900 epsilon 0.75 steps 49794
# Episode: 259 Total Revenue: 51550  Cumulative average 50893.6 best score: 54900 epsilon 0.75 steps 49987
# Episode: 260 Total Revenue: 52850  Cumulative average 50901.2 best score: 54900 epsilon 0.75 steps 50180
# Episode: 261 Total Revenue: 51100  Cumulative average 50901.9 best score: 54900 epsilon 0.75 steps 50373
# Episode: 262 Total Revenue: 50850  Cumulative average 50901.7 best score: 54900 epsilon 0.75 steps 50566
# Episode: 263 Total Revenue: 51000  Cumulative average 50902.1 best score: 54900 epsilon 0.75 steps 50759
# Episode: 264 Total Revenue: 54700  Cumulative average 50916.5 best score: 54900 epsilon 0.75 steps 50952
# Episode: 265 Total Revenue: 51150  Cumulative average 50917.4 best score: 54900 epsilon 0.75 steps 51145
# Episode: 266 Total Revenue: 51350  Cumulative average 50919.0 best score: 54900 epsilon 0.75 steps 51338
# Episode: 267 Total Revenue: 51100  Cumulative average 50919.7 best score: 54900 epsilon 0.74 steps 51531
# Episode: 268 Total Revenue: 53450  Cumulative average 50929.1 best score: 54900 epsilon 0.74 steps 51724
# Episode: 269 Total Revenue: 51850  Cumulative average 50932.5 best score: 54900 epsilon 0.74 steps 51917
# Episode: 270 Total Revenue: 52850  Cumulative average 50939.6 best score: 54900 epsilon 0.74 steps 52110
# Episode: 271 Total Revenue: 51000  Cumulative average 50939.9 best score: 54900 epsilon 0.74 steps 52303
# Episode: 272 Total Revenue: 51050  Cumulative average 50940.3 best score: 54900 epsilon 0.74 steps 52496
# Episode: 273 Total Revenue: 51300  Cumulative average 50941.6 best score: 54900 epsilon 0.74 steps 52689
# Episode: 274 Total Revenue: 51900  Cumulative average 50945.1 best score: 54900 epsilon 0.74 steps 52882
# Episode: 275 Total Revenue: 52200  Cumulative average 50949.6 best score: 54900 epsilon 0.74 steps 53075
# Episode: 276 Total Revenue: 56200  Cumulative average 50968.7 best score: 56200 epsilon 0.74 steps 53268
# Episode: 277 Total Revenue: 53300  Cumulative average 50977.1 best score: 56200 epsilon 0.74 steps 53461
# Episode: 278 Total Revenue: 52950  Cumulative average 50984.2 best score: 56200 epsilon 0.73 steps 53654
# Episode: 279 Total Revenue: 50750  Cumulative average 50983.3 best score: 56200 epsilon 0.73 steps 53847
# Episode: 280 Total Revenue: 53000  Cumulative average 50990.5 best score: 56200 epsilon 0.73 steps 54040
# Episode: 281 Total Revenue: 53050  Cumulative average 50997.9 best score: 56200 epsilon 0.73 steps 54233
# Episode: 282 Total Revenue: 51400  Cumulative average 50999.3 best score: 56200 epsilon 0.73 steps 54426
# Episode: 283 Total Revenue: 52050  Cumulative average 51003.0 best score: 56200 epsilon 0.73 steps 54619
# Episode: 284 Total Revenue: 52200  Cumulative average 51007.2 best score: 56200 epsilon 0.73 steps 54812
# Episode: 285 Total Revenue: 54350  Cumulative average 51018.9 best score: 56200 epsilon 0.73 steps 55005
# Episode: 286 Total Revenue: 50350  Cumulative average 51016.6 best score: 56200 epsilon 0.73 steps 55198
# Episode: 287 Total Revenue: 50550  Cumulative average 51015.0 best score: 56200 epsilon 0.73 steps 55391
# Episode: 288 Total Revenue: 51900  Cumulative average 51018.1 best score: 56200 epsilon 0.72 steps 55584
# Episode: 289 Total Revenue: 51700  Cumulative average 51020.4 best score: 56200 epsilon 0.72 steps 55777
# Episode: 290 Total Revenue: 54050  Cumulative average 51030.9 best score: 56200 epsilon 0.72 steps 55970
# Episode: 291 Total Revenue: 52950  Cumulative average 51037.5 best score: 56200 epsilon 0.72 steps 56163
# Episode: 292 Total Revenue: 55100  Cumulative average 51051.4 best score: 56200 epsilon 0.72 steps 56356
# Episode: 293 Total Revenue: 53800  Cumulative average 51060.8 best score: 56200 epsilon 0.72 steps 56549
# Episode: 294 Total Revenue: 49500  Cumulative average 51055.4 best score: 56200 epsilon 0.72 steps 56742
# Episode: 295 Total Revenue: 54300  Cumulative average 51066.4 best score: 56200 epsilon 0.72 steps 56935
# Episode: 296 Total Revenue: 52250  Cumulative average 51070.4 best score: 56200 epsilon 0.72 steps 57128
# Episode: 297 Total Revenue: 52300  Cumulative average 51074.6 best score: 56200 epsilon 0.72 steps 57321
# Episode: 298 Total Revenue: 53900  Cumulative average 51084.1 best score: 56200 epsilon 0.71 steps 57514
# Episode: 299 Total Revenue: 53250  Cumulative average 51091.3 best score: 56200 epsilon 0.71 steps 57707
# Episode: 300 Total Revenue: 53000  Cumulative average 51097.7 best score: 56200 epsilon 0.71 steps 57900
# Episode: 301 Total Revenue: 50800  Cumulative average 51096.7 best score: 56200 epsilon 0.71 steps 58093
# Episode: 302 Total Revenue: 51600  Cumulative average 51098.3 best score: 56200 epsilon 0.71 steps 58286
# Episode: 303 Total Revenue: 50350  Cumulative average 51095.9 best score: 56200 epsilon 0.71 steps 58479
# Episode: 304 Total Revenue: 53950  Cumulative average 51105.3 best score: 56200 epsilon 0.71 steps 58672
# Episode: 305 Total Revenue: 54300  Cumulative average 51115.7 best score: 56200 epsilon 0.71 steps 58865
# Episode: 306 Total Revenue: 51350  Cumulative average 51116.5 best score: 56200 epsilon 0.71 steps 59058
# Episode: 307 Total Revenue: 52450  Cumulative average 51120.8 best score: 56200 epsilon 0.71 steps 59251
# Episode: 308 Total Revenue: 53050  Cumulative average 51127.1 best score: 56200 epsilon 0.71 steps 59444
# Episode: 309 Total Revenue: 50750  Cumulative average 51125.9 best score: 56200 epsilon 0.70 steps 59637
# Episode: 310 Total Revenue: 53600  Cumulative average 51133.9 best score: 56200 epsilon 0.70 steps 59830
# Episode: 311 Total Revenue: 50750  Cumulative average 51132.6 best score: 56200 epsilon 0.70 steps 60023
# Episode: 312 Total Revenue: 51250  Cumulative average 51133.0 best score: 56200 epsilon 0.70 steps 60216
# Episode: 313 Total Revenue: 51800  Cumulative average 51135.1 best score: 56200 epsilon 0.70 steps 60409
# Episode: 314 Total Revenue: 50700  Cumulative average 51133.8 best score: 56200 epsilon 0.70 steps 60602
# Episode: 315 Total Revenue: 52150  Cumulative average 51137.0 best score: 56200 epsilon 0.70 steps 60795
# Episode: 316 Total Revenue: 52400  Cumulative average 51141.0 best score: 56200 epsilon 0.70 steps 60988
# Episode: 317 Total Revenue: 50950  Cumulative average 51140.4 best score: 56200 epsilon 0.70 steps 61181
# Episode: 318 Total Revenue: 53050  Cumulative average 51146.4 best score: 56200 epsilon 0.70 steps 61374
# Episode: 319 Total Revenue: 52900  Cumulative average 51151.9 best score: 56200 epsilon 0.69 steps 61567
# Episode: 320 Total Revenue: 51600  Cumulative average 51153.3 best score: 56200 epsilon 0.69 steps 61760
# Episode: 321 Total Revenue: 50150  Cumulative average 51150.2 best score: 56200 epsilon 0.69 steps 61953
# Episode: 322 Total Revenue: 51750  Cumulative average 51152.0 best score: 56200 epsilon 0.69 steps 62146
# Episode: 323 Total Revenue: 51300  Cumulative average 51152.5 best score: 56200 epsilon 0.69 steps 62339
# Episode: 324 Total Revenue: 51700  Cumulative average 51154.2 best score: 56200 epsilon 0.69 steps 62532
# Episode: 325 Total Revenue: 52500  Cumulative average 51158.3 best score: 56200 epsilon 0.69 steps 62725
# Episode: 326 Total Revenue: 53300  Cumulative average 51164.9 best score: 56200 epsilon 0.69 steps 62918
# Episode: 327 Total Revenue: 53350  Cumulative average 51171.6 best score: 56200 epsilon 0.69 steps 63111
# Episode: 328 Total Revenue: 52500  Cumulative average 51175.6 best score: 56200 epsilon 0.69 steps 63304
# Episode: 329 Total Revenue: 52600  Cumulative average 51179.9 best score: 56200 epsilon 0.69 steps 63497
# Episode: 330 Total Revenue: 52500  Cumulative average 51183.9 best score: 56200 epsilon 0.68 steps 63690
# Episode: 331 Total Revenue: 52000  Cumulative average 51186.4 best score: 56200 epsilon 0.68 steps 63883
# Episode: 332 Total Revenue: 50850  Cumulative average 51185.4 best score: 56200 epsilon 0.68 steps 64076
# Episode: 333 Total Revenue: 49750  Cumulative average 51181.1 best score: 56200 epsilon 0.68 steps 64269
# Episode: 334 Total Revenue: 51400  Cumulative average 51181.7 best score: 56200 epsilon 0.68 steps 64462
# Episode: 335 Total Revenue: 54100  Cumulative average 51190.4 best score: 56200 epsilon 0.68 steps 64655
# Episode: 336 Total Revenue: 52750  Cumulative average 51195.1 best score: 56200 epsilon 0.68 steps 64848
# Episode: 337 Total Revenue: 52150  Cumulative average 51197.9 best score: 56200 epsilon 0.68 steps 65041
# Episode: 338 Total Revenue: 51200  Cumulative average 51197.9 best score: 56200 epsilon 0.68 steps 65234
# Episode: 339 Total Revenue: 51750  Cumulative average 51199.6 best score: 56200 epsilon 0.68 steps 65427
# Episode: 340 Total Revenue: 53450  Cumulative average 51206.2 best score: 56200 epsilon 0.67 steps 65620
# Episode: 341 Total Revenue: 51000  Cumulative average 51205.6 best score: 56200 epsilon 0.67 steps 65813
# Episode: 342 Total Revenue: 53500  Cumulative average 51212.3 best score: 56200 epsilon 0.67 steps 66006
# Episode: 343 Total Revenue: 54050  Cumulative average 51220.6 best score: 56200 epsilon 0.67 steps 66199
# Episode: 344 Total Revenue: 52900  Cumulative average 51225.4 best score: 56200 epsilon 0.67 steps 66392
# Episode: 345 Total Revenue: 52500  Cumulative average 51229.1 best score: 56200 epsilon 0.67 steps 66585
# Episode: 346 Total Revenue: 52800  Cumulative average 51233.7 best score: 56200 epsilon 0.67 steps 66778
# Episode: 347 Total Revenue: 52350  Cumulative average 51236.9 best score: 56200 epsilon 0.67 steps 66971
# Episode: 348 Total Revenue: 51400  Cumulative average 51237.4 best score: 56200 epsilon 0.67 steps 67164
# Episode: 349 Total Revenue: 53600  Cumulative average 51244.1 best score: 56200 epsilon 0.67 steps 67357
# Episode: 350 Total Revenue: 49900  Cumulative average 51240.3 best score: 56200 epsilon 0.66 steps 67550
# Episode: 351 Total Revenue: 53200  Cumulative average 51245.9 best score: 56200 epsilon 0.66 steps 67743
# Episode: 352 Total Revenue: 53300  Cumulative average 51251.7 best score: 56200 epsilon 0.66 steps 67936
# Episode: 353 Total Revenue: 54650  Cumulative average 51261.3 best score: 56200 epsilon 0.66 steps 68129
# Episode: 354 Total Revenue: 51300  Cumulative average 51261.4 best score: 56200 epsilon 0.66 steps 68322
# Episode: 355 Total Revenue: 53150  Cumulative average 51266.8 best score: 56200 epsilon 0.66 steps 68515
# Episode: 356 Total Revenue: 52250  Cumulative average 51269.5 best score: 56200 epsilon 0.66 steps 68708
# Episode: 357 Total Revenue: 52700  Cumulative average 51273.5 best score: 56200 epsilon 0.66 steps 68901
# Episode: 358 Total Revenue: 50950  Cumulative average 51272.6 best score: 56200 epsilon 0.66 steps 69094
# Episode: 359 Total Revenue: 51400  Cumulative average 51273.0 best score: 56200 epsilon 0.66 steps 69287
# Episode: 360 Total Revenue: 51000  Cumulative average 51272.2 best score: 56200 epsilon 0.66 steps 69480
# Episode: 361 Total Revenue: 51600  Cumulative average 51273.1 best score: 56200 epsilon 0.65 steps 69673
# Episode: 362 Total Revenue: 51100  Cumulative average 51272.7 best score: 56200 epsilon 0.65 steps 69866
# Episode: 363 Total Revenue: 51000  Cumulative average 51271.9 best score: 56200 epsilon 0.65 steps 70059
# Episode: 364 Total Revenue: 51250  Cumulative average 51271.8 best score: 56200 epsilon 0.65 steps 70252
# Episode: 365 Total Revenue: 51000  Cumulative average 51271.1 best score: 56200 epsilon 0.65 steps 70445
# Episode: 366 Total Revenue: 53700  Cumulative average 51277.7 best score: 56200 epsilon 0.65 steps 70638
# Episode: 367 Total Revenue: 51700  Cumulative average 51278.9 best score: 56200 epsilon 0.65 steps 70831
# Episode: 368 Total Revenue: 51200  Cumulative average 51278.7 best score: 56200 epsilon 0.65 steps 71024
# Episode: 369 Total Revenue: 52250  Cumulative average 51281.3 best score: 56200 epsilon 0.65 steps 71217
# Episode: 370 Total Revenue: 54550  Cumulative average 51290.1 best score: 56200 epsilon 0.65 steps 71410
# Episode: 371 Total Revenue: 53050  Cumulative average 51294.9 best score: 56200 epsilon 0.64 steps 71603
# Episode: 372 Total Revenue: 51150  Cumulative average 51294.5 best score: 56200 epsilon 0.64 steps 71796
# Episode: 373 Total Revenue: 52550  Cumulative average 51297.9 best score: 56200 epsilon 0.64 steps 71989
# Episode: 374 Total Revenue: 50800  Cumulative average 51296.5 best score: 56200 epsilon 0.64 steps 72182
# Episode: 375 Total Revenue: 52500  Cumulative average 51299.7 best score: 56200 epsilon 0.64 steps 72375
# Episode: 376 Total Revenue: 51000  Cumulative average 51298.9 best score: 56200 epsilon 0.64 steps 72568
# Episode: 377 Total Revenue: 51000  Cumulative average 51298.1 best score: 56200 epsilon 0.64 steps 72761
# Episode: 378 Total Revenue: 50800  Cumulative average 51296.8 best score: 56200 epsilon 0.64 steps 72954
# Episode: 379 Total Revenue: 51800  Cumulative average 51298.2 best score: 56200 epsilon 0.64 steps 73147
# Episode: 380 Total Revenue: 51800  Cumulative average 51299.5 best score: 56200 epsilon 0.64 steps 73340
# Episode: 381 Total Revenue: 52000  Cumulative average 51301.3 best score: 56200 epsilon 0.63 steps 73533
# Episode: 382 Total Revenue: 51500  Cumulative average 51301.8 best score: 56200 epsilon 0.63 steps 73726
# Episode: 383 Total Revenue: 53550  Cumulative average 51307.7 best score: 56200 epsilon 0.63 steps 73919
# Episode: 384 Total Revenue: 51450  Cumulative average 51308.1 best score: 56200 epsilon 0.63 steps 74112
# Episode: 385 Total Revenue: 53450  Cumulative average 51313.6 best score: 56200 epsilon 0.63 steps 74305
# Episode: 386 Total Revenue: 51300  Cumulative average 51313.6 best score: 56200 epsilon 0.63 steps 74498
# Episode: 387 Total Revenue: 52300  Cumulative average 51316.1 best score: 56200 epsilon 0.63 steps 74691
# Episode: 388 Total Revenue: 53500  Cumulative average 51321.8 best score: 56200 epsilon 0.63 steps 74884
# Episode: 389 Total Revenue: 52750  Cumulative average 51325.4 best score: 56200 epsilon 0.63 steps 75077
# Episode: 390 Total Revenue: 53100  Cumulative average 51330.0 best score: 56200 epsilon 0.63 steps 75270
# Episode: 391 Total Revenue: 52000  Cumulative average 51331.7 best score: 56200 epsilon 0.63 steps 75463
# Episode: 392 Total Revenue: 52450  Cumulative average 51334.6 best score: 56200 epsilon 0.62 steps 75656
# Episode: 393 Total Revenue: 53500  Cumulative average 51340.1 best score: 56200 epsilon 0.62 steps 75849
# Episode: 394 Total Revenue: 50700  Cumulative average 51338.5 best score: 56200 epsilon 0.62 steps 76042
# Episode: 395 Total Revenue: 50200  Cumulative average 51335.6 best score: 56200 epsilon 0.62 steps 76235
# Episode: 396 Total Revenue: 53750  Cumulative average 51341.7 best score: 56200 epsilon 0.62 steps 76428
# Episode: 397 Total Revenue: 51050  Cumulative average 51340.9 best score: 56200 epsilon 0.62 steps 76621
# Episode: 398 Total Revenue: 53800  Cumulative average 51347.1 best score: 56200 epsilon 0.62 steps 76814
# Episode: 399 Total Revenue: 52400  Cumulative average 51349.7 best score: 56200 epsilon 0.62 steps 77007
# Episode: 400 Total Revenue: 52400  Cumulative average 51352.4 best score: 56200 epsilon 0.62 steps 77200
# Episode: 401 Total Revenue: 51000  Cumulative average 51351.5 best score: 56200 epsilon 0.62 steps 77393
# Episode: 402 Total Revenue: 52350  Cumulative average 51354.0 best score: 56200 epsilon 0.61 steps 77586
# Episode: 403 Total Revenue: 51800  Cumulative average 51355.1 best score: 56200 epsilon 0.61 steps 77779
# Episode: 404 Total Revenue: 52850  Cumulative average 51358.8 best score: 56200 epsilon 0.61 steps 77972
# Episode: 405 Total Revenue: 52600  Cumulative average 51361.9 best score: 56200 epsilon 0.61 steps 78165
# Episode: 406 Total Revenue: 51900  Cumulative average 51363.2 best score: 56200 epsilon 0.61 steps 78358
# Episode: 407 Total Revenue: 54200  Cumulative average 51370.1 best score: 56200 epsilon 0.61 steps 78551
# Episode: 408 Total Revenue: 51200  Cumulative average 51369.7 best score: 56200 epsilon 0.61 steps 78744
# Episode: 409 Total Revenue: 50300  Cumulative average 51367.1 best score: 56200 epsilon 0.61 steps 78937
# Episode: 410 Total Revenue: 53300  Cumulative average 51371.8 best score: 56200 epsilon 0.61 steps 79130
# Episode: 411 Total Revenue: 53450  Cumulative average 51376.9 best score: 56200 epsilon 0.61 steps 79323
# Episode: 412 Total Revenue: 52200  Cumulative average 51378.9 best score: 56200 epsilon 0.60 steps 79516
# Episode: 413 Total Revenue: 53600  Cumulative average 51384.3 best score: 56200 epsilon 0.60 steps 79709
# Episode: 414 Total Revenue: 52900  Cumulative average 51387.9 best score: 56200 epsilon 0.60 steps 79902
# Episode: 415 Total Revenue: 50400  Cumulative average 51385.5 best score: 56200 epsilon 0.60 steps 80095
# Episode: 416 Total Revenue: 50750  Cumulative average 51384.0 best score: 56200 epsilon 0.60 steps 80288
# Episode: 417 Total Revenue: 50950  Cumulative average 51383.0 best score: 56200 epsilon 0.60 steps 80481
# Episode: 418 Total Revenue: 51700  Cumulative average 51383.7 best score: 56200 epsilon 0.60 steps 80674
# Episode: 419 Total Revenue: 53800  Cumulative average 51389.5 best score: 56200 epsilon 0.60 steps 80867
# Episode: 420 Total Revenue: 51800  Cumulative average 51390.5 best score: 56200 epsilon 0.60 steps 81060
# Episode: 421 Total Revenue: 53900  Cumulative average 51396.4 best score: 56200 epsilon 0.60 steps 81253
# Episode: 422 Total Revenue: 53200  Cumulative average 51400.7 best score: 56200 epsilon 0.60 steps 81446
# Episode: 423 Total Revenue: 53950  Cumulative average 51406.7 best score: 56200 epsilon 0.59 steps 81639
# Episode: 424 Total Revenue: 50700  Cumulative average 51405.1 best score: 56200 epsilon 0.59 steps 81832
# Episode: 425 Total Revenue: 53650  Cumulative average 51410.4 best score: 56200 epsilon 0.59 steps 82025
# Episode: 426 Total Revenue: 52350  Cumulative average 51412.6 best score: 56200 epsilon 0.59 steps 82218
# Episode: 427 Total Revenue: 52300  Cumulative average 51414.6 best score: 56200 epsilon 0.59 steps 82411
# Episode: 428 Total Revenue: 50500  Cumulative average 51412.5 best score: 56200 epsilon 0.59 steps 82604
# Episode: 429 Total Revenue: 50500  Cumulative average 51410.4 best score: 56200 epsilon 0.59 steps 82797
# Episode: 430 Total Revenue: 52300  Cumulative average 51412.4 best score: 56200 epsilon 0.59 steps 82990
# Episode: 431 Total Revenue: 53300  Cumulative average 51416.8 best score: 56200 epsilon 0.59 steps 83183
# Episode: 432 Total Revenue: 51450  Cumulative average 51416.9 best score: 56200 epsilon 0.59 steps 83376
# Episode: 433 Total Revenue: 55500  Cumulative average 51426.3 best score: 56200 epsilon 0.58 steps 83569
# Episode: 434 Total Revenue: 53750  Cumulative average 51431.7 best score: 56200 epsilon 0.58 steps 83762
# Episode: 435 Total Revenue: 52950  Cumulative average 51435.2 best score: 56200 epsilon 0.58 steps 83955
# Episode: 436 Total Revenue: 52300  Cumulative average 51437.2 best score: 56200 epsilon 0.58 steps 84148
# Episode: 437 Total Revenue: 51100  Cumulative average 51436.4 best score: 56200 epsilon 0.58 steps 84341
# Episode: 438 Total Revenue: 51750  Cumulative average 51437.1 best score: 56200 epsilon 0.58 steps 84534
# Episode: 439 Total Revenue: 54150  Cumulative average 51443.3 best score: 56200 epsilon 0.58 steps 84727
# Episode: 440 Total Revenue: 53150  Cumulative average 51447.2 best score: 56200 epsilon 0.58 steps 84920
# Episode: 441 Total Revenue: 49750  Cumulative average 51443.3 best score: 56200 epsilon 0.58 steps 85113
# Episode: 442 Total Revenue: 51550  Cumulative average 51443.6 best score: 56200 epsilon 0.58 steps 85306
# Episode: 443 Total Revenue: 52300  Cumulative average 51445.5 best score: 56200 epsilon 0.58 steps 85499
# Episode: 444 Total Revenue: 51050  Cumulative average 51444.6 best score: 56200 epsilon 0.57 steps 85692
# Episode: 445 Total Revenue: 52850  Cumulative average 51447.8 best score: 56200 epsilon 0.57 steps 85885
# Episode: 446 Total Revenue: 51850  Cumulative average 51448.7 best score: 56200 epsilon 0.57 steps 86078
# Episode: 447 Total Revenue: 55250  Cumulative average 51457.2 best score: 56200 epsilon 0.57 steps 86271
# Episode: 448 Total Revenue: 52700  Cumulative average 51459.9 best score: 56200 epsilon 0.57 steps 86464
# Episode: 449 Total Revenue: 54050  Cumulative average 51465.7 best score: 56200 epsilon 0.57 steps 86657
# Episode: 450 Total Revenue: 50650  Cumulative average 51463.9 best score: 56200 epsilon 0.57 steps 86850
# Episode: 451 Total Revenue: 51350  Cumulative average 51463.6 best score: 56200 epsilon 0.57 steps 87043
# Episode: 452 Total Revenue: 54750  Cumulative average 51470.9 best score: 56200 epsilon 0.57 steps 87236
# Episode: 453 Total Revenue: 51850  Cumulative average 51471.7 best score: 56200 epsilon 0.57 steps 87429
# Episode: 454 Total Revenue: 51600  Cumulative average 51472.0 best score: 56200 epsilon 0.56 steps 87622
# ...
# Episode: 1171 Total Revenue: 50600  Cumulative average 51445.1 best score: 56200 epsilon 0.10 steps 226003
# Episode: 1172 Total Revenue: 49350  Cumulative average 51443.3 best score: 56200 epsilon 0.10 steps 226196
# Episode: 1173 Total Revenue: 53400  Cumulative average 51445.0 best score: 56200 epsilon 0.10 steps 226389
# Episode: 1174 Total Revenue: 49850  Cumulative average 51443.7 best score: 56200 epsilon 0.10 steps 226582
# Episode: 1175 Total Revenue: 50500  Cumulative average 51442.9 best score: 56200 epsilon 0.10 steps 226775
# Episode: 1176 Total Revenue: 48800  Cumulative average 51440.6 best score: 56200 epsilon 0.10 steps 226968
# Episode: 1177 Total Revenue: 52200  Cumulative average 51441.2 best score: 56200 epsilon 0.10 steps 227161
# Episode: 1178 Total Revenue: 49750  Cumulative average 51439.8 best score: 56200 epsilon 0.10 steps 227354
# Episode: 1179 Total Revenue: 50200  Cumulative average 51438.8 best score: 56200 epsilon 0.10 steps 227547
# Episode: 1180 Total Revenue: 50400  Cumulative average 51437.9 best score: 56200 epsilon 0.10 steps 227740
# Episode: 1181 Total Revenue: 52650  Cumulative average 51438.9 best score: 56200 epsilon 0.10 steps 227933
# Episode: 1182 Total Revenue: 49450  Cumulative average 51437.2 best score: 56200 epsilon 0.10 steps 228126
# Episode: 1183 Total Revenue: 50600  Cumulative average 51436.5 best score: 56200 epsilon 0.10 steps 228319
# Episode: 1184 Total Revenue: 51050  Cumulative average 51436.2 best score: 56200 epsilon 0.10 steps 228512
# Episode: 1185 Total Revenue: 51800  Cumulative average 51436.5 best score: 56200 epsilon 0.10 steps 228705
# Episode: 1186 Total Revenue: 50550  Cumulative average 51435.8 best score: 56200 epsilon 0.10 steps 228898
# Episode: 1187 Total Revenue: 49500  Cumulative average 51434.1 best score: 56200 epsilon 0.10 steps 229091
# Episode: 1188 Total Revenue: 52400  Cumulative average 51434.9 best score: 56200 epsilon 0.10 steps 229284
# Episode: 1189 Total Revenue: 50500  Cumulative average 51434.1 best score: 56200 epsilon 0.10 steps 229477
# Episode: 1190 Total Revenue: 51700  Cumulative average 51434.4 best score: 56200 epsilon 0.10 steps 229670
# Episode: 1191 Total Revenue: 49550  Cumulative average 51432.8 best score: 56200 epsilon 0.10 steps 229863
# Episode: 1192 Total Revenue: 51000  Cumulative average 51432.4 best score: 56200 epsilon 0.10 steps 230056
# Episode: 1193 Total Revenue: 50600  Cumulative average 51431.7 best score: 56200 epsilon 0.10 steps 230249
# Episode: 1194 Total Revenue: 50000  Cumulative average 51430.5 best score: 56200 epsilon 0.10 steps 230442
# Episode: 1195 Total Revenue: 52050  Cumulative average 51431.0 best score: 56200 epsilon 0.10 steps 230635
# Episode: 1196 Total Revenue: 51600  Cumulative average 51431.2 best score: 56200 epsilon 0.10 steps 230828
# Episode: 1197 Total Revenue: 50900  Cumulative average 51430.7 best score: 56200 epsilon 0.10 steps 231021
# Episode: 1198 Total Revenue: 50650  Cumulative average 51430.1 best score: 56200 epsilon 0.10 steps 231214
# Episode: 1199 Total Revenue: 50350  Cumulative average 51429.2 best score: 56200 epsilon 0.10 steps 231407
# Episode: 1200 Total Revenue: 50950  Cumulative average 51428.8 best score: 56200 epsilon 0.10 steps 231600
# Episode: 1201 Total Revenue: 48900  Cumulative average 51426.7 best score: 56200 epsilon 0.10 steps 231793
# Episode: 1202 Total Revenue: 50500  Cumulative average 51425.9 best score: 56200 epsilon 0.10 steps 231986
# Episode: 1203 Total Revenue: 51500  Cumulative average 51426.0 best score: 56200 epsilon 0.10 steps 232179
# Episode: 1204 Total Revenue: 49300  Cumulative average 51424.2 best score: 56200 epsilon 0.10 steps 232372
# Episode: 1205 Total Revenue: 48900  Cumulative average 51422.1 best score: 56200 epsilon 0.10 steps 232565
# Episode: 1206 Total Revenue: 49950  Cumulative average 51420.9 best score: 56200 epsilon 0.10 steps 232758
# Episode: 1207 Total Revenue: 52000  Cumulative average 51421.4 best score: 56200 epsilon 0.10 steps 232951
# Episode: 1208 Total Revenue: 50050  Cumulative average 51420.2 best score: 56200 epsilon 0.10 steps 233144
# Episode: 1209 Total Revenue: 50700  Cumulative average 51419.6 best score: 56200 epsilon 0.10 steps 233337
# Episode: 1210 Total Revenue: 49250  Cumulative average 51417.9 best score: 56200 epsilon 0.10 steps 233530
# Episode: 1211 Total Revenue: 50900  Cumulative average 51417.4 best score: 56200 epsilon 0.10 steps 233723
# Episode: 1212 Total Revenue: 52200  Cumulative average 51418.1 best score: 56200 epsilon 0.10 steps 233916
# Episode: 1213 Total Revenue: 51050  Cumulative average 51417.8 best score: 56200 epsilon 0.10 steps 234109
# Episode: 1214 Total Revenue: 49450  Cumulative average 51416.1 best score: 56200 epsilon 0.10 steps 234302
# Episode: 1215 Total Revenue: 51150  Cumulative average 51415.9 best score: 56200 epsilon 0.10 steps 234495
# Episode: 1216 Total Revenue: 50450  Cumulative average 51415.1 best score: 56200 epsilon 0.10 steps 234688
# Episode: 1217 Total Revenue: 51350  Cumulative average 51415.1 best score: 56200 epsilon 0.10 steps 234881
# Episode: 1218 Total Revenue: 50300  Cumulative average 51414.2 best score: 56200 epsilon 0.10 steps 235074
# Episode: 1219 Total Revenue: 50550  Cumulative average 51413.5 best score: 56200 epsilon 0.10 steps 235267
# Episode: 1220 Total Revenue: 51850  Cumulative average 51413.8 best score: 56200 epsilon 0.10 steps 235460
# Episode: 1221 Total Revenue: 50600  Cumulative average 51413.1 best score: 56200 epsilon 0.10 steps 235653
# Episode: 1222 Total Revenue: 50850  Cumulative average 51412.7 best score: 56200 epsilon 0.10 steps 235846
# Episode: 1223 Total Revenue: 50050  Cumulative average 51411.6 best score: 56200 epsilon 0.10 steps 236039
# Episode: 1224 Total Revenue: 51900  Cumulative average 51412.0 best score: 56200 epsilon 0.10 steps 236232
# Episode: 1225 Total Revenue: 52850  Cumulative average 51413.1 best score: 56200 epsilon 0.10 steps 236425
# Episode: 1226 Total Revenue: 50900  Cumulative average 51412.7 best score: 56200 epsilon 0.10 steps 236618
# Episode: 1227 Total Revenue: 51700  Cumulative average 51413.0 best score: 56200 epsilon 0.10 steps 236811
# Episode: 1228 Total Revenue: 51550  Cumulative average 51413.1 best score: 56200 epsilon 0.10 steps 237004
# Episode: 1229 Total Revenue: 49600  Cumulative average 51411.6 best score: 56200 epsilon 0.10 steps 237197
# Episode: 1230 Total Revenue: 50950  Cumulative average 51411.2 best score: 56200 epsilon 0.10 steps 237390
# Episode: 1231 Total Revenue: 49600  Cumulative average 51409.7 best score: 56200 epsilon 0.10 steps 237583
# Episode: 1232 Total Revenue: 49850  Cumulative average 51408.5 best score: 56200 epsilon 0.10 steps 237776
# Episode: 1233 Total Revenue: 52850  Cumulative average 51409.7 best score: 56200 epsilon 0.10 steps 237969
# Episode: 1234 Total Revenue: 51600  Cumulative average 51409.8 best score: 56200 epsilon 0.10 steps 238162
# Episode: 1235 Total Revenue: 50250  Cumulative average 51408.9 best score: 56200 epsilon 0.10 steps 238355
# Episode: 1236 Total Revenue: 49850  Cumulative average 51407.6 best score: 56200 epsilon 0.10 steps 238548
# Episode: 1237 Total Revenue: 51250  Cumulative average 51407.5 best score: 56200 epsilon 0.10 steps 238741
# Episode: 1238 Total Revenue: 49350  Cumulative average 51405.8 best score: 56200 epsilon 0.10 steps 238934
# Episode: 1239 Total Revenue: 52350  Cumulative average 51406.6 best score: 56200 epsilon 0.10 steps 239127
# Episode: 1240 Total Revenue: 51950  Cumulative average 51407.0 best score: 56200 epsilon 0.10 steps 239320
# Episode: 1241 Total Revenue: 52650  Cumulative average 51408.0 best score: 56200 epsilon 0.10 steps 239513
# Episode: 1242 Total Revenue: 49700  Cumulative average 51406.6 best score: 56200 epsilon 0.10 steps 239706
# Episode: 1243 Total Revenue: 50700  Cumulative average 51406.1 best score: 56200 epsilon 0.10 steps 239899
# Episode: 1244 Total Revenue: 51050  Cumulative average 51405.8 best score: 56200 epsilon 0.10 steps 240092
# Episode: 1245 Total Revenue: 51050  Cumulative average 51405.5 best score: 56200 epsilon 0.10 steps 240285
# Episode: 1246 Total Revenue: 50600  Cumulative average 51404.9 best score: 56200 epsilon 0.10 steps 240478
# Episode: 1247 Total Revenue: 50950  Cumulative average 51404.5 best score: 56200 epsilon 0.10 steps 240671
# Episode: 1248 Total Revenue: 48400  Cumulative average 51402.1 best score: 56200 epsilon 0.10 steps 240864
# Episode: 1249 Total Revenue: 51050  Cumulative average 51401.8 best score: 56200 epsilon 0.10 steps 241057
# Episode: 1250 Total Revenue: 50950  Cumulative average 51401.4 best score: 56200 epsilon 0.10 steps 241250
# Episode: 1251 Total Revenue: 49950  Cumulative average 51400.3 best score: 56200 epsilon 0.10 steps 241443
# Episode: 1252 Total Revenue: 48950  Cumulative average 51398.3 best score: 56200 epsilon 0.10 steps 241636
# Episode: 1253 Total Revenue: 51100  Cumulative average 51398.1 best score: 56200 epsilon 0.10 steps 241829
# Episode: 1254 Total Revenue: 51300  Cumulative average 51398.0 best score: 56200 epsilon 0.10 steps 242022
# Episode: 1255 Total Revenue: 51150  Cumulative average 51397.8 best score: 56200 epsilon 0.10 steps 242215
# Episode: 1256 Total Revenue: 51850  Cumulative average 51398.2 best score: 56200 epsilon 0.10 steps 242408
# Episode: 1257 Total Revenue: 51450  Cumulative average 51398.2 best score: 56200 epsilon 0.10 steps 242601
# Episode: 1258 Total Revenue: 48850  Cumulative average 51396.2 best score: 56200 epsilon 0.10 steps 242794
# Episode: 1259 Total Revenue: 53050  Cumulative average 51397.5 best score: 56200 epsilon 0.10 steps 242987
# Episode: 1260 Total Revenue: 51950  Cumulative average 51397.9 best score: 56200 epsilon 0.10 steps 243180
# Episode: 1261 Total Revenue: 50450  Cumulative average 51397.2 best score: 56200 epsilon 0.10 steps 243373
# Episode: 1262 Total Revenue: 50450  Cumulative average 51396.4 best score: 56200 epsilon 0.10 steps 243566
# Episode: 1263 Total Revenue: 50200  Cumulative average 51395.5 best score: 56200 epsilon 0.10 steps 243759
# Episode: 1264 Total Revenue: 50950  Cumulative average 51395.1 best score: 56200 epsilon 0.10 steps 243952
# Episode: 1265 Total Revenue: 51000  Cumulative average 51394.8 best score: 56200 epsilon 0.10 steps 244145
# Episode: 1266 Total Revenue: 48900  Cumulative average 51392.9 best score: 56200 epsilon 0.10 steps 244338
# Episode: 1267 Total Revenue: 51950  Cumulative average 51393.3 best score: 56200 epsilon 0.10 steps 244531
# Episode: 1268 Total Revenue: 52050  Cumulative average 51393.8 best score: 56200 epsilon 0.10 steps 244724
# Episode: 1269 Total Revenue: 49500  Cumulative average 51392.3 best score: 56200 epsilon 0.10 steps 244917
# Episode: 1270 Total Revenue: 49650  Cumulative average 51390.9 best score: 56200 epsilon 0.10 steps 245110
# Episode: 1271 Total Revenue: 53150  Cumulative average 51392.3 best score: 56200 epsilon 0.10 steps 245303
# Episode: 1272 Total Revenue: 49950  Cumulative average 51391.2 best score: 56200 epsilon 0.10 steps 245496
# Episode: 1273 Total Revenue: 50750  Cumulative average 51390.7 best score: 56200 epsilon 0.10 steps 245689
# Episode: 1274 Total Revenue: 50900  Cumulative average 51390.3 best score: 56200 epsilon 0.10 steps 245882
# Episode: 1275 Total Revenue: 50700  Cumulative average 51389.8 best score: 56200 epsilon 0.10 steps 246075
# Episode: 1276 Total Revenue: 50500  Cumulative average 51389.1 best score: 56200 epsilon 0.10 steps 246268
# Episode: 1277 Total Revenue: 51900  Cumulative average 51389.5 best score: 56200 epsilon 0.10 steps 246461
# Episode: 1278 Total Revenue: 52100  Cumulative average 51390.0 best score: 56200 epsilon 0.10 steps 246654
# Episode: 1279 Total Revenue: 49600  Cumulative average 51388.6 best score: 56200 epsilon 0.10 steps 246847
# Episode: 1280 Total Revenue: 53050  Cumulative average 51389.9 best score: 56200 epsilon 0.10 steps 247040
# Episode: 1281 Total Revenue: 50000  Cumulative average 51388.8 best score: 56200 epsilon 0.10 steps 247233
# Episode: 1282 Total Revenue: 50800  Cumulative average 51388.4 best score: 56200 epsilon 0.10 steps 247426
# Episode: 1283 Total Revenue: 50550  Cumulative average 51387.7 best score: 56200 epsilon 0.10 steps 247619
# Episode: 1284 Total Revenue: 49850  Cumulative average 51386.5 best score: 56200 epsilon 0.10 steps 247812
# Episode: 1285 Total Revenue: 52150  Cumulative average 51387.1 best score: 56200 epsilon 0.10 steps 248005
# Episode: 1286 Total Revenue: 52250  Cumulative average 51387.8 best score: 56200 epsilon 0.10 steps 248198
# Episode: 1287 Total Revenue: 50850  Cumulative average 51387.4 best score: 56200 epsilon 0.10 steps 248391
# Episode: 1288 Total Revenue: 51700  Cumulative average 51387.6 best score: 56200 epsilon 0.10 steps 248584
# Episode: 1289 Total Revenue: 51450  Cumulative average 51387.7 best score: 56200 epsilon 0.10 steps 248777
# Episode: 1290 Total Revenue: 52250  Cumulative average 51388.3 best score: 56200 epsilon 0.10 steps 248970
# Episode: 1291 Total Revenue: 51000  Cumulative average 51388.0 best score: 56200 epsilon 0.10 steps 249163
# Episode: 1292 Total Revenue: 51600  Cumulative average 51388.2 best score: 56200 epsilon 0.10 steps 249356
# Episode: 1293 Total Revenue: 49350  Cumulative average 51386.6 best score: 56200 epsilon 0.10 steps 249549
# Episode: 1294 Total Revenue: 51500  Cumulative average 51386.7 best score: 56200 epsilon 0.10 steps 249742
# Episode: 1295 Total Revenue: 50400  Cumulative average 51385.9 best score: 56200 epsilon 0.10 steps 249935
# Episode: 1296 Total Revenue: 51450  Cumulative average 51386.0 best score: 56200 epsilon 0.10 steps 250128
# Episode: 1297 Total Revenue: 50800  Cumulative average 51385.5 best score: 56200 epsilon 0.10 steps 250321
# Episode: 1298 Total Revenue: 49850  Cumulative average 51384.4 best score: 56200 epsilon 0.10 steps 250514
# Episode: 1299 Total Revenue: 49650  Cumulative average 51383.0 best score: 56200 epsilon 0.10 steps 250707
# Episode: 1300 Total Revenue: 50550  Cumulative average 51382.4 best score: 56200 epsilon 0.10 steps 250900
# Episode: 1301 Total Revenue: 49550  Cumulative average 51381.0 best score: 56200 epsilon 0.10 steps 251093
# Episode: 1302 Total Revenue: 50050  Cumulative average 51380.0 best score: 56200 epsilon 0.10 steps 251286
# Episode: 1303 Total Revenue: 52400  Cumulative average 51380.7 best score: 56200 epsilon 0.10 steps 251479
# Episode: 1304 Total Revenue: 53000  Cumulative average 51382.0 best score: 56200 epsilon 0.10 steps 251672
# Episode: 1305 Total Revenue: 50350  Cumulative average 51381.2 best score: 56200 epsilon 0.10 steps 251865
# Episode: 1306 Total Revenue: 49850  Cumulative average 51380.0 best score: 56200 epsilon 0.10 steps 252058
# Episode: 1307 Total Revenue: 50000  Cumulative average 51379.0 best score: 56200 epsilon 0.10 steps 252251
# Episode: 1308 Total Revenue: 50100  Cumulative average 51378.0 best score: 56200 epsilon 0.10 steps 252444
# Episode: 1309 Total Revenue: 51550  Cumulative average 51378.1 best score: 56200 epsilon 0.10 steps 252637
# Episode: 1310 Total Revenue: 52000  Cumulative average 51378.6 best score: 56200 epsilon 0.10 steps 252830
# Episode: 1311 Total Revenue: 51450  Cumulative average 51378.6 best score: 56200 epsilon 0.10 steps 253023
# Episode: 1312 Total Revenue: 52900  Cumulative average 51379.8 best score: 56200 epsilon 0.10 steps 253216
# Episode: 1313 Total Revenue: 50000  Cumulative average 51378.8 best score: 56200 epsilon 0.10 steps 253409
# Episode: 1314 Total Revenue: 49500  Cumulative average 51377.3 best score: 56200 epsilon 0.10 steps 253602
# Episode: 1315 Total Revenue: 52000  Cumulative average 51377.8 best score: 56200 epsilon 0.10 steps 253795
# Episode: 1316 Total Revenue: 51150  Cumulative average 51377.6 best score: 56200 epsilon 0.10 steps 253988
# Episode: 1317 Total Revenue: 50650  Cumulative average 51377.1 best score: 56200 epsilon 0.10 steps 254181
# Episode: 1318 Total Revenue: 50400  Cumulative average 51376.3 best score: 56200 epsilon 0.10 steps 254374
# Episode: 1319 Total Revenue: 50850  Cumulative average 51375.9 best score: 56200 epsilon 0.10 steps 254567

# %%
# Plot results
plt.figure(figsize=(10, 6))  
plt.plot(range(num_episodes), DDQN_total_revenues, label='DDQN each episode', alpha=0.5, color='b')
plt.plot(range(num_episodes), DDQN_per_50_avg, label='DDQN per 50 episode', alpha=0.5, color='green')
plt.plot(range(num_episodes), DDQN_cumulative_average, label='DDQN Cumulative')
plt.axhline(y=dp, color='r', label='DP')
plt.axhline(y=fcfs, color='orange', label='FCFS')
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('Total Reward per Episode')
plt.legend()  
plt.grid(True)
plt.show()
