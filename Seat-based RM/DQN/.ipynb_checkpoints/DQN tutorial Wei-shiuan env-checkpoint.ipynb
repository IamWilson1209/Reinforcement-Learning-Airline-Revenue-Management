# %%
import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count
import numpy as np

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
'''Dynamic Programming, FCFS Simulated result'''
dp = 61135
fcfs = 45564

# %%
'''Establish an aircraft'''
class aircraft:

    # Initialize aircraft
    def __init__(self):
        self.seat_capacity = 100
        self.seat_type = ['Y', 'M', 'K']
        self.seat_price = {'f': 0, 'Y': 800, 'M': 500, 'K': 450}

# %%
''' Demand model from Balaiyan et al.'''
class demandmodel:
    
    # Initialize demand model
    def __init__(self):
        
        # inherent attributes from aircraft class
        self.aircraft = aircraft()
        self.seat_set = self.aircraft.seat_type
        self.seat_price = self.aircraft.seat_price
        
        # demand model parameters
        self.total_booking = 105
        self.market_share = 0.25
        self.gamma = 0.08426
        self.alpha = 0.001251
        self.beta = {'DFARE':-0.006, 'LOT3':-0.944}
        self.a = {'Y':{'DFARE':800, 'LOT3':1},
                  'M':{'DFARE':500, 'LOT3':1},
                  'K':{'DFARE':450, 'LOT3':1},
                 }
        self.fare_diff_avg = sum(self.seat_price.values()) / len(self.seat_price)
        for seat_type in self.a:
            self.a[seat_type]['DFARE'] = round(self.a[seat_type]['DFARE'] - self.fare_diff_avg, 2)

    # Calculate dm
    def dm(self):
        dm = self.total_booking/self.market_share
        return dm

    # Calcilate booking curve
    def booking_curve(self, RD2, RD1):
        booking_curve = math.exp(-self.gamma*RD2)-math.exp(-self.gamma*RD1)
        return booking_curve

    # find pj+1
    def find_pj1(self, seat):
        smaller_keys = [key for key in self.seat_price.keys() if key < seat]
        if smaller_keys:
            max_smaller_key = max(smaller_keys)
            pj1 = self.seat_price[max_smaller_key]
        else:
            pj1 = min(self.seat_price.values())
        return pj1

    # Multinomial logit model
    def mnl(self):
        choose_prob = {}
        value_dict = {}
        for seat in self.seat_set:
            result = {key: self.beta[key] * value for key, value in self.a[seat].items()}
            total = sum(result.values())
            value = math.exp(total)
            value_dict[seat] = value
        for seat in value_dict:
            exp_value = math.exp(value_dict[seat])
            choose_prob[seat] = exp_value / sum(math.exp(value) for value in value_dict.values())
        # print("mnl: ", choose_prob)
        return choose_prob

    # Calculate customer choice
    def customer_choice(self, seat_type):
        total_sum = 0
        choose_prob = self.mnl()
        min_key = min(self.seat_price, key=self.seat_price.get)
        p0 = self.seat_price[min_key]
        for seat in self.seat_set:
            pj = self.seat_price['Y'] # 暫時寫這樣
            pj1 = self.seat_price['M'] # 暫時寫這樣
            # print('p0: ',p0 , 'p1: ', pj, 'pj1: ', pj1)
            sum_of_set = (math.exp(-self.alpha*(pj-p0))-math.exp(-self.alpha*(pj1-p0))) * choose_prob[seat_type] 
            # print('sum of set: ', sum_of_set)
            total_sum += sum_of_set
        return total_sum

    # Calculate demand
    def formulation(self, RD2, RD1):
        dm = self.dm()
        # print('dm',dm)
        booking_curve = self.booking_curve(RD2, RD1)
        # print('booking curve: ',booking_curve)
        BR_dict = {}
        
        for seat in self.seat_set:
            # print("calculate", seat, " ing...")
            customer_choice = self.customer_choice(seat)
            # print('customer choice', customer_choice)
            BR = dm * booking_curve * customer_choice
            BR_dict[seat] = BR
            # print(' seat: ', seat, ' predicted demand model from ', RD2,' to ', RD1, 'is', BR)
        print("total demand: ", sum(BR_dict.values()))
        return BR_dict
    
    # Plot demand result
    def plot_demand(self):
        
        # Store calculated result
        every_rd = {seat: [] for seat in model.seat_set}  
        cumulative_demand = {seat: [] for seat in model.seat_set}  
        total_demand = {seat: 0 for seat in model.seat_set}  
        cumulative_total_demand_per_rd = []  # Store each RD cumulative demand

        # Calculate all RD demand
        cumulative_total_demand = 0  # Initialize cumulative demand
        for i in range(2, max_rd+1):
            # print('i: ', i)
            BR_results = model.formulation(i, i-1)  
            total_demand_rd = sum(BR_results.values())  # Calculate demand form all rd
            cumulative_total_demand += total_demand_rd  # update cumulative total deamnd
            cumulative_total_demand_per_rd.append(cumulative_total_demand)  # append cumulative total demand
            for seat, demand in BR_results.items():  
                every_rd[seat].append(demand) 
                total_demand[seat] += demand  
                cumulative_demand[seat].append(total_demand[seat])  
        
        plt.figure(figsize=(10, 6))
        plt.plot(range(1, max_rd), cumulative_total_demand_per_rd, label='Total Demand')
        plt.xlabel('RD')
        plt.ylabel('Total Demand')
        plt.title('Total Demand Model')
        plt.legend()
        plt.xticks(range(0, max_rd, int(max_rd/10)))
        plt.grid(True)
        plt.show()

# %%
'''Action space'''
class AgentActionSpace:
    def __init__(self):
        self.action_list = [0, 1, 2, 3, 4, 5, 6, 7]
        self.n = len(self.action_list)  

    def sample(self):
        return np.random.choice(self.action_list)

    def contains(self, action):
        return action in self.action_list

# %%
'''Uniform distribution'''
class uniform_distribution:

    # Initialize parameters
    def __init__(self, total_demand, total_lambda):
        self.total_demand = total_demand
        self.total_lambda = total_lambda
        self.num_period = int(total_demand/total_lambda)
        self.prob = {'Bus1': 0.1, 'Bus2': 0.2, 'Leis1': 0.2, 'Leis2': 0.2, 'Leis3': 0.3}
    
    # Calculate lambda for each type of customer
    def calculate_lambda(self):
        lambda_list = []
        lambda_list.append(round(1-self.total_lambda, 2))
        for customer in self.prob:
            lambda_list.append(round(self.prob[customer] * self.total_lambda, 2)) 
        # print("lambda_list: ", lambda_list)
        return lambda_list

# %%
'''Establish Customer class'''
class Customer:

    ''' Initialization '''
    def __init__(self, total_demand, total_lambda):
        self.customer_type = {0: 'f', 1: 'Bus1', 2:'Bus2', 3:'Leis1', 4: 'Leis2', 5: 'Leis3'}
        self.num_customer_type = len(self.customer_type)
        self.customer_preference = {
            'f':{'Y': False, 'M': False, 'K': False},
            'Bus1': {'Y': True, 'M': False, 'K': False},
            'Bus2': {'Y': True, 'M': True, 'K': False},
            'Leis1': {'Y': False, 'M': True, 'K': False},
            'Leis2': {'Y': False, 'M': True, 'K': True},
            'Leis3': {'Y': False, 'M': False, 'K': True},
        }

        # inherent from uniform distribution class
        self.uniform_distribution = uniform_distribution(total_demand, total_lambda)
        self.arrival_rates = self.uniform_distribution.calculate_lambda() # calculate arrival rates for each customer type
        
        # inherent from aircraft class
        self.aircraft = aircraft()
        self.seat_price = self.aircraft.seat_price

    '''Customer generation'''
    def generate_customer(self):
        random_number = np.random.rand() # generate random number
        probabilities = self.arrival_rates # arrival rates list
        cumulative_probability = 0 # Use cumulative probability decide customer type
        customer_index = 0
        for probability in probabilities:
            cumulative_probability += probability
            if random_number <= cumulative_probability:
                break
            customer_index += 1
        customer_type = self.customer_type[customer_index] # return customer will buy what kind of seat   
        # print(f"random_number: {random_number}, customer_index: {customer_index}, customer_type: {customer_type}")
        return customer_type

    '''customer's preference seat under control'''
    def preference_seat(self, customer_type, seat_open):
        preferred_seats = []  
        preferences = self.customer_preference[customer_type]  
        for seat_type, preference in preferences.items():
            if preference and seat_type in seat_open:
                preferred_seats.append(seat_type)
        # print("preference seats: ", preferred_seats)
        return preferred_seats  
    
    '''customer make decision'''
    def make_decision(self, customer_type, seat_open):
        preferred_seats = self.preference_seat(customer_type, seat_open)  
        if preferred_seats:
            cheapest_seat = min(preferred_seats, key=lambda x: self.seat_price[x])
            return cheapest_seat
        else:
            return 'f'

# %%
'''Establish env with Single Cabin mulitiple fare classes'''
class AirlineEnvironment:
    
    '''Initialize env parameters'''
    def __init__(self, name):
        
        # name of env
        self.name = name
        
        # inherent aircraft
        self.aircraft = aircraft()
        self.seat_capacity = self.aircraft.seat_capacity # seat limitation
        self.seat_type = self.aircraft.seat_type # seat type
        
        # inherent action space class
        self.action_space = AgentActionSpace() 
        
        # inherent attributes from demand model
        self.max_rd = 20 # total selling RDs
        self.demand_model = demandmodel()
        self.total_demand = sum(self.demand_model.formulation(self.max_rd, 1).values()) # total demand from demand model
        self.total_lambda = 0.8 # total lambda from test
        self.max_period = int(self.total_demand/self.total_lambda) # total period
        
        # inherent attributes from uniform distribution class
        self.uniform_distribution = uniform_distribution(self.total_demand, self.total_lambda)
        self.arrival_rates = self.uniform_distribution.calculate_lambda() # calculate arrival rates for each customer type

        # inherent attributes from Customer class
        self.customer = Customer(self.total_demand, self.total_lambda) 
        
        # environment parameters
        self.seat_remain = self.seat_capacity # seat limitation
        self.state = (self.seat_capacity, self.max_period) # Initialize state : (num seat sold, period)
        self.a_s_ref = {0: 'f', 1: 'Y', 2: 'M', 3: 'K', 4: 'YM', 5: 'YK', 6: 'MK', 7: 'YMK'} # action reference to seat open combination
        
    '''reset env'''
    def reset(self):
        self.seat_remain = self.seat_capacity # Initialize total seat 
        self.state = (self.seat_remain, self.max_period)  # Initialize state
        return self.state
    
    '''Step'''
    def step(self, state, action):

        # print(f"Action: {action}, state: {state}")
        
        # With remaining seat
        if self.seat_remain > 0:

            # Agent choose a seat combination
            seat_open = self.a_s_ref[action]   
            # print("seat_open: ", seat_open)
            
            # Customer generation
            customer_type = self.customer.generate_customer()
            # print("customer type: ", customer_type)

            # Customer choose seat
            chosen_seat = self.customer.make_decision(customer_type, seat_open) 
            # print("chosen seat: ", chosen_seat)

            # Decide immediate revenue
            reward = self.aircraft.seat_price[chosen_seat] 

            # Update seat remain
            if reward > 0:
                self.seat_remain = self.seat_remain-1
        
        # Without remaining seat 
        else:
            # print("No remaining seat.")
            reward = 0

        # Update period
        next_time = state[0, 1].item() - 1
        
        # Check departure or not 
        departure = (next_time <= 0)

        # update state
        state[0, 0] = self.seat_remain
        state[0, 1] = next_time
        return state.cpu().detach().numpy(), reward, departure

# %%
# if GPU is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Define tuple structure, use tuple structure to store info
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))

''' Establish Memory Replay Buffer '''
class ReplayMemory(object):

    # Capacity of the Memory replay buffer
    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)

    # Push a Transition to moemory
    def push(self, *args):
        self.memory.append(Transition(*args))

    # Sample a Batch size of memory to train
    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    # define the length of memory stored
    def __len__(self):
        return len(self.memory)

# %%
'''DQN Agent'''
class DQN(nn.Module):

    # Initialization
    def __init__(self, n_observations, n_actions):
        super(DQN, self).__init__()
        self.layer1 = nn.Linear(n_observations, 128)
        self.layer2 = nn.Linear(128, 128)
        self.layer3 = nn.Linear(128, n_actions)

    # Back Propogation
    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        return self.layer3(x)

# %%
'''Establish environment from Airline env'''
env = AirlineEnvironment("Single route parallel flight.v0")

''' Reinforcement Learning Hyparameter '''
BATCH_SIZE = 256  # Batch size from experience replay buffer
GAMMA = 0.99  # Reward discount rate Gamma
EPS_START = 0.9  # Epilson-Greedy strategy's hyparameter eplison
EPS_END = 0.05 # Final value of eplison 
EPS_DECAY = 1000 # Control eplison decay，higher represent slower decay
TAU = 0.005 # Update rate of target network
LR = 1e-4 # Learning rate of optimizer

''' Simulated Environment Parameter '''
n_actions = env.action_space.n # num action
state = env.reset() # initialize env
n_observations = len(state) # num state

''' Establish Policy Network, Target Network '''
policy_net = DQN(n_observations, n_actions).to(device) # Policy Network
target_net = DQN(n_observations, n_actions).to(device) # Target Network
target_net.load_state_dict(policy_net.state_dict())
memory = ReplayMemory(10000) # Memory size of Replay Buffer
optimizer = optim.AdamW(policy_net.parameters(), lr=LR, amsgrad=True) # AdamW optimizer

''' Agent Select Action'''
steps_done = 0
def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        # Exploit：Select Max Value action
        with torch.no_grad():
            # t.max(1) return max expected value column
            return policy_net(state).max(1).indices.view(1, 1)
    else:
        # Explore：Randomly select action
        return torch.tensor([[env.action_space.sample()]], device=device, dtype=torch.long)
# Out:
# total demand:  154.78080374954658

# %%
''' Optimize Network '''
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    batch = Transition(*zip(*transitions)) # Converts batch-array of Transitions to Transition of batch-arrays.

    # Compute a mask of non-final states and concatenate the batch elements
    # (a final state would've been the one after which simulation ended)
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
    # columns of actions taken. These are the actions which would've been taken
    # for each batch state according to policy_net
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Compute V(s_{t+1}) for all next states.
    # Expected values of actions for non_final_next_states are computed based
    # on the "older" target_net; selecting their best reward with max(1).values
    # This is merged based on the mask, such that we'll have either the expected
    # state value or 0 in case the state was final.
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    with torch.no_grad():
        next_state_values[non_final_mask] = target_net(non_final_next_states).max(1).values
    # Compute the expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Compute Huber loss
    criterion = nn.SmoothL1Loss()
    loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    
    # In-place gradient clipping
    torch.nn.utils.clip_grad_value_(policy_net.parameters(), 100)
    optimizer.step()

# %%
# Initialize Training parameters
num_episodes = 3000
DQN_total_revenues = []
DQN_cumulative_average = []
DQN_per_50_avg = []

# Start Training
for episode in range(num_episodes):
    
    # Initialize environment
    print("---------- Episode ", episode, "-----------")
    state = env.reset()
    state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
    total_revenue = 0 # Initialize total revenue
    
    for step in count():
        
        # print("------- step " , env.max_period - step," ---------")
        
        # agent 選擇動作
        action = select_action(state)

        # 這裡應該怪怪的
        observation, reward, departure = env.step(state, action.item())
        # print("observation: ", observation, "reward: ",  reward, "departure: ", departure)
        reward = torch.tensor([reward], device=device)

        if departure:
            break
        else:
            observation = observation.flatten()
            next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)

        # Update total revenue
        total_revenue += reward

        # Store the transition in memory
        memory.push(state, action, next_state, reward)

        # Move on to the next state
        state = next_state

        # Perform one step of the optimization (on the policy network)
        optimize_model()

        # Soft update of the target network's weights
        # θ′ ← τ θ + (1 −τ )θ′
        target_net_state_dict = target_net.state_dict()
        policy_net_state_dict = policy_net.state_dict()
        for key in policy_net_state_dict:
            target_net_state_dict[key] = policy_net_state_dict[key]*TAU + target_net_state_dict[key]*(1-TAU)
        target_net.load_state_dict(target_net_state_dict)
    
    # 將每個 episode 的 total reward 加入列表中  
    DQN_total_revenues.append(total_revenue.cpu().numpy()) 
    
    # 計算每50個 episode 的平均總獎勵
    if episode % 50 == 0 and episode != 0:
        DQN_per_50_avg.append(np.mean(DQN_total_revenues[-50:]))
    
    # 累積平均獎勵
    DQN_cumulative_avg = sum(DQN_total_revenues) / (episode + 1)
    DQN_cumulative_average.append(DQN_cumulative_avg)
    print(f"Episode: {episode}, Total Revenue: {total_revenue}, Cumulative average: {DQN_cumulative_avg}")
# Out:
# ---------- Episode  0 -----------
# Episode: 0, Total Revenue: tensor([47150], device='cuda:0'), Cumulative average: [47150.]
# ---------- Episode  1 -----------
# Episode: 1, Total Revenue: tensor([50350], device='cuda:0'), Cumulative average: [48750.]
# ---------- Episode  2 -----------
# Episode: 2, Total Revenue: tensor([51500], device='cuda:0'), Cumulative average: [49666.66666667]
# ---------- Episode  3 -----------
# Episode: 3, Total Revenue: tensor([50100], device='cuda:0'), Cumulative average: [49775.]
# ---------- Episode  4 -----------
# Episode: 4, Total Revenue: tensor([49100], device='cuda:0'), Cumulative average: [49640.]
# ---------- Episode  5 -----------
# Episode: 5, Total Revenue: tensor([50300], device='cuda:0'), Cumulative average: [49750.]
# ---------- Episode  6 -----------
# Episode: 6, Total Revenue: tensor([51450], device='cuda:0'), Cumulative average: [49992.85714286]
# ---------- Episode  7 -----------
# Episode: 7, Total Revenue: tensor([50150], device='cuda:0'), Cumulative average: [50012.5]
# ---------- Episode  8 -----------
# Episode: 8, Total Revenue: tensor([49550], device='cuda:0'), Cumulative average: [49961.11111111]
# ---------- Episode  9 -----------
# Episode: 9, Total Revenue: tensor([50150], device='cuda:0'), Cumulative average: [49980.]
# ---------- Episode  10 -----------
# Episode: 10, Total Revenue: tensor([50350], device='cuda:0'), Cumulative average: [50013.63636364]
# ---------- Episode  11 -----------
# Episode: 11, Total Revenue: tensor([52450], device='cuda:0'), Cumulative average: [50216.66666667]
# ---------- Episode  12 -----------
# Episode: 12, Total Revenue: tensor([49200], device='cuda:0'), Cumulative average: [50138.46153846]
# ---------- Episode  13 -----------
# Episode: 13, Total Revenue: tensor([49600], device='cuda:0'), Cumulative average: [50100.]
# ---------- Episode  14 -----------
# Episode: 14, Total Revenue: tensor([49850], device='cuda:0'), Cumulative average: [50083.33333333]
# ---------- Episode  15 -----------
# Episode: 15, Total Revenue: tensor([50300], device='cuda:0'), Cumulative average: [50096.875]
# ---------- Episode  16 -----------
# Episode: 16, Total Revenue: tensor([50250], device='cuda:0'), Cumulative average: [50105.88235294]
# ---------- Episode  17 -----------
# Episode: 17, Total Revenue: tensor([50600], device='cuda:0'), Cumulative average: [50133.33333333]
# ---------- Episode  18 -----------
# Episode: 18, Total Revenue: tensor([49550], device='cuda:0'), Cumulative average: [50102.63157895]
# ---------- Episode  19 -----------
# Episode: 19, Total Revenue: tensor([52500], device='cuda:0'), Cumulative average: [50222.5]
# ---------- Episode  20 -----------
# Episode: 20, Total Revenue: tensor([51300], device='cuda:0'), Cumulative average: [50273.80952381]
# ---------- Episode  21 -----------
# Episode: 21, Total Revenue: tensor([50950], device='cuda:0'), Cumulative average: [50304.54545455]
# ---------- Episode  22 -----------
# Episode: 22, Total Revenue: tensor([49750], device='cuda:0'), Cumulative average: [50280.43478261]
# ---------- Episode  23 -----------
# Episode: 23, Total Revenue: tensor([49850], device='cuda:0'), Cumulative average: [50262.5]
# ---------- Episode  24 -----------
# Episode: 24, Total Revenue: tensor([48600], device='cuda:0'), Cumulative average: [50196.]
# ---------- Episode  25 -----------
# Episode: 25, Total Revenue: tensor([51050], device='cuda:0'), Cumulative average: [50228.84615385]
# ---------- Episode  26 -----------
# Episode: 26, Total Revenue: tensor([51750], device='cuda:0'), Cumulative average: [50285.18518519]
# ---------- Episode  27 -----------
# Episode: 27, Total Revenue: tensor([49750], device='cuda:0'), Cumulative average: [50266.07142857]
# ---------- Episode  28 -----------
# Episode: 28, Total Revenue: tensor([50050], device='cuda:0'), Cumulative average: [50258.62068966]
# ---------- Episode  29 -----------
# Episode: 29, Total Revenue: tensor([49550], device='cuda:0'), Cumulative average: [50235.]
# ---------- Episode  30 -----------
# Episode: 30, Total Revenue: tensor([49300], device='cuda:0'), Cumulative average: [50204.83870968]
# ---------- Episode  31 -----------
# Episode: 31, Total Revenue: tensor([50250], device='cuda:0'), Cumulative average: [50206.25]
# ---------- Episode  32 -----------
# Episode: 32, Total Revenue: tensor([51550], device='cuda:0'), Cumulative average: [50246.96969697]
# ---------- Episode  33 -----------
# Episode: 33, Total Revenue: tensor([51400], device='cuda:0'), Cumulative average: [50280.88235294]
# ---------- Episode  34 -----------
# Episode: 34, Total Revenue: tensor([50650], device='cuda:0'), Cumulative average: [50291.42857143]
# ---------- Episode  35 -----------
# Episode: 35, Total Revenue: tensor([51500], device='cuda:0'), Cumulative average: [50325.]
# ---------- Episode  36 -----------
# Episode: 36, Total Revenue: tensor([49650], device='cuda:0'), Cumulative average: [50306.75675676]
# ---------- Episode  37 -----------
# Episode: 37, Total Revenue: tensor([52650], device='cuda:0'), Cumulative average: [50368.42105263]
# ---------- Episode  38 -----------
# Episode: 38, Total Revenue: tensor([50900], device='cuda:0'), Cumulative average: [50382.05128205]
# ---------- Episode  39 -----------
# Episode: 39, Total Revenue: tensor([51050], device='cuda:0'), Cumulative average: [50398.75]
# ---------- Episode  40 -----------
# Episode: 40, Total Revenue: tensor([49800], device='cuda:0'), Cumulative average: [50384.14634146]
# ---------- Episode  41 -----------
# Episode: 41, Total Revenue: tensor([50400], device='cuda:0'), Cumulative average: [50384.52380952]
# ---------- Episode  42 -----------
# Episode: 42, Total Revenue: tensor([49350], device='cuda:0'), Cumulative average: [50360.46511628]
# ---------- Episode  43 -----------
# Episode: 43, Total Revenue: tensor([49950], device='cuda:0'), Cumulative average: [50351.13636364]
# ---------- Episode  44 -----------
# Episode: 44, Total Revenue: tensor([49850], device='cuda:0'), Cumulative average: [50340.]
# ---------- Episode  45 -----------
# Episode: 45, Total Revenue: tensor([49350], device='cuda:0'), Cumulative average: [50318.47826087]
# ---------- Episode  46 -----------
# Episode: 46, Total Revenue: tensor([51400], device='cuda:0'), Cumulative average: [50341.4893617]
# ---------- Episode  47 -----------
# Episode: 47, Total Revenue: tensor([49750], device='cuda:0'), Cumulative average: [50329.16666667]
# ---------- Episode  48 -----------
# Episode: 48, Total Revenue: tensor([50050], device='cuda:0'), Cumulative average: [50323.46938776]
# ---------- Episode  49 -----------
# Episode: 49, Total Revenue: tensor([50800], device='cuda:0'), Cumulative average: [50333.]
# ---------- Episode  50 -----------
# Episode: 50, Total Revenue: tensor([51400], device='cuda:0'), Cumulative average: [50353.92156863]
# ---------- Episode  51 -----------
# Episode: 51, Total Revenue: tensor([50600], device='cuda:0'), Cumulative average: [50358.65384615]
# ---------- Episode  52 -----------
# Episode: 52, Total Revenue: tensor([51150], device='cuda:0'), Cumulative average: [50373.58490566]
# ---------- Episode  53 -----------
# Episode: 53, Total Revenue: tensor([51100], device='cuda:0'), Cumulative average: [50387.03703704]
# ---------- Episode  54 -----------
# Episode: 54, Total Revenue: tensor([50400], device='cuda:0'), Cumulative average: [50387.27272727]
# ---------- Episode  55 -----------
# Episode: 55, Total Revenue: tensor([50650], device='cuda:0'), Cumulative average: [50391.96428571]
# ---------- Episode  56 -----------
# Episode: 56, Total Revenue: tensor([50550], device='cuda:0'), Cumulative average: [50394.73684211]
# ---------- Episode  57 -----------
# Episode: 57, Total Revenue: tensor([50900], device='cuda:0'), Cumulative average: [50403.44827586]
# ---------- Episode  58 -----------
# Episode: 58, Total Revenue: tensor([49250], device='cuda:0'), Cumulative average: [50383.89830508]
# ---------- Episode  59 -----------
# Episode: 59, Total Revenue: tensor([51700], device='cuda:0'), Cumulative average: [50405.83333333]
# ---------- Episode  60 -----------
# Episode: 60, Total Revenue: tensor([48400], device='cuda:0'), Cumulative average: [50372.95081967]
# ---------- Episode  61 -----------
# Episode: 61, Total Revenue: tensor([49750], device='cuda:0'), Cumulative average: [50362.90322581]
# ---------- Episode  62 -----------
# Episode: 62, Total Revenue: tensor([49350], device='cuda:0'), Cumulative average: [50346.82539683]
# ---------- Episode  63 -----------
# Episode: 63, Total Revenue: tensor([49150], device='cuda:0'), Cumulative average: [50328.125]
# ---------- Episode  64 -----------
# Episode: 64, Total Revenue: tensor([53700], device='cuda:0'), Cumulative average: [50380.]
# ---------- Episode  65 -----------
# Episode: 65, Total Revenue: tensor([50850], device='cuda:0'), Cumulative average: [50387.12121212]
# ---------- Episode  66 -----------
# Episode: 66, Total Revenue: tensor([50800], device='cuda:0'), Cumulative average: [50393.28358209]
# ---------- Episode  67 -----------
# Episode: 67, Total Revenue: tensor([49150], device='cuda:0'), Cumulative average: [50375.]
# ---------- Episode  68 -----------
# Episode: 68, Total Revenue: tensor([48950], device='cuda:0'), Cumulative average: [50354.34782609]
# ---------- Episode  69 -----------
# Episode: 69, Total Revenue: tensor([50300], device='cuda:0'), Cumulative average: [50353.57142857]
# ---------- Episode  70 -----------
# Episode: 70, Total Revenue: tensor([52800], device='cuda:0'), Cumulative average: [50388.02816901]
# ---------- Episode  71 -----------
# Episode: 71, Total Revenue: tensor([50450], device='cuda:0'), Cumulative average: [50388.88888889]
# ---------- Episode  72 -----------
# Episode: 72, Total Revenue: tensor([51050], device='cuda:0'), Cumulative average: [50397.94520548]
# ---------- Episode  73 -----------
# Episode: 73, Total Revenue: tensor([48850], device='cuda:0'), Cumulative average: [50377.02702703]
# ---------- Episode  74 -----------
# Episode: 74, Total Revenue: tensor([49650], device='cuda:0'), Cumulative average: [50367.33333333]
# ---------- Episode  75 -----------
# Episode: 75, Total Revenue: tensor([50550], device='cuda:0'), Cumulative average: [50369.73684211]
# ---------- Episode  76 -----------
# Episode: 76, Total Revenue: tensor([50800], device='cuda:0'), Cumulative average: [50375.32467532]
# ---------- Episode  77 -----------
# Episode: 77, Total Revenue: tensor([51350], device='cuda:0'), Cumulative average: [50387.82051282]
# ---------- Episode  78 -----------
# Episode: 78, Total Revenue: tensor([50500], device='cuda:0'), Cumulative average: [50389.24050633]
# ---------- Episode  79 -----------
# Episode: 79, Total Revenue: tensor([50350], device='cuda:0'), Cumulative average: [50388.75]
# ---------- Episode  80 -----------
# Episode: 80, Total Revenue: tensor([49200], device='cuda:0'), Cumulative average: [50374.07407407]
# ---------- Episode  81 -----------
# Episode: 81, Total Revenue: tensor([49500], device='cuda:0'), Cumulative average: [50363.41463415]
# ---------- Episode  82 -----------
# Episode: 82, Total Revenue: tensor([51500], device='cuda:0'), Cumulative average: [50377.10843373]
# ---------- Episode  83 -----------
# Episode: 83, Total Revenue: tensor([50800], device='cuda:0'), Cumulative average: [50382.14285714]
# ---------- Episode  84 -----------
# Episode: 84, Total Revenue: tensor([50150], device='cuda:0'), Cumulative average: [50379.41176471]
# ---------- Episode  85 -----------
# Episode: 85, Total Revenue: tensor([51900], device='cuda:0'), Cumulative average: [50397.09302326]
# ---------- Episode  86 -----------
# Episode: 86, Total Revenue: tensor([51200], device='cuda:0'), Cumulative average: [50406.32183908]
# ---------- Episode  87 -----------
# Episode: 87, Total Revenue: tensor([49950], device='cuda:0'), Cumulative average: [50401.13636364]
# ---------- Episode  88 -----------
# Episode: 88, Total Revenue: tensor([52750], device='cuda:0'), Cumulative average: [50427.52808989]
# ---------- Episode  89 -----------
# Episode: 89, Total Revenue: tensor([50250], device='cuda:0'), Cumulative average: [50425.55555556]
# ---------- Episode  90 -----------
# Episode: 90, Total Revenue: tensor([50500], device='cuda:0'), Cumulative average: [50426.37362637]
# ---------- Episode  91 -----------
# Episode: 91, Total Revenue: tensor([51350], device='cuda:0'), Cumulative average: [50436.41304348]
# ---------- Episode  92 -----------
# Episode: 92, Total Revenue: tensor([51050], device='cuda:0'), Cumulative average: [50443.01075269]
# ---------- Episode  93 -----------
# Episode: 93, Total Revenue: tensor([51800], device='cuda:0'), Cumulative average: [50457.44680851]
# ---------- Episode  94 -----------
# Episode: 94, Total Revenue: tensor([51200], device='cuda:0'), Cumulative average: [50465.26315789]
# ---------- Episode  95 -----------
# Episode: 95, Total Revenue: tensor([51150], device='cuda:0'), Cumulative average: [50472.39583333]
# ---------- Episode  96 -----------
# Episode: 96, Total Revenue: tensor([51000], device='cuda:0'), Cumulative average: [50477.83505155]
# ---------- Episode  97 -----------
# Episode: 97, Total Revenue: tensor([51150], device='cuda:0'), Cumulative average: [50484.69387755]
# ---------- Episode  98 -----------
# Episode: 98, Total Revenue: tensor([50950], device='cuda:0'), Cumulative average: [50489.39393939]
# ---------- Episode  99 -----------
# Episode: 99, Total Revenue: tensor([53950], device='cuda:0'), Cumulative average: [50524.]
# ---------- Episode  100 -----------
# Episode: 100, Total Revenue: tensor([54200], device='cuda:0'), Cumulative average: [50560.3960396]
# ---------- Episode  101 -----------
# Episode: 101, Total Revenue: tensor([52650], device='cuda:0'), Cumulative average: [50580.88235294]
# ---------- Episode  102 -----------
# Episode: 102, Total Revenue: tensor([50550], device='cuda:0'), Cumulative average: [50580.58252427]
# ---------- Episode  103 -----------
# Episode: 103, Total Revenue: tensor([49550], device='cuda:0'), Cumulative average: [50570.67307692]
# ---------- Episode  104 -----------
# Episode: 104, Total Revenue: tensor([49700], device='cuda:0'), Cumulative average: [50562.38095238]
# ---------- Episode  105 -----------
# Episode: 105, Total Revenue: tensor([50500], device='cuda:0'), Cumulative average: [50561.79245283]
# ---------- Episode  106 -----------
# Episode: 106, Total Revenue: tensor([49800], device='cuda:0'), Cumulative average: [50554.6728972]
# ---------- Episode  107 -----------
# Episode: 107, Total Revenue: tensor([49800], device='cuda:0'), Cumulative average: [50547.68518519]
# ---------- Episode  108 -----------
# Episode: 108, Total Revenue: tensor([48850], device='cuda:0'), Cumulative average: [50532.11009174]
# ---------- Episode  109 -----------
# Episode: 109, Total Revenue: tensor([50000], device='cuda:0'), Cumulative average: [50527.27272727]
# ---------- Episode  110 -----------
# Episode: 110, Total Revenue: tensor([55300], device='cuda:0'), Cumulative average: [50570.27027027]
# ---------- Episode  111 -----------
# Episode: 111, Total Revenue: tensor([50000], device='cuda:0'), Cumulative average: [50565.17857143]
# ---------- Episode  112 -----------
# Episode: 112, Total Revenue: tensor([49450], device='cuda:0'), Cumulative average: [50555.30973451]
# ---------- Episode  113 -----------
# Episode: 113, Total Revenue: tensor([49750], device='cuda:0'), Cumulative average: [50548.24561404]
# ---------- Episode  114 -----------
# Episode: 114, Total Revenue: tensor([49750], device='cuda:0'), Cumulative average: [50541.30434783]
# ---------- Episode  115 -----------
# Episode: 115, Total Revenue: tensor([49900], device='cuda:0'), Cumulative average: [50535.77586207]
# ---------- Episode  116 -----------
# Episode: 116, Total Revenue: tensor([49900], device='cuda:0'), Cumulative average: [50530.34188034]
# ---------- Episode  117 -----------
# Episode: 117, Total Revenue: tensor([49500], device='cuda:0'), Cumulative average: [50521.61016949]
# ---------- Episode  118 -----------
# Episode: 118, Total Revenue: tensor([50400], device='cuda:0'), Cumulative average: [50520.58823529]
# ---------- Episode  119 -----------
# Episode: 119, Total Revenue: tensor([52400], device='cuda:0'), Cumulative average: [50536.25]
# ---------- Episode  120 -----------
# Episode: 120, Total Revenue: tensor([51700], device='cuda:0'), Cumulative average: [50545.8677686]
# ---------- Episode  121 -----------
# Episode: 121, Total Revenue: tensor([49400], device='cuda:0'), Cumulative average: [50536.47540984]
# ---------- Episode  122 -----------
# Episode: 122, Total Revenue: tensor([52000], device='cuda:0'), Cumulative average: [50548.37398374]
# ---------- Episode  123 -----------
# Episode: 123, Total Revenue: tensor([48250], device='cuda:0'), Cumulative average: [50529.83870968]
# ---------- Episode  124 -----------
# Episode: 124, Total Revenue: tensor([49500], device='cuda:0'), Cumulative average: [50521.6]
# ---------- Episode  125 -----------
# Episode: 125, Total Revenue: tensor([50500], device='cuda:0'), Cumulative average: [50521.42857143]
# ---------- Episode  126 -----------
# Episode: 126, Total Revenue: tensor([51200], device='cuda:0'), Cumulative average: [50526.77165354]
# ---------- Episode  127 -----------
# Episode: 127, Total Revenue: tensor([50000], device='cuda:0'), Cumulative average: [50522.65625]
# ---------- Episode  128 -----------
# Episode: 128, Total Revenue: tensor([50000], device='cuda:0'), Cumulative average: [50518.60465116]
# ---------- Episode  129 -----------
# Episode: 129, Total Revenue: tensor([53700], device='cuda:0'), Cumulative average: [50543.07692308]
# ---------- Episode  130 -----------
# Episode: 130, Total Revenue: tensor([51300], device='cuda:0'), Cumulative average: [50548.85496183]
# ---------- Episode  131 -----------
# Episode: 131, Total Revenue: tensor([50850], device='cuda:0'), Cumulative average: [50551.13636364]
# ---------- Episode  132 -----------
# Episode: 132, Total Revenue: tensor([48900], device='cuda:0'), Cumulative average: [50538.72180451]
# ---------- Episode  133 -----------
# Episode: 133, Total Revenue: tensor([50550], device='cuda:0'), Cumulative average: [50538.80597015]
# ---------- Episode  134 -----------
# Episode: 134, Total Revenue: tensor([50850], device='cuda:0'), Cumulative average: [50541.11111111]
# ---------- Episode  135 -----------
# Episode: 135, Total Revenue: tensor([51500], device='cuda:0'), Cumulative average: [50548.16176471]
# ---------- Episode  136 -----------
# Episode: 136, Total Revenue: tensor([50700], device='cuda:0'), Cumulative average: [50549.27007299]
# ---------- Episode  137 -----------
# Episode: 137, Total Revenue: tensor([53300], device='cuda:0'), Cumulative average: [50569.20289855]
# ---------- Episode  138 -----------
# Episode: 138, Total Revenue: tensor([50250], device='cuda:0'), Cumulative average: [50566.90647482]
# ---------- Episode  139 -----------
# Episode: 139, Total Revenue: tensor([50650], device='cuda:0'), Cumulative average: [50567.5]
# ---------- Episode  140 -----------
# Episode: 140, Total Revenue: tensor([49900], device='cuda:0'), Cumulative average: [50562.76595745]
# ---------- Episode  141 -----------
# Episode: 141, Total Revenue: tensor([49100], device='cuda:0'), Cumulative average: [50552.46478873]
# ---------- Episode  142 -----------
# Episode: 142, Total Revenue: tensor([52550], device='cuda:0'), Cumulative average: [50566.43356643]
# ---------- Episode  143 -----------
# Episode: 143, Total Revenue: tensor([50000], device='cuda:0'), Cumulative average: [50562.5]
# ---------- Episode  144 -----------
# Episode: 144, Total Revenue: tensor([49050], device='cuda:0'), Cumulative average: [50552.06896552]
# ---------- Episode  145 -----------
# Episode: 145, Total Revenue: tensor([50700], device='cuda:0'), Cumulative average: [50553.08219178]
# ---------- Episode  146 -----------
# Episode: 146, Total Revenue: tensor([50100], device='cuda:0'), Cumulative average: [50550.]
# ---------- Episode  147 -----------
# Episode: 147, Total Revenue: tensor([48550], device='cuda:0'), Cumulative average: [50536.48648649]
# ---------- Episode  148 -----------
# Episode: 148, Total Revenue: tensor([50800], device='cuda:0'), Cumulative average: [50538.25503356]
# ---------- Episode  149 -----------
# Episode: 149, Total Revenue: tensor([50300], device='cuda:0'), Cumulative average: [50536.66666667]
# ---------- Episode  150 -----------
# Episode: 150, Total Revenue: tensor([49100], device='cuda:0'), Cumulative average: [50527.15231788]
# ---------- Episode  151 -----------
# Episode: 151, Total Revenue: tensor([50500], device='cuda:0'), Cumulative average: [50526.97368421]
# ---------- Episode  152 -----------
# Episode: 152, Total Revenue: tensor([49450], device='cuda:0'), Cumulative average: [50519.93464052]
# ---------- Episode  153 -----------
# Episode: 153, Total Revenue: tensor([50100], device='cuda:0'), Cumulative average: [50517.20779221]
# ---------- Episode  154 -----------
# Episode: 154, Total Revenue: tensor([51600], device='cuda:0'), Cumulative average: [50524.19354839]
# ---------- Episode  155 -----------
# Episode: 155, Total Revenue: tensor([49900], device='cuda:0'), Cumulative average: [50520.19230769]
# ---------- Episode  156 -----------
# Episode: 156, Total Revenue: tensor([49700], device='cuda:0'), Cumulative average: [50514.96815287]
# ---------- Episode  157 -----------
# Episode: 157, Total Revenue: tensor([50300], device='cuda:0'), Cumulative average: [50513.60759494]
# ---------- Episode  158 -----------
# Episode: 158, Total Revenue: tensor([50100], device='cuda:0'), Cumulative average: [50511.00628931]
# ---------- Episode  159 -----------
# Episode: 159, Total Revenue: tensor([51100], device='cuda:0'), Cumulative average: [50514.6875]
# ---------- Episode  160 -----------
# Episode: 160, Total Revenue: tensor([49400], device='cuda:0'), Cumulative average: [50507.76397516]
# ---------- Episode  161 -----------
# Episode: 161, Total Revenue: tensor([49900], device='cuda:0'), Cumulative average: [50504.01234568]
# ---------- Episode  162 -----------
# Episode: 162, Total Revenue: tensor([50550], device='cuda:0'), Cumulative average: [50504.29447853]
# ---------- Episode  163 -----------
# Episode: 163, Total Revenue: tensor([49450], device='cuda:0'), Cumulative average: [50497.86585366]
# ---------- Episode  164 -----------
# Episode: 164, Total Revenue: tensor([50200], device='cuda:0'), Cumulative average: [50496.06060606]
# ---------- Episode  165 -----------
# Episode: 165, Total Revenue: tensor([50750], device='cuda:0'), Cumulative average: [50497.59036145]
# ---------- Episode  166 -----------
# Episode: 166, Total Revenue: tensor([52850], device='cuda:0'), Cumulative average: [50511.67664671]
# ---------- Episode  167 -----------
# Episode: 167, Total Revenue: tensor([52350], device='cuda:0'), Cumulative average: [50522.61904762]
# ---------- Episode  168 -----------
# Episode: 168, Total Revenue: tensor([51150], device='cuda:0'), Cumulative average: [50526.33136095]
# ---------- Episode  169 -----------
# Episode: 169, Total Revenue: tensor([53050], device='cuda:0'), Cumulative average: [50541.17647059]
# ---------- Episode  170 -----------
# Episode: 170, Total Revenue: tensor([50900], device='cuda:0'), Cumulative average: [50543.2748538]
# ---------- Episode  171 -----------
# Episode: 171, Total Revenue: tensor([50150], device='cuda:0'), Cumulative average: [50540.98837209]
# ---------- Episode  172 -----------
# Episode: 172, Total Revenue: tensor([50500], device='cuda:0'), Cumulative average: [50540.75144509]
# ---------- Episode  173 -----------
# Episode: 173, Total Revenue: tensor([49300], device='cuda:0'), Cumulative average: [50533.62068966]
# ---------- Episode  174 -----------
# Episode: 174, Total Revenue: tensor([52450], device='cuda:0'), Cumulative average: [50544.57142857]
# ---------- Episode  175 -----------
# Episode: 175, Total Revenue: tensor([50350], device='cuda:0'), Cumulative average: [50543.46590909]
# ---------- Episode  176 -----------
# Episode: 176, Total Revenue: tensor([51400], device='cuda:0'), Cumulative average: [50548.30508475]
# ---------- Episode  177 -----------
# Episode: 177, Total Revenue: tensor([49950], device='cuda:0'), Cumulative average: [50544.94382022]
# ---------- Episode  178 -----------
# Episode: 178, Total Revenue: tensor([51000], device='cuda:0'), Cumulative average: [50547.48603352]
# ---------- Episode  179 -----------
# Episode: 179, Total Revenue: tensor([49600], device='cuda:0'), Cumulative average: [50542.22222222]
# ---------- Episode  180 -----------
# Episode: 180, Total Revenue: tensor([49900], device='cuda:0'), Cumulative average: [50538.67403315]
# ---------- Episode  181 -----------
# Episode: 181, Total Revenue: tensor([50450], device='cuda:0'), Cumulative average: [50538.18681319]
# ---------- Episode  182 -----------
# Episode: 182, Total Revenue: tensor([50700], device='cuda:0'), Cumulative average: [50539.07103825]
# ---------- Episode  183 -----------
# Episode: 183, Total Revenue: tensor([50550], device='cuda:0'), Cumulative average: [50539.13043478]
# ---------- Episode  184 -----------
# Episode: 184, Total Revenue: tensor([49000], device='cuda:0'), Cumulative average: [50530.81081081]
# ---------- Episode  185 -----------
# Episode: 185, Total Revenue: tensor([50700], device='cuda:0'), Cumulative average: [50531.72043011]
# ---------- Episode  186 -----------
# Episode: 186, Total Revenue: tensor([51350], device='cuda:0'), Cumulative average: [50536.09625668]
# ---------- Episode  187 -----------
# Episode: 187, Total Revenue: tensor([51550], device='cuda:0'), Cumulative average: [50541.4893617]
# ---------- Episode  188 -----------
# Episode: 188, Total Revenue: tensor([50100], device='cuda:0'), Cumulative average: [50539.15343915]
# ---------- Episode  189 -----------
# Episode: 189, Total Revenue: tensor([51900], device='cuda:0'), Cumulative average: [50546.31578947]
# ---------- Episode  190 -----------
# Episode: 190, Total Revenue: tensor([50400], device='cuda:0'), Cumulative average: [50545.54973822]
# ---------- Episode  191 -----------
# Episode: 191, Total Revenue: tensor([49450], device='cuda:0'), Cumulative average: [50539.84375]
# ---------- Episode  192 -----------
# Episode: 192, Total Revenue: tensor([50100], device='cuda:0'), Cumulative average: [50537.56476684]
# ---------- Episode  193 -----------
# Episode: 193, Total Revenue: tensor([49650], device='cuda:0'), Cumulative average: [50532.98969072]
# ---------- Episode  194 -----------
# Episode: 194, Total Revenue: tensor([49500], device='cuda:0'), Cumulative average: [50527.69230769]
# ---------- Episode  195 -----------
# Episode: 195, Total Revenue: tensor([54000], device='cuda:0'), Cumulative average: [50545.40816327]
# ---------- Episode  196 -----------
# Episode: 196, Total Revenue: tensor([50700], device='cuda:0'), Cumulative average: [50546.1928934]
# ---------- Episode  197 -----------
# Episode: 197, Total Revenue: tensor([50550], device='cuda:0'), Cumulative average: [50546.21212121]
# ---------- Episode  198 -----------
# Episode: 198, Total Revenue: tensor([51400], device='cuda:0'), Cumulative average: [50550.50251256]
# ---------- Episode  199 -----------
# Episode: 199, Total Revenue: tensor([50950], device='cuda:0'), Cumulative average: [50552.5]
# ---------- Episode  200 -----------
# Episode: 200, Total Revenue: tensor([51250], device='cuda:0'), Cumulative average: [50555.97014925]
# ---------- Episode  201 -----------
# Episode: 201, Total Revenue: tensor([49500], device='cuda:0'), Cumulative average: [50550.74257426]
# ---------- Episode  202 -----------
# Episode: 202, Total Revenue: tensor([49100], device='cuda:0'), Cumulative average: [50543.59605911]
# ---------- Episode  203 -----------
# Episode: 203, Total Revenue: tensor([51850], device='cuda:0'), Cumulative average: [50550.]
# ---------- Episode  204 -----------
# Episode: 204, Total Revenue: tensor([49950], device='cuda:0'), Cumulative average: [50547.07317073]
# ---------- Episode  205 -----------
# Episode: 205, Total Revenue: tensor([52000], device='cuda:0'), Cumulative average: [50554.12621359]
# ---------- Episode  206 -----------
# Episode: 206, Total Revenue: tensor([49750], device='cuda:0'), Cumulative average: [50550.24154589]
# ---------- Episode  207 -----------
# Episode: 207, Total Revenue: tensor([51900], device='cuda:0'), Cumulative average: [50556.73076923]
# ---------- Episode  208 -----------
# Episode: 208, Total Revenue: tensor([49300], device='cuda:0'), Cumulative average: [50550.71770335]
# ---------- Episode  209 -----------
# Episode: 209, Total Revenue: tensor([50150], device='cuda:0'), Cumulative average: [50548.80952381]
# ---------- Episode  210 -----------
# Episode: 210, Total Revenue: tensor([49400], device='cuda:0'), Cumulative average: [50543.36492891]
# ---------- Episode  211 -----------
# Episode: 211, Total Revenue: tensor([51900], device='cuda:0'), Cumulative average: [50549.76415094]
# ---------- Episode  212 -----------
# Episode: 212, Total Revenue: tensor([51500], device='cuda:0'), Cumulative average: [50554.22535211]
# ---------- Episode  213 -----------
# Episode: 213, Total Revenue: tensor([50600], device='cuda:0'), Cumulative average: [50554.43925234]
# ---------- Episode  214 -----------
# Episode: 214, Total Revenue: tensor([51350], device='cuda:0'), Cumulative average: [50558.13953488]
# ---------- Episode  215 -----------
# Episode: 215, Total Revenue: tensor([51400], device='cuda:0'), Cumulative average: [50562.03703704]
# ---------- Episode  216 -----------
# Episode: 216, Total Revenue: tensor([50050], device='cuda:0'), Cumulative average: [50559.67741935]
# ---------- Episode  217 -----------
# Episode: 217, Total Revenue: tensor([51250], device='cuda:0'), Cumulative average: [50562.8440367]
# ---------- Episode  218 -----------
# Episode: 218, Total Revenue: tensor([50000], device='cuda:0'), Cumulative average: [50560.2739726]
# ---------- Episode  219 -----------
# Episode: 219, Total Revenue: tensor([52500], device='cuda:0'), Cumulative average: [50569.09090909]
# ---------- Episode  220 -----------
# Episode: 220, Total Revenue: tensor([49350], device='cuda:0'), Cumulative average: [50563.57466063]
# ---------- Episode  221 -----------
# Episode: 221, Total Revenue: tensor([51250], device='cuda:0'), Cumulative average: [50566.66666667]
# ---------- Episode  222 -----------
# Episode: 222, Total Revenue: tensor([51300], device='cuda:0'), Cumulative average: [50569.95515695]
# ---------- Episode  223 -----------
# Episode: 223, Total Revenue: tensor([50200], device='cuda:0'), Cumulative average: [50568.30357143]
# ---------- Episode  224 -----------
# Episode: 224, Total Revenue: tensor([50900], device='cuda:0'), Cumulative average: [50569.77777778]
# ---------- Episode  225 -----------
# Episode: 225, Total Revenue: tensor([51050], device='cuda:0'), Cumulative average: [50571.90265487]
# ---------- Episode  226 -----------
# Episode: 226, Total Revenue: tensor([51700], device='cuda:0'), Cumulative average: [50576.8722467]
# ---------- Episode  227 -----------
# Episode: 227, Total Revenue: tensor([49400], device='cuda:0'), Cumulative average: [50571.71052632]
# ---------- Episode  228 -----------
# Episode: 228, Total Revenue: tensor([50050], device='cuda:0'), Cumulative average: [50569.43231441]
# ---------- Episode  229 -----------
# Episode: 229, Total Revenue: tensor([50300], device='cuda:0'), Cumulative average: [50568.26086957]
# ---------- Episode  230 -----------
# Episode: 230, Total Revenue: tensor([50150], device='cuda:0'), Cumulative average: [50566.45021645]
# ---------- Episode  231 -----------
# Episode: 231, Total Revenue: tensor([51050], device='cuda:0'), Cumulative average: [50568.53448276]
# ---------- Episode  232 -----------
# Episode: 232, Total Revenue: tensor([51400], device='cuda:0'), Cumulative average: [50572.10300429]
# ---------- Episode  233 -----------
# Episode: 233, Total Revenue: tensor([50400], device='cuda:0'), Cumulative average: [50571.36752137]
# ---------- Episode  234 -----------
# Episode: 234, Total Revenue: tensor([50100], device='cuda:0'), Cumulative average: [50569.36170213]
# ---------- Episode  235 -----------
# Episode: 235, Total Revenue: tensor([50850], device='cuda:0'), Cumulative average: [50570.55084746]
# ---------- Episode  236 -----------
# Episode: 236, Total Revenue: tensor([50250], device='cuda:0'), Cumulative average: [50569.19831224]
# ---------- Episode  237 -----------
# Episode: 237, Total Revenue: tensor([49900], device='cuda:0'), Cumulative average: [50566.38655462]
# ---------- Episode  238 -----------
# Episode: 238, Total Revenue: tensor([51200], device='cuda:0'), Cumulative average: [50569.0376569]
# ---------- Episode  239 -----------
# Episode: 239, Total Revenue: tensor([49800], device='cuda:0'), Cumulative average: [50565.83333333]
# ---------- Episode  240 -----------
# Episode: 240, Total Revenue: tensor([51800], device='cuda:0'), Cumulative average: [50570.95435685]
# ---------- Episode  241 -----------
# Episode: 241, Total Revenue: tensor([50150], device='cuda:0'), Cumulative average: [50569.21487603]
# ---------- Episode  242 -----------
# Episode: 242, Total Revenue: tensor([51200], device='cuda:0'), Cumulative average: [50571.81069959]
# ---------- Episode  243 -----------
# Episode: 243, Total Revenue: tensor([50200], device='cuda:0'), Cumulative average: [50570.28688525]
# ---------- Episode  244 -----------
# Episode: 244, Total Revenue: tensor([51100], device='cuda:0'), Cumulative average: [50572.44897959]
# ---------- Episode  245 -----------
# Episode: 245, Total Revenue: tensor([50050], device='cuda:0'), Cumulative average: [50570.32520325]
# ---------- Episode  246 -----------
# Episode: 246, Total Revenue: tensor([48550], device='cuda:0'), Cumulative average: [50562.14574899]
# ---------- Episode  247 -----------
# Episode: 247, Total Revenue: tensor([50250], device='cuda:0'), Cumulative average: [50560.88709677]
# ---------- Episode  248 -----------
# Episode: 248, Total Revenue: tensor([51400], device='cuda:0'), Cumulative average: [50564.25702811]
# ---------- Episode  249 -----------
# Episode: 249, Total Revenue: tensor([49750], device='cuda:0'), Cumulative average: [50561.]
# ---------- Episode  250 -----------
# Episode: 250, Total Revenue: tensor([50100], device='cuda:0'), Cumulative average: [50559.16334661]
# ---------- Episode  251 -----------
# Episode: 251, Total Revenue: tensor([49850], device='cuda:0'), Cumulative average: [50556.34920635]
# ---------- Episode  252 -----------
# Episode: 252, Total Revenue: tensor([50000], device='cuda:0'), Cumulative average: [50554.15019763]
# ---------- Episode  253 -----------
# Episode: 253, Total Revenue: tensor([50550], device='cuda:0'), Cumulative average: [50554.13385827]
# ---------- Episode  254 -----------
# Episode: 254, Total Revenue: tensor([49550], device='cuda:0'), Cumulative average: [50550.19607843]
# ---------- Episode  255 -----------
# Episode: 255, Total Revenue: tensor([48400], device='cuda:0'), Cumulative average: [50541.796875]
# ---------- Episode  256 -----------
# Episode: 256, Total Revenue: tensor([49700], device='cuda:0'), Cumulative average: [50538.52140078]
# ---------- Episode  257 -----------
# Episode: 257, Total Revenue: tensor([49700], device='cuda:0'), Cumulative average: [50535.27131783]
# ---------- Episode  258 -----------
# Episode: 258, Total Revenue: tensor([51400], device='cuda:0'), Cumulative average: [50538.61003861]
# ---------- Episode  259 -----------
# Episode: 259, Total Revenue: tensor([51300], device='cuda:0'), Cumulative average: [50541.53846154]
# ---------- Episode  260 -----------
# Episode: 260, Total Revenue: tensor([51200], device='cuda:0'), Cumulative average: [50544.06130268]
# ---------- Episode  261 -----------
# Episode: 261, Total Revenue: tensor([49800], device='cuda:0'), Cumulative average: [50541.22137405]
# ---------- Episode  262 -----------
# Episode: 262, Total Revenue: tensor([51650], device='cuda:0'), Cumulative average: [50545.43726236]
# ---------- Episode  263 -----------
# Episode: 263, Total Revenue: tensor([51350], device='cuda:0'), Cumulative average: [50548.48484848]
# ---------- Episode  264 -----------
# Episode: 264, Total Revenue: tensor([50150], device='cuda:0'), Cumulative average: [50546.98113208]
# ---------- Episode  265 -----------
# Episode: 265, Total Revenue: tensor([49400], device='cuda:0'), Cumulative average: [50542.66917293]
# ---------- Episode  266 -----------
# Episode: 266, Total Revenue: tensor([51150], device='cuda:0'), Cumulative average: [50544.94382022]
# ---------- Episode  267 -----------
# Episode: 267, Total Revenue: tensor([50350], device='cuda:0'), Cumulative average: [50544.21641791]
# ---------- Episode  268 -----------
# Episode: 268, Total Revenue: tensor([51750], device='cuda:0'), Cumulative average: [50548.69888476]
# ---------- Episode  269 -----------
# Episode: 269, Total Revenue: tensor([51700], device='cuda:0'), Cumulative average: [50552.96296296]
# ---------- Episode  270 -----------
# Episode: 270, Total Revenue: tensor([50100], device='cuda:0'), Cumulative average: [50551.29151292]
# ---------- Episode  271 -----------
# Episode: 271, Total Revenue: tensor([51800], device='cuda:0'), Cumulative average: [50555.88235294]
# ---------- Episode  272 -----------
# Episode: 272, Total Revenue: tensor([51100], device='cuda:0'), Cumulative average: [50557.87545788]
# ---------- Episode  273 -----------
# Episode: 273, Total Revenue: tensor([50300], device='cuda:0'), Cumulative average: [50556.93430657]
# ---------- Episode  274 -----------
# Episode: 274, Total Revenue: tensor([49250], device='cuda:0'), Cumulative average: [50552.18181818]
# ---------- Episode  275 -----------
# Episode: 275, Total Revenue: tensor([48250], device='cuda:0'), Cumulative average: [50543.84057971]
# ---------- Episode  276 -----------
# Episode: 276, Total Revenue: tensor([50850], device='cuda:0'), Cumulative average: [50544.94584838]
# ---------- Episode  277 -----------
# Episode: 277, Total Revenue: tensor([50700], device='cuda:0'), Cumulative average: [50545.50359712]
# ---------- Episode  278 -----------
# Episode: 278, Total Revenue: tensor([51300], device='cuda:0'), Cumulative average: [50548.2078853]
# ---------- Episode  279 -----------
# Episode: 279, Total Revenue: tensor([53150], device='cuda:0'), Cumulative average: [50557.5]
# ---------- Episode  280 -----------
# Episode: 280, Total Revenue: tensor([48600], device='cuda:0'), Cumulative average: [50550.53380783]
# ---------- Episode  281 -----------
# Episode: 281, Total Revenue: tensor([49800], device='cuda:0'), Cumulative average: [50547.87234043]
# ---------- Episode  282 -----------
# Episode: 282, Total Revenue: tensor([54550], device='cuda:0'), Cumulative average: [50562.01413428]
# ---------- Episode  283 -----------
# Episode: 283, Total Revenue: tensor([49850], device='cuda:0'), Cumulative average: [50559.50704225]
# ---------- Episode  284 -----------
# Episode: 284, Total Revenue: tensor([49450], device='cuda:0'), Cumulative average: [50555.61403509]
# ---------- Episode  285 -----------
# Episode: 285, Total Revenue: tensor([53700], device='cuda:0'), Cumulative average: [50566.60839161]
# ---------- Episode  286 -----------
# Episode: 286, Total Revenue: tensor([50900], device='cuda:0'), Cumulative average: [50567.77003484]
# ---------- Episode  287 -----------
# Episode: 287, Total Revenue: tensor([50700], device='cuda:0'), Cumulative average: [50568.22916667]
# ---------- Episode  288 -----------
# Episode: 288, Total Revenue: tensor([50650], device='cuda:0'), Cumulative average: [50568.51211073]
# ---------- Episode  289 -----------
# Episode: 289, Total Revenue: tensor([48850], device='cuda:0'), Cumulative average: [50562.5862069]
# ---------- Episode  290 -----------
# Episode: 290, Total Revenue: tensor([49450], device='cuda:0'), Cumulative average: [50558.7628866]
# ---------- Episode  291 -----------
# Episode: 291, Total Revenue: tensor([49200], device='cuda:0'), Cumulative average: [50554.10958904]
# ---------- Episode  292 -----------
# Episode: 292, Total Revenue: tensor([50950], device='cuda:0'), Cumulative average: [50555.46075085]
# ---------- Episode  293 -----------
# Episode: 293, Total Revenue: tensor([49550], device='cuda:0'), Cumulative average: [50552.04081633]
# ---------- Episode  294 -----------
# Episode: 294, Total Revenue: tensor([49750], device='cuda:0'), Cumulative average: [50549.3220339]
# ---------- Episode  295 -----------
# Episode: 295, Total Revenue: tensor([48450], device='cuda:0'), Cumulative average: [50542.22972973]
# ---------- Episode  296 -----------
# Episode: 296, Total Revenue: tensor([49000], device='cuda:0'), Cumulative average: [50537.03703704]
# ---------- Episode  297 -----------
# Episode: 297, Total Revenue: tensor([49450], device='cuda:0'), Cumulative average: [50533.38926174]
# ---------- Episode  298 -----------
# Episode: 298, Total Revenue: tensor([52100], device='cuda:0'), Cumulative average: [50538.62876254]
# ---------- Episode  299 -----------
# Episode: 299, Total Revenue: tensor([50400], device='cuda:0'), Cumulative average: [50538.16666667]
# ---------- Episode  300 -----------
# Episode: 300, Total Revenue: tensor([49000], device='cuda:0'), Cumulative average: [50533.05647841]
# ---------- Episode  301 -----------
# Episode: 301, Total Revenue: tensor([51100], device='cuda:0'), Cumulative average: [50534.93377483]
# ---------- Episode  302 -----------
# Episode: 302, Total Revenue: tensor([50000], device='cuda:0'), Cumulative average: [50533.16831683]
# ---------- Episode  303 -----------
# Episode: 303, Total Revenue: tensor([50300], device='cuda:0'), Cumulative average: [50532.40131579]
# ---------- Episode  304 -----------
# Episode: 304, Total Revenue: tensor([48500], device='cuda:0'), Cumulative average: [50525.73770492]
# ---------- Episode  305 -----------
# Episode: 305, Total Revenue: tensor([50700], device='cuda:0'), Cumulative average: [50526.30718954]
# ---------- Episode  306 -----------
# Episode: 306, Total Revenue: tensor([49350], device='cuda:0'), Cumulative average: [50522.47557003]
# ---------- Episode  307 -----------
# Episode: 307, Total Revenue: tensor([48750], device='cuda:0'), Cumulative average: [50516.72077922]
# ---------- Episode  308 -----------
# Episode: 308, Total Revenue: tensor([50100], device='cuda:0'), Cumulative average: [50515.37216828]
# ---------- Episode  309 -----------
# Episode: 309, Total Revenue: tensor([49600], device='cuda:0'), Cumulative average: [50512.41935484]
# ---------- Episode  310 -----------
# Episode: 310, Total Revenue: tensor([49000], device='cuda:0'), Cumulative average: [50507.5562701]
# ---------- Episode  311 -----------
# Episode: 311, Total Revenue: tensor([49750], device='cuda:0'), Cumulative average: [50505.12820513]
# ---------- Episode  312 -----------
# Episode: 312, Total Revenue: tensor([52150], device='cuda:0'), Cumulative average: [50510.38338658]
# ---------- Episode  313 -----------
# Episode: 313, Total Revenue: tensor([49950], device='cuda:0'), Cumulative average: [50508.59872611]
# ---------- Episode  314 -----------
# Episode: 314, Total Revenue: tensor([50800], device='cuda:0'), Cumulative average: [50509.52380952]
# ---------- Episode  315 -----------
# Episode: 315, Total Revenue: tensor([53250], device='cuda:0'), Cumulative average: [50518.19620253]
# ---------- Episode  316 -----------
# Episode: 316, Total Revenue: tensor([45500], device='cuda:0'), Cumulative average: [50502.3659306]
# ---------- Episode  317 -----------
# Episode: 317, Total Revenue: tensor([50800], device='cuda:0'), Cumulative average: [50503.30188679]
# ---------- Episode  318 -----------
# Episode: 318, Total Revenue: tensor([49700], device='cuda:0'), Cumulative average: [50500.78369906]
# ---------- Episode  319 -----------
# Episode: 319, Total Revenue: tensor([49650], device='cuda:0'), Cumulative average: [50498.125]
# ---------- Episode  320 -----------
# Episode: 320, Total Revenue: tensor([50650], device='cuda:0'), Cumulative average: [50498.59813084]
# ---------- Episode  321 -----------
# Episode: 321, Total Revenue: tensor([51700], device='cuda:0'), Cumulative average: [50502.32919255]
# ---------- Episode  322 -----------
# Episode: 322, Total Revenue: tensor([50400], device='cuda:0'), Cumulative average: [50502.0123839]
# ---------- Episode  323 -----------
# Episode: 323, Total Revenue: tensor([51750], device='cuda:0'), Cumulative average: [50505.86419753]
# ---------- Episode  324 -----------
# Episode: 324, Total Revenue: tensor([50700], device='cuda:0'), Cumulative average: [50506.46153846]
# ---------- Episode  325 -----------
# Episode: 325, Total Revenue: tensor([49900], device='cuda:0'), Cumulative average: [50504.60122699]
# ---------- Episode  326 -----------
# Episode: 326, Total Revenue: tensor([48950], device='cuda:0'), Cumulative average: [50499.8470948]
# ---------- Episode  327 -----------
# Episode: 327, Total Revenue: tensor([51950], device='cuda:0'), Cumulative average: [50504.26829268]
# ---------- Episode  328 -----------
# Episode: 328, Total Revenue: tensor([50600], device='cuda:0'), Cumulative average: [50504.55927052]
# ---------- Episode  329 -----------
# Episode: 329, Total Revenue: tensor([50950], device='cuda:0'), Cumulative average: [50505.90909091]
# ---------- Episode  330 -----------
# Episode: 330, Total Revenue: tensor([53500], device='cuda:0'), Cumulative average: [50514.95468278]
# ---------- Episode  331 -----------
# Episode: 331, Total Revenue: tensor([49550], device='cuda:0'), Cumulative average: [50512.04819277]
# ---------- Episode  332 -----------
# Episode: 332, Total Revenue: tensor([50050], device='cuda:0'), Cumulative average: [50510.66066066]
# ---------- Episode  333 -----------
# Episode: 333, Total Revenue: tensor([49400], device='cuda:0'), Cumulative average: [50507.33532934]
# ---------- Episode  334 -----------
# Episode: 334, Total Revenue: tensor([51350], device='cuda:0'), Cumulative average: [50509.85074627]
# ---------- Episode  335 -----------
# Episode: 335, Total Revenue: tensor([52350], device='cuda:0'), Cumulative average: [50515.32738095]
# ---------- Episode  336 -----------
# Episode: 336, Total Revenue: tensor([51200], device='cuda:0'), Cumulative average: [50517.35905045]
# ---------- Episode  337 -----------
# Episode: 337, Total Revenue: tensor([49400], device='cuda:0'), Cumulative average: [50514.05325444]
# ---------- Episode  338 -----------
# Episode: 338, Total Revenue: tensor([51300], device='cuda:0'), Cumulative average: [50516.37168142]
# ---------- Episode  339 -----------
# Episode: 339, Total Revenue: tensor([50750], device='cuda:0'), Cumulative average: [50517.05882353]
# ---------- Episode  340 -----------
# Episode: 340, Total Revenue: tensor([52500], device='cuda:0'), Cumulative average: [50522.87390029]
# ---------- Episode  341 -----------
# Episode: 341, Total Revenue: tensor([49800], device='cuda:0'), Cumulative average: [50520.76023392]
# ---------- Episode  342 -----------
# Episode: 342, Total Revenue: tensor([52550], device='cuda:0'), Cumulative average: [50526.67638484]
# ---------- Episode  343 -----------
# Episode: 343, Total Revenue: tensor([49550], device='cuda:0'), Cumulative average: [50523.8372093]
# ---------- Episode  344 -----------
# Episode: 344, Total Revenue: tensor([48000], device='cuda:0'), Cumulative average: [50516.52173913]
# ---------- Episode  345 -----------
# Episode: 345, Total Revenue: tensor([50450], device='cuda:0'), Cumulative average: [50516.32947977]
# ---------- Episode  346 -----------
# Episode: 346, Total Revenue: tensor([50500], device='cuda:0'), Cumulative average: [50516.28242075]
# ---------- Episode  347 -----------
# Episode: 347, Total Revenue: tensor([51150], device='cuda:0'), Cumulative average: [50518.10344828]
# ---------- Episode  348 -----------
# Episode: 348, Total Revenue: tensor([50900], device='cuda:0'), Cumulative average: [50519.19770774]
# ---------- Episode  349 -----------
# Episode: 349, Total Revenue: tensor([52100], device='cuda:0'), Cumulative average: [50523.71428571]
# ---------- Episode  350 -----------
# Episode: 350, Total Revenue: tensor([50400], device='cuda:0'), Cumulative average: [50523.36182336]
# ---------- Episode  351 -----------
# Episode: 351, Total Revenue: tensor([52100], device='cuda:0'), Cumulative average: [50527.84090909]
# ---------- Episode  352 -----------
# Episode: 352, Total Revenue: tensor([49350], device='cuda:0'), Cumulative average: [50524.50424929]
# ---------- Episode  353 -----------
# Episode: 353, Total Revenue: tensor([51550], device='cuda:0'), Cumulative average: [50527.40112994]
# ---------- Episode  354 -----------
# Episode: 354, Total Revenue: tensor([52150], device='cuda:0'), Cumulative average: [50531.97183099]
# ---------- Episode  355 -----------
# Episode: 355, Total Revenue: tensor([50150], device='cuda:0'), Cumulative average: [50530.8988764]
# ---------- Episode  356 -----------
# ...
# ------- step  71  ---------
# Action: 5, state: tensor([[24., 71.]], device='cuda:0')
# seat_open:  YK
# random_number: 0.6016497298711968, customer_index: 4, customer_type: Leis2
# customer type:  Leis2
# preference seats:  ['K']
# chosen seat:  K
# observation:  [[23. 70.]] reward:  450 departure:  False
# ------- step  70  ---------
# Action: 5, state: tensor([[23., 70.]], device='cuda:0')
# seat_open:  YK
# random_number: 0.7819037899938438, customer_index: 5, customer_type: Leis3
# customer type:  Leis3
# preference seats:  ['K']
# chosen seat:  K
# observation:  [[22. 69.]] reward:  450 departure:  False
# ------- step  69  ---------
# Action: 5, state: tensor([[22., 69.]], device='cuda:0')
# seat_open:  YK
# random_number: 0.33916499409384415, customer_index: 2, customer_type: Bus2
# customer type:  Bus2
# preference seats:  ['Y']
# chosen seat:  Y
# observation:  [[21. 68.]] reward:  800 departure:  False
# ------- step  68  ---------
# Action: 5, state: tensor([[21., 68.]], device='cuda:0')
# seat_open:  YK
# random_number: 0.6444757755231604, customer_index: 4, customer_type: Leis2
# customer type:  Leis2
# preference seats:  ['K']
# chosen seat:  K
# observation:  [[20. 67.]] reward:  450 departure:  False
# ------- step  67  ---------
# Action: 7, state: tensor([[20., 67.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.3884132619177527, customer_index: 2, customer_type: Bus2
# customer type:  Bus2
# preference seats:  ['Y', 'M']
# chosen seat:  M
# observation:  [[19. 66.]] reward:  500 departure:  False
# ------- step  66  ---------
# Action: 2, state: tensor([[19., 66.]], device='cuda:0')
# seat_open:  M
# random_number: 0.3301380060318845, customer_index: 2, customer_type: Bus2
# customer type:  Bus2
# preference seats:  ['M']
# chosen seat:  M
# observation:  [[18. 65.]] reward:  500 departure:  False
# ------- step  65  ---------
# Action: 7, state: tensor([[18., 65.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.8379822440819885, customer_index: 5, customer_type: Leis3
# customer type:  Leis3
# preference seats:  ['K']
# chosen seat:  K
# observation:  [[17. 64.]] reward:  450 departure:  False
# ------- step  64  ---------
# Action: 7, state: tensor([[17., 64.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.0005154295928336827, customer_index: 0, customer_type: f
# customer type:  f
# preference seats:  []
# chosen seat:  f
# observation:  [[17. 63.]] reward:  0 departure:  False
# ------- step  63  ---------
# Action: 7, state: tensor([[17., 63.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.5320083980932395, customer_index: 3, customer_type: Leis1
# customer type:  Leis1
# preference seats:  ['M']
# chosen seat:  M
# observation:  [[16. 62.]] reward:  500 departure:  False
# ------- step  62  ---------
# Action: 7, state: tensor([[16., 62.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.761565492892757, customer_index: 5, customer_type: Leis3
# customer type:  Leis3
# preference seats:  ['K']
# chosen seat:  K
# observation:  [[15. 61.]] reward:  450 departure:  False
# ------- step  61  ---------
# Action: 7, state: tensor([[15., 61.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.6966183008701087, customer_index: 4, customer_type: Leis2
# customer type:  Leis2
# preference seats:  ['M', 'K']
# chosen seat:  K
# observation:  [[14. 60.]] reward:  450 departure:  False
# ------- step  60  ---------
# Action: 7, state: tensor([[14., 60.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.7186419837854177, customer_index: 4, customer_type: Leis2
# customer type:  Leis2
# preference seats:  ['M', 'K']
# chosen seat:  K
# observation:  [[13. 59.]] reward:  450 departure:  False
# ------- step  59  ---------
# Action: 7, state: tensor([[13., 59.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.99268738759755, customer_index: 5, customer_type: Leis3
# customer type:  Leis3
# preference seats:  ['K']
# chosen seat:  K
# observation:  [[12. 58.]] reward:  450 departure:  False
# ------- step  58  ---------
# Action: 2, state: tensor([[12., 58.]], device='cuda:0')
# seat_open:  M
# random_number: 0.7690850175584243, customer_index: 5, customer_type: Leis3
# customer type:  Leis3
# preference seats:  []
# chosen seat:  f
# observation:  [[12. 57.]] reward:  0 departure:  False
# ------- step  57  ---------
# Action: 2, state: tensor([[12., 57.]], device='cuda:0')
# seat_open:  M
# random_number: 0.16830035787499087, customer_index: 0, customer_type: f
# customer type:  f
# preference seats:  []
# chosen seat:  f
# observation:  [[12. 56.]] reward:  0 departure:  False
# ------- step  56  ---------
# Action: 5, state: tensor([[12., 56.]], device='cuda:0')
# seat_open:  YK
# random_number: 0.8543506608800161, customer_index: 5, customer_type: Leis3
# customer type:  Leis3
# preference seats:  ['K']
# chosen seat:  K
# observation:  [[11. 55.]] reward:  450 departure:  False
# ------- step  55  ---------
# Action: 5, state: tensor([[11., 55.]], device='cuda:0')
# seat_open:  YK
# random_number: 0.02948106957836616, customer_index: 0, customer_type: f
# customer type:  f
# preference seats:  []
# chosen seat:  f
# observation:  [[11. 54.]] reward:  0 departure:  False
# ------- step  54  ---------
# Action: 5, state: tensor([[11., 54.]], device='cuda:0')
# seat_open:  YK
# random_number: 0.03062145609313438, customer_index: 0, customer_type: f
# customer type:  f
# preference seats:  []
# chosen seat:  f
# observation:  [[11. 53.]] reward:  0 departure:  False
# ------- step  53  ---------
# Action: 5, state: tensor([[11., 53.]], device='cuda:0')
# seat_open:  YK
# random_number: 0.65921990411019, customer_index: 4, customer_type: Leis2
# customer type:  Leis2
# preference seats:  ['K']
# chosen seat:  K
# observation:  [[10. 52.]] reward:  450 departure:  False
# ------- step  52  ---------
# Action: 7, state: tensor([[10., 52.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.27120823511923664, customer_index: 1, customer_type: Bus1
# customer type:  Bus1
# preference seats:  ['Y']
# chosen seat:  Y
# observation:  [[ 9. 51.]] reward:  800 departure:  False
# ------- step  51  ---------
# Action: 7, state: tensor([[ 9., 51.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.7754634600142024, customer_index: 5, customer_type: Leis3
# customer type:  Leis3
# preference seats:  ['K']
# chosen seat:  K
# observation:  [[ 8. 50.]] reward:  450 departure:  False
# ------- step  50  ---------
# Action: 1, state: tensor([[ 8., 50.]], device='cuda:0')
# seat_open:  Y
# random_number: 0.6293620789263906, customer_index: 4, customer_type: Leis2
# customer type:  Leis2
# preference seats:  []
# chosen seat:  f
# observation:  [[ 8. 49.]] reward:  0 departure:  False
# ------- step  49  ---------
# Action: 7, state: tensor([[ 8., 49.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.7422913466283063, customer_index: 4, customer_type: Leis2
# customer type:  Leis2
# preference seats:  ['M', 'K']
# chosen seat:  K
# observation:  [[ 7. 48.]] reward:  450 departure:  False
# ------- step  48  ---------
# Action: 7, state: tensor([[ 7., 48.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.2194660643077594, customer_index: 1, customer_type: Bus1
# customer type:  Bus1
# preference seats:  ['Y']
# chosen seat:  Y
# observation:  [[ 6. 47.]] reward:  800 departure:  False
# ------- step  47  ---------
# Action: 7, state: tensor([[ 6., 47.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.07874194338351026, customer_index: 0, customer_type: f
# customer type:  f
# preference seats:  []
# chosen seat:  f
# observation:  [[ 6. 46.]] reward:  0 departure:  False
# ------- step  46  ---------
# Action: 7, state: tensor([[ 6., 46.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.9164841787710573, customer_index: 5, customer_type: Leis3
# customer type:  Leis3
# preference seats:  ['K']
# chosen seat:  K
# observation:  [[ 5. 45.]] reward:  450 departure:  False
# ------- step  45  ---------
# Action: 7, state: tensor([[ 5., 45.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.1483119873757418, customer_index: 0, customer_type: f
# customer type:  f
# preference seats:  []
# chosen seat:  f
# observation:  [[ 5. 44.]] reward:  0 departure:  False
# ------- step  44  ---------
# Action: 7, state: tensor([[ 5., 44.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.8712161577739699, customer_index: 5, customer_type: Leis3
# customer type:  Leis3
# preference seats:  ['K']
# chosen seat:  K
# observation:  [[ 4. 43.]] reward:  450 departure:  False
# ------- step  43  ---------
# Action: 1, state: tensor([[ 4., 43.]], device='cuda:0')
# seat_open:  Y
# random_number: 0.9240232483537636, customer_index: 5, customer_type: Leis3
# customer type:  Leis3
# preference seats:  []
# chosen seat:  f
# observation:  [[ 4. 42.]] reward:  0 departure:  False
# ------- step  42  ---------
# Action: 7, state: tensor([[ 4., 42.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.6264100223103511, customer_index: 4, customer_type: Leis2
# customer type:  Leis2
# preference seats:  ['M', 'K']
# chosen seat:  K
# observation:  [[ 3. 41.]] reward:  450 departure:  False
# ------- step  41  ---------
# Action: 7, state: tensor([[ 3., 41.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.701029027435423, customer_index: 4, customer_type: Leis2
# customer type:  Leis2
# preference seats:  ['M', 'K']
# chosen seat:  K
# observation:  [[ 2. 40.]] reward:  450 departure:  False
# ------- step  40  ---------
# Action: 7, state: tensor([[ 2., 40.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.8502382782801639, customer_index: 5, customer_type: Leis3
# customer type:  Leis3
# preference seats:  ['K']
# chosen seat:  K
# observation:  [[ 1. 39.]] reward:  450 departure:  False
# ------- step  39  ---------
# Action: 7, state: tensor([[ 1., 39.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.06699662507731363, customer_index: 0, customer_type: f
# customer type:  f
# preference seats:  []
# chosen seat:  f
# observation:  [[ 1. 38.]] reward:  0 departure:  False
# ------- step  38  ---------
# Action: 0, state: tensor([[ 1., 38.]], device='cuda:0')
# seat_open:  f
# random_number: 0.3850852650292662, customer_index: 2, customer_type: Bus2
# customer type:  Bus2
# preference seats:  []
# chosen seat:  f
# observation:  [[ 1. 37.]] reward:  0 departure:  False
# ------- step  37  ---------
# Action: 7, state: tensor([[ 1., 37.]], device='cuda:0')
# seat_open:  YMK
# random_number: 0.6327286301537217, customer_index: 4, customer_type: Leis2
# customer type:  Leis2
# preference seats:  ['M', 'K']
# chosen seat:  K
# observation:  [[ 0. 36.]] reward:  450 departure:  False
# ------- step  36  ---------
# Action: 6, state: tensor([[ 0., 36.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 35.]] reward:  0 departure:  False
# ------- step  35  ---------
# Action: 6, state: tensor([[ 0., 35.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 34.]] reward:  0 departure:  False
# ------- step  34  ---------
# Action: 6, state: tensor([[ 0., 34.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 33.]] reward:  0 departure:  False
# ------- step  33  ---------
# Action: 6, state: tensor([[ 0., 33.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 32.]] reward:  0 departure:  False
# ------- step  32  ---------
# Action: 6, state: tensor([[ 0., 32.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 31.]] reward:  0 departure:  False
# ------- step  31  ---------
# Action: 7, state: tensor([[ 0., 31.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 30.]] reward:  0 departure:  False
# ------- step  30  ---------
# Action: 7, state: tensor([[ 0., 30.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 29.]] reward:  0 departure:  False
# ------- step  29  ---------
# Action: 4, state: tensor([[ 0., 29.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 28.]] reward:  0 departure:  False
# ------- step  28  ---------
# Action: 4, state: tensor([[ 0., 28.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 27.]] reward:  0 departure:  False
# ------- step  27  ---------
# Action: 4, state: tensor([[ 0., 27.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 26.]] reward:  0 departure:  False
# ------- step  26  ---------
# Action: 4, state: tensor([[ 0., 26.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 25.]] reward:  0 departure:  False
# ------- step  25  ---------
# Action: 4, state: tensor([[ 0., 25.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 24.]] reward:  0 departure:  False
# ------- step  24  ---------
# Action: 4, state: tensor([[ 0., 24.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 23.]] reward:  0 departure:  False
# ------- step  23  ---------
# Action: 6, state: tensor([[ 0., 23.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 22.]] reward:  0 departure:  False
# ------- step  22  ---------
# Action: 4, state: tensor([[ 0., 22.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 21.]] reward:  0 departure:  False
# ------- step  21  ---------
# Action: 4, state: tensor([[ 0., 21.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 20.]] reward:  0 departure:  False
# ------- step  20  ---------
# Action: 4, state: tensor([[ 0., 20.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 19.]] reward:  0 departure:  False
# ------- step  19  ---------
# Action: 4, state: tensor([[ 0., 19.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 18.]] reward:  0 departure:  False
# ------- step  18  ---------
# Action: 4, state: tensor([[ 0., 18.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 17.]] reward:  0 departure:  False
# ------- step  17  ---------
# Action: 4, state: tensor([[ 0., 17.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 16.]] reward:  0 departure:  False
# ------- step  16  ---------
# Action: 4, state: tensor([[ 0., 16.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 15.]] reward:  0 departure:  False
# ------- step  15  ---------
# Action: 3, state: tensor([[ 0., 15.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 14.]] reward:  0 departure:  False
# ------- step  14  ---------
# Action: 3, state: tensor([[ 0., 14.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 13.]] reward:  0 departure:  False
# ------- step  13  ---------
# Action: 3, state: tensor([[ 0., 13.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 12.]] reward:  0 departure:  False
# ------- step  12  ---------
# Action: 3, state: tensor([[ 0., 12.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 11.]] reward:  0 departure:  False
# ------- step  11  ---------
# Action: 0, state: tensor([[ 0., 11.]], device='cuda:0')
# No remaining seat.
# observation:  [[ 0. 10.]] reward:  0 departure:  False
# ------- step  10  ---------
# Action: 1, state: tensor([[ 0., 10.]], device='cuda:0')
# No remaining seat.
# observation:  [[0. 9.]] reward:  0 departure:  False
# ------- step  9  ---------
# Action: 6, state: tensor([[0., 9.]], device='cuda:0')
# No remaining seat.
# observation:  [[0. 8.]] reward:  0 departure:  False
# ------- step  8  ---------
# Action: 0, state: tensor([[0., 8.]], device='cuda:0')
# No remaining seat.
# observation:  [[0. 7.]] reward:  0 departure:  False
# ------- step  7  ---------
# Action: 3, state: tensor([[0., 7.]], device='cuda:0')
# No remaining seat.
# observation:  [[0. 6.]] reward:  0 departure:  False
# ------- step  6  ---------
# Action: 3, state: tensor([[0., 6.]], device='cuda:0')
# No remaining seat.
# observation:  [[0. 5.]] reward:  0 departure:  False
# ------- step  5  ---------
# Action: 1, state: tensor([[0., 5.]], device='cuda:0')
# No remaining seat.
# observation:  [[0. 4.]] reward:  0 departure:  False
# ------- step  4  ---------
# Action: 7, state: tensor([[0., 4.]], device='cuda:0')
# No remaining seat.
# observation:  [[0. 3.]] reward:  0 departure:  False
# ------- step  3  ---------
# Action: 4, state: tensor([[0., 3.]], device='cuda:0')
# No remaining seat.
# observation:  [[0. 2.]] reward:  0 departure:  False
# ------- step  2  ---------
# Action: 4, state: tensor([[0., 2.]], device='cuda:0')
# No remaining seat.
# observation:  [[0. 1.]] reward:  0 departure:  False
# ------- step  1  ---------
# Action: 7, state: tensor([[0., 1.]], device='cuda:0')
# No remaining seat.
# observation:  [[0. 0.]] reward:  0 departure:  True
# Episode: 9, Total Revenue: tensor([52750], device='cuda:0'), Cumulative average: [52630.]

# %%
# Plot results
plt.figure(figsize=(10, 6))  
plt.plot(range(num_episodes), DQN_total_revenues, label='DQN each episode', alpha=0.5, color='b')
plt.plot(range(50, num_episodes, 50), DQN_per_50_avg, label='DQN per 50 episode', alpha=0.5, color='green')
plt.plot(range(num_episodes), DQN_cumulative_average, label='DQN Cumulative')
plt.axhline(y=dp, color='r', label='DP')
plt.axhline(y=fcfs, color='orange', label='FCFS')
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('Total Reward per Episode')
plt.legend()  
plt.grid(True)
plt.show()
