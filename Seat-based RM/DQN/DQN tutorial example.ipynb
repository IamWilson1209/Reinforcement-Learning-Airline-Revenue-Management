# %%
import gymnasium as gym
import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
env = gym.make("CartPole-v1")

# 印出動作空間和觀察空間的維度信息
print("動作空間維度：", env.action_space)
print("觀察空間維度：", env.observation_space)

# 如果需要，可以進一步查看更多細節
print("動作空間樣本：", env.action_space.sample())
print("觀察空間樣本：", env.observation_space.sample())

# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# if GPU is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# 動作空間維度： Discrete(2)
# 觀察空間維度： Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)
# 動作空間樣本： 0
# 觀察空間樣本： [ 5.3931439e-01 -2.8232627e+38 -2.0398787e-01  3.1226217e+37]

# %%
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))

class ReplayMemory(object):

    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)

    def push(self, *args):
        """Save a transition"""
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
class DQN(nn.Module):

    def __init__(self, n_observations, n_actions):
        super(DQN, self).__init__()
        self.layer1 = nn.Linear(n_observations, 128)
        self.layer2 = nn.Linear(128, 128)
        self.layer3 = nn.Linear(128, n_actions)

    # Called with either one element to determine next action, or a batch
    # during optimization. Returns tensor([[left0exp,right0exp]...]).
    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        return self.layer3(x)

# %%
# BATCH_SIZE is the number of transitions sampled from the replay buffer
# GAMMA is the discount factor as mentioned in the previous section
# EPS_START is the starting value of epsilon
# EPS_END is the final value of epsilon
# EPS_DECAY controls the rate of exponential decay of epsilon, higher means a slower decay
# TAU is the update rate of the target network
# LR is the learning rate of the ``AdamW`` optimizer
BATCH_SIZE = 128
GAMMA = 0.99
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 1000
TAU = 0.005
LR = 1e-4

# Get number of actions from gym action space
n_actions = env.action_space.n
print(type(env.action_space))
print("n_actions: ", n_actions)
# Get the number of state observations
state, info = env.reset()
n_observations = len(state)
print(type(state))
print("n_observations: ", n_observations)

policy_net = DQN(n_observations, n_actions).to(device)
target_net = DQN(n_observations, n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())

optimizer = optim.AdamW(policy_net.parameters(), lr=LR, amsgrad=True)
memory = ReplayMemory(10000)


steps_done = 0


def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max(1) will return the largest column value of each row.
            # second column on max result is index of where max element was
            # found, so we pick action with the larger expected reward.
            return policy_net(state).max(1).indices.view(1, 1)
    else:
        return torch.tensor([[env.action_space.sample()]], device=device, dtype=torch.long)


episode_durations = []


def plot_durations(show_result=False):
    plt.figure(1)
    durations_t = torch.tensor(episode_durations, dtype=torch.float)
    if show_result:
        plt.title('Result')
    else:
        plt.clf()
        plt.title('Training...')
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.plot(durations_t.numpy())
    # Take 100 episode averages and plot them too
    if len(durations_t) >= 100:
        means = durations_t.unfold(0, 100, 1).mean(1).view(-1)
        means = torch.cat((torch.zeros(99), means))
        plt.plot(means.numpy())

    plt.pause(0.001)  # pause a bit so that plots are updated
    if is_ipython:
        if not show_result:
            display.display(plt.gcf())
            display.clear_output(wait=True)
        else:
            display.display(plt.gcf())
# Out:
# <class 'gymnasium.spaces.discrete.Discrete'>
# n_actions:  2
# <class 'numpy.ndarray'>
# n_observations:  4

# %%
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    # Transpose the batch (see https://stackoverflow.com/a/19343/3343043 for
    # detailed explanation). This converts batch-array of Transitions
    # to Transition of batch-arrays.
    batch = Transition(*zip(*transitions))

    # Compute a mask of non-final states and concatenate the batch elements
    # (a final state would've been the one after which simulation ended)
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
    # columns of actions taken. These are the actions which would've been taken
    # for each batch state according to policy_net
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Compute V(s_{t+1}) for all next states.
    # Expected values of actions for non_final_next_states are computed based
    # on the "older" target_net; selecting their best reward with max(1).values
    # This is merged based on the mask, such that we'll have either the expected
    # state value or 0 in case the state was final.
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    with torch.no_grad():
        next_state_values[non_final_mask] = target_net(non_final_next_states).max(1).values
    # Compute the expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Compute Huber loss
    criterion = nn.SmoothL1Loss()
    loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    # In-place gradient clipping
    torch.nn.utils.clip_grad_value_(policy_net.parameters(), 100)
    optimizer.step()

# %%
if torch.cuda.is_available():
    num_episodes = 50
else:
    num_episodes = 50

for i_episode in range(num_episodes):
    
    # 初始化環境
    print("----------episode: ", i_episode)
    state, info = env.reset()
    print("state: ", state)
    print("info: ",info)
    state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
    print("unsqueeze state: ", state)
    
    for t in count():
        print("-------step: ",t)
        
        # agent 選擇動作
        action = select_action(state)
        print("action: ", action)

        print("action item: ", action.item())

        # 環境回傳狀態
        observation, reward, terminated, truncated, _ = env.step(action.item())
        print("observation: ", observation, "reward: ",  reward, "terminated: ", terminated, "truncated: ", truncated)
        print("type obs: ", type(observation))
        reward = torch.tensor([reward], device=device)
        done = terminated or truncated

        if terminated:
            next_state = None
        else:
            next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)
            print("next_state", next_state)

        # 將觀察到的狀態、動作、獎勵和下一個狀態存儲到記憶緩衝區中
        memory.push(state, action, next_state, reward)

        # 更新狀態
        state = next_state

        # Perform one step of the optimization (on the policy network)
        optimize_model()

        # Soft update of the target network's weights
        # θ′ ← τ θ + (1 −τ )θ′
        target_net_state_dict = target_net.state_dict()
        policy_net_state_dict = policy_net.state_dict()
        for key in policy_net_state_dict:
            target_net_state_dict[key] = policy_net_state_dict[key]*TAU + target_net_state_dict[key]*(1-TAU)
        target_net.load_state_dict(target_net_state_dict)

        if done:
            episode_durations.append(t + 1)
            # plot_durations()
            break

print('Complete')
plot_durations(show_result=True)
plt.ioff()
plt.show()
# Out:
# ----------episode:  0
# state:  [-0.00876418  0.02228226  0.03295755 -0.01247041]
# info:  {}
# unsqueeze state:  tensor([[-0.0088,  0.0223,  0.0330, -0.0125]], device='cuda:0')
# -------step:  0
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.00831853  0.21691643  0.03270814 -0.29457536] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0083,  0.2169,  0.0327, -0.2946]], device='cuda:0')
# -------step:  1
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.0039802   0.0213438   0.02681663  0.00824114] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0040,  0.0213,  0.0268,  0.0082]], device='cuda:0')
# -------step:  2
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.00355333 -0.17415227  0.02698145  0.30926296] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0036, -0.1742,  0.0270,  0.3093]], device='cuda:0')
# -------step:  3
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.00703637  0.02057507  0.03316671  0.02520986] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0070,  0.0206,  0.0332,  0.0252]], device='cuda:0')
# -------step:  4
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.00662487 -0.17500643  0.03367091  0.32817   ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0066, -0.1750,  0.0337,  0.3282]], device='cuda:0')
# -------step:  5
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.010125    0.01962039  0.04023431  0.04629262] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0101,  0.0196,  0.0402,  0.0463]], device='cuda:0')
# -------step:  6
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.00973259 -0.17605472  0.04116016  0.35139343] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0097, -0.1761,  0.0412,  0.3514]], device='cuda:0')
# -------step:  7
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.01325369 -0.3717371   0.04818803  0.65676606] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0133, -0.3717,  0.0482,  0.6568]], device='cuda:0')
# -------step:  8
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.02068843 -0.5674956   0.06132335  0.9642247 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0207, -0.5675,  0.0613,  0.9642]], device='cuda:0')
# -------step:  9
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.03203834 -0.76338536  0.08060785  1.2755249 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0320, -0.7634,  0.0806,  1.2755]], device='cuda:0')
# -------step:  10
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.04730605 -0.9594375   0.10611834  1.5923213 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0473, -0.9594,  0.1061,  1.5923]], device='cuda:0')
# -------step:  11
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.0664948  -1.1556469   0.13796477  1.9161199 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0665, -1.1556,  0.1380,  1.9161]], device='cuda:0')
# -------step:  12
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.08960774 -1.3519582   0.17628717  2.2482219 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0896, -1.3520,  0.1763,  2.2482]], device='cuda:0')
# -------step:  13
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.1166469 -1.5482497  0.2212516  2.5896564] reward:  1.0 terminated:  True truncated:  False
# type obs:  <class 'numpy.ndarray'>
# ----------episode:  1
# state:  [-0.04453526 -0.01762914 -0.03211937 -0.04387974]
# info:  {}
# unsqueeze state:  tensor([[-0.0445, -0.0176, -0.0321, -0.0439]], device='cuda:0')
# -------step:  0
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.04488784 -0.21227615 -0.03299696  0.2384987 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0449, -0.2123, -0.0330,  0.2385]], device='cuda:0')
# -------step:  1
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.04913337 -0.40691155 -0.02822699  0.5205935 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0491, -0.4069, -0.0282,  0.5206]], device='cuda:0')
# -------step:  2
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.0572716  -0.601625   -0.01781512  0.80424976] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0573, -0.6016, -0.0178,  0.8042]], device='cuda:0')
# -------step:  3
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.0693041  -0.40626338 -0.00173012  0.50601643] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0693, -0.4063, -0.0017,  0.5060]], device='cuda:0')
# -------step:  4
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.07742937 -0.6013609   0.00839021  0.79815364] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0774, -0.6014,  0.0084,  0.7982]], device='cuda:0')
# -------step:  5
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.08945659 -0.40635508  0.02435328  0.5081219 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0895, -0.4064,  0.0244,  0.5081]], device='cuda:0')
# -------step:  6
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.09758369 -0.6018115   0.03451572  0.8083788 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0976, -0.6018,  0.0345,  0.8084]], device='cuda:0')
# -------step:  7
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.10961992 -0.40717918  0.05068329  0.52674973] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1096, -0.4072,  0.0507,  0.5267]], device='cuda:0')
# -------step:  8
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.1177635  -0.60297626  0.06121829  0.8349627 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1178, -0.6030,  0.0612,  0.8350]], device='cuda:0')
# -------step:  9
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.12982303 -0.7988787   0.07791755  1.1462529 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1298, -0.7989,  0.0779,  1.1463]], device='cuda:0')
# -------step:  10
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.1458006 -0.9949269  0.1008426  1.4623176] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1458, -0.9949,  0.1008,  1.4623]], device='cuda:0')
# -------step:  11
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.16569914 -1.1911298   0.13008896  1.7847242 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1657, -1.1911,  0.1301,  1.7847]], device='cuda:0')
# -------step:  12
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.18952173 -1.3874515   0.16578344  2.114857  ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1895, -1.3875,  0.1658,  2.1149]], device='cuda:0')
# -------step:  13
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.21727076 -1.5837964   0.20808057  2.4538536 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.2173, -1.5838,  0.2081,  2.4539]], device='cuda:0')
# -------step:  14
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.2489467  -1.7799909   0.25715765  2.8025324 ] reward:  1.0 terminated:  True truncated:  False
# type obs:  <class 'numpy.ndarray'>
# ----------episode:  2
# state:  [ 0.01935204  0.03603393 -0.00753162 -0.01582927]
# info:  {}
# unsqueeze state:  tensor([[ 0.0194,  0.0360, -0.0075, -0.0158]], device='cuda:0')
# -------step:  0
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [ 0.02007272  0.23126309 -0.0078482  -0.31087896] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0201,  0.2313, -0.0078, -0.3109]], device='cuda:0')
# -------step:  1
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.02469799  0.03625382 -0.01406578 -0.02068142] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0247,  0.0363, -0.0141, -0.0207]], device='cuda:0')
# -------step:  2
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.02542306 -0.15866362 -0.01447941  0.26753062] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0254, -0.1587, -0.0145,  0.2675]], device='cuda:0')
# -------step:  3
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [ 0.02224979  0.03666195 -0.0091288  -0.02968383] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0222,  0.0367, -0.0091, -0.0297]], device='cuda:0')
# -------step:  4
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [ 0.02298303  0.23191361 -0.00972247 -0.32523295] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0230,  0.2319, -0.0097, -0.3252]], device='cuda:0')
# -------step:  5
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.0276213   0.03693144 -0.01622713 -0.03563187] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0276,  0.0369, -0.0162, -0.0356]], device='cuda:0')
# -------step:  6
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.02835993 -0.1579541  -0.01693977  0.25188738] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0284, -0.1580, -0.0169,  0.2519]], device='cuda:0')
# -------step:  7
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.02520085 -0.3528301  -0.01190202  0.5391794 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0252, -0.3528, -0.0119,  0.5392]], device='cuda:0')
# -------step:  8
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.01814425 -0.5477827  -0.00111843  0.8280885 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0181, -0.5478, -0.0011,  0.8281]], device='cuda:0')
# -------step:  9
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [ 0.00718859 -0.35264552  0.01544334  0.5350541 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0072, -0.3526,  0.0154,  0.5351]], device='cuda:0')
# -------step:  10
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [ 1.3568011e-04 -1.5774409e-01  2.6144419e-02  2.4727695e-01] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 1.3568e-04, -1.5774e-01,  2.6144e-02,  2.4728e-01]], device='cuda:0')
# -------step:  11
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.0030192  -0.3532295   0.03108996  0.5480904 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0030, -0.3532,  0.0311,  0.5481]], device='cuda:0')
# -------step:  12
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.01008379 -0.15855779  0.04205177  0.26536295] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0101, -0.1586,  0.0421,  0.2654]], device='cuda:0')
# -------step:  13
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.01325495 -0.35425392  0.04735903  0.5710072 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0133, -0.3543,  0.0474,  0.5710]], device='cuda:0')
# -------step:  14
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.02034003 -0.15982698  0.05877917  0.29361215] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0203, -0.1598,  0.0588,  0.2936]], device='cuda:0')
# -------step:  15
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.02353656  0.03440983  0.06465141  0.02003123] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0235,  0.0344,  0.0647,  0.0200]], device='cuda:0')
# -------step:  16
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.02284837 -0.16157685  0.06505204  0.33239135] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0228, -0.1616,  0.0651,  0.3324]], device='cuda:0')
# -------step:  17
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.02607991 -0.3575615   0.07169987  0.64485836] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0261, -0.3576,  0.0717,  0.6449]], device='cuda:0')
# -------step:  18
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.03323114 -0.55360556  0.08459703  0.95923054] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0332, -0.5536,  0.0846,  0.9592]], device='cuda:0')
# -------step:  19
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.04430325 -0.74975663  0.10378164  1.2772468 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0443, -0.7498,  0.1038,  1.2772]], device='cuda:0')
# -------step:  20
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.05929838 -0.9460373   0.12932658  1.6005408 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0593, -0.9460,  0.1293,  1.6005]], device='cuda:0')
# -------step:  21
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.07821912 -1.142432    0.16133739  1.9305888 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0782, -1.1424,  0.1613,  1.9306]], device='cuda:0')
# -------step:  22
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.10106777 -1.3388728   0.19994918  2.268651  ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1011, -1.3389,  0.1999,  2.2687]], device='cuda:0')
# -------step:  23
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.12784523 -1.1461017   0.2453222   2.0436494 ] reward:  1.0 terminated:  True truncated:  False
# type obs:  <class 'numpy.ndarray'>
# ----------episode:  3
# state:  [ 0.03533126 -0.01087958 -0.02120593  0.00872026]
# info:  {}
# unsqueeze state:  tensor([[ 0.0353, -0.0109, -0.0212,  0.0087]], device='cuda:0')
# -------step:  0
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.03511367 -0.2056911  -0.02103152  0.29463774] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0351, -0.2057, -0.0210,  0.2946]], device='cuda:0')
# -------step:  1
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [ 0.03099985 -0.01027571 -0.01513877 -0.0046033 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0310, -0.0103, -0.0151, -0.0046]], device='cuda:0')
# -------step:  2
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.03079433 -0.20517732 -0.01523083  0.28326496] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0308, -0.2052, -0.0152,  0.2833]], device='cuda:0')
# -------step:  3
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.02669079 -0.40007874 -0.00956553  0.57110554] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0267, -0.4001, -0.0096,  0.5711]], device='cuda:0')
# -------step:  4
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.01868921 -0.5950653   0.00185658  0.8607597 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0187, -0.5951,  0.0019,  0.8608]], device='cuda:0')
# -------step:  5
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [ 0.00678791 -0.39996865  0.01907177  0.5686611 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0068, -0.4000,  0.0191,  0.5687]], device='cuda:0')
# -------step:  6
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.00121147 -0.5953528   0.03044499  0.86729085] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0012, -0.5954,  0.0304,  0.8673]], device='cuda:0')
# -------step:  7
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.01311852 -0.4006581   0.04779081  0.58433354] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0131, -0.4007,  0.0478,  0.5843]], device='cuda:0')
# -------step:  8
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.02113169 -0.5964158   0.05947748  0.89167994] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0211, -0.5964,  0.0595,  0.8917]], device='cuda:0')
# -------step:  9
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.03306    -0.40214893  0.07731108  0.61827105] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0331, -0.4021,  0.0773,  0.6183]], device='cuda:0')
# -------step:  10
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.04110298 -0.5982608   0.0896765   0.934267  ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0411, -0.5983,  0.0897,  0.9343]], device='cuda:0')
# -------step:  11
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.0530682  -0.40445557  0.10836184  0.6710568 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0531, -0.4045,  0.1084,  0.6711]], device='cuda:0')
# -------step:  12
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.06115731 -0.2109936   0.12178298  0.414362  ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0612, -0.2110,  0.1218,  0.4144]], device='cuda:0')
# -------step:  13
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.06537718 -0.4076122   0.13007022  0.74282134] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0654, -0.4076,  0.1301,  0.7428]], device='cuda:0')
# -------step:  14
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.07352942 -0.6042667   0.14492665  1.0734442 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0735, -0.6043,  0.1449,  1.0734]], device='cuda:0')
# -------step:  15
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.08561476 -0.41132632  0.16639553  0.82952714] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0856, -0.4113,  0.1664,  0.8295]], device='cuda:0')
# -------step:  16
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.09384128 -0.6082843   0.18298607  1.1695784 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0938, -0.6083,  0.1830,  1.1696]], device='cuda:0')
# -------step:  17
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.10600697 -0.80525225  0.20637764  1.5135959 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1060, -0.8053,  0.2064,  1.5136]], device='cuda:0')
# -------step:  18
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.12211201 -1.0021876   0.23664956  1.8629755 ] reward:  1.0 terminated:  True truncated:  False
# type obs:  <class 'numpy.ndarray'>
# ----------episode:  4
# state:  [ 0.03683641 -0.02055424 -0.01482601 -0.01205569]
# info:  {}
# unsqueeze state:  tensor([[ 0.0368, -0.0206, -0.0148, -0.0121]], device='cuda:0')
# -------step:  0
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.03642532 -0.21546046 -0.01506713  0.27591282] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0364, -0.2155, -0.0151,  0.2759]], device='cuda:0')
# -------step:  1
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.03211611 -0.41036424 -0.00954887  0.56380576] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0321, -0.4104, -0.0095,  0.5638]], device='cuda:0')
# -------step:  2
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.02390883 -0.6053509   0.00172724  0.8534651 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0239, -0.6054,  0.0017,  0.8535]], device='cuda:0')
# -------step:  3
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [ 0.01180181 -0.41025257  0.01879655  0.5613258 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0118, -0.4103,  0.0188,  0.5613]], device='cuda:0')
# -------step:  4
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.00359676 -0.6056332   0.03002306  0.85987085] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0036, -0.6056,  0.0300,  0.8599]], device='cuda:0')
# -------step:  5
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.00851591 -0.8011509   0.04722048  1.1618407 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0085, -0.8012,  0.0472,  1.1618]], device='cuda:0')
# -------step:  6
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.02453892 -0.996855    0.07045729  1.4689473 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0245, -0.9969,  0.0705,  1.4689]], device='cuda:0')
# -------step:  7
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.04447602 -0.8026624   0.09983624  1.1990783 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0445, -0.8027,  0.0998,  1.1991]], device='cuda:0')
# -------step:  8
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.06052927 -0.99892414  0.12381781  1.5213082 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0605, -0.9989,  0.1238,  1.5213]], device='cuda:0')
# -------step:  9
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.08050776 -1.1953057   0.15424398  1.8499349 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0805, -1.1953,  0.1542,  1.8499]], device='cuda:0')
# -------step:  10
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.10441387 -1.0021815   0.19124267  1.608856  ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1044, -1.0022,  0.1912,  1.6089]], device='cuda:0')
# -------step:  11
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.1244575  -0.80976456  0.22341979  1.3813757 ] reward:  1.0 terminated:  True truncated:  False
# type obs:  <class 'numpy.ndarray'>
# ----------episode:  5
# state:  [ 0.04763789 -0.01360798 -0.02937113 -0.0347077 ]
# info:  {}
# unsqueeze state:  tensor([[ 0.0476, -0.0136, -0.0294, -0.0347]], device='cuda:0')
# -------step:  0
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.04736574 -0.2082967  -0.03006529  0.24856555] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0474, -0.2083, -0.0301,  0.2486]], device='cuda:0')
# -------step:  1
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.0431998  -0.40297666 -0.02509398  0.5316157 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0432, -0.4030, -0.0251,  0.5316]], device='cuda:0')
# -------step:  2
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [ 0.03514027 -0.2075109  -0.01446166  0.23113248] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0351, -0.2075, -0.0145,  0.2311]], device='cuda:0')
# -------step:  3
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.03099005 -0.40242326 -0.00983901  0.51921886] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0310, -0.4024, -0.0098,  0.5192]], device='cuda:0')
# -------step:  4
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 2.2941586e-02 -5.9740531e-01  5.4536283e-04  8.0878514e-01] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 2.2942e-02, -5.9741e-01,  5.4536e-04,  8.0879e-01]], device='cuda:0')
# -------step:  5
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.01099348 -0.7925347   0.01672107  1.1016396 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0110, -0.7925,  0.0167,  1.1016]], device='cuda:0')
# -------step:  6
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.00485721 -0.98787266  0.03875386  1.3995212 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0049, -0.9879,  0.0388,  1.3995]], device='cuda:0')
# -------step:  7
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.02461467 -0.7932533   0.06674428  1.1192021 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0246, -0.7933,  0.0667,  1.1192]], device='cuda:0')
# -------step:  8
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.04047973 -0.9891843   0.08912833  1.4320526 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0405, -0.9892,  0.0891,  1.4321]], device='cuda:0')
# -------step:  9
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.06026342 -0.7952682   0.11776938  1.168502  ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0603, -0.7953,  0.1178,  1.1685]], device='cuda:0')
# -------step:  10
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.07616878 -0.6018585   0.14113942  0.91494125] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0762, -0.6019,  0.1411,  0.9149]], device='cuda:0')
# -------step:  11
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.08820596 -0.7985781   0.15943824  1.2484438 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0882, -0.7986,  0.1594,  1.2484]], device='cuda:0')
# -------step:  12
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.10417751 -0.99534374  0.18440711  1.5865253 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1042, -0.9953,  0.1844,  1.5865]], device='cuda:0')
# -------step:  13
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.12408439 -1.1921165   0.21613763  1.930589  ] reward:  1.0 terminated:  True truncated:  False
# type obs:  <class 'numpy.ndarray'>
# ----------episode:  6
# state:  [-0.02662416 -0.03414907 -0.01206984  0.03763498]
# info:  {}
# unsqueeze state:  tensor([[-0.0266, -0.0341, -0.0121,  0.0376]], device='cuda:0')
# -------step:  0
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.02730715  0.16114387 -0.01131714 -0.25883153] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0273,  0.1611, -0.0113, -0.2588]], device='cuda:0')
# -------step:  1
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.02408427 -0.03381471 -0.01649377  0.03026043] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0241, -0.0338, -0.0165,  0.0303]], device='cuda:0')
# -------step:  2
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.02476056 -0.22869629 -0.01588856  0.3176941 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0248, -0.2287, -0.0159,  0.3177]], device='cuda:0')
# -------step:  3
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.02933449 -0.4235884  -0.00953468  0.60532427] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0293, -0.4236, -0.0095,  0.6053]], device='cuda:0')
# -------step:  4
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.03780626 -0.22833441  0.0025718   0.3096535 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0378, -0.2283,  0.0026,  0.3097]], device='cuda:0')
# -------step:  5
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.04237295 -0.4234929   0.00876487  0.6031464 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0424, -0.4235,  0.0088,  0.6031]], device='cuda:0')
# -------step:  6
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.0508428 -0.6187363  0.0208278  0.8985771] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0508, -0.6187,  0.0208,  0.8986]], device='cuda:0')
# -------step:  7
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.06321753 -0.8141343   0.03879935  1.1977334 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0632, -0.8141,  0.0388,  1.1977]], device='cuda:0')
# -------step:  8
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.07950021 -0.6195354   0.06275401  0.91745883] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0795, -0.6195,  0.0628,  0.9175]], device='cuda:0')
# -------step:  9
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.09189092 -0.8154471   0.08110319  1.2291855 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0919, -0.8154,  0.0811,  1.2292]], device='cuda:0')
# -------step:  10
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.10819986 -0.6214569   0.1056869   0.96297497] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1082, -0.6215,  0.1057,  0.9630]], device='cuda:0')
# -------step:  11
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.12062901 -0.81782794  0.1249464   1.2869022 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1206, -0.8178,  0.1249,  1.2869]], device='cuda:0')
# -------step:  12
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.13698556 -1.0142986   0.15068445  1.6159495 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1370, -1.0143,  0.1507,  1.6159]], device='cuda:0')
# -------step:  13
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.15727153 -1.2108425   0.18300343  1.9515585 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1573, -1.2108,  0.1830,  1.9516]], device='cuda:0')
# -------step:  14
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.18148838 -1.4073783   0.2220346   2.2949426 ] reward:  1.0 terminated:  True truncated:  False
# type obs:  <class 'numpy.ndarray'>
# ----------episode:  7
# state:  [ 0.01898812  0.04093453  0.04736586 -0.03230155]
# info:  {}
# unsqueeze state:  tensor([[ 0.0190,  0.0409,  0.0474, -0.0323]], device='cuda:0')
# -------step:  0
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.01980681 -0.15483354  0.04671983  0.27494156] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0198, -0.1548,  0.0467,  0.2749]], device='cuda:0')
# -------step:  1
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [ 0.01671014  0.03959176  0.05221866 -0.00264754] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0167,  0.0396,  0.0522, -0.0026]], device='cuda:0')
# -------step:  2
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [ 0.01750198  0.23392744  0.05216571 -0.2784084 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0175,  0.2339,  0.0522, -0.2784]], device='cuda:0')
# -------step:  3
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [0.02218053 0.03810162 0.04659754 0.03026052] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[0.0222, 0.0381, 0.0466, 0.0303]], device='cuda:0')
# -------step:  4
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [ 0.02294256  0.23252544  0.04720275 -0.24736392] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0229,  0.2325,  0.0472, -0.2474]], device='cuda:0')
# -------step:  5
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [0.02759307 0.03676224 0.04225548 0.05982625] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[0.0276, 0.0368, 0.0423, 0.0598]], device='cuda:0')
# -------step:  6
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [ 0.02832831  0.23125365  0.043452   -0.21923105] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0283,  0.2313,  0.0435, -0.2192]], device='cuda:0')
# -------step:  7
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [ 0.03295339  0.4257284   0.03906738 -0.49789697] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0330,  0.4257,  0.0391, -0.4979]], device='cuda:0')
# -------step:  8
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.04146795  0.23007804  0.02910944 -0.19316244] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0415,  0.2301,  0.0291, -0.1932]], device='cuda:0')
# -------step:  9
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [0.04606951 0.03455203 0.02524619 0.10855928] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[0.0461, 0.0346, 0.0252, 0.1086]], device='cuda:0')
# -------step:  10
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.04676056 -0.16092244  0.02741738  0.40909913] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0468, -0.1609,  0.0274,  0.4091]], device='cuda:0')
# -------step:  11
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.04354211 -0.35642216  0.03559936  0.71029824] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0435, -0.3564,  0.0356,  0.7103]], device='cuda:0')
# -------step:  12
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.03641367 -0.5520186   0.04980532  1.013971  ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0364, -0.5520,  0.0498,  1.0140]], device='cuda:0')
# -------step:  13
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [ 0.02537329 -0.35759506  0.07008474  0.737334  ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0254, -0.3576,  0.0701,  0.7373]], device='cuda:0')
# -------step:  14
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.01822139 -0.55361134  0.08483142  1.0512247 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0182, -0.5536,  0.0848,  1.0512]], device='cuda:0')
# -------step:  15
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [ 0.00714916 -0.3597107   0.10585592  0.78633016] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0071, -0.3597,  0.1059,  0.7863]], device='cuda:0')
# -------step:  16
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-4.5049717e-05 -1.6618989e-01  1.2158252e-01  5.2873737e-01] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-4.5050e-05, -1.6619e-01,  1.2158e-01,  5.2874e-01]], device='cuda:0')
# -------step:  17
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.00336885 -0.3627937   0.13215727  0.8571233 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0034, -0.3628,  0.1322,  0.8571]], device='cuda:0')
# -------step:  18
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.01062472 -0.55944467  0.14929974  1.1882688 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0106, -0.5594,  0.1493,  1.1883]], device='cuda:0')
# -------step:  19
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.02181362 -0.36653963  0.17306511  0.9458614 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0218, -0.3665,  0.1731,  0.9459]], device='cuda:0')
# -------step:  20
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.02914441 -0.5635166   0.19198234  1.2875407 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0291, -0.5635,  0.1920,  1.2875]], device='cuda:0')
# -------step:  21
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.04041474 -0.76049143  0.21773314  1.6336713 ] reward:  1.0 terminated:  True truncated:  False
# type obs:  <class 'numpy.ndarray'>
# ----------episode:  8
# state:  [ 0.019726   -0.03831236 -0.03185503 -0.03531227]
# info:  {}
# unsqueeze state:  tensor([[ 0.0197, -0.0383, -0.0319, -0.0353]], device='cuda:0')
# -------step:  0
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.01895976 -0.23296337 -0.03256127  0.24715231] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0190, -0.2330, -0.0326,  0.2472]], device='cuda:0')
# -------step:  1
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.01430049 -0.4276055  -0.02761823  0.52938944] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0143, -0.4276, -0.0276,  0.5294]], device='cuda:0')
# -------step:  2
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [ 0.00574838 -0.23210615 -0.01703044  0.2281335 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0057, -0.2321, -0.0170,  0.2281]], device='cuda:0')
# -------step:  3
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.00110626 -0.4269806  -0.01246777  0.5153961 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0011, -0.4270, -0.0125,  0.5154]], device='cuda:0')
# -------step:  4
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.00743336 -0.6219248  -0.00215985  0.80412424] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0074, -0.6219, -0.0022,  0.8041]], device='cuda:0')
# -------step:  5
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.01987185 -0.8170171   0.01392264  1.0961269 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0199, -0.8170,  0.0139,  1.0961]], device='cuda:0')
# -------step:  6
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.03621219 -1.0123196   0.03584518  1.3931454 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0362, -1.0123,  0.0358,  1.3931]], device='cuda:0')
# -------step:  7
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.05645858 -1.2078689   0.06370809  1.6968173 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0565, -1.2079,  0.0637,  1.6968]], device='cuda:0')
# -------step:  8
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.08061597 -1.4036652   0.09764443  2.0086334 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0806, -1.4037,  0.0976,  2.0086]], device='cuda:0')
# -------step:  9
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.10868927 -1.5996586   0.1378171   2.329885  ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1087, -1.5997,  0.1378,  2.3299]], device='cuda:0')
# -------step:  10
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.14068244 -1.406028    0.1844148   2.0825832 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1407, -1.4060,  0.1844,  2.0826]], device='cuda:0')
# -------step:  11
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.168803   -1.602476    0.22606646  2.4261696 ] reward:  1.0 terminated:  True truncated:  False
# type obs:  <class 'numpy.ndarray'>
# ----------episode:  9
# state:  [-0.01681042  0.02683958  0.00349105  0.04763777]
# info:  {}
# unsqueeze state:  tensor([[-0.0168,  0.0268,  0.0035,  0.0476]], device='cuda:0')
# -------step:  0
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.01627363 -0.16833225  0.0044438   0.3414201 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0163, -0.1683,  0.0044,  0.3414]], device='cuda:0')
# -------step:  1
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.01964028 -0.36351714  0.01127221  0.635501  ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0196, -0.3635,  0.0113,  0.6355]], device='cuda:0')
# -------step:  2
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.02691062 -0.5587945   0.02398222  0.9317124 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0269, -0.5588,  0.0240,  0.9317]], device='cuda:0')
# -------step:  3
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.03808651 -0.7542317   0.04261647  1.231834  ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0381, -0.7542,  0.0426,  1.2318]], device='cuda:0')
# -------step:  4
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.05317114 -0.94987506  0.06725316  1.5375581 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0532, -0.9499,  0.0673,  1.5376]], device='cuda:0')
# -------step:  5
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.07216865 -1.1457388   0.09800431  1.8504472 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0722, -1.1457,  0.0980,  1.8504]], device='cuda:0')
# -------step:  6
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.09508342 -1.3417932   0.13501325  2.1718845 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0951, -1.3418,  0.1350,  2.1719]], device='cuda:0')
# -------step:  7
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.12191929 -1.1482213   0.17845094  1.9237424 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1219, -1.1482,  0.1785,  1.9237]], device='cuda:0')
# -------step:  8
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.1448837 -1.3447545  0.2169258  2.2660475] reward:  1.0 terminated:  True truncated:  False
# type obs:  <class 'numpy.ndarray'>
# ----------episode:  10
# state:  [-0.04051448  0.03078775 -0.00438726  0.04660866]
# info:  {}
# unsqueeze state:  tensor([[-0.0405,  0.0308, -0.0044,  0.0466]], device='cuda:0')
# -------step:  0
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.03989872  0.22597234 -0.00345508 -0.24745524] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0399,  0.2260, -0.0035, -0.2475]], device='cuda:0')
# -------step:  1
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.03537928  0.0308999  -0.00840419  0.04413587] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# ...
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1254, -0.5794,  0.1972,  1.0448]], device='cuda:0')
# -------step:  13
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.13698688 -0.3873613   0.21804684  0.8199026 ] reward:  1.0 terminated:  True truncated:  False
# type obs:  <class 'numpy.ndarray'>
# ----------episode:  42
# state:  [-0.03666877  0.00184354  0.0259342   0.01488982]
# info:  {}
# unsqueeze state:  tensor([[-0.0367,  0.0018,  0.0259,  0.0149]], device='cuda:0')
# -------step:  0
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.0366319  -0.19364056  0.026232    0.31564116] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0366, -0.1936,  0.0262,  0.3156]], device='cuda:0')
# -------step:  1
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.04050472  0.00109811  0.03254482  0.03134498] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0405,  0.0011,  0.0325,  0.0313]], device='cuda:0')
# -------step:  2
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.04048275 -0.19447507  0.03317172  0.3341159 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0405, -0.1945,  0.0332,  0.3341]], device='cuda:0')
# -------step:  3
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.04437225 -0.39005306  0.03985404  0.63707215] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0444, -0.3901,  0.0399,  0.6371]], device='cuda:0')
# -------step:  4
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.05217332 -0.5857075   0.05259548  0.9420347 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0522, -0.5857,  0.0526,  0.9420]], device='cuda:0')
# -------step:  5
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.06388746 -0.7814972   0.07143617  1.2507691 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0639, -0.7815,  0.0714,  1.2508]], device='cuda:0')
# -------step:  6
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.07951741 -0.9774582   0.09645156  1.5649453 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0795, -0.9775,  0.0965,  1.5649]], device='cuda:0')
# -------step:  7
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.09906657 -1.1735916   0.12775047  1.8860909 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0991, -1.1736,  0.1278,  1.8861]], device='cuda:0')
# -------step:  8
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.1225384  -0.98006964  0.16547228  1.63563   ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1225, -0.9801,  0.1655,  1.6356]], device='cuda:0')
# -------step:  9
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.14213979 -0.7872306   0.19818488  1.3987497 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1421, -0.7872,  0.1982,  1.3987]], device='cuda:0')
# -------step:  10
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.1578844  -0.5950464   0.22615989  1.1740019 ] reward:  1.0 terminated:  True truncated:  False
# type obs:  <class 'numpy.ndarray'>
# ----------episode:  43
# state:  [ 0.01550171 -0.03315919 -0.01791194  0.04114835]
# info:  {}
# unsqueeze state:  tensor([[ 0.0155, -0.0332, -0.0179,  0.0411]], device='cuda:0')
# -------step:  0
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.01483853 -0.22801976 -0.01708898  0.3281265 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0148, -0.2280, -0.0171,  0.3281]], device='cuda:0')
# -------step:  1
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.01027813 -0.4228943  -0.01052645  0.6153717 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0103, -0.4229, -0.0105,  0.6154]], device='cuda:0')
# -------step:  2
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.00182025 -0.61786765  0.00178099  0.9047208 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0018, -0.6179,  0.0018,  0.9047]], device='cuda:0')
# -------step:  3
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.01053711 -0.8130137   0.01987541  1.197963  ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0105, -0.8130,  0.0199,  1.1980]], device='cuda:0')
# -------step:  4
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.02679738 -0.61815447  0.04383466  0.9115749 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0268, -0.6182,  0.0438,  0.9116]], device='cuda:0')
# -------step:  5
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.03916047 -0.42365217  0.06206616  0.63298494] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0392, -0.4237,  0.0621,  0.6330]], device='cuda:0')
# -------step:  6
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.04763351 -0.61958253  0.07472586  0.9445504 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0476, -0.6196,  0.0747,  0.9446]], device='cuda:0')
# -------step:  7
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.06002516 -0.8156273   0.09361687  1.2597457 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0600, -0.8156,  0.0936,  1.2597]], device='cuda:0')
# -------step:  8
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.07633771 -1.0118138   0.11881179  1.5802201 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0763, -1.0118,  0.1188,  1.5802]], device='cuda:0')
# -------step:  9
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.09657399 -0.81829     0.15041618  1.3268294 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0966, -0.8183,  0.1504,  1.3268]], device='cuda:0')
# -------step:  10
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.11293978 -0.62535244  0.17695278  1.0847467 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1129, -0.6254,  0.1770,  1.0847]], device='cuda:0')
# -------step:  11
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.12544684 -0.43294978  0.19864771  0.8524024 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.1254, -0.4329,  0.1986,  0.8524]], device='cuda:0')
# -------step:  12
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [-0.13410583 -0.6301445   0.21569575  1.2003965 ] reward:  1.0 terminated:  True truncated:  False
# type obs:  <class 'numpy.ndarray'>
# ----------episode:  44
# state:  [ 0.02136895 -0.0459944  -0.00141808  0.02064927]
# info:  {}
# unsqueeze state:  tensor([[ 0.0214, -0.0460, -0.0014,  0.0206]], device='cuda:0')
# -------step:  0
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.02044906 -0.24109599 -0.0010051   0.31288445] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0204, -0.2411, -0.0010,  0.3129]], device='cuda:0')
# -------step:  1
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.01562714 -0.4362036   0.00525259  0.60525024] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0156, -0.4362,  0.0053,  0.6053]], device='cuda:0')
# -------step:  2
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [ 0.00690306 -0.2411555   0.0173576   0.31422636] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0069, -0.2412,  0.0174,  0.3142]], device='cuda:0')
# -------step:  3
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.00207995 -0.43652037  0.02364212  0.61233234] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0021, -0.4365,  0.0236,  0.6123]], device='cuda:0')
# -------step:  4
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.00665045 -0.24173665  0.03588877  0.3271886 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0067, -0.2417,  0.0359,  0.3272]], device='cuda:0')
# -------step:  5
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.01148519 -0.04714355  0.04243254  0.04603594] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0115, -0.0471,  0.0424,  0.0460]], device='cuda:0')
# -------step:  6
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.01242806  0.14734507  0.04335326 -0.23296297] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0124,  0.1473,  0.0434, -0.2330]], device='cuda:0')
# -------step:  7
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.00948115  0.3418216   0.03869401 -0.5116618 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0095,  0.3418,  0.0387, -0.5117]], device='cuda:0')
# -------step:  8
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [-0.00264472  0.5363778   0.02846077 -0.7919044 ] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[-0.0026,  0.5364,  0.0285, -0.7919]], device='cuda:0')
# -------step:  9
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.00808283  0.34087688  0.01262268 -0.49040547] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0081,  0.3409,  0.0126, -0.4904]], device='cuda:0')
# -------step:  10
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.01490037  0.14557914  0.00281457 -0.19377126] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0149,  0.1456,  0.0028, -0.1938]], device='cuda:0')
# -------step:  11
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.01781195 -0.04958295 -0.00106086  0.09979821] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0178, -0.0496, -0.0011,  0.0998]], device='cuda:0')
# -------step:  12
# action:  tensor([[1]], device='cuda:0')
# action item:  1
# observation:  [ 0.01682029  0.14555418  0.00093511 -0.19321923] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0168,  0.1456,  0.0009, -0.1932]], device='cuda:0')
# -------step:  13
# action:  tensor([[0]], device='cuda:0')
# action item:  0
# observation:  [ 0.01973138 -0.04958113 -0.00292928  0.09975854] reward:  1.0 terminated:  False truncated:  False
# type obs:  <class 'numpy.ndarray'>
# next_state tensor([[ 0.0197, -0.0496, -0.0029,  0.0998]], device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 45
#      42 state = next_state
#      44 # Perform one step of the optimization (on the policy network)
# ---> 45 optimize_model()
#      47 # Soft update of the target network's weights
#      48 # θ′ ← τ θ + (1 −τ )θ′
#      49 target_net_state_dict = target_net.state_dict()
#
# Cell In[6], line 45, in optimize_model()
#      43 # In-place gradient clipping
#      44 torch.nn.utils.clip_grad_value_(policy_net.parameters(), 100)
# ---> 45 optimizer.step()
#
# File ~\anaconda3\envs\RL_env\Lib\site-packages\torch\optim\optimizer.py:373, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     368         else:
#     369             raise RuntimeError(
#     370                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     371             )
# --> 373 out = func(*args, **kwargs)
#     374 self._optimizer_step_code()
#     376 # call optimizer step post hooks
#
# File ~\anaconda3\envs\RL_env\Lib\site-packages\torch\optim\optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File ~\anaconda3\envs\RL_env\Lib\site-packages\torch\optim\adamw.py:184, in AdamW.step(self, closure)
#     171     beta1, beta2 = group["betas"]
#     173     self._init_group(
#     174         group,
#     175         params_with_grad,
#    (...)
#     181         state_steps,
#     182     )
# --> 184     adamw(
#     185         params_with_grad,
#     186         grads,
#     187         exp_avgs,
#     188         exp_avg_sqs,
#     189         max_exp_avg_sqs,
#     190         state_steps,
#     191         amsgrad=amsgrad,
#     192         beta1=beta1,
#     193         beta2=beta2,
#     194         lr=group["lr"],
#     195         weight_decay=group["weight_decay"],
#     196         eps=group["eps"],
#     197         maximize=group["maximize"],
#     198         foreach=group["foreach"],
#     199         capturable=group["capturable"],
#     200         differentiable=group["differentiable"],
#     201         fused=group["fused"],
#     202         grad_scale=getattr(self, "grad_scale", None),
#     203         found_inf=getattr(self, "found_inf", None),
#     204     )
#     206 return loss
#
# File ~\anaconda3\envs\RL_env\Lib\site-packages\torch\optim\adamw.py:335, in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     332 else:
#     333     func = _single_tensor_adamw
# --> 335 func(
#     336     params,
#     337     grads,
#     338     exp_avgs,
#     339     exp_avg_sqs,
#     340     max_exp_avg_sqs,
#     341     state_steps,
#     342     amsgrad=amsgrad,
#     343     beta1=beta1,
#     344     beta2=beta2,
#     345     lr=lr,
#     346     weight_decay=weight_decay,
#     347     eps=eps,
#     348     maximize=maximize,
#     349     capturable=capturable,
#     350     differentiable=differentiable,
#     351     grad_scale=grad_scale,
#     352     found_inf=found_inf,
#     353 )
#
# File ~\anaconda3\envs\RL_env\Lib\site-packages\torch\optim\adamw.py:543, in _multi_tensor_adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     540 torch._foreach_lerp_(device_exp_avgs, device_grads, 1 - beta1)
#     542 torch._foreach_mul_(device_exp_avg_sqs, beta2)
# --> 543 torch._foreach_addcmul_(device_exp_avg_sqs, device_grads, device_grads, 1 - beta2)
#     545 # Delete the local intermediate since it won't be used anymore to save on peak memory
#     546 del device_grads
#
# KeyboardInterrupt:
