# %%
import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count
import numpy as np

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
'''Dynamic Programming, FCFS Simulated result'''
dp = 61135
fcfs = 45564

# %%
'''Establish an aircraft'''
class aircraft:

    # Initialize aircraft
    def __init__(self):
        self.seat_capacity = 100
        self.seat_type = ['Y', 'M', 'K']
        self.seat_price = {'f': 0, 'Y': 800, 'M': 500, 'K': 450}

# %%
''' Demand model from Balaiyan et al.'''
class demandmodel:
    
    # Initialize demand model
    def __init__(self):
        
        # inherent attributes from aircraft class
        self.aircraft = aircraft()
        self.seat_set = self.aircraft.seat_type
        self.seat_price = self.aircraft.seat_price
        
        # demand model parameters
        self.total_booking = 105
        self.market_share = 0.25
        self.gamma = 0.08426
        self.alpha = 0.001251
        self.beta = {'DFARE':-0.006, 'LOT3':-0.944}
        self.a = {'Y':{'DFARE':800, 'LOT3':1},
                  'M':{'DFARE':500, 'LOT3':1},
                  'K':{'DFARE':450, 'LOT3':1},
                 }
        self.fare_diff_avg = sum(self.seat_price.values()) / len(self.seat_price)
        for seat_type in self.a:
            self.a[seat_type]['DFARE'] = round(self.a[seat_type]['DFARE'] - self.fare_diff_avg, 2)

    # Calculate dm
    def dm(self):
        dm = self.total_booking/self.market_share
        return dm

    # Calcilate booking curve
    def booking_curve(self, RD2, RD1):
        booking_curve = math.exp(-self.gamma*RD2)-math.exp(-self.gamma*RD1)
        return booking_curve

    # find pj+1
    def find_pj1(self, seat):
        smaller_keys = [key for key in self.seat_price.keys() if key < seat]
        if smaller_keys:
            max_smaller_key = max(smaller_keys)
            pj1 = self.seat_price[max_smaller_key]
        else:
            pj1 = min(self.seat_price.values())
        return pj1

    # Multinomial logit model
    def mnl(self):
        choose_prob = {}
        value_dict = {}
        for seat in self.seat_set:
            result = {key: self.beta[key] * value for key, value in self.a[seat].items()}
            total = sum(result.values())
            value = math.exp(total)
            value_dict[seat] = value
        for seat in value_dict:
            exp_value = math.exp(value_dict[seat])
            choose_prob[seat] = exp_value / sum(math.exp(value) for value in value_dict.values())
        # print("mnl: ", choose_prob)
        return choose_prob

    # Calculate customer choice
    def customer_choice(self, seat_type):
        total_sum = 0
        choose_prob = self.mnl()
        min_key = min(self.seat_price, key=self.seat_price.get)
        p0 = self.seat_price[min_key]
        for seat in self.seat_set:
            pj = self.seat_price['Y'] # 暫時寫這樣
            pj1 = self.seat_price['M'] # 暫時寫這樣
            # print('p0: ',p0 , 'p1: ', pj, 'pj1: ', pj1)
            sum_of_set = (math.exp(-self.alpha*(pj-p0))-math.exp(-self.alpha*(pj1-p0))) * choose_prob[seat_type] 
            # print('sum of set: ', sum_of_set)
            total_sum += sum_of_set
        return total_sum

    # Calculate demand
    def formulation(self, RD2, RD1):
        dm = self.dm()
        # print('dm',dm)
        booking_curve = self.booking_curve(RD2, RD1)
        # print('booking curve: ',booking_curve)
        BR_dict = {}
        
        for seat in self.seat_set:
            # print("calculate", seat, " ing...")
            customer_choice = self.customer_choice(seat)
            # print('customer choice', customer_choice)
            BR = dm * booking_curve * customer_choice
            BR_dict[seat] = BR
            # print(' seat: ', seat, ' predicted demand model from ', RD2,' to ', RD1, 'is', BR)
        print("total demand: ", sum(BR_dict.values()))
        return BR_dict
    
    # Plot demand result
    def plot_demand(self):
        
        # Store calculated result
        every_rd = {seat: [] for seat in model.seat_set}  
        cumulative_demand = {seat: [] for seat in model.seat_set}  
        total_demand = {seat: 0 for seat in model.seat_set}  
        cumulative_total_demand_per_rd = []  # Store each RD cumulative demand

        # Calculate all RD demand
        cumulative_total_demand = 0  # Initialize cumulative demand
        for i in range(2, max_rd+1):
            # print('i: ', i)
            BR_results = model.formulation(i, i-1)  
            total_demand_rd = sum(BR_results.values())  # Calculate demand form all rd
            cumulative_total_demand += total_demand_rd  # update cumulative total deamnd
            cumulative_total_demand_per_rd.append(cumulative_total_demand)  # append cumulative total demand
            for seat, demand in BR_results.items():  
                every_rd[seat].append(demand) 
                total_demand[seat] += demand  
                cumulative_demand[seat].append(total_demand[seat])  
        
        plt.figure(figsize=(10, 6))
        plt.plot(range(1, max_rd), cumulative_total_demand_per_rd, label='Total Demand')
        plt.xlabel('RD')
        plt.ylabel('Total Demand')
        plt.title('Total Demand Model')
        plt.legend()
        plt.xticks(range(0, max_rd, int(max_rd/10)))
        plt.grid(True)
        plt.show()

# %%
class AgentActionSpace:
    def __init__(self):
        self.action_list = [0, 1, 2, 3, 4, 5, 6, 7]
        self.n = len(action_list)  # 動作的數量

    def sample(self):
        return np.random.choice(self.action_list)

    def contains(self, action):
        return action in self.action_list

# 創建一個列表動作空間
action_list = [0, 1, 2, 3, 4, 5, 6, 7]
action_space = AgentActionSpace()
print(type(action_space))
# Out:
# <class '__main__.AgentActionSpace'>

# %%
'''Uniform distribution'''
class uniform_distribution:

    # Initialize parameters
    def __init__(self, total_demand, total_lambda):
        self.total_demand = total_demand
        self.total_lambda = total_lambda
        self.num_period = int(total_demand/total_lambda)
        self.prob = {'Bus1': 0.1, 'Bus2': 0.2, 'Leis1': 0.2, 'Leis2': 0.2, 'Leis3': 0.3}
    
    # Calculate lambda for each type of customer
    def calculate_lambda(self):
        lambda_list = []
        lambda_list.append(round(1-self.total_lambda, 2))
        for customer in self.prob:
            lambda_list.append(round(self.prob[customer] * self.total_lambda, 2)) 
        print("lambda_list: ", lambda_list)
        return lambda_list

# %%
'''Establish Customer class'''
class Customer:

    ''' Initialization '''
    def __init__(self, total_demand, total_lambda):
        self.customer_type = {0: 'f', 1: 'Bus1', 2:'Bus2', 3:'Leis1', 4: 'Leis2', 5: 'Leis3'}
        self.num_customer_type = len(self.customer_type)
        self.customer_preference = {
            'f':{'Y': False, 'M': False, 'K': False},
            'Bus1': {'Y': True, 'M': False, 'K': False},
            'Bus2': {'Y': True, 'M': True, 'K': False},
            'Leis1': {'Y': False, 'M': True, 'K': False},
            'Leis2': {'Y': False, 'M': True, 'K': True},
            'Leis3': {'Y': False, 'M': False, 'K': True},
        }

        # inherent from uniform distribution class
        self.uniform_distribution = uniform_distribution(total_demand, total_lambda)
        self.arrival_rates = self.uniform_distribution.calculate_lambda() # calculate arrival rates for each customer type

        # inherent from aircraft class
        self.aircraft = aircraft()
        self.seat_price = self.aircraft.seat_price

    '''Customer generation'''
    def generate_customer(self):
        random_number = np.random.rand() # generate random number
        probabilities = self.arrival_rates # arrival rates list
        cumulative_probability = 0 # Use cumulative probability decide customer type
        customer_index = 0
        for probability in probabilities:
            cumulative_probability += probability
            if random_number <= cumulative_probability:
                break
            customer_index += 1
        customer_type = self.customer_type[customer_index] # return customer will buy what kind of seat   
        print(f"random_number: {random_number}, customer_index: {customer_index}, customer_type: {customer_type}")
        return customer_type

    '''customer's preference seat under control'''
    def preference_seat(self, customer_type, seat_open):
        preferred_seats = []  
        preferences = self.customer_preference[customer_type]  
        for seat_type, preference in preferences.items():
            if preference and seat_type in seat_open:
                preferred_seats.append(seat_type)
        # print("preference seats: ", preferred_seats)
        return preferred_seats  
    
    '''customer make decision'''
    def make_decision(self, customer_type, seat_open):
        preferred_seats = self.preference_seat(customer_type, seat_open)  
        if preferred_seats:
            cheapest_seat = min(preferred_seats, key=lambda x: self.seat_price[x])
            return cheapest_seat
        else:
            return 'f'

# %%
'''Establish env with Single Cabin mulitiple fare classes'''
class AirlineEnvironmentv2:
    
    '''Initialize env parameters'''
    def __init__(self, name):
        
        # name of env
        self.name = name
        
        # inherent aircraft
        self.aircraft = aircraft()
        self.seat_capacity = self.aircraft.seat_capacity # seat limitation
        self.seat_type = self.aircraft.seat_type # seat type
        
        # environment parameters
        self.seat_remain = self.seat_capacity # seat limitation
        self.state = (self.seat_capacity, 1) # Initialize state : (num seat sold, period)
        self.a_s_ref = {0: 'f', 1: 'Y', 2: 'M', 3: 'K', 4: 'YM', 5: 'YK', 6: 'MK', 7: 'YMK'} # action reference to seat open combination
        self.seat_combination = {
            'f': {'f': 0.0, 'Y': 0.0, 'M': 0.0, 'K': 0.0},
            'Y': {'f': 0.0, 'Y': 800, 'M': 0.0, 'K': 0.0},
            'M': {'f': 0.0, 'Y': 0.0, 'M': 500, 'K': 0.0},
            'K': {'f': 0.0, 'Y': 0.0, 'M': 0.0, 'K': 450},
            'YM': {'f': 0.0, 'Y': 800, 'M': 500, 'K': 0.0},
            'YK': {'f': 0.0, 'Y': 800, 'M': 0.0, 'K': 450},
            'MK': {'f': 0.0, 'Y': 0.0, 'M': 500, 'K': 450},
            'YMK': {'f': 0.0, 'Y': 800, 'M': 500, 'K': 450}
        } # Seat combination & seat open
        
        # inherent action space class
        self.action_space = AgentActionSpace() 
        
        # inherent attributes from demand model
        self.max_rd = 20 # total selling RDs
        self.demand_model = demandmodel()
        self.total_demand = sum(self.demand_model.formulation(self.max_rd, 1).values()) # total demand from demand model
        self.total_lambda = 0.8 # total lambda from test
        self.max_period = self.total_demand/self.total_lambda # total period
        
        # inherent attributes from uniform distribution class
        self.uniform_distribution = uniform_distribution(self.total_demand, self.total_lambda)
        self.arrival_rates = self.uniform_distribution.calculate_lambda() # calculate arrival rates for each customer type

        # inherent attributes from Customer class
        self.customer = Customer(self.total_demand, self.total_lambda) 
        
    '''reset env'''
    def reset(self):
        self.seat_remain = self.seat_capacity # Initialize total seat 
        self.state = (self.seat_remain, 1)  # Initialize state
        return self.state

    '''Step'''
    def step_v2(self, state, action):

        # total reward this RD
        total_reward = 0
        
        # Agent choose a seat combination
        seat_open = self.a_s_ref[action]   
        # print("seat_open: ", seat_open)

        # calculate reward this period
        for period in range(1, int(self.max_period/self.max_rd)):
            
            # With remaining seat
            if self.seat_remain > 0:
                
                # Customer generation
                customer_type = self.customer.generate_customer()
                # print("customer type: ", customer_type)
    
                # Customer choose seat
                chosen_seat = self.customer.make_decision(customer_type, seat_open) 
                # print("chosen seat: ", chosen_seat)
    
                # Decide immediate revenue
                reward = self.aircraft.seat_price[chosen_seat] 
    
                # Update seat remain
                if reward > 0:
                    self.seat_remain = self.seat_remain-1
            
            # Without remaining seat
            else:
                # print("No remaining seat.")
                reward = 0

            # add reward to total reward this period
            # print("reward: ", reward)
            total_reward += reward
            # print("total reward: ", total_reward)
    
        # Update rd
        next_rd = state[0, 1].item() + 1
            
        # Check departure or not 
        departure = (next_rd >= self.max_rd+1)
    
        # update state
        state[0, 0] = self.seat_remain
        state[0, 1] = next_rd            
        # print(f"state[0, 0]: {state[0, 0]}, state[0, 1]: {state[0, 1]}")    
        return state.cpu().detach().numpy(), total_reward, departure

# %%
# if GPU is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Define tuple structure, use tuple structure to store info
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))

''' Establish Memory Replay Buffer '''
class ReplayMemory(object):

    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)

    def push(self, *args):
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
''' 建構 DQN '''
class DQN(nn.Module):

    def __init__(self, n_observations, n_actions):
        super(DQN, self).__init__()
        self.layer1 = nn.Linear(n_observations, 128)
        self.layer2 = nn.Linear(128, 128)
        self.layer3 = nn.Linear(128, n_actions)

    # Called with either one element to determine next action, or a batch
    # during optimization. Returns tensor([[left0exp,right0exp]...]).
    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        return self.layer3(x)

# %%
'''Establish environment from Airline env'''
env = AirlineEnvironmentv2("Single route parallel flight.v0")

''' Reinforcement Learning Hyparameter '''
BATCH_SIZE = 128  # Batch size from experience replay buffer
GAMMA = 0.99  # Reward discount rate Gamma
EPS_START = 0.9  # Epilson-Greedy strategy's hyparameter eplison
EPS_END = 0.05 # Final value of eplison 
EPS_DECAY = 1000 # Control eplison decay，higher represent slower decay
TAU = 0.005 # Update rate of target network
LR = 1e-4 # Learning rate of optimizer

''' Simulated Environment Parameter '''
n_actions = env.action_space.n # num action
state = env.reset() # initialize env
n_observations = len(state) # num state

''' Establish Policy Network, Target Network '''
policy_net = DQN(n_observations, n_actions).to(device) # Policy Network
target_net = DQN(n_observations, n_actions).to(device) # Target Network
target_net.load_state_dict(policy_net.state_dict())
memory = ReplayMemory(10000) # Memory size of Replay Buffer
optimizer = optim.AdamW(policy_net.parameters(), lr=LR, amsgrad=True) # AdamW optimizer

''' Agent Select Action'''
steps_done = 0
def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        # Exploit：Select Max Value action
        with torch.no_grad():
            # t.max(1) return max expected value column
            return policy_net(state).max(1).indices.view(1, 1)
    else:
        # Explore：Randomly select action
        return torch.tensor([[env.action_space.sample()]], device=device, dtype=torch.long)
# Out:
# total demand:  154.78080374954658
# lambda_list:  [0.2, 0.08, 0.16, 0.16, 0.16, 0.24]
# lambda_list:  [0.2, 0.08, 0.16, 0.16, 0.16, 0.24]

# %%
''' Optimize Network '''
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    batch = Transition(*zip(*transitions)) # Converts batch-array of Transitions to Transition of batch-arrays.

    # Compute a mask of non-final states and concatenate the batch elements
    # (a final state would've been the one after which simulation ended)
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
    # columns of actions taken. These are the actions which would've been taken
    # for each batch state according to policy_net
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Compute V(s_{t+1}) for all next states.
    # Expected values of actions for non_final_next_states are computed based
    # on the "older" target_net; selecting their best reward with max(1).values
    # This is merged based on the mask, such that we'll have either the expected
    # state value or 0 in case the state was final.
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    with torch.no_grad():
        next_state_values[non_final_mask] = target_net(non_final_next_states).max(1).values
    # Compute the expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Compute Huber loss
    criterion = nn.SmoothL1Loss()
    loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    
    # In-place gradient clipping
    torch.nn.utils.clip_grad_value_(policy_net.parameters(), 100)
    optimizer.step()

# %%
# Initialize Training parameters
num_episodes = 3000
DQN_total_revenues = []
DQN_cumulative_average = []
DQN_per_50_avg = []

# Start Training
for episode in range(num_episodes):
    
    # Initialize environment
    print("---------- Episode ", episode, "-----------")
    state = env.reset()
    state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
    total_revenue = 0 # Initialize total revenue
    
    for step in count():
        
        # print("------- step " ,step + 1 ," ---------")
        
        # agent 選擇動作
        action = select_action(state)
        # print("action: ", action)

        observation, reward, departure = env.step_v2(state, action.item())
        # print("observation: ", observation, "reward: ",  reward, "departure: ", departure)
        reward = torch.tensor([reward], device=device)
        done = departure

        if departure:
            break
        else:
            observation = observation.flatten()
            next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)

        # Update total revenue
        total_revenue += reward

        # Store the transition in memory
        memory.push(state, action, next_state, reward)

        # Move on to the next state
        state = next_state

        # Perform one step of the optimization (on the policy network)
        optimize_model()

        # Soft update of the target network's weights
        # θ′ ← τ θ + (1 −τ )θ′
        target_net_state_dict = target_net.state_dict()
        policy_net_state_dict = policy_net.state_dict()
        for key in policy_net_state_dict:
            target_net_state_dict[key] = policy_net_state_dict[key]*TAU + target_net_state_dict[key]*(1-TAU)
        target_net.load_state_dict(target_net_state_dict)
    
    # 將每個 episode 的 total reward 加入列表中  
    DQN_total_revenues.append(total_revenue.cpu().numpy()) 
    
    # 計算每50個 episode 的平均總獎勵
    if episode % 50 == 0 and episode != 0:
        DQN_per_50_avg.append(np.mean(DQN_total_revenues[-50:]))
    
    # 累積平均獎勵
    DQN_cumulative_avg = sum(DQN_total_revenues) / (episode + 1)
    DQN_cumulative_average.append(DQN_cumulative_avg)
    print(f"Episode: {episode}, Total Revenue: {total_revenue}, Cumulative average: {DQN_cumulative_avg}")
# Out:
# ---------- Episode  0 -----------
# random_number: 0.0505566286272604, customer_index: 0, customer_type: f
# random_number: 0.6206713659819961, customer_index: 4, customer_type: Leis2
# random_number: 0.7040437645875989, customer_index: 4, customer_type: Leis2
# random_number: 0.1821638819019169, customer_index: 0, customer_type: f
# random_number: 0.5694514759640049, customer_index: 3, customer_type: Leis1
# random_number: 0.1537483793606116, customer_index: 0, customer_type: f
# random_number: 0.06274221770833588, customer_index: 0, customer_type: f
# random_number: 0.07412673969574624, customer_index: 0, customer_type: f
# random_number: 0.9805094220671061, customer_index: 5, customer_type: Leis3
# random_number: 0.7955806254122563, customer_index: 5, customer_type: Leis3
# random_number: 0.9866635547884887, customer_index: 5, customer_type: Leis3
# random_number: 0.5809042441422412, customer_index: 3, customer_type: Leis1
# random_number: 0.12798547218575496, customer_index: 0, customer_type: f
# random_number: 0.5698094001227004, customer_index: 3, customer_type: Leis1
# random_number: 0.5222966507310688, customer_index: 3, customer_type: Leis1
# random_number: 0.8710961587485399, customer_index: 5, customer_type: Leis3
# random_number: 0.7740676476958788, customer_index: 5, customer_type: Leis3
# random_number: 0.8396900295840937, customer_index: 5, customer_type: Leis3
# random_number: 0.2970894200977614, customer_index: 2, customer_type: Bus2
# random_number: 0.4126811330228637, customer_index: 2, customer_type: Bus2
# random_number: 0.22864180898534203, customer_index: 1, customer_type: Bus1
# random_number: 0.2911084582251574, customer_index: 2, customer_type: Bus2
# random_number: 0.06914946498076058, customer_index: 0, customer_type: f
# random_number: 0.5295777244209527, customer_index: 3, customer_type: Leis1
# random_number: 0.346916782490851, customer_index: 2, customer_type: Bus2
# random_number: 0.7764069104492245, customer_index: 5, customer_type: Leis3
# random_number: 0.06943274647593545, customer_index: 0, customer_type: f
# random_number: 0.9112493643705584, customer_index: 5, customer_type: Leis3
# random_number: 0.23874293965538307, customer_index: 1, customer_type: Bus1
# random_number: 0.6385748571594961, customer_index: 4, customer_type: Leis2
# random_number: 0.5954422495040576, customer_index: 3, customer_type: Leis1
# random_number: 0.1758135121917591, customer_index: 0, customer_type: f
# random_number: 0.7144613217926887, customer_index: 4, customer_type: Leis2
# random_number: 0.01809769889374835, customer_index: 0, customer_type: f
# random_number: 0.6208457371079642, customer_index: 4, customer_type: Leis2
# random_number: 0.19864878050922963, customer_index: 0, customer_type: f
# random_number: 0.05790282886083087, customer_index: 0, customer_type: f
# random_number: 0.16484543791589923, customer_index: 0, customer_type: f
# random_number: 0.6346457276232936, customer_index: 4, customer_type: Leis2
# random_number: 0.7083772055497506, customer_index: 4, customer_type: Leis2
# random_number: 0.18689555320883222, customer_index: 0, customer_type: f
# random_number: 0.9132405931018405, customer_index: 5, customer_type: Leis3
# random_number: 0.5164144458321493, customer_index: 3, customer_type: Leis1
# random_number: 0.09970377383036022, customer_index: 0, customer_type: f
# random_number: 0.6775026908400079, customer_index: 4, customer_type: Leis2
# random_number: 0.043210768942746225, customer_index: 0, customer_type: f
# random_number: 0.08726258059083813, customer_index: 0, customer_type: f
# random_number: 0.4701981957534298, customer_index: 3, customer_type: Leis1
# random_number: 0.6781087712434627, customer_index: 4, customer_type: Leis2
# random_number: 0.42970420192922365, customer_index: 2, customer_type: Bus2
# random_number: 0.48564335118280544, customer_index: 3, customer_type: Leis1
# random_number: 0.23480842535132218, customer_index: 1, customer_type: Bus1
# random_number: 0.8589366156588562, customer_index: 5, customer_type: Leis3
# random_number: 0.22228653811344912, customer_index: 1, customer_type: Bus1
# random_number: 0.08232083842125848, customer_index: 0, customer_type: f
# random_number: 0.49029405613386245, customer_index: 3, customer_type: Leis1
# random_number: 0.3104142680667874, customer_index: 2, customer_type: Bus2
# random_number: 0.6880998930971394, customer_index: 4, customer_type: Leis2
# random_number: 0.4327245636539583, customer_index: 2, customer_type: Bus2
# random_number: 0.7606001202537243, customer_index: 5, customer_type: Leis3
# random_number: 0.9479825748384443, customer_index: 5, customer_type: Leis3
# random_number: 0.8632124484368915, customer_index: 5, customer_type: Leis3
# random_number: 0.8557542629278441, customer_index: 5, customer_type: Leis3
# random_number: 0.8191732555182788, customer_index: 5, customer_type: Leis3
# random_number: 0.4294268797155739, customer_index: 2, customer_type: Bus2
# random_number: 0.8967509887606103, customer_index: 5, customer_type: Leis3
# random_number: 0.7564148862738095, customer_index: 4, customer_type: Leis2
# random_number: 0.3510306936572112, customer_index: 2, customer_type: Bus2
# random_number: 0.6552111184174098, customer_index: 4, customer_type: Leis2
# random_number: 0.3300154858282909, customer_index: 2, customer_type: Bus2
# random_number: 0.06521044141653753, customer_index: 0, customer_type: f
# random_number: 0.48850549253807063, customer_index: 3, customer_type: Leis1
# random_number: 0.8911365047001361, customer_index: 5, customer_type: Leis3
# random_number: 0.2026153126917577, customer_index: 1, customer_type: Bus1
# random_number: 0.9544006820065529, customer_index: 5, customer_type: Leis3
# random_number: 0.10578445333909758, customer_index: 0, customer_type: f
# random_number: 0.9656624490407453, customer_index: 5, customer_type: Leis3
# random_number: 0.3198871655635669, customer_index: 2, customer_type: Bus2
# random_number: 0.25094586217337334, customer_index: 1, customer_type: Bus1
# random_number: 0.8312345334810576, customer_index: 5, customer_type: Leis3
# random_number: 0.13791669398674855, customer_index: 0, customer_type: f
# random_number: 0.48551103438592247, customer_index: 3, customer_type: Leis1
# random_number: 0.06283778842450671, customer_index: 0, customer_type: f
# random_number: 0.15298176655705864, customer_index: 0, customer_type: f
# random_number: 0.5855473339880791, customer_index: 3, customer_type: Leis1
# random_number: 0.9492445185519968, customer_index: 5, customer_type: Leis3
# random_number: 0.6116810736685351, customer_index: 4, customer_type: Leis2
# random_number: 0.2607212690487698, customer_index: 1, customer_type: Bus1
# random_number: 0.3406921910825511, customer_index: 2, customer_type: Bus2
# random_number: 0.6037544112350243, customer_index: 4, customer_type: Leis2
# random_number: 0.2016657422814443, customer_index: 1, customer_type: Bus1
# random_number: 0.3550422170227514, customer_index: 2, customer_type: Bus2
# random_number: 0.6670241331175523, customer_index: 4, customer_type: Leis2
# random_number: 0.6315778265040086, customer_index: 4, customer_type: Leis2
# random_number: 0.534098690805295, customer_index: 3, customer_type: Leis1
# random_number: 0.41379570075508254, customer_index: 2, customer_type: Bus2
# random_number: 0.07598987465061469, customer_index: 0, customer_type: f
# random_number: 0.8729393101079802, customer_index: 5, customer_type: Leis3
# random_number: 0.29910549229839445, customer_index: 2, customer_type: Bus2
# random_number: 0.1336646964249808, customer_index: 0, customer_type: f
# random_number: 0.011770071845566443, customer_index: 0, customer_type: f
# random_number: 0.8829173910017557, customer_index: 5, customer_type: Leis3
# random_number: 0.5301916563958831, customer_index: 3, customer_type: Leis1
# random_number: 0.35065281727983333, customer_index: 2, customer_type: Bus2
# random_number: 0.9104564017268619, customer_index: 5, customer_type: Leis3
# random_number: 0.047486491947754006, customer_index: 0, customer_type: f
# random_number: 0.45785260938208094, customer_index: 3, customer_type: Leis1
# random_number: 0.8318695960390753, customer_index: 5, customer_type: Leis3
# random_number: 0.5513727838338578, customer_index: 3, customer_type: Leis1
# random_number: 0.15794786110889592, customer_index: 0, customer_type: f
# random_number: 0.7096733015725697, customer_index: 4, customer_type: Leis2
# random_number: 0.6023246146097953, customer_index: 4, customer_type: Leis2
# random_number: 0.40855762110403904, customer_index: 2, customer_type: Bus2
# random_number: 0.10126897306101612, customer_index: 0, customer_type: f
# random_number: 0.8587058131527865, customer_index: 5, customer_type: Leis3
# random_number: 0.7336844189499467, customer_index: 4, customer_type: Leis2
# random_number: 0.14007706049379554, customer_index: 0, customer_type: f
# random_number: 0.6011251843747235, customer_index: 4, customer_type: Leis2
# random_number: 0.9072101472445936, customer_index: 5, customer_type: Leis3
# random_number: 0.5111853971751478, customer_index: 3, customer_type: Leis1
# random_number: 0.6487530892912422, customer_index: 4, customer_type: Leis2
# random_number: 0.2621170614216425, customer_index: 1, customer_type: Bus1
# random_number: 0.8354154005194295, customer_index: 5, customer_type: Leis3
# random_number: 0.4930005320172285, customer_index: 3, customer_type: Leis1
# random_number: 0.9334752868250576, customer_index: 5, customer_type: Leis3
# random_number: 0.30746289293231177, customer_index: 2, customer_type: Bus2
# random_number: 0.8502667131751354, customer_index: 5, customer_type: Leis3
# random_number: 0.7908926489478387, customer_index: 5, customer_type: Leis3
# random_number: 0.6300622273148985, customer_index: 4, customer_type: Leis2
# random_number: 0.6816299278307811, customer_index: 4, customer_type: Leis2
# random_number: 0.12603636378159377, customer_index: 0, customer_type: f
# random_number: 0.4897054978448053, customer_index: 3, customer_type: Leis1
# random_number: 0.6398938114525233, customer_index: 4, customer_type: Leis2
# random_number: 0.13324346078872862, customer_index: 0, customer_type: f
# random_number: 0.12093808338530687, customer_index: 0, customer_type: f
# random_number: 0.20692693094387926, customer_index: 1, customer_type: Bus1
# random_number: 0.8056011244279743, customer_index: 5, customer_type: Leis3
# random_number: 0.6658873168438554, customer_index: 4, customer_type: Leis2
# random_number: 0.609681700913467, customer_index: 4, customer_type: Leis2
# random_number: 0.6225891607974048, customer_index: 4, customer_type: Leis2
# random_number: 0.22713107897871188, customer_index: 1, customer_type: Bus1
# random_number: 0.5645673999698189, customer_index: 3, customer_type: Leis1
# random_number: 0.79465290135614, customer_index: 5, customer_type: Leis3
# random_number: 0.9433376265280818, customer_index: 5, customer_type: Leis3
# random_number: 0.7447823580200562, customer_index: 4, customer_type: Leis2
# random_number: 0.06353432652854474, customer_index: 0, customer_type: f
# random_number: 0.37474925705512363, customer_index: 2, customer_type: Bus2
# random_number: 0.726907311676366, customer_index: 4, customer_type: Leis2
# random_number: 0.22411316207134124, customer_index: 1, customer_type: Bus1
# random_number: 0.4114863993448047, customer_index: 2, customer_type: Bus2
# random_number: 0.7884886880903359, customer_index: 5, customer_type: Leis3
# random_number: 0.1405890689559981, customer_index: 0, customer_type: f
# random_number: 0.8226234962676556, customer_index: 5, customer_type: Leis3
# random_number: 0.026240035115891902, customer_index: 0, customer_type: f
# random_number: 0.557700230155761, customer_index: 3, customer_type: Leis1
# random_number: 0.2817663315674023, customer_index: 2, customer_type: Bus2
# random_number: 0.9949474458643629, customer_index: 5, customer_type: Leis3
# random_number: 0.2807555446288721, customer_index: 2, customer_type: Bus2
# random_number: 0.8696329206627026, customer_index: 5, customer_type: Leis3
# random_number: 0.1953524858037825, customer_index: 0, customer_type: f
# Episode: 0, Total Revenue: tensor([32700], device='cuda:0'), Cumulative average: [32700.]
# ---------- Episode  1 -----------
# random_number: 0.4080826141160693, customer_index: 2, customer_type: Bus2
# random_number: 0.3002845271700565, customer_index: 2, customer_type: Bus2
# random_number: 0.60017234837553, customer_index: 4, customer_type: Leis2
# random_number: 0.5474218134328646, customer_index: 3, customer_type: Leis1
# random_number: 0.9282081606886107, customer_index: 5, customer_type: Leis3
# random_number: 0.3469192806545893, customer_index: 2, customer_type: Bus2
# random_number: 0.9492794339558847, customer_index: 5, customer_type: Leis3
# random_number: 0.8651850223559716, customer_index: 5, customer_type: Leis3
# random_number: 0.8556675535489183, customer_index: 5, customer_type: Leis3
# random_number: 0.4641705952651084, customer_index: 3, customer_type: Leis1
# random_number: 0.03163104724151189, customer_index: 0, customer_type: f
# random_number: 0.9418573794633964, customer_index: 5, customer_type: Leis3
# random_number: 0.10519841280426523, customer_index: 0, customer_type: f
# random_number: 0.8565226708289502, customer_index: 5, customer_type: Leis3
# random_number: 0.580393637025735, customer_index: 3, customer_type: Leis1
# random_number: 0.3040029328389372, customer_index: 2, customer_type: Bus2
# random_number: 0.8384205533748679, customer_index: 5, customer_type: Leis3
# random_number: 0.9283908653334586, customer_index: 5, customer_type: Leis3
# random_number: 0.48723543140265757, customer_index: 3, customer_type: Leis1
# random_number: 0.9763271201262255, customer_index: 5, customer_type: Leis3
# random_number: 0.5071795693259571, customer_index: 3, customer_type: Leis1
# random_number: 0.2413273825827894, customer_index: 1, customer_type: Bus1
# random_number: 0.07049708936581645, customer_index: 0, customer_type: f
# random_number: 0.13665255584225722, customer_index: 0, customer_type: f
# random_number: 0.9342432776414771, customer_index: 5, customer_type: Leis3
# random_number: 0.04799312999015137, customer_index: 0, customer_type: f
# random_number: 0.9215350869844888, customer_index: 5, customer_type: Leis3
# random_number: 0.8617565756047766, customer_index: 5, customer_type: Leis3
# random_number: 0.721564090739849, customer_index: 4, customer_type: Leis2
# random_number: 0.659133246124563, customer_index: 4, customer_type: Leis2
# random_number: 0.1365318299280438, customer_index: 0, customer_type: f
# random_number: 0.09888432738818709, customer_index: 0, customer_type: f
# random_number: 0.3791448224529691, customer_index: 2, customer_type: Bus2
# random_number: 0.4517957541561245, customer_index: 3, customer_type: Leis1
# random_number: 0.653045581929256, customer_index: 4, customer_type: Leis2
# random_number: 0.2571048779026902, customer_index: 1, customer_type: Bus1
# random_number: 0.7218152046276065, customer_index: 4, customer_type: Leis2
# random_number: 0.7394758156116596, customer_index: 4, customer_type: Leis2
# random_number: 0.3551815266427073, customer_index: 2, customer_type: Bus2
# random_number: 0.36080803305493747, customer_index: 2, customer_type: Bus2
# random_number: 0.19186794008805563, customer_index: 0, customer_type: f
# random_number: 0.6727649891647485, customer_index: 4, customer_type: Leis2
# random_number: 0.7220175949296657, customer_index: 4, customer_type: Leis2
# random_number: 0.5191029694937785, customer_index: 3, customer_type: Leis1
# random_number: 0.31123640610355296, customer_index: 2, customer_type: Bus2
# random_number: 0.598083388493892, customer_index: 3, customer_type: Leis1
# random_number: 0.03203533584719198, customer_index: 0, customer_type: f
# random_number: 0.7698624211046418, customer_index: 5, customer_type: Leis3
# random_number: 0.7159484705214593, customer_index: 4, customer_type: Leis2
# random_number: 0.11661889599757258, customer_index: 0, customer_type: f
# random_number: 0.8668332698154235, customer_index: 5, customer_type: Leis3
# random_number: 0.9311016755825946, customer_index: 5, customer_type: Leis3
# random_number: 0.35368512015271425, customer_index: 2, customer_type: Bus2
# random_number: 0.2596677593365564, customer_index: 1, customer_type: Bus1
# random_number: 0.8419196784665907, customer_index: 5, customer_type: Leis3
# random_number: 0.2266447206913591, customer_index: 1, customer_type: Bus1
# random_number: 0.7717871799328966, customer_index: 5, customer_type: Leis3
# random_number: 0.5111556439162581, customer_index: 3, customer_type: Leis1
# random_number: 0.11877294905862423, customer_index: 0, customer_type: f
# random_number: 0.29105559802887837, customer_index: 2, customer_type: Bus2
# random_number: 0.3495171794556631, customer_index: 2, customer_type: Bus2
# random_number: 0.6920640278286223, customer_index: 4, customer_type: Leis2
# random_number: 0.6060056406650802, customer_index: 4, customer_type: Leis2
# random_number: 0.1742257859053531, customer_index: 0, customer_type: f
# random_number: 0.12412467221585666, customer_index: 0, customer_type: f
# random_number: 0.9081839990165319, customer_index: 5, customer_type: Leis3
# random_number: 0.27780494787315846, customer_index: 1, customer_type: Bus1
# random_number: 0.380507267183089, customer_index: 2, customer_type: Bus2
# random_number: 0.8454812264757458, customer_index: 5, customer_type: Leis3
# random_number: 0.24289235396103703, customer_index: 1, customer_type: Bus1
# random_number: 0.9341161768346945, customer_index: 5, customer_type: Leis3
# random_number: 0.35287948841279293, customer_index: 2, customer_type: Bus2
# random_number: 0.28712420865355825, customer_index: 2, customer_type: Bus2
# random_number: 0.7177328483694405, customer_index: 4, customer_type: Leis2
# random_number: 0.5803153595540134, customer_index: 3, customer_type: Leis1
# random_number: 0.3280317228393482, customer_index: 2, customer_type: Bus2
# random_number: 0.3038896252019103, customer_index: 2, customer_type: Bus2
# random_number: 0.675463080312716, customer_index: 4, customer_type: Leis2
# random_number: 0.9969708306827495, customer_index: 5, customer_type: Leis3
# random_number: 0.9982024820763715, customer_index: 5, customer_type: Leis3
# random_number: 0.005680790410014458, customer_index: 0, customer_type: f
# random_number: 0.717677104867822, customer_index: 4, customer_type: Leis2
# random_number: 0.3894837706051283, customer_index: 2, customer_type: Bus2
# random_number: 0.06016281981735516, customer_index: 0, customer_type: f
# random_number: 0.03801846376308926, customer_index: 0, customer_type: f
# random_number: 0.6787130729310941, customer_index: 4, customer_type: Leis2
# random_number: 0.780310188897918, customer_index: 5, customer_type: Leis3
# random_number: 0.31087645389990526, customer_index: 2, customer_type: Bus2
# random_number: 0.18546855695633213, customer_index: 0, customer_type: f
# random_number: 0.4899824502862562, customer_index: 3, customer_type: Leis1
# random_number: 0.8397142743891695, customer_index: 5, customer_type: Leis3
# random_number: 0.17801894949178898, customer_index: 0, customer_type: f
# random_number: 0.6887133046188624, customer_index: 4, customer_type: Leis2
# random_number: 0.15168809416593065, customer_index: 0, customer_type: f
# random_number: 0.34038866237744314, customer_index: 2, customer_type: Bus2
# random_number: 0.014006785719526293, customer_index: 0, customer_type: f
# random_number: 0.9764421714762364, customer_index: 5, customer_type: Leis3
# random_number: 0.7173210729451908, customer_index: 4, customer_type: Leis2
# random_number: 0.5715714022042772, customer_index: 3, customer_type: Leis1
# random_number: 0.22992173033439978, customer_index: 1, customer_type: Bus1
# random_number: 0.15439707601816188, customer_index: 0, customer_type: f
# random_number: 0.3904592368193689, customer_index: 2, customer_type: Bus2
# random_number: 0.0010932981823669197, customer_index: 0, customer_type: f
# random_number: 0.08801147633822115, customer_index: 0, customer_type: f
# random_number: 0.2360996427466192, customer_index: 1, customer_type: Bus1
# random_number: 0.6399645817594539, customer_index: 4, customer_type: Leis2
# random_number: 0.2274009756861829, customer_index: 1, customer_type: Bus1
# random_number: 0.14947757978343756, customer_index: 0, customer_type: f
# random_number: 0.35869095864775546, customer_index: 2, customer_type: Bus2
# random_number: 0.43700139665606963, customer_index: 2, customer_type: Bus2
# random_number: 0.04368255670955545, customer_index: 0, customer_type: f
# random_number: 0.7885486407673543, customer_index: 5, customer_type: Leis3
# random_number: 0.10495138911833002, customer_index: 0, customer_type: f
# random_number: 0.5968600964504744, customer_index: 3, customer_type: Leis1
# random_number: 0.42754834240134576, customer_index: 2, customer_type: Bus2
# random_number: 0.7922062358664046, customer_index: 5, customer_type: Leis3
# random_number: 0.44551703712724866, customer_index: 3, customer_type: Leis1
# random_number: 0.9289009859319087, customer_index: 5, customer_type: Leis3
# random_number: 0.3880134215733233, customer_index: 2, customer_type: Bus2
# random_number: 0.1507545920549872, customer_index: 0, customer_type: f
# random_number: 0.04766552742229169, customer_index: 0, customer_type: f
# random_number: 0.6800961052779746, customer_index: 4, customer_type: Leis2
# random_number: 0.7444637330818543, customer_index: 4, customer_type: Leis2
# random_number: 0.9765556180802599, customer_index: 5, customer_type: Leis3
# random_number: 0.5387944467529849, customer_index: 3, customer_type: Leis1
# random_number: 0.9953647127650074, customer_index: 5, customer_type: Leis3
# random_number: 0.16583742774709964, customer_index: 0, customer_type: f
# random_number: 0.7836923420434438, customer_index: 5, customer_type: Leis3
# random_number: 0.5096624464711399, customer_index: 3, customer_type: Leis1
# random_number: 0.5680100174576818, customer_index: 3, customer_type: Leis1
# random_number: 0.8612365491491478, customer_index: 5, customer_type: Leis3
# random_number: 0.8776376749409752, customer_index: 5, customer_type: Leis3
# random_number: 0.7918760565472465, customer_index: 5, customer_type: Leis3
# random_number: 0.3188501714564139, customer_index: 2, customer_type: Bus2
# random_number: 0.580873808037919, customer_index: 3, customer_type: Leis1
# random_number: 0.39007076075132163, customer_index: 2, customer_type: Bus2
# random_number: 0.8806484040904972, customer_index: 5, customer_type: Leis3
# random_number: 0.7377170403548038, customer_index: 4, customer_type: Leis2
# random_number: 0.04720153796651827, customer_index: 0, customer_type: f
# random_number: 0.21967204010997676, customer_index: 1, customer_type: Bus1
# random_number: 0.8711063962369305, customer_index: 5, customer_type: Leis3
# random_number: 0.8839750365519613, customer_index: 5, customer_type: Leis3
# random_number: 0.6541527207421808, customer_index: 4, customer_type: Leis2
# random_number: 0.22195590843357527, customer_index: 1, customer_type: Bus1
# random_number: 0.2298944472119563, customer_index: 1, customer_type: Bus1
# random_number: 0.2218022617643043, customer_index: 1, customer_type: Bus1
# random_number: 0.7220482416521017, customer_index: 4, customer_type: Leis2
# random_number: 0.8411025611100668, customer_index: 5, customer_type: Leis3
# random_number: 0.8239797723607564, customer_index: 5, customer_type: Leis3
# random_number: 0.9048294175422905, customer_index: 5, customer_type: Leis3
# random_number: 0.1122677968072544, customer_index: 0, customer_type: f
# random_number: 0.3902188479894333, customer_index: 2, customer_type: Bus2
# random_number: 0.8614003109233398, customer_index: 5, customer_type: Leis3
# random_number: 0.7372898643108019, customer_index: 4, customer_type: Leis2
# random_number: 0.08289676504976984, customer_index: 0, customer_type: f
# random_number: 0.4880642327156025, customer_index: 3, customer_type: Leis1
# random_number: 0.8689053951115095, customer_index: 5, customer_type: Leis3
# random_number: 0.2656498530184368, customer_index: 1, customer_type: Bus1
# random_number: 0.30937994449724837, customer_index: 2, customer_type: Bus2
# random_number: 0.4371289862124861, customer_index: 2, customer_type: Bus2
# Episode: 1, Total Revenue: tensor([33750], device='cuda:0'), Cumulative average: [33225.]
# ---------- Episode  2 -----------
# random_number: 0.2694868130754554, customer_index: 1, customer_type: Bus1
# random_number: 0.7874679310756397, customer_index: 5, customer_type: Leis3
# random_number: 0.3534230195675727, customer_index: 2, customer_type: Bus2
# random_number: 0.09714344208816061, customer_index: 0, customer_type: f
# random_number: 0.09149426535126093, customer_index: 0, customer_type: f
# random_number: 0.8341665351910532, customer_index: 5, customer_type: Leis3
# random_number: 0.4644168802579304, customer_index: 3, customer_type: Leis1
# random_number: 0.2521678750712375, customer_index: 1, customer_type: Bus1
# random_number: 0.48330479619722255, customer_index: 3, customer_type: Leis1
# random_number: 0.5211571952306455, customer_index: 3, customer_type: Leis1
# random_number: 0.24177896366523643, customer_index: 1, customer_type: Bus1
# random_number: 0.22581855969860554, customer_index: 1, customer_type: Bus1
# random_number: 0.49619062887532894, customer_index: 3, customer_type: Leis1
# random_number: 0.06224714607800064, customer_index: 0, customer_type: f
# random_number: 0.1933415246327279, customer_index: 0, customer_type: f
# random_number: 0.559190628267021, customer_index: 3, customer_type: Leis1
# random_number: 0.8019851796893833, customer_index: 5, customer_type: Leis3
# random_number: 0.6716479834694917, customer_index: 4, customer_type: Leis2
# random_number: 0.9605990143882953, customer_index: 5, customer_type: Leis3
# random_number: 0.8872971778992454, customer_index: 5, customer_type: Leis3
# random_number: 0.19222244258632837, customer_index: 0, customer_type: f
# random_number: 0.6394890576817515, customer_index: 4, customer_type: Leis2
# random_number: 0.4476684135434805, customer_index: 3, customer_type: Leis1
# random_number: 0.8293542253135013, customer_index: 5, customer_type: Leis3
# random_number: 0.31752222814653286, customer_index: 2, customer_type: Bus2
# random_number: 0.6408558639532941, customer_index: 4, customer_type: Leis2
# random_number: 0.929415398273215, customer_index: 5, customer_type: Leis3
# random_number: 0.2737207734017634, customer_index: 1, customer_type: Bus1
# random_number: 0.2742505754979131, customer_index: 1, customer_type: Bus1
# random_number: 0.7435698757563878, customer_index: 4, customer_type: Leis2
# random_number: 0.17443515748768212, customer_index: 0, customer_type: f
# random_number: 0.7764361087160101, customer_index: 5, customer_type: Leis3
# random_number: 0.22052943541303305, customer_index: 1, customer_type: Bus1
# random_number: 0.025666277264113524, customer_index: 0, customer_type: f
# random_number: 0.9341428765998825, customer_index: 5, customer_type: Leis3
# random_number: 0.1116537905467413, customer_index: 0, customer_type: f
# random_number: 0.4113197195017877, customer_index: 2, customer_type: Bus2
# random_number: 0.5340450542101844, customer_index: 3, customer_type: Leis1
# random_number: 0.7648069672397533, customer_index: 5, customer_type: Leis3
# random_number: 0.7421545000531602, customer_index: 4, customer_type: Leis2
# random_number: 0.1489639770666803, customer_index: 0, customer_type: f
# random_number: 0.25245120238218843, customer_index: 1, customer_type: Bus1
# random_number: 0.5618710759670159, customer_index: 3, customer_type: Leis1
# random_number: 0.3831663703631235, customer_index: 2, customer_type: Bus2
# random_number: 0.8230654774518136, customer_index: 5, customer_type: Leis3
# random_number: 0.9238669750092602, customer_index: 5, customer_type: Leis3
# random_number: 0.15677192702122367, customer_index: 0, customer_type: f
# random_number: 0.5552784417941722, customer_index: 3, customer_type: Leis1
# random_number: 0.4410321663424064, customer_index: 3, customer_type: Leis1
# random_number: 0.2856318053197533, customer_index: 2, customer_type: Bus2
# random_number: 0.7017153196396081, customer_index: 4, customer_type: Leis2
# random_number: 0.31220732777596205, customer_index: 2, customer_type: Bus2
# random_number: 0.6176646788128932, customer_index: 4, customer_type: Leis2
# random_number: 0.7547028509021138, customer_index: 4, customer_type: Leis2
# random_number: 0.12522459304972977, customer_index: 0, customer_type: f
# random_number: 0.9278340553509443, customer_index: 5, customer_type: Leis3
# random_number: 0.13628048517834956, customer_index: 0, customer_type: f
# random_number: 0.4009335642744454, customer_index: 2, customer_type: Bus2
# random_number: 0.2405629248256661, customer_index: 1, customer_type: Bus1
# random_number: 0.171211562123049, customer_index: 0, customer_type: f
# random_number: 0.7749933147323224, customer_index: 5, customer_type: Leis3
# random_number: 0.32851064528575524, customer_index: 2, customer_type: Bus2
# random_number: 0.584105588329658, customer_index: 3, customer_type: Leis1
# random_number: 0.6449367563064834, customer_index: 4, customer_type: Leis2
# random_number: 0.3648654784703199, customer_index: 2, customer_type: Bus2
# random_number: 0.7013868109824306, customer_index: 4, customer_type: Leis2
# random_number: 0.7504874407576955, customer_index: 4, customer_type: Leis2
# random_number: 0.00915595743682529, customer_index: 0, customer_type: f
# random_number: 0.7984941669864152, customer_index: 5, customer_type: Leis3
# random_number: 0.9052605216496032, customer_index: 5, customer_type: Leis3
# random_number: 0.35919096883483237, customer_index: 2, customer_type: Bus2
# random_number: 0.7811314876248937, customer_index: 5, customer_type: Leis3
# random_number: 0.7026757524123772, customer_index: 4, customer_type: Leis2
# random_number: 0.05088033928522162, customer_index: 0, customer_type: f
# random_number: 0.9647614150420056, customer_index: 5, customer_type: Leis3
# random_number: 0.23235658302361262, customer_index: 1, customer_type: Bus1
# random_number: 0.9139171775545631, customer_index: 5, customer_type: Leis3
# random_number: 0.07016574964832845, customer_index: 0, customer_type: f
# random_number: 0.7426574084988048, customer_index: 4, customer_type: Leis2
# random_number: 0.03991185829723454, customer_index: 0, customer_type: f
# random_number: 0.9201337973030388, customer_index: 5, customer_type: Leis3
# random_number: 0.1598334809811065, customer_index: 0, customer_type: f
# random_number: 0.042433093987726545, customer_index: 0, customer_type: f
# random_number: 0.7530664601446078, customer_index: 4, customer_type: Leis2
# random_number: 0.3695522361616188, customer_index: 2, customer_type: Bus2
# random_number: 0.9876870797874642, customer_index: 5, customer_type: Leis3
# random_number: 0.9944199178938548, customer_index: 5, customer_type: Leis3
# random_number: 0.9093748570730117, customer_index: 5, customer_type: Leis3
# random_number: 0.9443092895986555, customer_index: 5, customer_type: Leis3
# random_number: 0.4696036806906032, customer_index: 3, customer_type: Leis1
# random_number: 0.8679742188076134, customer_index: 5, customer_type: Leis3
# random_number: 0.23147459876413345, customer_index: 1, customer_type: Bus1
# random_number: 0.0650417606535586, customer_index: 0, customer_type: f
# random_number: 0.5479478396065284, customer_index: 3, customer_type: Leis1
# random_number: 0.5350021954402173, customer_index: 3, customer_type: Leis1
# random_number: 0.2379746973468546, customer_index: 1, customer_type: Bus1
# random_number: 0.387910447375974, customer_index: 2, customer_type: Bus2
# random_number: 0.2250480670610272, customer_index: 1, customer_type: Bus1
# random_number: 0.20159706113278386, customer_index: 1, customer_type: Bus1
# random_number: 0.192406500590934, customer_index: 0, customer_type: f
# random_number: 0.22183836300773363, customer_index: 1, customer_type: Bus1
# random_number: 0.11674058814249877, customer_index: 0, customer_type: f
# random_number: 0.7506207079281009, customer_index: 4, customer_type: Leis2
# random_number: 0.693680496849307, customer_index: 4, customer_type: Leis2
# random_number: 0.31211386453354406, customer_index: 2, customer_type: Bus2
# random_number: 0.746254110577567, customer_index: 4, customer_type: Leis2
# random_number: 0.36902676183358485, customer_index: 2, customer_type: Bus2
# random_number: 0.3392026378770032, customer_index: 2, customer_type: Bus2
# random_number: 0.561391774333034, customer_index: 3, customer_type: Leis1
# random_number: 0.39480361237842476, customer_index: 2, customer_type: Bus2
# random_number: 0.9561873725287666, customer_index: 5, customer_type: Leis3
# random_number: 0.2967807084857653, customer_index: 2, customer_type: Bus2
# random_number: 0.9531652118446657, customer_index: 5, customer_type: Leis3
# random_number: 0.10418559519349557, customer_index: 0, customer_type: f
# random_number: 0.37539301591270535, customer_index: 2, customer_type: Bus2
# random_number: 0.9164655015384675, customer_index: 5, customer_type: Leis3
# random_number: 0.7937677005138537, customer_index: 5, customer_type: Leis3
# random_number: 0.5936634928721757, customer_index: 3, customer_type: Leis1
# random_number: 0.15083111353210332, customer_index: 0, customer_type: f
# random_number: 0.049847404560160236, customer_index: 0, customer_type: f
# random_number: 0.39193207122852625, customer_index: 2, customer_type: Bus2
# random_number: 0.49120340177126365, customer_index: 3, customer_type: Leis1
# random_number: 0.5002268062460861, customer_index: 3, customer_type: Leis1
# random_number: 0.4635531245640836, customer_index: 3, customer_type: Leis1
# random_number: 0.38469029894864426, customer_index: 2, customer_type: Bus2
# random_number: 0.18865379064842247, customer_index: 0, customer_type: f
# random_number: 0.03535434943553717, customer_index: 0, customer_type: f
# random_number: 0.6393253813543444, customer_index: 4, customer_type: Leis2
# random_number: 0.876115095969172, customer_index: 5, customer_type: Leis3
# random_number: 0.54028640134339, customer_index: 3, customer_type: Leis1
# random_number: 0.6399054959088317, customer_index: 4, customer_type: Leis2
# random_number: 0.03849289368195885, customer_index: 0, customer_type: f
# random_number: 0.5812620811348981, customer_index: 3, customer_type: Leis1
# random_number: 0.9483934541540068, customer_index: 5, customer_type: Leis3
# random_number: 0.6382093314758874, customer_index: 4, customer_type: Leis2
# random_number: 0.4567872242735562, customer_index: 3, customer_type: Leis1
# random_number: 0.8655807078530242, customer_index: 5, customer_type: Leis3
# random_number: 0.9754066705181251, customer_index: 5, customer_type: Leis3
# random_number: 0.11349422379442087, customer_index: 0, customer_type: f
# random_number: 0.9821349166576655, customer_index: 5, customer_type: Leis3
# random_number: 0.6637089188121297, customer_index: 4, customer_type: Leis2
# random_number: 0.5020093513769677, customer_index: 3, customer_type: Leis1
# random_number: 0.3659681903622013, customer_index: 2, customer_type: Bus2
# random_number: 0.5491258413762088, customer_index: 3, customer_type: Leis1
# random_number: 0.5289941288594996, customer_index: 3, customer_type: Leis1
# random_number: 0.5011223382804585, customer_index: 3, customer_type: Leis1
# random_number: 0.23150527335189175, customer_index: 1, customer_type: Bus1
# random_number: 0.0758833649012165, customer_index: 0, customer_type: f
# random_number: 0.6900569651899815, customer_index: 4, customer_type: Leis2
# random_number: 0.09030571224981065, customer_index: 0, customer_type: f
# random_number: 0.8044231010634272, customer_index: 5, customer_type: Leis3
# random_number: 0.15734598794369314, customer_index: 0, customer_type: f
# random_number: 0.25332986187371476, customer_index: 1, customer_type: Bus1
# random_number: 0.9930201160958808, customer_index: 5, customer_type: Leis3
# random_number: 0.5788463316526774, customer_index: 3, customer_type: Leis1
# random_number: 0.16715769842557682, customer_index: 0, customer_type: f
# random_number: 0.48455737131082055, customer_index: 3, customer_type: Leis1
# random_number: 0.24626231895830952, customer_index: 1, customer_type: Bus1
# random_number: 0.5883875222571215, customer_index: 3, customer_type: Leis1
# random_number: 0.0258335248654753, customer_index: 0, customer_type: f
# Episode: 2, Total Revenue: tensor([24600], device='cuda:0'), Cumulative average: [30350.]
# ---------- Episode  3 -----------
# random_number: 0.43742171857212364, customer_index: 2, customer_type: Bus2
# random_number: 0.8753342610480964, customer_index: 5, customer_type: Leis3
# random_number: 0.7180325282108938, customer_index: 4, customer_type: Leis2
# random_number: 0.5155379092354356, customer_index: 3, customer_type: Leis1
# random_number: 0.032333375586379276, customer_index: 0, customer_type: f
# random_number: 0.3260747710973284, customer_index: 2, customer_type: Bus2
# random_number: 0.8159703664733012, customer_index: 5, customer_type: Leis3
# random_number: 0.3857291548123839, customer_index: 2, customer_type: Bus2
# random_number: 0.5819697152667468, customer_index: 3, customer_type: Leis1
# random_number: 0.1229729768433202, customer_index: 0, customer_type: f
# random_number: 0.9298334897104829, customer_index: 5, customer_type: Leis3
# random_number: 0.07590840930606868, customer_index: 0, customer_type: f
# random_number: 0.5914205510171909, customer_index: 3, customer_type: Leis1
# random_number: 0.5057773441222249, customer_index: 3, customer_type: Leis1
# random_number: 0.5060923324268561, customer_index: 3, customer_type: Leis1
# random_number: 0.007657619745251698, customer_index: 0, customer_type: f
# random_number: 0.9531756207369869, customer_index: 5, customer_type: Leis3
# random_number: 0.5256322814620488, customer_index: 3, customer_type: Leis1
# random_number: 0.8068905313284663, customer_index: 5, customer_type: Leis3
# random_number: 0.9377986083112655, customer_index: 5, customer_type: Leis3
# random_number: 0.5105519257345675, customer_index: 3, customer_type: Leis1
# random_number: 0.18660633023846096, customer_index: 0, customer_type: f
# random_number: 0.8624462829971627, customer_index: 5, customer_type: Leis3
# random_number: 0.2629387303776153, customer_index: 1, customer_type: Bus1
# random_number: 0.29358174784341284, customer_index: 2, customer_type: Bus2
# random_number: 0.8982738217184644, customer_index: 5, customer_type: Leis3
# random_number: 0.6643576853669982, customer_index: 4, customer_type: Leis2
# random_number: 0.6050118871742091, customer_index: 4, customer_type: Leis2
# random_number: 0.1883620475616412, customer_index: 0, customer_type: f
# random_number: 0.14856263704163664, customer_index: 0, customer_type: f
# random_number: 0.026573817989242632, customer_index: 0, customer_type: f
# random_number: 0.04182379829291516, customer_index: 0, customer_type: f
# random_number: 0.9548897701374146, customer_index: 5, customer_type: Leis3
# random_number: 0.363117869824402, customer_index: 2, customer_type: Bus2
# random_number: 0.34641034531727233, customer_index: 2, customer_type: Bus2
# random_number: 0.7978308207928083, customer_index: 5, customer_type: Leis3
# random_number: 0.05525761879652935, customer_index: 0, customer_type: f
# random_number: 0.5592053185216139, customer_index: 3, customer_type: Leis1
# random_number: 0.6921245983130528, customer_index: 4, customer_type: Leis2
# random_number: 0.632903051560434, customer_index: 4, customer_type: Leis2
# random_number: 0.8020535766290129, customer_index: 5, customer_type: Leis3
# random_number: 0.2872978140046061, customer_index: 2, customer_type: Bus2
# random_number: 0.9254280334013086, customer_index: 5, customer_type: Leis3
# random_number: 0.8821624402309031, customer_index: 5, customer_type: Leis3
# random_number: 0.7025084852410861, customer_index: 4, customer_type: Leis2
# random_number: 0.628499257799458, customer_index: 4, customer_type: Leis2
# random_number: 0.43228721337470255, customer_index: 2, customer_type: Bus2
# random_number: 0.6809112107038726, customer_index: 4, customer_type: Leis2
# random_number: 0.974300751043431, customer_index: 5, customer_type: Leis3
# random_number: 0.8064036935887728, customer_index: 5, customer_type: Leis3
# random_number: 0.3081232671964391, customer_index: 2, customer_type: Bus2
# random_number: 0.7376433642938167, customer_index: 4, customer_type: Leis2
# random_number: 0.31668712649688835, customer_index: 2, customer_type: Bus2
# random_number: 0.12862478732092486, customer_index: 0, customer_type: f
# random_number: 0.5125188258597502, customer_index: 3, customer_type: Leis1
# random_number: 0.2923615690387308, customer_index: 2, customer_type: Bus2
# random_number: 0.9128674978619352, customer_index: 5, customer_type: Leis3
# random_number: 0.5085153132422766, customer_index: 3, customer_type: Leis1
# random_number: 0.48918704771189825, customer_index: 3, customer_type: Leis1
# random_number: 0.29208827095089707, customer_index: 2, customer_type: Bus2
# random_number: 0.5558086947117212, customer_index: 3, customer_type: Leis1
# random_number: 0.4317362034745079, customer_index: 2, customer_type: Bus2
# random_number: 0.6480357124219578, customer_index: 4, customer_type: Leis2
# random_number: 0.16448171252508859, customer_index: 0, customer_type: f
# random_number: 0.943666891174315, customer_index: 5, customer_type: Leis3
# random_number: 0.7281524699024884, customer_index: 4, customer_type: Leis2
# random_number: 0.2302625195504755, customer_index: 1, customer_type: Bus1
# random_number: 0.10135253644904874, customer_index: 0, customer_type: f
# random_number: 0.22544227101346592, customer_index: 1, customer_type: Bus1
# random_number: 0.2503471675242598, customer_index: 1, customer_type: Bus1
# random_number: 0.9808596388599471, customer_index: 5, customer_type: Leis3
# random_number: 0.7998391209253254, customer_index: 5, customer_type: Leis3
# random_number: 0.4958479042558176, customer_index: 3, customer_type: Leis1
# random_number: 0.9379009815335941, customer_index: 5, customer_type: Leis3
# random_number: 0.2782875273705694, customer_index: 1, customer_type: Bus1
# random_number: 0.019558678136006202, customer_index: 0, customer_type: f
# random_number: 0.4297946831686318, customer_index: 2, customer_type: Bus2
# random_number: 0.03284816229452159, customer_index: 0, customer_type: f
# random_number: 0.689621644981161, customer_index: 4, customer_type: Leis2
# random_number: 0.8407680609563178, customer_index: 5, customer_type: Leis3
# random_number: 0.16560746210091548, customer_index: 0, customer_type: f
# random_number: 0.8864282763119118, customer_index: 5, customer_type: Leis3
# random_number: 0.4425513194312982, customer_index: 3, customer_type: Leis1
# random_number: 0.1895763707789796, customer_index: 0, customer_type: f
# random_number: 0.1308898466826739, customer_index: 0, customer_type: f
# random_number: 0.8304155960404523, customer_index: 5, customer_type: Leis3
# random_number: 0.12801235710205672, customer_index: 0, customer_type: f
# random_number: 0.6439200134830749, customer_index: 4, customer_type: Leis2
# random_number: 0.7695950329793733, customer_index: 5, customer_type: Leis3
# random_number: 0.03175712363432326, customer_index: 0, customer_type: f
# random_number: 0.22873395971180166, customer_index: 1, customer_type: Bus1
# random_number: 0.6839861572203534, customer_index: 4, customer_type: Leis2
# random_number: 0.14199943040762275, customer_index: 0, customer_type: f
# random_number: 0.457250737054967, customer_index: 3, customer_type: Leis1
# random_number: 0.8599039737818587, customer_index: 5, customer_type: Leis3
# random_number: 0.04920692704742746, customer_index: 0, customer_type: f
# random_number: 0.25562605700592234, customer_index: 1, customer_type: Bus1
# random_number: 0.10322034141425263, customer_index: 0, customer_type: f
# random_number: 0.8202954421102242, customer_index: 5, customer_type: Leis3
# random_number: 0.3114920096084228, customer_index: 2, customer_type: Bus2
# random_number: 0.8513052502385113, customer_index: 5, customer_type: Leis3
# random_number: 0.4469535064096871, customer_index: 3, customer_type: Leis1
# random_number: 0.7164411727260027, customer_index: 4, customer_type: Leis2
# random_number: 0.5913944480755896, customer_index: 3, customer_type: Leis1
# random_number: 0.10498779976005701, customer_index: 0, customer_type: f
# random_number: 0.26045066983080245, customer_index: 1, customer_type: Bus1
# random_number: 0.35359819460492325, customer_index: 2, customer_type: Bus2
# random_number: 0.08164845208267613, customer_index: 0, customer_type: f
# random_number: 0.4209140126582853, customer_index: 2, customer_type: Bus2
# random_number: 0.44432552862587815, customer_index: 3, customer_type: Leis1
# random_number: 0.538338492530302, customer_index: 3, customer_type: Leis1
# random_number: 0.4089426461352724, customer_index: 2, customer_type: Bus2
# random_number: 0.7348746959438162, customer_index: 4, customer_type: Leis2
# random_number: 0.30230020173742045, customer_index: 2, customer_type: Bus2
# random_number: 0.7235756376411203, customer_index: 4, customer_type: Leis2
# random_number: 0.37371857190375224, customer_index: 2, customer_type: Bus2
# random_number: 0.10942285574092725, customer_index: 0, customer_type: f
# random_number: 0.6988390426164449, customer_index: 4, customer_type: Leis2
# random_number: 0.5835100663702548, customer_index: 3, customer_type: Leis1
# random_number: 0.8356524542663987, customer_index: 5, customer_type: Leis3
# random_number: 0.6532321514741469, customer_index: 4, customer_type: Leis2
# random_number: 0.5208843135874842, customer_index: 3, customer_type: Leis1
# random_number: 0.980291343756321, customer_index: 5, customer_type: Leis3
# random_number: 0.7630550979001015, customer_index: 5, customer_type: Leis3
# random_number: 0.4917453201184745, customer_index: 3, customer_type: Leis1
# random_number: 0.04134312586133082, customer_index: 0, customer_type: f
# random_number: 0.2868458490212601, customer_index: 2, customer_type: Bus2
# random_number: 0.5981794267596797, customer_index: 3, customer_type: Leis1
# random_number: 0.0012273099935019571, customer_index: 0, customer_type: f
# random_number: 0.4582247768281378, customer_index: 3, customer_type: Leis1
# random_number: 0.09619334645260091, customer_index: 0, customer_type: f
# random_number: 0.3015940990495951, customer_index: 2, customer_type: Bus2
# random_number: 0.9602391975378597, customer_index: 5, customer_type: Leis3
# random_number: 0.44643257727654184, customer_index: 3, customer_type: Leis1
# random_number: 0.7183823480658112, customer_index: 4, customer_type: Leis2
# random_number: 0.9966096564829752, customer_index: 5, customer_type: Leis3
# random_number: 0.43702421239608, customer_index: 2, customer_type: Bus2
# random_number: 0.484886531024614, customer_index: 3, customer_type: Leis1
# random_number: 0.747584726230925, customer_index: 4, customer_type: Leis2
# random_number: 0.24479054997361882, customer_index: 1, customer_type: Bus1
# random_number: 0.9503043974555092, customer_index: 5, customer_type: Leis3
# random_number: 0.20779242442853063, customer_index: 1, customer_type: Bus1
# random_number: 0.9446525142564752, customer_index: 5, customer_type: Leis3
# random_number: 0.656735700540799, customer_index: 4, customer_type: Leis2
# random_number: 0.22684658590443885, customer_index: 1, customer_type: Bus1
# random_number: 0.2533623442619629, customer_index: 1, customer_type: Bus1
# random_number: 0.4579100914027141, customer_index: 3, customer_type: Leis1
# random_number: 0.5339301821611449, customer_index: 3, customer_type: Leis1
# random_number: 0.5141880800817438, customer_index: 3, customer_type: Leis1
# random_number: 0.9161473598774597, customer_index: 5, customer_type: Leis3
# random_number: 0.07455626922418768, customer_index: 0, customer_type: f
# random_number: 0.6552348802145946, customer_index: 4, customer_type: Leis2
# random_number: 0.17368594335513132, customer_index: 0, customer_type: f
# random_number: 0.3647892722429449, customer_index: 2, customer_type: Bus2
# random_number: 0.13622640417087506, customer_index: 0, customer_type: f
# random_number: 0.8510932044184968, customer_index: 5, customer_type: Leis3
# random_number: 0.8083300248190659, customer_index: 5, customer_type: Leis3
# random_number: 0.532886648089896, customer_index: 3, customer_type: Leis1
# random_number: 0.9686911941414983, customer_index: 5, customer_type: Leis3
# random_number: 0.5431842858603716, customer_index: 3, customer_type: Leis1
# Episode: 3, Total Revenue: tensor([43750], device='cuda:0'), Cumulative average: [33700.]
# ...
# random_number: 0.37350877358851364, customer_index: 2, customer_type: Bus2
# random_number: 0.05218066997787252, customer_index: 0, customer_type: f
# random_number: 0.9806934537248717, customer_index: 5, customer_type: Leis3
# random_number: 0.3063206964763068, customer_index: 2, customer_type: Bus2
# random_number: 0.28718788125465866, customer_index: 2, customer_type: Bus2
# random_number: 0.5257981601059943, customer_index: 3, customer_type: Leis1
# random_number: 0.3474078678797796, customer_index: 2, customer_type: Bus2
# random_number: 0.4572829937758165, customer_index: 3, customer_type: Leis1
# random_number: 0.46653764060978653, customer_index: 3, customer_type: Leis1
# random_number: 0.13160125373450526, customer_index: 0, customer_type: f
# random_number: 0.9826371136589908, customer_index: 5, customer_type: Leis3
# random_number: 0.5927676244342834, customer_index: 3, customer_type: Leis1
# random_number: 0.2776616548927441, customer_index: 1, customer_type: Bus1
# random_number: 0.833202363170931, customer_index: 5, customer_type: Leis3
# random_number: 0.1246931562932676, customer_index: 0, customer_type: f
# random_number: 0.40591651527966743, customer_index: 2, customer_type: Bus2
# random_number: 0.19947158726079106, customer_index: 0, customer_type: f
# random_number: 0.6026061263062324, customer_index: 4, customer_type: Leis2
# random_number: 0.8480090938343152, customer_index: 5, customer_type: Leis3
# random_number: 0.46860065148758856, customer_index: 3, customer_type: Leis1
# random_number: 0.7716676064776882, customer_index: 5, customer_type: Leis3
# random_number: 0.5818575524255338, customer_index: 3, customer_type: Leis1
# random_number: 0.5716372767414041, customer_index: 3, customer_type: Leis1
# random_number: 0.7708023862013497, customer_index: 5, customer_type: Leis3
# random_number: 0.45315505544815005, customer_index: 3, customer_type: Leis1
# random_number: 0.9713946343259391, customer_index: 5, customer_type: Leis3
# random_number: 0.16133517522102392, customer_index: 0, customer_type: f
# random_number: 0.1284329935295796, customer_index: 0, customer_type: f
# random_number: 0.3095738421118993, customer_index: 2, customer_type: Bus2
# random_number: 0.9014843905613319, customer_index: 5, customer_type: Leis3
# random_number: 0.9671174679410074, customer_index: 5, customer_type: Leis3
# random_number: 0.8644695457877911, customer_index: 5, customer_type: Leis3
# random_number: 0.02161090573151725, customer_index: 0, customer_type: f
# random_number: 0.7352637079071682, customer_index: 4, customer_type: Leis2
# random_number: 0.20710262809706148, customer_index: 1, customer_type: Bus1
# random_number: 0.4331407235574607, customer_index: 2, customer_type: Bus2
# random_number: 0.1865787367875259, customer_index: 0, customer_type: f
# random_number: 0.22486070829277693, customer_index: 1, customer_type: Bus1
# random_number: 0.00969803897540955, customer_index: 0, customer_type: f
# random_number: 0.6281382335013418, customer_index: 4, customer_type: Leis2
# random_number: 0.6303526406961599, customer_index: 4, customer_type: Leis2
# random_number: 0.23324180388831706, customer_index: 1, customer_type: Bus1
# random_number: 0.5348642430465277, customer_index: 3, customer_type: Leis1
# random_number: 0.06141510460495836, customer_index: 0, customer_type: f
# random_number: 0.6824011140028571, customer_index: 4, customer_type: Leis2
# random_number: 0.5085568001298622, customer_index: 3, customer_type: Leis1
# random_number: 0.9462360456842838, customer_index: 5, customer_type: Leis3
# random_number: 0.9299789696282457, customer_index: 5, customer_type: Leis3
# random_number: 0.8931399792513249, customer_index: 5, customer_type: Leis3
# random_number: 0.33425418401155005, customer_index: 2, customer_type: Bus2
# random_number: 0.5351165202342866, customer_index: 3, customer_type: Leis1
# random_number: 0.77842687449313, customer_index: 5, customer_type: Leis3
# random_number: 0.49773271215280557, customer_index: 3, customer_type: Leis1
# random_number: 0.015302926221892665, customer_index: 0, customer_type: f
# random_number: 0.06692256166878019, customer_index: 0, customer_type: f
# random_number: 0.7246756168641654, customer_index: 4, customer_type: Leis2
# random_number: 0.4288325519911118, customer_index: 2, customer_type: Bus2
# random_number: 0.9230293501694576, customer_index: 5, customer_type: Leis3
# random_number: 0.6906461095612169, customer_index: 4, customer_type: Leis2
# random_number: 0.2399798616297506, customer_index: 1, customer_type: Bus1
# random_number: 0.41955561452209666, customer_index: 2, customer_type: Bus2
# random_number: 0.7256537390750987, customer_index: 4, customer_type: Leis2
# random_number: 0.6263841441625532, customer_index: 4, customer_type: Leis2
# random_number: 0.47097775798729247, customer_index: 3, customer_type: Leis1
# random_number: 0.595312299659708, customer_index: 3, customer_type: Leis1
# random_number: 0.6119491372663045, customer_index: 4, customer_type: Leis2
# random_number: 0.8440116239854616, customer_index: 5, customer_type: Leis3
# random_number: 0.21542702921496348, customer_index: 1, customer_type: Bus1
# random_number: 0.37871453028376567, customer_index: 2, customer_type: Bus2
# random_number: 0.5394467591162474, customer_index: 3, customer_type: Leis1
# random_number: 0.9959467784999175, customer_index: 5, customer_type: Leis3
# random_number: 0.2393797908148152, customer_index: 1, customer_type: Bus1
# random_number: 0.19754443013606315, customer_index: 0, customer_type: f
# random_number: 0.8758370416661522, customer_index: 5, customer_type: Leis3
# random_number: 0.8633129382820839, customer_index: 5, customer_type: Leis3
# random_number: 0.9946965941515875, customer_index: 5, customer_type: Leis3
# random_number: 0.5551377640328956, customer_index: 3, customer_type: Leis1
# random_number: 0.690657990551012, customer_index: 4, customer_type: Leis2
# random_number: 0.677632065935257, customer_index: 4, customer_type: Leis2
# random_number: 0.5269848093765086, customer_index: 3, customer_type: Leis1
# random_number: 0.8174392405164784, customer_index: 5, customer_type: Leis3
# random_number: 0.6893324995396096, customer_index: 4, customer_type: Leis2
# random_number: 0.7292989399644287, customer_index: 4, customer_type: Leis2
# random_number: 0.43234531535866527, customer_index: 2, customer_type: Bus2
# random_number: 0.07544056153273893, customer_index: 0, customer_type: f
# random_number: 0.6828799057872725, customer_index: 4, customer_type: Leis2
# random_number: 0.287857826913794, customer_index: 2, customer_type: Bus2
# random_number: 0.3905322341026308, customer_index: 2, customer_type: Bus2
# random_number: 0.6121648868928473, customer_index: 4, customer_type: Leis2
# random_number: 0.06574022352307296, customer_index: 0, customer_type: f
# random_number: 0.10362573629708838, customer_index: 0, customer_type: f
# random_number: 0.9476356582035116, customer_index: 5, customer_type: Leis3
# random_number: 0.3566613252009565, customer_index: 2, customer_type: Bus2
# random_number: 0.3103802498277617, customer_index: 2, customer_type: Bus2
# random_number: 0.19629523174274088, customer_index: 0, customer_type: f
# random_number: 0.16101060709868453, customer_index: 0, customer_type: f
# Episode: 20, Total Revenue: tensor([33650], device='cuda:0'), Cumulative average: [40707.14285714]
# ---------- Episode  21 -----------
# random_number: 0.8625639396745394, customer_index: 5, customer_type: Leis3
# random_number: 0.5556191632739351, customer_index: 3, customer_type: Leis1
# random_number: 0.8483064040460166, customer_index: 5, customer_type: Leis3
# random_number: 0.566002899281262, customer_index: 3, customer_type: Leis1
# random_number: 0.17479376135971414, customer_index: 0, customer_type: f
# random_number: 0.3909946887316951, customer_index: 2, customer_type: Bus2
# random_number: 0.45745432704010636, customer_index: 3, customer_type: Leis1
# random_number: 0.5169932285236043, customer_index: 3, customer_type: Leis1
# random_number: 0.2461621088930186, customer_index: 1, customer_type: Bus1
# random_number: 0.7860704451068737, customer_index: 5, customer_type: Leis3
# random_number: 0.6870271234926315, customer_index: 4, customer_type: Leis2
# random_number: 0.19597593092736232, customer_index: 0, customer_type: f
# random_number: 0.10458214658622178, customer_index: 0, customer_type: f
# random_number: 0.6609147508981468, customer_index: 4, customer_type: Leis2
# random_number: 0.7150912110680049, customer_index: 4, customer_type: Leis2
# random_number: 0.9679539967263041, customer_index: 5, customer_type: Leis3
# random_number: 0.6827326721882903, customer_index: 4, customer_type: Leis2
# random_number: 0.5854599639704604, customer_index: 3, customer_type: Leis1
# random_number: 0.8137936263321103, customer_index: 5, customer_type: Leis3
# random_number: 0.5877867832017405, customer_index: 3, customer_type: Leis1
# random_number: 0.3416417037616618, customer_index: 2, customer_type: Bus2
# random_number: 0.18335389935046242, customer_index: 0, customer_type: f
# random_number: 0.8242116817925322, customer_index: 5, customer_type: Leis3
# random_number: 0.847520452896574, customer_index: 5, customer_type: Leis3
# random_number: 0.15867212571080935, customer_index: 0, customer_type: f
# random_number: 0.10037195373417818, customer_index: 0, customer_type: f
# random_number: 0.7302007055558775, customer_index: 4, customer_type: Leis2
# random_number: 0.5967694431582421, customer_index: 3, customer_type: Leis1
# random_number: 0.32616492336618197, customer_index: 2, customer_type: Bus2
# random_number: 0.46230915389866967, customer_index: 3, customer_type: Leis1
# random_number: 0.9255371713220465, customer_index: 5, customer_type: Leis3
# random_number: 0.3318246411036606, customer_index: 2, customer_type: Bus2
# random_number: 0.7198412313045977, customer_index: 4, customer_type: Leis2
# random_number: 0.7289273665572287, customer_index: 4, customer_type: Leis2
# random_number: 0.7256628490354079, customer_index: 4, customer_type: Leis2
# random_number: 0.5343939782494632, customer_index: 3, customer_type: Leis1
# random_number: 0.08481500514007123, customer_index: 0, customer_type: f
# random_number: 0.8941002916972087, customer_index: 5, customer_type: Leis3
# random_number: 0.022869038362801075, customer_index: 0, customer_type: f
# random_number: 0.5133297724836366, customer_index: 3, customer_type: Leis1
# random_number: 0.602749334083381, customer_index: 4, customer_type: Leis2
# random_number: 0.6359833953241912, customer_index: 4, customer_type: Leis2
# random_number: 0.7661707548534308, customer_index: 5, customer_type: Leis3
# random_number: 0.4671868765579049, customer_index: 3, customer_type: Leis1
# random_number: 0.9637759652134232, customer_index: 5, customer_type: Leis3
# random_number: 0.23366198175274278, customer_index: 1, customer_type: Bus1
# random_number: 0.3757124959962378, customer_index: 2, customer_type: Bus2
# random_number: 0.5403939582217034, customer_index: 3, customer_type: Leis1
# random_number: 0.9988153402724534, customer_index: 5, customer_type: Leis3
# random_number: 0.6851284106688758, customer_index: 4, customer_type: Leis2
# random_number: 0.2821551525372218, customer_index: 2, customer_type: Bus2
# random_number: 0.36404933507395, customer_index: 2, customer_type: Bus2
# random_number: 0.2065838085175351, customer_index: 1, customer_type: Bus1
# random_number: 0.3134964970302744, customer_index: 2, customer_type: Bus2
# random_number: 0.24479500718975866, customer_index: 1, customer_type: Bus1
# random_number: 0.965440292112708, customer_index: 5, customer_type: Leis3
# random_number: 0.33113111535851014, customer_index: 2, customer_type: Bus2
# random_number: 0.6403518803803617, customer_index: 4, customer_type: Leis2
# random_number: 0.3958317191269487, customer_index: 2, customer_type: Bus2
# random_number: 0.6785438581955184, customer_index: 4, customer_type: Leis2
# random_number: 0.9886252656048324, customer_index: 5, customer_type: Leis3
# random_number: 0.7234459465432321, customer_index: 4, customer_type: Leis2
# random_number: 0.0610195002109013, customer_index: 0, customer_type: f
# random_number: 0.05000465361415951, customer_index: 0, customer_type: f
# random_number: 0.5438545042936205, customer_index: 3, customer_type: Leis1
# random_number: 0.6287793920792893, customer_index: 4, customer_type: Leis2
# random_number: 0.9985516246238012, customer_index: 5, customer_type: Leis3
# random_number: 0.13398706338570798, customer_index: 0, customer_type: f
# random_number: 0.9646609861438359, customer_index: 5, customer_type: Leis3
# random_number: 0.6176393169143665, customer_index: 4, customer_type: Leis2
# random_number: 0.9567884059271704, customer_index: 5, customer_type: Leis3
# random_number: 0.6196632800109835, customer_index: 4, customer_type: Leis2
# random_number: 0.006880857499645732, customer_index: 0, customer_type: f
# random_number: 0.2663842422578633, customer_index: 1, customer_type: Bus1
# random_number: 0.36769603723932254, customer_index: 2, customer_type: Bus2
# random_number: 0.6911490126124898, customer_index: 4, customer_type: Leis2
# random_number: 0.63135144238656, customer_index: 4, customer_type: Leis2
# random_number: 0.9363825731844827, customer_index: 5, customer_type: Leis3
# random_number: 0.45217888079941837, customer_index: 3, customer_type: Leis1
# random_number: 0.4622239462515676, customer_index: 3, customer_type: Leis1
# random_number: 0.16884077704018574, customer_index: 0, customer_type: f
# random_number: 0.22385854098109148, customer_index: 1, customer_type: Bus1
# random_number: 0.9615318999629363, customer_index: 5, customer_type: Leis3
# random_number: 0.8746693978263669, customer_index: 5, customer_type: Leis3
# random_number: 0.11817387580732475, customer_index: 0, customer_type: f
# random_number: 0.21693599687289433, customer_index: 1, customer_type: Bus1
# random_number: 0.1525654799478371, customer_index: 0, customer_type: f
# random_number: 0.4848096828413426, customer_index: 3, customer_type: Leis1
# random_number: 0.6933902748792024, customer_index: 4, customer_type: Leis2
# random_number: 0.8156912507470644, customer_index: 5, customer_type: Leis3
# random_number: 0.9520369104353844, customer_index: 5, customer_type: Leis3
# random_number: 0.6187816848238442, customer_index: 4, customer_type: Leis2
# random_number: 0.6213740791125083, customer_index: 4, customer_type: Leis2
# random_number: 0.7922884594278048, customer_index: 5, customer_type: Leis3
# random_number: 0.22372940919597895, customer_index: 1, customer_type: Bus1
# random_number: 0.6048161695594878, customer_index: 4, customer_type: Leis2
# random_number: 0.16587658370467295, customer_index: 0, customer_type: f
# random_number: 0.5669519220933944, customer_index: 3, customer_type: Leis1
# random_number: 0.5606058559831637, customer_index: 3, customer_type: Leis1
# random_number: 0.5829034554372937, customer_index: 3, customer_type: Leis1
# random_number: 0.9249666169247491, customer_index: 5, customer_type: Leis3
# random_number: 0.21313767617951418, customer_index: 1, customer_type: Bus1
# random_number: 0.020237796459549706, customer_index: 0, customer_type: f
# random_number: 0.6445834037070247, customer_index: 4, customer_type: Leis2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 45
#      42 state = next_state
#      44 # Perform one step of the optimization (on the policy network)
# ---> 45 optimize_model()
#      47 # Soft update of the target network's weights
#      48 # θ′ ← τ θ + (1 −τ )θ′
#      49 target_net_state_dict = target_net.state_dict()
#
# Cell In[14], line 16, in optimize_model()
#      14 state_batch = torch.cat(batch.state)
#      15 action_batch = torch.cat(batch.action)
# ---> 16 reward_batch = torch.cat(batch.reward)
#      18 # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
#      19 # columns of actions taken. These are the actions which would've been taken
#      20 # for each batch state according to policy_net
#      21 state_action_values = policy_net(state_batch).gather(1, action_batch)
#
# KeyboardInterrupt:

# %%
# Plot results
plt.figure(figsize=(10, 6))  
plt.plot(range(num_episodes), DQN_total_revenues, label='DQN each episode', alpha=0.5, color='b')
plt.plot(range(50, num_episodes, 50), DQN_per_50_avg, label='DQN per 50 episode', alpha=0.5, color='green')
plt.plot(range(num_episodes), DQN_cumulative_average, label='DQN Cumulative')
plt.axhline(y=dp, color='r', label='DP')
plt.axhline(y=fcfs, color='orange', label='FCFS')
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('Total Reward per Episode')
plt.legend()  
plt.grid(True)
plt.show()
