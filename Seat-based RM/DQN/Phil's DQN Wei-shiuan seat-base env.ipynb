# %%
import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count
import numpy as np

# %%
import torch as T
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
'''Dynamic Programming, FCFS Simulated result'''
dp = 60940
fcfs = 45276

# %%
'''Establish an aircraft'''
class aircraft:

    # Initialize aircraft
    def __init__(self):
        self.seat_capacity = 100
        self.seat_type = ['Y', 'M', 'K']
        self.seat_price = {'f': 0, 'Y': 800, 'M': 500, 'K': 450}

# %%
''' Demand model from Balaiyan et al.'''
class demandmodel:
    
    # Initialize demand model
    def __init__(self):
        
        # inherent attributes from aircraft class
        self.aircraft = aircraft()
        self.seat_set = self.aircraft.seat_type
        self.seat_price = self.aircraft.seat_price
        
        # demand model parameters
        self.total_booking = 105
        self.market_share = 0.25
        self.gamma = 0.08426
        self.alpha = 0.001251
        self.beta = {'DFARE':-0.006, 'LOT3':-0.944}
        self.a = {'Y':{'DFARE':800, 'LOT3':1},
                  'M':{'DFARE':500, 'LOT3':1},
                  'K':{'DFARE':450, 'LOT3':1},
                 }
        self.fare_diff_avg = sum(self.seat_price.values()) / len(self.seat_price)
        for seat_type in self.a:
            self.a[seat_type]['DFARE'] = round(self.a[seat_type]['DFARE'] - self.fare_diff_avg, 2)

    # Calculate dm
    def dm(self):
        dm = self.total_booking/self.market_share
        return dm

    # Calcilate booking curve
    def booking_curve(self, RD2, RD1):
        booking_curve = math.exp(-self.gamma*RD2)-math.exp(-self.gamma*RD1)
        return booking_curve

    # find pj+1
    def find_pj1(self, seat):
        smaller_keys = [key for key in self.seat_price.keys() if key < seat]
        if smaller_keys:
            max_smaller_key = max(smaller_keys)
            pj1 = self.seat_price[max_smaller_key]
        else:
            pj1 = min(self.seat_price.values())
        return pj1

    # Multinomial logit model
    def mnl(self):
        choose_prob = {}
        value_dict = {}
        for seat in self.seat_set:
            result = {key: self.beta[key] * value for key, value in self.a[seat].items()}
            total = sum(result.values())
            value = math.exp(total)
            value_dict[seat] = value
        for seat in value_dict:
            exp_value = math.exp(value_dict[seat])
            choose_prob[seat] = exp_value / sum(math.exp(value) for value in value_dict.values())
        # print("mnl: ", choose_prob)
        return choose_prob

    # Calculate customer choice
    def customer_choice(self, seat_type):
        total_sum = 0
        choose_prob = self.mnl()
        min_key = min(self.seat_price, key=self.seat_price.get)
        p0 = self.seat_price[min_key]
        for seat in self.seat_set:
            pj = self.seat_price['Y'] # 暫時寫這樣
            pj1 = self.seat_price['M'] # 暫時寫這樣
            # print('p0: ',p0 , 'p1: ', pj, 'pj1: ', pj1)
            sum_of_set = (math.exp(-self.alpha*(pj-p0))-math.exp(-self.alpha*(pj1-p0))) * choose_prob[seat_type] 
            # print('sum of set: ', sum_of_set)
            total_sum += sum_of_set
        return total_sum

    # Calculate demand
    def formulation(self, RD2, RD1):
        dm = self.dm()
        # print('dm',dm)
        booking_curve = self.booking_curve(RD2, RD1)
        # print('booking curve: ',booking_curve)
        BR_dict = {}
        
        for seat in self.seat_set:
            # print("calculate", seat, " ing...")
            customer_choice = self.customer_choice(seat)
            # print('customer choice', customer_choice)
            BR = dm * booking_curve * customer_choice
            BR_dict[seat] = BR
            # print(' seat: ', seat, ' predicted demand model from ', RD2,' to ', RD1, 'is', BR)
        # print("total demand: ", sum(BR_dict.values()))
        return BR_dict
    
    # Plot demand result
    def plot_demand(self):
        
        # Store calculated result
        every_rd = {seat: [] for seat in model.seat_set}  
        cumulative_demand = {seat: [] for seat in model.seat_set}  
        total_demand = {seat: 0 for seat in model.seat_set}  
        cumulative_total_demand_per_rd = []  # Store each RD cumulative demand

        # Calculate all RD demand
        cumulative_total_demand = 0  # Initialize cumulative demand
        for i in range(2, max_rd+1):
            # print('i: ', i)
            BR_results = model.formulation(i, i-1)  
            total_demand_rd = sum(BR_results.values())  # Calculate demand form all rd
            cumulative_total_demand += total_demand_rd  # update cumulative total deamnd
            cumulative_total_demand_per_rd.append(cumulative_total_demand)  # append cumulative total demand
            for seat, demand in BR_results.items():  
                every_rd[seat].append(demand) 
                total_demand[seat] += demand  
                cumulative_demand[seat].append(total_demand[seat])  
        
        plt.figure(figsize=(10, 6))
        plt.plot(range(1, max_rd), cumulative_total_demand_per_rd, label='Total Demand')
        plt.xlabel('RD')
        plt.ylabel('Total Demand')
        plt.title('Total Demand Model')
        plt.legend()
        plt.xticks(range(0, max_rd, int(max_rd/10)))
        plt.grid(True)
        plt.show()

# %%
'''Action space'''
class AgentActionSpace:
    def __init__(self):
        # self.action_list = [0, 1, 2, 3, 4, 5, 6, 7]
        self.action_list = [0, 1, 2, 3]
        self.n = len(self.action_list)  

    def sample(self):
        return np.random.choice(self.action_list)

    def contains(self, action):
        return action in self.action_list

# %%
'''Uniform distribution'''
class uniform_distribution:

    # Initialize parameters
    def __init__(self, total_demand, total_lambda):
        self.total_demand = total_demand
        self.total_lambda = total_lambda
        self.num_period = int(total_demand/total_lambda)
        self.prob = {'Bus1': 0.1, 'Bus2': 0.2, 'Leis1': 0.2, 'Leis2': 0.2, 'Leis3': 0.3}
    
    # Calculate lambda for each type of customer
    def calculate_lambda(self):
        lambda_list = []
        lambda_list.append(round(1-self.total_lambda, 2))
        for customer in self.prob:
            lambda_list.append(round(self.prob[customer] * self.total_lambda, 2)) 
        # print("lambda_list: ", lambda_list)
        return lambda_list

# %%
'''Establish Customer class'''
class Customer:

    ''' Initialization '''
    def __init__(self, total_demand, total_lambda):
        self.customer_type = {0: 'f', 1: 'Bus1', 2:'Bus2', 3:'Leis1', 4: 'Leis2', 5: 'Leis3'}
        self.num_customer_type = len(self.customer_type)
        self.customer_preference = {
            'f':{'Y': False, 'M': False, 'K': False},
            'Bus1': {'Y': True, 'M': False, 'K': False},
            'Bus2': {'Y': True, 'M': True, 'K': False},
            'Leis1': {'Y': False, 'M': True, 'K': False},
            'Leis2': {'Y': False, 'M': True, 'K': True},
            'Leis3': {'Y': False, 'M': False, 'K': True},
        }

        # inherent from uniform distribution class
        self.uniform_distribution = uniform_distribution(total_demand, total_lambda)
        self.arrival_rates = self.uniform_distribution.calculate_lambda() # calculate arrival rates for each customer type
        
        # inherent from aircraft class
        self.aircraft = aircraft()
        self.seat_price = self.aircraft.seat_price

    '''Customer generation'''
    def generate_customer(self):
        random_number = np.random.rand() # generate random number
        probabilities = self.arrival_rates # arrival rates list
        cumulative_probability = 0 # Use cumulative probability decide customer type
        customer_index = 0
        for probability in probabilities:
            cumulative_probability += probability
            if random_number <= cumulative_probability:
                break
            customer_index += 1
        customer_type = self.customer_type[customer_index] # return customer will buy what kind of seat   
        # print(f"random_number: {random_number}, customer_index: {customer_index}, customer_type: {customer_type}")
        return customer_type

    '''customer's preference seat under control'''
    def preference_seat(self, customer_type, seat_open):
        preferred_seats = []  
        preferences = self.customer_preference[customer_type]  
        for seat_type, preference in preferences.items():
            if preference and seat_type in seat_open:
                preferred_seats.append(seat_type)
        # print("preference seats: ", preferred_seats)
        return preferred_seats  
    
    '''customer make decision'''
    def make_decision(self, customer_type, seat_open):
        preferred_seats = self.preference_seat(customer_type, seat_open)  
        if preferred_seats:
            cheapest_seat = min(preferred_seats, key=lambda x: self.seat_price[x])
            return cheapest_seat
        else:
            return 'f'

# %%
'''Establish env with Single Cabin mulitiple fare classes'''
class AirlineEnvironment:
    
    '''Initialize env parameters'''
    def __init__(self, name):
        
        # name of env
        self.name = name
        
        # inherent aircraft
        self.aircraft = aircraft()
        self.seat_capacity = self.aircraft.seat_capacity # seat limitation
        self.seat_type = self.aircraft.seat_type # seat type
        
        # inherent action space class
        self.action_space = AgentActionSpace() 
        
        # inherent attributes from demand model
        self.max_rd = 20 # total selling RDs
        self.demand_model = demandmodel()
        self.total_demand = sum(self.demand_model.formulation(self.max_rd, 1).values()) # total demand from demand model
        self.total_lambda = 0.8 # total lambda from test
        self.max_period = int(self.total_demand/self.total_lambda) # total period
        
        # inherent attributes from uniform distribution class
        self.uniform_distribution = uniform_distribution(self.total_demand, self.total_lambda)
        self.arrival_rates = self.uniform_distribution.calculate_lambda() # calculate arrival rates for each customer type

        # inherent attributes from Customer class
        self.customer = Customer(self.total_demand, self.total_lambda) 
        
        # environment parameters
        self.seat_remain = self.seat_capacity # seat limitation
        self.state = np.array([self.seat_capacity, self.max_period]) # Initialize state : (num seat sold, period)
        # self.a_s_ref = {0: 'f', 1: 'Y', 2: 'M', 3: 'K', 4: 'YM', 5: 'YK', 6: 'MK', 7: 'YMK'} # action reference to seat open combination
        self.a_s_ref = {0: 'f', 1: 'Y', 2: 'YK', 3: 'YMK'}
    
    '''reset env'''
    def reset(self):
        self.seat_remain = self.seat_capacity # Initialize total seat 
        self.state = np.array([self.seat_remain, self.max_period])  # Initialize state
        return self.state
    
    '''Step'''
    def step(self, state, action):

        # print(f"Action: {action}, state: {state}")
        
        # With remaining seat
        if self.seat_remain > 0:

            # Agent choose a seat combination
            seat_open = self.a_s_ref[action]   
            # print("seat_open: ", seat_open)
            
            # Customer generation
            customer_type = self.customer.generate_customer()
            # print("customer type: ", customer_type)

            # Customer choose seat
            chosen_seat = self.customer.make_decision(customer_type, seat_open) 
            # print("chosen seat: ", chosen_seat)

            # Decide immediate revenue
            reward = self.aircraft.seat_price[chosen_seat] 

            # Update seat remain
            if reward > 0:
                self.seat_remain = self.seat_remain-1
        
        # Without remaining seat 
        else:
            # print("No remaining seat.")
            reward = 0

        # Update period
        next_time = state[1].item() - 1
        
        # Check departure or not 
        departure = (next_time <= 0)

        # update state
        state[0] = self.seat_remain
        state[1] = next_time
        return state, reward, departure

# %%
'''Deep Q Network'''
class DeepQNetwork(nn.Module):
    def __init__(self, lr, n_actions, input_dims):
        super(DeepQNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dims, 512)
        self.fc2 = nn.Linear(512, n_actions)

        self.optimizer = optim.RMSprop(self.parameters(), lr=lr)

        self.loss = nn.MSELoss()
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)

    def forward(self, state):
        x = F.relu(self.fc1(state))
        actions = self.fc2(x)

        return actions

# %%
'''Define replay buffer'''
class ReplayBuffer(object):
    def __init__(self, max_size, input_shape, n_actions):
        self.mem_size = max_size
        self.mem_cntr = 0
        self.state_memory = np.zeros((self.mem_size, *input_shape),
                                     dtype=np.float32)
        self.new_state_memory = np.zeros((self.mem_size, *input_shape),
                                         dtype=np.float32)

        self.action_memory = np.zeros(self.mem_size, dtype=np.int64)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool_)

    # store transition to buffer
    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.terminal_memory[index] = done
        self.mem_cntr += 1

    # sample transition from buffer
    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)
        batch = np.random.choice(max_mem, batch_size, replace=False)

        states = self.state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        states_ = self.new_state_memory[batch]
        terminal = self.terminal_memory[batch]

        return states, actions, rewards, states_, terminal

# %%
''' Define DQN agent'''
class DQNAgent(object):
    def __init__(self, gamma, epsilon, lr, n_actions, input_dims,
                 mem_size, batch_size, eps_min, eps_dec, replace):
        self.gamma = gamma # time discount gamma
        self.epsilon = epsilon # epilson-greedy hyperparameter eplison
        self.lr = lr # learning rate
        self.n_actions = n_actions # number of action
        self.input_dims = input_dims # number of state
        self.batch_size = batch_size # batch size of sample memory
        self.eps_min = eps_min # minimum of hyperparameter epilson
        self.eps_dec = eps_dec # epilson decay rate, higher represent slower decay
        self.replace_target_cnt = replace # frequence of replace target network 
        self.action_space = [i for i in range(n_actions)]
        self.learn_step_counter = 0
        self.memory = ReplayBuffer(mem_size, (input_dims,), n_actions) # Replay buffer
        self.q_eval = DeepQNetwork(self.lr, self.n_actions,
                                    input_dims=self.input_dims) # Target network
        self.q_next = DeepQNetwork(self.lr, self.n_actions,
                                    input_dims=self.input_dims) # Policy network

    # agent choose action
    def choose_action(self, observation):
        if np.random.random() > self.epsilon: # exploit: selection max value column
            state = T.tensor([observation],dtype=T.float).to(self.q_eval.device)
            actions = self.q_eval.forward(state)
            action = T.argmax(actions).item()
        else: # explore: randomly select aciton
            action = np.random.choice(self.action_space)
        return action

    # store transition
    def store_transition(self, state, action, reward, state_, done):
        self.memory.store_transition(state, action, reward, state_, done)

    # sample memory
    def sample_memory(self):
        state, action, reward, new_state, done = \
                                self.memory.sample_buffer(self.batch_size)
        states = T.tensor(state).to(self.q_eval.device)
        rewards = T.tensor(reward).to(self.q_eval.device)
        dones = T.tensor(done).to(self.q_eval.device)
        actions = T.tensor(action).to(self.q_eval.device)
        states_ = T.tensor(new_state).to(self.q_eval.device)
        return states, actions, rewards, states_, dones

    # update parameter of target network
    def replace_target_network(self):
        if self.learn_step_counter % self.replace_target_cnt == 0:
            self.q_next.load_state_dict(self.q_eval.state_dict())

    # decrease value of epilson
    def decrement_epsilon(self):
        self.epsilon = self.epsilon - self.eps_dec \
                           if self.epsilon > self.eps_min else self.eps_min

    # optimizer model
    def learn(self):

        if self.memory.mem_cntr < self.batch_size: # check whether have enough memory
            return

        self.q_eval.optimizer.zero_grad() # diminish previous gradient

        self.replace_target_network()

        states, actions, rewards, states_, dones = self.sample_memory()
        indices = np.arange(self.batch_size)

        q_pred = self.q_eval.forward(states)[indices, actions]
        q_next = self.q_next.forward(states_).max(dim=1)[0]

        q_next[dones] = 0.0
        q_target = rewards + self.gamma*q_next

        loss = self.q_eval.loss(q_target, q_pred).to(self.q_eval.device)
        loss.backward()
        self.q_eval.optimizer.step()
        self.learn_step_counter += 1

        self.decrement_epsilon()

# %%
# Initialize Training parameters
num_episodes = 1000
DQN_total_revenues = []
DQN_cumulative_average = []
DQN_per_50_avg = []

env = AirlineEnvironment("Single route parallel flight.v0")
agent = DQNAgent(gamma=0.95, epsilon=1, lr=0.0001,
                 input_dims=len(env.state),
                 n_actions=env.action_space.n, mem_size=300000, eps_min=0.1,
                 batch_size=256, replace=1000, eps_dec=1e-5)

n_step = 0
best_score = 0

# Start Training
for episode in range(1, num_episodes+1):
    
    # Initialize environment
    # print("---------- Episode ", episode, "-----------")
    observation = env.reset()
    total_revenue = 0 # Initialize total revenue
    departure = None
    
    while not departure:
        
        # print("------- step " , env.max_period - n_step," ---------")
        
        # agent select action
        action = agent.choose_action(observation)
        # print("action", action)

        # env return observation
        observation_, reward, departure = env.step(observation, action)
        # print("observation_: ", observation, "reward: ",  reward, "departure: ", departure)
        total_revenue += reward # Update total revenue

        # agent memorize transition
        agent.store_transition(observation, action, reward, observation_, departure)
        agent.learn()

        # Move on to the next state
        observation = observation_ 
        n_step += 1

    if total_revenue > best_score:
        best_score = total_revenue
        
    DQN_total_revenues.append(total_revenue) 
    DQN_per_50_avg.append(np.mean(DQN_total_revenues[-50:])) 
    DQN_cumulative_avg = sum(DQN_total_revenues) / (episode)
    DQN_cumulative_average.append(DQN_cumulative_avg)
    print('Episode:',episode ,'Total Revenue:', total_revenue,
             'Cumulative average %.1f' % DQN_cumulative_avg, 'best score:', best_score,
            'epsilon %.2f' % agent.epsilon, 'steps', n_step)
# Out:
# Episode: 1 Total Revenue: 44550  Cumulative average 44550.0 best score: 44550 epsilon 1.00 steps 193
# Episode: 2 Total Revenue: 50400  Cumulative average 47475.0 best score: 50400 epsilon 1.00 steps 386
# C:\Users\User\AppData\Local\Temp\ipykernel_93444\99049053.py:25: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:264.)
#   state = T.tensor([observation],dtype=T.float).to(self.q_eval.device)
# Episode: 3 Total Revenue: 49450  Cumulative average 48133.3 best score: 50400 epsilon 1.00 steps 579
# Episode: 4 Total Revenue: 44100  Cumulative average 47125.0 best score: 50400 epsilon 0.99 steps 772
# Episode: 5 Total Revenue: 48850  Cumulative average 47470.0 best score: 50400 epsilon 0.99 steps 965
# Episode: 6 Total Revenue: 41350  Cumulative average 46450.0 best score: 50400 epsilon 0.99 steps 1158
# Episode: 7 Total Revenue: 53500  Cumulative average 47457.1 best score: 53500 epsilon 0.99 steps 1351
# Episode: 8 Total Revenue: 46950  Cumulative average 47393.8 best score: 53500 epsilon 0.99 steps 1544
# Episode: 9 Total Revenue: 41850  Cumulative average 46777.8 best score: 53500 epsilon 0.99 steps 1737
# Episode: 10 Total Revenue: 45100  Cumulative average 46610.0 best score: 53500 epsilon 0.98 steps 1930
# Episode: 11 Total Revenue: 47600  Cumulative average 46700.0 best score: 53500 epsilon 0.98 steps 2123
# Episode: 12 Total Revenue: 44100  Cumulative average 46483.3 best score: 53500 epsilon 0.98 steps 2316
# Episode: 13 Total Revenue: 52650  Cumulative average 46957.7 best score: 53500 epsilon 0.98 steps 2509
# Episode: 14 Total Revenue: 43450  Cumulative average 46707.1 best score: 53500 epsilon 0.98 steps 2702
# Episode: 15 Total Revenue: 52550  Cumulative average 47096.7 best score: 53500 epsilon 0.97 steps 2895
# Episode: 16 Total Revenue: 46250  Cumulative average 47043.8 best score: 53500 epsilon 0.97 steps 3088
# Episode: 17 Total Revenue: 42950  Cumulative average 46802.9 best score: 53500 epsilon 0.97 steps 3281
# Episode: 18 Total Revenue: 49350  Cumulative average 46944.4 best score: 53500 epsilon 0.97 steps 3474
# Episode: 19 Total Revenue: 46850  Cumulative average 46939.5 best score: 53500 epsilon 0.97 steps 3667
# Episode: 20 Total Revenue: 45000  Cumulative average 46842.5 best score: 53500 epsilon 0.96 steps 3860
# Episode: 21 Total Revenue: 44600  Cumulative average 46735.7 best score: 53500 epsilon 0.96 steps 4053
# Episode: 22 Total Revenue: 45000  Cumulative average 46656.8 best score: 53500 epsilon 0.96 steps 4246
# Episode: 23 Total Revenue: 55100  Cumulative average 47023.9 best score: 55100 epsilon 0.96 steps 4439
# Episode: 24 Total Revenue: 44300  Cumulative average 46910.4 best score: 55100 epsilon 0.96 steps 4632
# Episode: 25 Total Revenue: 58500  Cumulative average 47374.0 best score: 58500 epsilon 0.95 steps 4825
# Episode: 26 Total Revenue: 50650  Cumulative average 47500.0 best score: 58500 epsilon 0.95 steps 5018
# Episode: 27 Total Revenue: 44400  Cumulative average 47385.2 best score: 58500 epsilon 0.95 steps 5211
# Episode: 28 Total Revenue: 52050  Cumulative average 47551.8 best score: 58500 epsilon 0.95 steps 5404
# Episode: 29 Total Revenue: 44600  Cumulative average 47450.0 best score: 58500 epsilon 0.95 steps 5597
# Episode: 30 Total Revenue: 53800  Cumulative average 47661.7 best score: 58500 epsilon 0.94 steps 5790
# Episode: 31 Total Revenue: 56150  Cumulative average 47935.5 best score: 58500 epsilon 0.94 steps 5983
# Episode: 32 Total Revenue: 45700  Cumulative average 47865.6 best score: 58500 epsilon 0.94 steps 6176
# Episode: 33 Total Revenue: 48500  Cumulative average 47884.8 best score: 58500 epsilon 0.94 steps 6369
# Episode: 34 Total Revenue: 42500  Cumulative average 47726.5 best score: 58500 epsilon 0.94 steps 6562
# Episode: 35 Total Revenue: 48550  Cumulative average 47750.0 best score: 58500 epsilon 0.94 steps 6755
# Episode: 36 Total Revenue: 51850  Cumulative average 47863.9 best score: 58500 epsilon 0.93 steps 6948
# Episode: 37 Total Revenue: 45750  Cumulative average 47806.8 best score: 58500 epsilon 0.93 steps 7141
# Episode: 38 Total Revenue: 47800  Cumulative average 47806.6 best score: 58500 epsilon 0.93 steps 7334
# Episode: 39 Total Revenue: 49250  Cumulative average 47843.6 best score: 58500 epsilon 0.93 steps 7527
# Episode: 40 Total Revenue: 44600  Cumulative average 47762.5 best score: 58500 epsilon 0.93 steps 7720
# Episode: 41 Total Revenue: 45200  Cumulative average 47700.0 best score: 58500 epsilon 0.92 steps 7913
# Episode: 42 Total Revenue: 52750  Cumulative average 47820.2 best score: 58500 epsilon 0.92 steps 8106
# Episode: 43 Total Revenue: 50050  Cumulative average 47872.1 best score: 58500 epsilon 0.92 steps 8299
# Episode: 44 Total Revenue: 56200  Cumulative average 48061.4 best score: 58500 epsilon 0.92 steps 8492
# Episode: 45 Total Revenue: 48450  Cumulative average 48070.0 best score: 58500 epsilon 0.92 steps 8685
# Episode: 46 Total Revenue: 47450  Cumulative average 48056.5 best score: 58500 epsilon 0.91 steps 8878
# Episode: 47 Total Revenue: 54350  Cumulative average 48190.4 best score: 58500 epsilon 0.91 steps 9071
# Episode: 48 Total Revenue: 47900  Cumulative average 48184.4 best score: 58500 epsilon 0.91 steps 9264
# Episode: 49 Total Revenue: 41700  Cumulative average 48052.0 best score: 58500 epsilon 0.91 steps 9457
# Episode: 50 Total Revenue: 49250  Cumulative average 48076.0 best score: 58500 epsilon 0.91 steps 9650
# Episode: 51 Total Revenue: 56250  Cumulative average 48236.3 best score: 58500 epsilon 0.90 steps 9843
# Episode: 52 Total Revenue: 52500  Cumulative average 48318.3 best score: 58500 epsilon 0.90 steps 10036
# Episode: 53 Total Revenue: 52500  Cumulative average 48397.2 best score: 58500 epsilon 0.90 steps 10229
# Episode: 54 Total Revenue: 48950  Cumulative average 48407.4 best score: 58500 epsilon 0.90 steps 10422
# Episode: 55 Total Revenue: 53250  Cumulative average 48495.5 best score: 58500 epsilon 0.90 steps 10615
# Episode: 56 Total Revenue: 52700  Cumulative average 48570.5 best score: 58500 epsilon 0.89 steps 10808
# Episode: 57 Total Revenue: 55500  Cumulative average 48692.1 best score: 58500 epsilon 0.89 steps 11001
# Episode: 58 Total Revenue: 45450  Cumulative average 48636.2 best score: 58500 epsilon 0.89 steps 11194
# Episode: 59 Total Revenue: 54200  Cumulative average 48730.5 best score: 58500 epsilon 0.89 steps 11387
# Episode: 60 Total Revenue: 50550  Cumulative average 48760.8 best score: 58500 epsilon 0.89 steps 11580
# Episode: 61 Total Revenue: 50150  Cumulative average 48783.6 best score: 58500 epsilon 0.88 steps 11773
# Episode: 62 Total Revenue: 41400  Cumulative average 48664.5 best score: 58500 epsilon 0.88 steps 11966
# Episode: 63 Total Revenue: 45300  Cumulative average 48611.1 best score: 58500 epsilon 0.88 steps 12159
# Episode: 64 Total Revenue: 53550  Cumulative average 48688.3 best score: 58500 epsilon 0.88 steps 12352
# Episode: 65 Total Revenue: 56800  Cumulative average 48813.1 best score: 58500 epsilon 0.88 steps 12545
# Episode: 66 Total Revenue: 51100  Cumulative average 48847.7 best score: 58500 epsilon 0.88 steps 12738
# Episode: 67 Total Revenue: 48900  Cumulative average 48848.5 best score: 58500 epsilon 0.87 steps 12931
# Episode: 68 Total Revenue: 45250  Cumulative average 48795.6 best score: 58500 epsilon 0.87 steps 13124
# Episode: 69 Total Revenue: 57750  Cumulative average 48925.4 best score: 58500 epsilon 0.87 steps 13317
# Episode: 70 Total Revenue: 45400  Cumulative average 48875.0 best score: 58500 epsilon 0.87 steps 13510
# Episode: 71 Total Revenue: 58650  Cumulative average 49012.7 best score: 58650 epsilon 0.87 steps 13703
# Episode: 72 Total Revenue: 53950  Cumulative average 49081.2 best score: 58650 epsilon 0.86 steps 13896
# Episode: 73 Total Revenue: 50450  Cumulative average 49100.0 best score: 58650 epsilon 0.86 steps 14089
# Episode: 74 Total Revenue: 49300  Cumulative average 49102.7 best score: 58650 epsilon 0.86 steps 14282
# Episode: 75 Total Revenue: 50150  Cumulative average 49116.7 best score: 58650 epsilon 0.86 steps 14475
# Episode: 76 Total Revenue: 54350  Cumulative average 49185.5 best score: 58650 epsilon 0.86 steps 14668
# Episode: 77 Total Revenue: 57850  Cumulative average 49298.1 best score: 58650 epsilon 0.85 steps 14861
# Episode: 78 Total Revenue: 48650  Cumulative average 49289.7 best score: 58650 epsilon 0.85 steps 15054
# Episode: 79 Total Revenue: 43550  Cumulative average 49217.1 best score: 58650 epsilon 0.85 steps 15247
# Episode: 80 Total Revenue: 43950  Cumulative average 49151.2 best score: 58650 epsilon 0.85 steps 15440
# Episode: 81 Total Revenue: 47750  Cumulative average 49134.0 best score: 58650 epsilon 0.85 steps 15633
# Episode: 82 Total Revenue: 53500  Cumulative average 49187.2 best score: 58650 epsilon 0.84 steps 15826
# Episode: 83 Total Revenue: 59150  Cumulative average 49307.2 best score: 59150 epsilon 0.84 steps 16019
# Episode: 84 Total Revenue: 52400  Cumulative average 49344.0 best score: 59150 epsilon 0.84 steps 16212
# Episode: 85 Total Revenue: 49800  Cumulative average 49349.4 best score: 59150 epsilon 0.84 steps 16405
# Episode: 86 Total Revenue: 50650  Cumulative average 49364.5 best score: 59150 epsilon 0.84 steps 16598
# Episode: 87 Total Revenue: 54650  Cumulative average 49425.3 best score: 59150 epsilon 0.83 steps 16791
# Episode: 88 Total Revenue: 56500  Cumulative average 49505.7 best score: 59150 epsilon 0.83 steps 16984
# Episode: 89 Total Revenue: 47500  Cumulative average 49483.1 best score: 59150 epsilon 0.83 steps 17177
# Episode: 90 Total Revenue: 55600  Cumulative average 49551.1 best score: 59150 epsilon 0.83 steps 17370
# Episode: 91 Total Revenue: 50200  Cumulative average 49558.2 best score: 59150 epsilon 0.83 steps 17563
# Episode: 92 Total Revenue: 48950  Cumulative average 49551.6 best score: 59150 epsilon 0.82 steps 17756
# Episode: 93 Total Revenue: 50100  Cumulative average 49557.5 best score: 59150 epsilon 0.82 steps 17949
# Episode: 94 Total Revenue: 58450  Cumulative average 49652.1 best score: 59150 epsilon 0.82 steps 18142
# Episode: 95 Total Revenue: 48750  Cumulative average 49642.6 best score: 59150 epsilon 0.82 steps 18335
# Episode: 96 Total Revenue: 55200  Cumulative average 49700.5 best score: 59150 epsilon 0.82 steps 18528
# Episode: 97 Total Revenue: 54250  Cumulative average 49747.4 best score: 59150 epsilon 0.82 steps 18721
# Episode: 98 Total Revenue: 58200  Cumulative average 49833.7 best score: 59150 epsilon 0.81 steps 18914
# Episode: 99 Total Revenue: 48650  Cumulative average 49821.7 best score: 59150 epsilon 0.81 steps 19107
# Episode: 100 Total Revenue: 52500  Cumulative average 49848.5 best score: 59150 epsilon 0.81 steps 19300
# Episode: 101 Total Revenue: 53200  Cumulative average 49881.7 best score: 59150 epsilon 0.81 steps 19493
# Episode: 102 Total Revenue: 49550  Cumulative average 49878.4 best score: 59150 epsilon 0.81 steps 19686
# Episode: 103 Total Revenue: 47350  Cumulative average 49853.9 best score: 59150 epsilon 0.80 steps 19879
# Episode: 104 Total Revenue: 48600  Cumulative average 49841.8 best score: 59150 epsilon 0.80 steps 20072
# Episode: 105 Total Revenue: 51200  Cumulative average 49854.8 best score: 59150 epsilon 0.80 steps 20265
# Episode: 106 Total Revenue: 53150  Cumulative average 49885.8 best score: 59150 epsilon 0.80 steps 20458
# Episode: 107 Total Revenue: 50250  Cumulative average 49889.3 best score: 59150 epsilon 0.80 steps 20651
# Episode: 108 Total Revenue: 50100  Cumulative average 49891.2 best score: 59150 epsilon 0.79 steps 20844
# Episode: 109 Total Revenue: 51650  Cumulative average 49907.3 best score: 59150 epsilon 0.79 steps 21037
# Episode: 110 Total Revenue: 49600  Cumulative average 49904.5 best score: 59150 epsilon 0.79 steps 21230
# Episode: 111 Total Revenue: 47100  Cumulative average 49879.3 best score: 59150 epsilon 0.79 steps 21423
# Episode: 112 Total Revenue: 56350  Cumulative average 49937.1 best score: 59150 epsilon 0.79 steps 21616
# Episode: 113 Total Revenue: 51150  Cumulative average 49947.8 best score: 59150 epsilon 0.78 steps 21809
# Episode: 114 Total Revenue: 50000  Cumulative average 49948.2 best score: 59150 epsilon 0.78 steps 22002
# Episode: 115 Total Revenue: 56250  Cumulative average 50003.0 best score: 59150 epsilon 0.78 steps 22195
# Episode: 116 Total Revenue: 41450  Cumulative average 49929.3 best score: 59150 epsilon 0.78 steps 22388
# Episode: 117 Total Revenue: 54050  Cumulative average 49964.5 best score: 59150 epsilon 0.78 steps 22581
# Episode: 118 Total Revenue: 56550  Cumulative average 50020.3 best score: 59150 epsilon 0.77 steps 22774
# Episode: 119 Total Revenue: 53450  Cumulative average 50049.2 best score: 59150 epsilon 0.77 steps 22967
# Episode: 120 Total Revenue: 55000  Cumulative average 50090.4 best score: 59150 epsilon 0.77 steps 23160
# Episode: 121 Total Revenue: 50400  Cumulative average 50093.0 best score: 59150 epsilon 0.77 steps 23353
# Episode: 122 Total Revenue: 54700  Cumulative average 50130.7 best score: 59150 epsilon 0.77 steps 23546
# Episode: 123 Total Revenue: 57250  Cumulative average 50188.6 best score: 59150 epsilon 0.77 steps 23739
# Episode: 124 Total Revenue: 56050  Cumulative average 50235.9 best score: 59150 epsilon 0.76 steps 23932
# Episode: 125 Total Revenue: 57100  Cumulative average 50290.8 best score: 59150 epsilon 0.76 steps 24125
# Episode: 126 Total Revenue: 53400  Cumulative average 50315.5 best score: 59150 epsilon 0.76 steps 24318
# Episode: 127 Total Revenue: 53300  Cumulative average 50339.0 best score: 59150 epsilon 0.76 steps 24511
# Episode: 128 Total Revenue: 54050  Cumulative average 50368.0 best score: 59150 epsilon 0.76 steps 24704
# Episode: 129 Total Revenue: 53600  Cumulative average 50393.0 best score: 59150 epsilon 0.75 steps 24897
# Episode: 130 Total Revenue: 55450  Cumulative average 50431.9 best score: 59150 epsilon 0.75 steps 25090
# Episode: 131 Total Revenue: 47850  Cumulative average 50412.2 best score: 59150 epsilon 0.75 steps 25283
# Episode: 132 Total Revenue: 53600  Cumulative average 50436.4 best score: 59150 epsilon 0.75 steps 25476
# Episode: 133 Total Revenue: 53100  Cumulative average 50456.4 best score: 59150 epsilon 0.75 steps 25669
# Episode: 134 Total Revenue: 53650  Cumulative average 50480.2 best score: 59150 epsilon 0.74 steps 25862
# Episode: 135 Total Revenue: 56400  Cumulative average 50524.1 best score: 59150 epsilon 0.74 steps 26055
# Episode: 136 Total Revenue: 55800  Cumulative average 50562.9 best score: 59150 epsilon 0.74 steps 26248
# Episode: 137 Total Revenue: 53700  Cumulative average 50585.8 best score: 59150 epsilon 0.74 steps 26441
# Episode: 138 Total Revenue: 53450  Cumulative average 50606.5 best score: 59150 epsilon 0.74 steps 26634
# Episode: 139 Total Revenue: 55500  Cumulative average 50641.7 best score: 59150 epsilon 0.73 steps 26827
# Episode: 140 Total Revenue: 58600  Cumulative average 50698.6 best score: 59150 epsilon 0.73 steps 27020
# Episode: 141 Total Revenue: 54050  Cumulative average 50722.3 best score: 59150 epsilon 0.73 steps 27213
# Episode: 142 Total Revenue: 53700  Cumulative average 50743.3 best score: 59150 epsilon 0.73 steps 27406
# Episode: 143 Total Revenue: 50150  Cumulative average 50739.2 best score: 59150 epsilon 0.73 steps 27599
# Episode: 144 Total Revenue: 54950  Cumulative average 50768.4 best score: 59150 epsilon 0.72 steps 27792
# Episode: 145 Total Revenue: 55750  Cumulative average 50802.8 best score: 59150 epsilon 0.72 steps 27985
# Episode: 146 Total Revenue: 56550  Cumulative average 50842.1 best score: 59150 epsilon 0.72 steps 28178
# Episode: 147 Total Revenue: 55000  Cumulative average 50870.4 best score: 59150 epsilon 0.72 steps 28371
# Episode: 148 Total Revenue: 51400  Cumulative average 50874.0 best score: 59150 epsilon 0.72 steps 28564
# Episode: 149 Total Revenue: 54100  Cumulative average 50895.6 best score: 59150 epsilon 0.71 steps 28757
# Episode: 150 Total Revenue: 49500  Cumulative average 50886.3 best score: 59150 epsilon 0.71 steps 28950
# Episode: 151 Total Revenue: 53800  Cumulative average 50905.6 best score: 59150 epsilon 0.71 steps 29143
# Episode: 152 Total Revenue: 53000  Cumulative average 50919.4 best score: 59150 epsilon 0.71 steps 29336
# Episode: 153 Total Revenue: 56250  Cumulative average 50954.2 best score: 59150 epsilon 0.71 steps 29529
# Episode: 154 Total Revenue: 55850  Cumulative average 50986.0 best score: 59150 epsilon 0.71 steps 29722
# Episode: 155 Total Revenue: 52400  Cumulative average 50995.2 best score: 59150 epsilon 0.70 steps 29915
# Episode: 156 Total Revenue: 56100  Cumulative average 51027.9 best score: 59150 epsilon 0.70 steps 30108
# Episode: 157 Total Revenue: 51950  Cumulative average 51033.8 best score: 59150 epsilon 0.70 steps 30301
# Episode: 158 Total Revenue: 52600  Cumulative average 51043.7 best score: 59150 epsilon 0.70 steps 30494
# Episode: 159 Total Revenue: 54500  Cumulative average 51065.4 best score: 59150 epsilon 0.70 steps 30687
# Episode: 160 Total Revenue: 54500  Cumulative average 51086.9 best score: 59150 epsilon 0.69 steps 30880
# Episode: 161 Total Revenue: 43200  Cumulative average 51037.9 best score: 59150 epsilon 0.69 steps 31073
# Episode: 162 Total Revenue: 52400  Cumulative average 51046.3 best score: 59150 epsilon 0.69 steps 31266
# Episode: 163 Total Revenue: 55000  Cumulative average 51070.6 best score: 59150 epsilon 0.69 steps 31459
# Episode: 164 Total Revenue: 55350  Cumulative average 51096.6 best score: 59150 epsilon 0.69 steps 31652
# Episode: 165 Total Revenue: 53900  Cumulative average 51113.6 best score: 59150 epsilon 0.68 steps 31845
# Episode: 166 Total Revenue: 54000  Cumulative average 51131.0 best score: 59150 epsilon 0.68 steps 32038
# Episode: 167 Total Revenue: 55400  Cumulative average 51156.6 best score: 59150 epsilon 0.68 steps 32231
# Episode: 168 Total Revenue: 51250  Cumulative average 51157.1 best score: 59150 epsilon 0.68 steps 32424
# Episode: 169 Total Revenue: 56050  Cumulative average 51186.1 best score: 59150 epsilon 0.68 steps 32617
# Episode: 170 Total Revenue: 56400  Cumulative average 51216.8 best score: 59150 epsilon 0.67 steps 32810
# Episode: 171 Total Revenue: 55050  Cumulative average 51239.2 best score: 59150 epsilon 0.67 steps 33003
# Episode: 172 Total Revenue: 52400  Cumulative average 51245.9 best score: 59150 epsilon 0.67 steps 33196
# Episode: 173 Total Revenue: 54650  Cumulative average 51265.6 best score: 59150 epsilon 0.67 steps 33389
# Episode: 174 Total Revenue: 50250  Cumulative average 51259.8 best score: 59150 epsilon 0.67 steps 33582
# Episode: 175 Total Revenue: 54850  Cumulative average 51280.3 best score: 59150 epsilon 0.66 steps 33775
# Episode: 176 Total Revenue: 54750  Cumulative average 51300.0 best score: 59150 epsilon 0.66 steps 33968
# Episode: 177 Total Revenue: 54700  Cumulative average 51319.2 best score: 59150 epsilon 0.66 steps 34161
# Episode: 178 Total Revenue: 51700  Cumulative average 51321.3 best score: 59150 epsilon 0.66 steps 34354
# Episode: 179 Total Revenue: 53650  Cumulative average 51334.4 best score: 59150 epsilon 0.66 steps 34547
# Episode: 180 Total Revenue: 53800  Cumulative average 51348.1 best score: 59150 epsilon 0.66 steps 34740
# Episode: 181 Total Revenue: 52850  Cumulative average 51356.4 best score: 59150 epsilon 0.65 steps 34933
# Episode: 182 Total Revenue: 50100  Cumulative average 51349.5 best score: 59150 epsilon 0.65 steps 35126
# Episode: 183 Total Revenue: 54350  Cumulative average 51365.8 best score: 59150 epsilon 0.65 steps 35319
# Episode: 184 Total Revenue: 50950  Cumulative average 51363.6 best score: 59150 epsilon 0.65 steps 35512
# Episode: 185 Total Revenue: 51900  Cumulative average 51366.5 best score: 59150 epsilon 0.65 steps 35705
# Episode: 186 Total Revenue: 48400  Cumulative average 51350.5 best score: 59150 epsilon 0.64 steps 35898
# Episode: 187 Total Revenue: 52900  Cumulative average 51358.8 best score: 59150 epsilon 0.64 steps 36091
# Episode: 188 Total Revenue: 55500  Cumulative average 51380.9 best score: 59150 epsilon 0.64 steps 36284
# Episode: 189 Total Revenue: 53850  Cumulative average 51393.9 best score: 59150 epsilon 0.64 steps 36477
# Episode: 190 Total Revenue: 53150  Cumulative average 51403.2 best score: 59150 epsilon 0.64 steps 36670
# Episode: 191 Total Revenue: 55900  Cumulative average 51426.7 best score: 59150 epsilon 0.63 steps 36863
# Episode: 192 Total Revenue: 51850  Cumulative average 51428.9 best score: 59150 epsilon 0.63 steps 37056
# Episode: 193 Total Revenue: 53850  Cumulative average 51441.5 best score: 59150 epsilon 0.63 steps 37249
# Episode: 194 Total Revenue: 54800  Cumulative average 51458.8 best score: 59150 epsilon 0.63 steps 37442
# Episode: 195 Total Revenue: 53750  Cumulative average 51470.5 best score: 59150 epsilon 0.63 steps 37635
# Episode: 196 Total Revenue: 53400  Cumulative average 51480.4 best score: 59150 epsilon 0.62 steps 37828
# Episode: 197 Total Revenue: 55500  Cumulative average 51500.8 best score: 59150 epsilon 0.62 steps 38021
# Episode: 198 Total Revenue: 52700  Cumulative average 51506.8 best score: 59150 epsilon 0.62 steps 38214
# Episode: 199 Total Revenue: 53800  Cumulative average 51518.3 best score: 59150 epsilon 0.62 steps 38407
# Episode: 200 Total Revenue: 53600  Cumulative average 51528.8 best score: 59150 epsilon 0.62 steps 38600
# Episode: 201 Total Revenue: 53650  Cumulative average 51539.3 best score: 59150 epsilon 0.61 steps 38793
# Episode: 202 Total Revenue: 53700  Cumulative average 51550.0 best score: 59150 epsilon 0.61 steps 38986
# Episode: 203 Total Revenue: 53950  Cumulative average 51561.8 best score: 59150 epsilon 0.61 steps 39179
# Episode: 204 Total Revenue: 53600  Cumulative average 51571.8 best score: 59150 epsilon 0.61 steps 39372
# Episode: 205 Total Revenue: 50850  Cumulative average 51568.3 best score: 59150 epsilon 0.61 steps 39565
# Episode: 206 Total Revenue: 53950  Cumulative average 51579.9 best score: 59150 epsilon 0.60 steps 39758
# Episode: 207 Total Revenue: 53700  Cumulative average 51590.1 best score: 59150 epsilon 0.60 steps 39951
# Episode: 208 Total Revenue: 53150  Cumulative average 51597.6 best score: 59150 epsilon 0.60 steps 40144
# Episode: 209 Total Revenue: 53400  Cumulative average 51606.2 best score: 59150 epsilon 0.60 steps 40337
# Episode: 210 Total Revenue: 53600  Cumulative average 51615.7 best score: 59150 epsilon 0.60 steps 40530
# Episode: 211 Total Revenue: 55800  Cumulative average 51635.5 best score: 59150 epsilon 0.60 steps 40723
# Episode: 212 Total Revenue: 52900  Cumulative average 51641.5 best score: 59150 epsilon 0.59 steps 40916
# Episode: 213 Total Revenue: 54850  Cumulative average 51656.6 best score: 59150 epsilon 0.59 steps 41109
# Episode: 214 Total Revenue: 54950  Cumulative average 51672.0 best score: 59150 epsilon 0.59 steps 41302
# Episode: 215 Total Revenue: 51650  Cumulative average 51671.9 best score: 59150 epsilon 0.59 steps 41495
# Episode: 216 Total Revenue: 52400  Cumulative average 51675.2 best score: 59150 epsilon 0.59 steps 41688
# Episode: 217 Total Revenue: 53300  Cumulative average 51682.7 best score: 59150 epsilon 0.58 steps 41881
# Episode: 218 Total Revenue: 52350  Cumulative average 51685.8 best score: 59150 epsilon 0.58 steps 42074
# Episode: 219 Total Revenue: 52200  Cumulative average 51688.1 best score: 59150 epsilon 0.58 steps 42267
# Episode: 220 Total Revenue: 54150  Cumulative average 51699.3 best score: 59150 epsilon 0.58 steps 42460
# Episode: 221 Total Revenue: 51850  Cumulative average 51700.0 best score: 59150 epsilon 0.58 steps 42653
# Episode: 222 Total Revenue: 53400  Cumulative average 51707.7 best score: 59150 epsilon 0.57 steps 42846
# Episode: 223 Total Revenue: 53300  Cumulative average 51714.8 best score: 59150 epsilon 0.57 steps 43039
# Episode: 224 Total Revenue: 53850  Cumulative average 51724.3 best score: 59150 epsilon 0.57 steps 43232
# Episode: 225 Total Revenue: 55250  Cumulative average 51740.0 best score: 59150 epsilon 0.57 steps 43425
# Episode: 226 Total Revenue: 54550  Cumulative average 51752.4 best score: 59150 epsilon 0.57 steps 43618
# Episode: 227 Total Revenue: 54450  Cumulative average 51764.3 best score: 59150 epsilon 0.56 steps 43811
# Episode: 228 Total Revenue: 53500  Cumulative average 51771.9 best score: 59150 epsilon 0.56 steps 44004
# Episode: 229 Total Revenue: 52300  Cumulative average 51774.2 best score: 59150 epsilon 0.56 steps 44197
# Episode: 230 Total Revenue: 52100  Cumulative average 51775.7 best score: 59150 epsilon 0.56 steps 44390
# Episode: 231 Total Revenue: 54250  Cumulative average 51786.4 best score: 59150 epsilon 0.56 steps 44583
# Episode: 232 Total Revenue: 54650  Cumulative average 51798.7 best score: 59150 epsilon 0.55 steps 44776
# Episode: 233 Total Revenue: 53000  Cumulative average 51803.9 best score: 59150 epsilon 0.55 steps 44969
# Episode: 234 Total Revenue: 53700  Cumulative average 51812.0 best score: 59150 epsilon 0.55 steps 45162
# Episode: 235 Total Revenue: 53050  Cumulative average 51817.2 best score: 59150 epsilon 0.55 steps 45355
# Episode: 236 Total Revenue: 52100  Cumulative average 51818.4 best score: 59150 epsilon 0.55 steps 45548
# Episode: 237 Total Revenue: 53900  Cumulative average 51827.2 best score: 59150 epsilon 0.55 steps 45741
# Episode: 238 Total Revenue: 53500  Cumulative average 51834.2 best score: 59150 epsilon 0.54 steps 45934
# Episode: 239 Total Revenue: 52850  Cumulative average 51838.5 best score: 59150 epsilon 0.54 steps 46127
# Episode: 240 Total Revenue: 55550  Cumulative average 51854.0 best score: 59150 epsilon 0.54 steps 46320
# Episode: 241 Total Revenue: 54750  Cumulative average 51866.0 best score: 59150 epsilon 0.54 steps 46513
# Episode: 242 Total Revenue: 50700  Cumulative average 51861.2 best score: 59150 epsilon 0.54 steps 46706
# Episode: 243 Total Revenue: 51250  Cumulative average 51858.6 best score: 59150 epsilon 0.53 steps 46899
# Episode: 244 Total Revenue: 51100  Cumulative average 51855.5 best score: 59150 epsilon 0.53 steps 47092
# Episode: 245 Total Revenue: 51850  Cumulative average 51855.5 best score: 59150 epsilon 0.53 steps 47285
# Episode: 246 Total Revenue: 52550  Cumulative average 51858.3 best score: 59150 epsilon 0.53 steps 47478
# Episode: 247 Total Revenue: 53900  Cumulative average 51866.6 best score: 59150 epsilon 0.53 steps 47671
# Episode: 248 Total Revenue: 54050  Cumulative average 51875.4 best score: 59150 epsilon 0.52 steps 47864
# Episode: 249 Total Revenue: 52750  Cumulative average 51878.9 best score: 59150 epsilon 0.52 steps 48057
# Episode: 250 Total Revenue: 52700  Cumulative average 51882.2 best score: 59150 epsilon 0.52 steps 48250
# Episode: 251 Total Revenue: 53500  Cumulative average 51888.6 best score: 59150 epsilon 0.52 steps 48443
# Episode: 252 Total Revenue: 52150  Cumulative average 51889.7 best score: 59150 epsilon 0.52 steps 48636
# Episode: 253 Total Revenue: 54600  Cumulative average 51900.4 best score: 59150 epsilon 0.51 steps 48829
# Episode: 254 Total Revenue: 54500  Cumulative average 51910.6 best score: 59150 epsilon 0.51 steps 49022
# Episode: 255 Total Revenue: 50650  Cumulative average 51905.7 best score: 59150 epsilon 0.51 steps 49215
# Episode: 256 Total Revenue: 54800  Cumulative average 51917.0 best score: 59150 epsilon 0.51 steps 49408
# Episode: 257 Total Revenue: 49750  Cumulative average 51908.6 best score: 59150 epsilon 0.51 steps 49601
# Episode: 258 Total Revenue: 53050  Cumulative average 51913.0 best score: 59150 epsilon 0.50 steps 49794
# Episode: 259 Total Revenue: 51850  Cumulative average 51912.7 best score: 59150 epsilon 0.50 steps 49987
# Episode: 260 Total Revenue: 54750  Cumulative average 51923.7 best score: 59150 epsilon 0.50 steps 50180
# Episode: 261 Total Revenue: 54000  Cumulative average 51931.6 best score: 59150 epsilon 0.50 steps 50373
# Episode: 262 Total Revenue: 53600  Cumulative average 51938.0 best score: 59150 epsilon 0.50 steps 50566
# Episode: 263 Total Revenue: 55250  Cumulative average 51950.6 best score: 59150 epsilon 0.49 steps 50759
# Episode: 264 Total Revenue: 55050  Cumulative average 51962.3 best score: 59150 epsilon 0.49 steps 50952
# Episode: 265 Total Revenue: 54200  Cumulative average 51970.8 best score: 59150 epsilon 0.49 steps 51145
# Episode: 266 Total Revenue: 54750  Cumulative average 51981.2 best score: 59150 epsilon 0.49 steps 51338
# Episode: 267 Total Revenue: 52950  Cumulative average 51984.8 best score: 59150 epsilon 0.49 steps 51531
# Episode: 268 Total Revenue: 51200  Cumulative average 51981.9 best score: 59150 epsilon 0.49 steps 51724
# Episode: 269 Total Revenue: 54800  Cumulative average 51992.4 best score: 59150 epsilon 0.48 steps 51917
# Episode: 270 Total Revenue: 54750  Cumulative average 52002.6 best score: 59150 epsilon 0.48 steps 52110
# Episode: 271 Total Revenue: 54850  Cumulative average 52013.1 best score: 59150 epsilon 0.48 steps 52303
# Episode: 272 Total Revenue: 51800  Cumulative average 52012.3 best score: 59150 epsilon 0.48 steps 52496
# Episode: 273 Total Revenue: 51300  Cumulative average 52009.7 best score: 59150 epsilon 0.48 steps 52689
# Episode: 274 Total Revenue: 55500  Cumulative average 52022.4 best score: 59150 epsilon 0.47 steps 52882
# Episode: 275 Total Revenue: 52350  Cumulative average 52023.6 best score: 59150 epsilon 0.47 steps 53075
# Episode: 276 Total Revenue: 53350  Cumulative average 52028.4 best score: 59150 epsilon 0.47 steps 53268
# Episode: 277 Total Revenue: 52800  Cumulative average 52031.2 best score: 59150 epsilon 0.47 steps 53461
# Episode: 278 Total Revenue: 52650  Cumulative average 52033.5 best score: 59150 epsilon 0.47 steps 53654
# Episode: 279 Total Revenue: 54200  Cumulative average 52041.2 best score: 59150 epsilon 0.46 steps 53847
# Episode: 280 Total Revenue: 53100  Cumulative average 52045.0 best score: 59150 epsilon 0.46 steps 54040
# Episode: 281 Total Revenue: 52800  Cumulative average 52047.7 best score: 59150 epsilon 0.46 steps 54233
# Episode: 282 Total Revenue: 54450  Cumulative average 52056.2 best score: 59150 epsilon 0.46 steps 54426
# Episode: 283 Total Revenue: 51600  Cumulative average 52054.6 best score: 59150 epsilon 0.46 steps 54619
# Episode: 284 Total Revenue: 53050  Cumulative average 52058.1 best score: 59150 epsilon 0.45 steps 54812
# Episode: 285 Total Revenue: 53750  Cumulative average 52064.0 best score: 59150 epsilon 0.45 steps 55005
# Episode: 286 Total Revenue: 54650  Cumulative average 52073.1 best score: 59150 epsilon 0.45 steps 55198
# Episode: 287 Total Revenue: 53200  Cumulative average 52077.0 best score: 59150 epsilon 0.45 steps 55391
# Episode: 288 Total Revenue: 52800  Cumulative average 52079.5 best score: 59150 epsilon 0.45 steps 55584
# Episode: 289 Total Revenue: 55100  Cumulative average 52090.0 best score: 59150 epsilon 0.44 steps 55777
# Episode: 290 Total Revenue: 51600  Cumulative average 52088.3 best score: 59150 epsilon 0.44 steps 55970
# Episode: 291 Total Revenue: 50950  Cumulative average 52084.4 best score: 59150 epsilon 0.44 steps 56163
# Episode: 292 Total Revenue: 49750  Cumulative average 52076.4 best score: 59150 epsilon 0.44 steps 56356
# Episode: 293 Total Revenue: 53000  Cumulative average 52079.5 best score: 59150 epsilon 0.44 steps 56549
# Episode: 294 Total Revenue: 53450  Cumulative average 52084.2 best score: 59150 epsilon 0.44 steps 56742
# Episode: 295 Total Revenue: 51700  Cumulative average 52082.9 best score: 59150 epsilon 0.43 steps 56935
# Episode: 296 Total Revenue: 53800  Cumulative average 52088.7 best score: 59150 epsilon 0.43 steps 57128
# Episode: 297 Total Revenue: 53350  Cumulative average 52092.9 best score: 59150 epsilon 0.43 steps 57321
# Episode: 298 Total Revenue: 51750  Cumulative average 52091.8 best score: 59150 epsilon 0.43 steps 57514
# Episode: 299 Total Revenue: 52100  Cumulative average 52091.8 best score: 59150 epsilon 0.43 steps 57707
# Episode: 300 Total Revenue: 51100  Cumulative average 52088.5 best score: 59150 epsilon 0.42 steps 57900
# Episode: 301 Total Revenue: 52050  Cumulative average 52088.4 best score: 59150 epsilon 0.42 steps 58093
# Episode: 302 Total Revenue: 53250  Cumulative average 52092.2 best score: 59150 epsilon 0.42 steps 58286
# Episode: 303 Total Revenue: 51750  Cumulative average 52091.1 best score: 59150 epsilon 0.42 steps 58479
# Episode: 304 Total Revenue: 53850  Cumulative average 52096.9 best score: 59150 epsilon 0.42 steps 58672
# Episode: 305 Total Revenue: 54050  Cumulative average 52103.3 best score: 59150 epsilon 0.41 steps 58865
# Episode: 306 Total Revenue: 54300  Cumulative average 52110.5 best score: 59150 epsilon 0.41 steps 59058
# Episode: 307 Total Revenue: 52900  Cumulative average 52113.0 best score: 59150 epsilon 0.41 steps 59251
# Episode: 308 Total Revenue: 52950  Cumulative average 52115.7 best score: 59150 epsilon 0.41 steps 59444
# Episode: 309 Total Revenue: 52050  Cumulative average 52115.5 best score: 59150 epsilon 0.41 steps 59637
# Episode: 310 Total Revenue: 52600  Cumulative average 52117.1 best score: 59150 epsilon 0.40 steps 59830
# Episode: 311 Total Revenue: 53250  Cumulative average 52120.7 best score: 59150 epsilon 0.40 steps 60023
# Episode: 312 Total Revenue: 53000  Cumulative average 52123.6 best score: 59150 epsilon 0.40 steps 60216
# Episode: 313 Total Revenue: 52500  Cumulative average 52124.8 best score: 59150 epsilon 0.40 steps 60409
# Episode: 314 Total Revenue: 54600  Cumulative average 52132.6 best score: 59150 epsilon 0.40 steps 60602
# Episode: 315 Total Revenue: 52850  Cumulative average 52134.9 best score: 59150 epsilon 0.39 steps 60795
# Episode: 316 Total Revenue: 54400  Cumulative average 52142.1 best score: 59150 epsilon 0.39 steps 60988
# Episode: 317 Total Revenue: 51200  Cumulative average 52139.1 best score: 59150 epsilon 0.39 steps 61181
# Episode: 318 Total Revenue: 53700  Cumulative average 52144.0 best score: 59150 epsilon 0.39 steps 61374
# Episode: 319 Total Revenue: 51250  Cumulative average 52141.2 best score: 59150 epsilon 0.39 steps 61567
# Episode: 320 Total Revenue: 50950  Cumulative average 52137.5 best score: 59150 epsilon 0.38 steps 61760
# Episode: 321 Total Revenue: 53850  Cumulative average 52142.8 best score: 59150 epsilon 0.38 steps 61953
# Episode: 322 Total Revenue: 51600  Cumulative average 52141.1 best score: 59150 epsilon 0.38 steps 62146
# Episode: 323 Total Revenue: 52450  Cumulative average 52142.1 best score: 59150 epsilon 0.38 steps 62339
# Episode: 324 Total Revenue: 55100  Cumulative average 52151.2 best score: 59150 epsilon 0.38 steps 62532
# Episode: 325 Total Revenue: 51550  Cumulative average 52149.4 best score: 59150 epsilon 0.38 steps 62725
# Episode: 326 Total Revenue: 53550  Cumulative average 52153.7 best score: 59150 epsilon 0.37 steps 62918
# Episode: 327 Total Revenue: 53300  Cumulative average 52157.2 best score: 59150 epsilon 0.37 steps 63111
# Episode: 328 Total Revenue: 51750  Cumulative average 52155.9 best score: 59150 epsilon 0.37 steps 63304
# Episode: 329 Total Revenue: 52200  Cumulative average 52156.1 best score: 59150 epsilon 0.37 steps 63497
# Episode: 330 Total Revenue: 54250  Cumulative average 52162.4 best score: 59150 epsilon 0.37 steps 63690
# Episode: 331 Total Revenue: 53250  Cumulative average 52165.7 best score: 59150 epsilon 0.36 steps 63883
# Episode: 332 Total Revenue: 52850  Cumulative average 52167.8 best score: 59150 epsilon 0.36 steps 64076
# Episode: 333 Total Revenue: 51700  Cumulative average 52166.4 best score: 59150 epsilon 0.36 steps 64269
# Episode: 334 Total Revenue: 52400  Cumulative average 52167.1 best score: 59150 epsilon 0.36 steps 64462
# Episode: 335 Total Revenue: 50450  Cumulative average 52161.9 best score: 59150 epsilon 0.36 steps 64655
# Episode: 336 Total Revenue: 50250  Cumulative average 52156.2 best score: 59150 epsilon 0.35 steps 64848
# Episode: 337 Total Revenue: 51150  Cumulative average 52153.3 best score: 59150 epsilon 0.35 steps 65041
# Episode: 338 Total Revenue: 51250  Cumulative average 52150.6 best score: 59150 epsilon 0.35 steps 65234
# Episode: 339 Total Revenue: 52200  Cumulative average 52150.7 best score: 59150 epsilon 0.35 steps 65427
# Episode: 340 Total Revenue: 53050  Cumulative average 52153.4 best score: 59150 epsilon 0.35 steps 65620
# Episode: 341 Total Revenue: 51850  Cumulative average 52152.5 best score: 59150 epsilon 0.34 steps 65813
# Episode: 342 Total Revenue: 52300  Cumulative average 52152.9 best score: 59150 epsilon 0.34 steps 66006
# Episode: 343 Total Revenue: 50900  Cumulative average 52149.3 best score: 59150 epsilon 0.34 steps 66199
# Episode: 344 Total Revenue: 52200  Cumulative average 52149.4 best score: 59150 epsilon 0.34 steps 66392
# Episode: 345 Total Revenue: 51250  Cumulative average 52146.8 best score: 59150 epsilon 0.34 steps 66585
# Episode: 346 Total Revenue: 51750  Cumulative average 52145.7 best score: 59150 epsilon 0.33 steps 66778
# Episode: 347 Total Revenue: 55150  Cumulative average 52154.3 best score: 59150 epsilon 0.33 steps 66971
# Episode: 348 Total Revenue: 52700  Cumulative average 52155.9 best score: 59150 epsilon 0.33 steps 67164
# Episode: 349 Total Revenue: 50550  Cumulative average 52151.3 best score: 59150 epsilon 0.33 steps 67357
# Episode: 350 Total Revenue: 53900  Cumulative average 52156.3 best score: 59150 epsilon 0.33 steps 67550
# Episode: 351 Total Revenue: 52350  Cumulative average 52156.8 best score: 59150 epsilon 0.33 steps 67743
# Episode: 352 Total Revenue: 54200  Cumulative average 52162.6 best score: 59150 epsilon 0.32 steps 67936
# Episode: 353 Total Revenue: 52500  Cumulative average 52163.6 best score: 59150 epsilon 0.32 steps 68129
# Episode: 354 Total Revenue: 54850  Cumulative average 52171.2 best score: 59150 epsilon 0.32 steps 68322
# Episode: 355 Total Revenue: 53550  Cumulative average 52175.1 best score: 59150 epsilon 0.32 steps 68515
# Episode: 356 Total Revenue: 52650  Cumulative average 52176.4 best score: 59150 epsilon 0.32 steps 68708
# Episode: 357 Total Revenue: 51450  Cumulative average 52174.4 best score: 59150 epsilon 0.31 steps 68901
# Episode: 358 Total Revenue: 54200  Cumulative average 52180.0 best score: 59150 epsilon 0.31 steps 69094
# Episode: 359 Total Revenue: 52850  Cumulative average 52181.9 best score: 59150 epsilon 0.31 steps 69287
# Episode: 360 Total Revenue: 53250  Cumulative average 52184.9 best score: 59150 epsilon 0.31 steps 69480
# Episode: 361 Total Revenue: 54150  Cumulative average 52190.3 best score: 59150 epsilon 0.31 steps 69673
# Episode: 362 Total Revenue: 48950  Cumulative average 52181.4 best score: 59150 epsilon 0.30 steps 69866
# Episode: 363 Total Revenue: 53150  Cumulative average 52184.0 best score: 59150 epsilon 0.30 steps 70059
# Episode: 364 Total Revenue: 50900  Cumulative average 52180.5 best score: 59150 epsilon 0.30 steps 70252
# Episode: 365 Total Revenue: 50050  Cumulative average 52174.7 best score: 59150 epsilon 0.30 steps 70445
# Episode: 366 Total Revenue: 52800  Cumulative average 52176.4 best score: 59150 epsilon 0.30 steps 70638
# Episode: 367 Total Revenue: 53100  Cumulative average 52178.9 best score: 59150 epsilon 0.29 steps 70831
# Episode: 368 Total Revenue: 52700  Cumulative average 52180.3 best score: 59150 epsilon 0.29 steps 71024
# Episode: 369 Total Revenue: 52050  Cumulative average 52179.9 best score: 59150 epsilon 0.29 steps 71217
# Episode: 370 Total Revenue: 53200  Cumulative average 52182.7 best score: 59150 epsilon 0.29 steps 71410
# Episode: 371 Total Revenue: 53200  Cumulative average 52185.4 best score: 59150 epsilon 0.29 steps 71603
# Episode: 372 Total Revenue: 53550  Cumulative average 52189.1 best score: 59150 epsilon 0.28 steps 71796
# Episode: 373 Total Revenue: 50700  Cumulative average 52185.1 best score: 59150 epsilon 0.28 steps 71989
# Episode: 374 Total Revenue: 52250  Cumulative average 52185.3 best score: 59150 epsilon 0.28 steps 72182
# Episode: 375 Total Revenue: 51400  Cumulative average 52183.2 best score: 59150 epsilon 0.28 steps 72375
# Episode: 376 Total Revenue: 50150  Cumulative average 52177.8 best score: 59150 epsilon 0.28 steps 72568
# Episode: 377 Total Revenue: 50700  Cumulative average 52173.9 best score: 59150 epsilon 0.27 steps 72761
# Episode: 378 Total Revenue: 50450  Cumulative average 52169.3 best score: 59150 epsilon 0.27 steps 72954
# Episode: 379 Total Revenue: 52700  Cumulative average 52170.7 best score: 59150 epsilon 0.27 steps 73147
# Episode: 380 Total Revenue: 50800  Cumulative average 52167.1 best score: 59150 epsilon 0.27 steps 73340
# Episode: 381 Total Revenue: 52500  Cumulative average 52168.0 best score: 59150 epsilon 0.27 steps 73533
# Episode: 382 Total Revenue: 52700  Cumulative average 52169.4 best score: 59150 epsilon 0.27 steps 73726
# Episode: 383 Total Revenue: 50700  Cumulative average 52165.5 best score: 59150 epsilon 0.26 steps 73919
# Episode: 384 Total Revenue: 50650  Cumulative average 52161.6 best score: 59150 epsilon 0.26 steps 74112
# Episode: 385 Total Revenue: 52050  Cumulative average 52161.3 best score: 59150 epsilon 0.26 steps 74305
# Episode: 386 Total Revenue: 53300  Cumulative average 52164.2 best score: 59150 epsilon 0.26 steps 74498
# Episode: 387 Total Revenue: 54850  Cumulative average 52171.2 best score: 59150 epsilon 0.26 steps 74691
# Episode: 388 Total Revenue: 51050  Cumulative average 52168.3 best score: 59150 epsilon 0.25 steps 74884
# Episode: 389 Total Revenue: 51450  Cumulative average 52166.5 best score: 59150 epsilon 0.25 steps 75077
# Episode: 390 Total Revenue: 52700  Cumulative average 52167.8 best score: 59150 epsilon 0.25 steps 75270
# Episode: 391 Total Revenue: 53050  Cumulative average 52170.1 best score: 59150 epsilon 0.25 steps 75463
# Episode: 392 Total Revenue: 49450  Cumulative average 52163.1 best score: 59150 epsilon 0.25 steps 75656
# Episode: 393 Total Revenue: 50700  Cumulative average 52159.4 best score: 59150 epsilon 0.24 steps 75849
# Episode: 394 Total Revenue: 50800  Cumulative average 52156.0 best score: 59150 epsilon 0.24 steps 76042
# Episode: 395 Total Revenue: 49350  Cumulative average 52148.9 best score: 59150 epsilon 0.24 steps 76235
# Episode: 396 Total Revenue: 52300  Cumulative average 52149.2 best score: 59150 epsilon 0.24 steps 76428
# Episode: 397 Total Revenue: 51150  Cumulative average 52146.7 best score: 59150 epsilon 0.24 steps 76621
# Episode: 398 Total Revenue: 50950  Cumulative average 52143.7 best score: 59150 epsilon 0.23 steps 76814
# Episode: 399 Total Revenue: 49900  Cumulative average 52138.1 best score: 59150 epsilon 0.23 steps 77007
# Episode: 400 Total Revenue: 51450  Cumulative average 52136.4 best score: 59150 epsilon 0.23 steps 77200
# Episode: 401 Total Revenue: 52500  Cumulative average 52137.3 best score: 59150 epsilon 0.23 steps 77393
# Episode: 402 Total Revenue: 52400  Cumulative average 52137.9 best score: 59150 epsilon 0.23 steps 77586
# Episode: 403 Total Revenue: 51450  Cumulative average 52136.2 best score: 59150 epsilon 0.22 steps 77779
# Episode: 404 Total Revenue: 50650  Cumulative average 52132.5 best score: 59150 epsilon 0.22 steps 77972
# Episode: 405 Total Revenue: 52950  Cumulative average 52134.6 best score: 59150 epsilon 0.22 steps 78165
# Episode: 406 Total Revenue: 52150  Cumulative average 52134.6 best score: 59150 epsilon 0.22 steps 78358
# Episode: 407 Total Revenue: 51600  Cumulative average 52133.3 best score: 59150 epsilon 0.22 steps 78551
# Episode: 408 Total Revenue: 52200  Cumulative average 52133.5 best score: 59150 epsilon 0.22 steps 78744
# Episode: 409 Total Revenue: 50700  Cumulative average 52130.0 best score: 59150 epsilon 0.21 steps 78937
# Episode: 410 Total Revenue: 51500  Cumulative average 52128.4 best score: 59150 epsilon 0.21 steps 79130
# Episode: 411 Total Revenue: 52100  Cumulative average 52128.3 best score: 59150 epsilon 0.21 steps 79323
# Episode: 412 Total Revenue: 52850  Cumulative average 52130.1 best score: 59150 epsilon 0.21 steps 79516
# Episode: 413 Total Revenue: 52800  Cumulative average 52131.7 best score: 59150 epsilon 0.21 steps 79709
# Episode: 414 Total Revenue: 52000  Cumulative average 52131.4 best score: 59150 epsilon 0.20 steps 79902
# Episode: 415 Total Revenue: 51900  Cumulative average 52130.8 best score: 59150 epsilon 0.20 steps 80095
# Episode: 416 Total Revenue: 52650  Cumulative average 52132.1 best score: 59150 epsilon 0.20 steps 80288
# Episode: 417 Total Revenue: 51100  Cumulative average 52129.6 best score: 59150 epsilon 0.20 steps 80481
# Episode: 418 Total Revenue: 50950  Cumulative average 52126.8 best score: 59150 epsilon 0.20 steps 80674
# Episode: 419 Total Revenue: 51450  Cumulative average 52125.2 best score: 59150 epsilon 0.19 steps 80867
# Episode: 420 Total Revenue: 51600  Cumulative average 52123.9 best score: 59150 epsilon 0.19 steps 81060
# Episode: 421 Total Revenue: 50800  Cumulative average 52120.8 best score: 59150 epsilon 0.19 steps 81253
# Episode: 422 Total Revenue: 50050  Cumulative average 52115.9 best score: 59150 epsilon 0.19 steps 81446
# Episode: 423 Total Revenue: 52450  Cumulative average 52116.7 best score: 59150 epsilon 0.19 steps 81639
# Episode: 424 Total Revenue: 51500  Cumulative average 52115.2 best score: 59150 epsilon 0.18 steps 81832
# Episode: 425 Total Revenue: 51850  Cumulative average 52114.6 best score: 59150 epsilon 0.18 steps 82025
# Episode: 426 Total Revenue: 49900  Cumulative average 52109.4 best score: 59150 epsilon 0.18 steps 82218
# Episode: 427 Total Revenue: 51650  Cumulative average 52108.3 best score: 59150 epsilon 0.18 steps 82411
# Episode: 428 Total Revenue: 51050  Cumulative average 52105.8 best score: 59150 epsilon 0.18 steps 82604
# Episode: 429 Total Revenue: 53250  Cumulative average 52108.5 best score: 59150 epsilon 0.17 steps 82797
# Episode: 430 Total Revenue: 52750  Cumulative average 52110.0 best score: 59150 epsilon 0.17 steps 82990
# Episode: 431 Total Revenue: 50550  Cumulative average 52106.4 best score: 59150 epsilon 0.17 steps 83183
# Episode: 432 Total Revenue: 49650  Cumulative average 52100.7 best score: 59150 epsilon 0.17 steps 83376
# Episode: 433 Total Revenue: 50250  Cumulative average 52096.4 best score: 59150 epsilon 0.17 steps 83569
# Episode: 434 Total Revenue: 50150  Cumulative average 52091.9 best score: 59150 epsilon 0.16 steps 83762
# Episode: 435 Total Revenue: 52050  Cumulative average 52091.8 best score: 59150 epsilon 0.16 steps 83955
# Episode: 436 Total Revenue: 51100  Cumulative average 52089.6 best score: 59150 epsilon 0.16 steps 84148
# Episode: 437 Total Revenue: 50200  Cumulative average 52085.2 best score: 59150 epsilon 0.16 steps 84341
# Episode: 438 Total Revenue: 51750  Cumulative average 52084.5 best score: 59150 epsilon 0.16 steps 84534
# Episode: 439 Total Revenue: 50950  Cumulative average 52081.9 best score: 59150 epsilon 0.16 steps 84727
# Episode: 440 Total Revenue: 49950  Cumulative average 52077.0 best score: 59150 epsilon 0.15 steps 84920
# Episode: 441 Total Revenue: 52250  Cumulative average 52077.4 best score: 59150 epsilon 0.15 steps 85113
# Episode: 442 Total Revenue: 52000  Cumulative average 52077.3 best score: 59150 epsilon 0.15 steps 85306
# Episode: 443 Total Revenue: 51200  Cumulative average 52075.3 best score: 59150 epsilon 0.15 steps 85499
# Episode: 444 Total Revenue: 53350  Cumulative average 52078.2 best score: 59150 epsilon 0.15 steps 85692
# Episode: 445 Total Revenue: 52300  Cumulative average 52078.7 best score: 59150 epsilon 0.14 steps 85885
# Episode: 446 Total Revenue: 51650  Cumulative average 52077.7 best score: 59150 epsilon 0.14 steps 86078
# Episode: 447 Total Revenue: 48950  Cumulative average 52070.7 best score: 59150 epsilon 0.14 steps 86271
# Episode: 448 Total Revenue: 52400  Cumulative average 52071.4 best score: 59150 epsilon 0.14 steps 86464
# Episode: 449 Total Revenue: 50550  Cumulative average 52068.0 best score: 59150 epsilon 0.14 steps 86657
# Episode: 450 Total Revenue: 51700  Cumulative average 52067.2 best score: 59150 epsilon 0.13 steps 86850
# Episode: 451 Total Revenue: 53000  Cumulative average 52069.3 best score: 59150 epsilon 0.13 steps 87043
# Episode: 452 Total Revenue: 51600  Cumulative average 52068.3 best score: 59150 epsilon 0.13 steps 87236
# Episode: 453 Total Revenue: 50850  Cumulative average 52065.6 best score: 59150 epsilon 0.13 steps 87429
# Episode: 454 Total Revenue: 51150  Cumulative average 52063.5 best score: 59150 epsilon 0.13 steps 87622
# ...
# Episode: 572 Total Revenue: 50650  Cumulative average 51856.6 best score: 59150 epsilon 0.10 steps 110396
# Episode: 573 Total Revenue: 52350  Cumulative average 51857.5 best score: 59150 epsilon 0.10 steps 110589
# Episode: 574 Total Revenue: 51050  Cumulative average 51856.1 best score: 59150 epsilon 0.10 steps 110782
# Episode: 575 Total Revenue: 52950  Cumulative average 51858.0 best score: 59150 epsilon 0.10 steps 110975
# Episode: 576 Total Revenue: 50450  Cumulative average 51855.6 best score: 59150 epsilon 0.10 steps 111168
# Episode: 577 Total Revenue: 50650  Cumulative average 51853.5 best score: 59150 epsilon 0.10 steps 111361
# Episode: 578 Total Revenue: 51650  Cumulative average 51853.1 best score: 59150 epsilon 0.10 steps 111554
# Episode: 579 Total Revenue: 50700  Cumulative average 51851.1 best score: 59150 epsilon 0.10 steps 111747
# Episode: 580 Total Revenue: 49850  Cumulative average 51847.7 best score: 59150 epsilon 0.10 steps 111940
# Episode: 581 Total Revenue: 54550  Cumulative average 51852.3 best score: 59150 epsilon 0.10 steps 112133
# Episode: 582 Total Revenue: 50300  Cumulative average 51849.7 best score: 59150 epsilon 0.10 steps 112326
# Episode: 583 Total Revenue: 51950  Cumulative average 51849.8 best score: 59150 epsilon 0.10 steps 112519
# Episode: 584 Total Revenue: 51100  Cumulative average 51848.5 best score: 59150 epsilon 0.10 steps 112712
# Episode: 585 Total Revenue: 51000  Cumulative average 51847.1 best score: 59150 epsilon 0.10 steps 112905
# Episode: 586 Total Revenue: 50700  Cumulative average 51845.1 best score: 59150 epsilon 0.10 steps 113098
# Episode: 587 Total Revenue: 49700  Cumulative average 51841.5 best score: 59150 epsilon 0.10 steps 113291
# Episode: 588 Total Revenue: 52000  Cumulative average 51841.8 best score: 59150 epsilon 0.10 steps 113484
# Episode: 589 Total Revenue: 51200  Cumulative average 51840.7 best score: 59150 epsilon 0.10 steps 113677
# Episode: 590 Total Revenue: 52350  Cumulative average 51841.5 best score: 59150 epsilon 0.10 steps 113870
# Episode: 591 Total Revenue: 51150  Cumulative average 51840.4 best score: 59150 epsilon 0.10 steps 114063
# Episode: 592 Total Revenue: 49450  Cumulative average 51836.3 best score: 59150 epsilon 0.10 steps 114256
# Episode: 593 Total Revenue: 50450  Cumulative average 51834.0 best score: 59150 epsilon 0.10 steps 114449
# Episode: 594 Total Revenue: 51750  Cumulative average 51833.8 best score: 59150 epsilon 0.10 steps 114642
# Episode: 595 Total Revenue: 49700  Cumulative average 51830.3 best score: 59150 epsilon 0.10 steps 114835
# Episode: 596 Total Revenue: 50950  Cumulative average 51828.8 best score: 59150 epsilon 0.10 steps 115028
# Episode: 597 Total Revenue: 51550  Cumulative average 51828.3 best score: 59150 epsilon 0.10 steps 115221
# Episode: 598 Total Revenue: 50300  Cumulative average 51825.8 best score: 59150 epsilon 0.10 steps 115414
# Episode: 599 Total Revenue: 50450  Cumulative average 51823.5 best score: 59150 epsilon 0.10 steps 115607
# Episode: 600 Total Revenue: 49500  Cumulative average 51819.6 best score: 59150 epsilon 0.10 steps 115800
# Episode: 601 Total Revenue: 50000  Cumulative average 51816.6 best score: 59150 epsilon 0.10 steps 115993
# Episode: 602 Total Revenue: 50500  Cumulative average 51814.4 best score: 59150 epsilon 0.10 steps 116186
# Episode: 603 Total Revenue: 51700  Cumulative average 51814.2 best score: 59150 epsilon 0.10 steps 116379
# Episode: 604 Total Revenue: 51850  Cumulative average 51814.2 best score: 59150 epsilon 0.10 steps 116572
# Episode: 605 Total Revenue: 49850  Cumulative average 51811.0 best score: 59150 epsilon 0.10 steps 116765
# Episode: 606 Total Revenue: 50550  Cumulative average 51808.9 best score: 59150 epsilon 0.10 steps 116958
# Episode: 607 Total Revenue: 49750  Cumulative average 51805.5 best score: 59150 epsilon 0.10 steps 117151
# Episode: 608 Total Revenue: 50850  Cumulative average 51803.9 best score: 59150 epsilon 0.10 steps 117344
# Episode: 609 Total Revenue: 52100  Cumulative average 51804.4 best score: 59150 epsilon 0.10 steps 117537
# Episode: 610 Total Revenue: 51850  Cumulative average 51804.5 best score: 59150 epsilon 0.10 steps 117730
# Episode: 611 Total Revenue: 49600  Cumulative average 51800.9 best score: 59150 epsilon 0.10 steps 117923
# Episode: 612 Total Revenue: 51200  Cumulative average 51799.9 best score: 59150 epsilon 0.10 steps 118116
# Episode: 613 Total Revenue: 49150  Cumulative average 51795.6 best score: 59150 epsilon 0.10 steps 118309
# Episode: 614 Total Revenue: 51350  Cumulative average 51794.9 best score: 59150 epsilon 0.10 steps 118502
# Episode: 615 Total Revenue: 51500  Cumulative average 51794.4 best score: 59150 epsilon 0.10 steps 118695
# Episode: 616 Total Revenue: 51250  Cumulative average 51793.5 best score: 59150 epsilon 0.10 steps 118888
# Episode: 617 Total Revenue: 53900  Cumulative average 51796.9 best score: 59150 epsilon 0.10 steps 119081
# Episode: 618 Total Revenue: 50800  Cumulative average 51795.3 best score: 59150 epsilon 0.10 steps 119274
# Episode: 619 Total Revenue: 50450  Cumulative average 51793.1 best score: 59150 epsilon 0.10 steps 119467
# Episode: 620 Total Revenue: 51850  Cumulative average 51793.2 best score: 59150 epsilon 0.10 steps 119660
# Episode: 621 Total Revenue: 53600  Cumulative average 51796.1 best score: 59150 epsilon 0.10 steps 119853
# Episode: 622 Total Revenue: 49300  Cumulative average 51792.1 best score: 59150 epsilon 0.10 steps 120046
# Episode: 623 Total Revenue: 49300  Cumulative average 51788.1 best score: 59150 epsilon 0.10 steps 120239
# Episode: 624 Total Revenue: 50300  Cumulative average 51785.7 best score: 59150 epsilon 0.10 steps 120432
# Episode: 625 Total Revenue: 51500  Cumulative average 51785.3 best score: 59150 epsilon 0.10 steps 120625
# Episode: 626 Total Revenue: 51100  Cumulative average 51784.2 best score: 59150 epsilon 0.10 steps 120818
# Episode: 627 Total Revenue: 51150  Cumulative average 51783.2 best score: 59150 epsilon 0.10 steps 121011
# Episode: 628 Total Revenue: 53500  Cumulative average 51785.9 best score: 59150 epsilon 0.10 steps 121204
# Episode: 629 Total Revenue: 52000  Cumulative average 51786.2 best score: 59150 epsilon 0.10 steps 121397
# Episode: 630 Total Revenue: 51350  Cumulative average 51785.6 best score: 59150 epsilon 0.10 steps 121590
# Episode: 631 Total Revenue: 51750  Cumulative average 51785.5 best score: 59150 epsilon 0.10 steps 121783
# Episode: 632 Total Revenue: 52300  Cumulative average 51786.3 best score: 59150 epsilon 0.10 steps 121976
# Episode: 633 Total Revenue: 51900  Cumulative average 51786.5 best score: 59150 epsilon 0.10 steps 122169
# Episode: 634 Total Revenue: 51200  Cumulative average 51785.6 best score: 59150 epsilon 0.10 steps 122362
# Episode: 635 Total Revenue: 52450  Cumulative average 51786.6 best score: 59150 epsilon 0.10 steps 122555
# Episode: 636 Total Revenue: 49650  Cumulative average 51783.3 best score: 59150 epsilon 0.10 steps 122748
# Episode: 637 Total Revenue: 50700  Cumulative average 51781.6 best score: 59150 epsilon 0.10 steps 122941
# Episode: 638 Total Revenue: 50750  Cumulative average 51779.9 best score: 59150 epsilon 0.10 steps 123134
# Episode: 639 Total Revenue: 51700  Cumulative average 51779.8 best score: 59150 epsilon 0.10 steps 123327
# Episode: 640 Total Revenue: 51050  Cumulative average 51778.7 best score: 59150 epsilon 0.10 steps 123520
# Episode: 641 Total Revenue: 50850  Cumulative average 51777.2 best score: 59150 epsilon 0.10 steps 123713
# Episode: 642 Total Revenue: 52100  Cumulative average 51777.7 best score: 59150 epsilon 0.10 steps 123906
# Episode: 643 Total Revenue: 50250  Cumulative average 51775.3 best score: 59150 epsilon 0.10 steps 124099
# Episode: 644 Total Revenue: 50550  Cumulative average 51773.4 best score: 59150 epsilon 0.10 steps 124292
# Episode: 645 Total Revenue: 50450  Cumulative average 51771.4 best score: 59150 epsilon 0.10 steps 124485
# Episode: 646 Total Revenue: 54250  Cumulative average 51775.2 best score: 59150 epsilon 0.10 steps 124678
# Episode: 647 Total Revenue: 49500  Cumulative average 51771.7 best score: 59150 epsilon 0.10 steps 124871
# Episode: 648 Total Revenue: 50650  Cumulative average 51770.0 best score: 59150 epsilon 0.10 steps 125064
# Episode: 649 Total Revenue: 51300  Cumulative average 51769.3 best score: 59150 epsilon 0.10 steps 125257
# Episode: 650 Total Revenue: 52900  Cumulative average 51771.0 best score: 59150 epsilon 0.10 steps 125450
# Episode: 651 Total Revenue: 53750  Cumulative average 51774.0 best score: 59150 epsilon 0.10 steps 125643
# Episode: 652 Total Revenue: 52200  Cumulative average 51774.7 best score: 59150 epsilon 0.10 steps 125836
# Episode: 653 Total Revenue: 52600  Cumulative average 51776.0 best score: 59150 epsilon 0.10 steps 126029
# Episode: 654 Total Revenue: 52600  Cumulative average 51777.2 best score: 59150 epsilon 0.10 steps 126222
# Episode: 655 Total Revenue: 51000  Cumulative average 51776.0 best score: 59150 epsilon 0.10 steps 126415
# Episode: 656 Total Revenue: 49700  Cumulative average 51772.9 best score: 59150 epsilon 0.10 steps 126608
# Episode: 657 Total Revenue: 50650  Cumulative average 51771.2 best score: 59150 epsilon 0.10 steps 126801
# Episode: 658 Total Revenue: 53650  Cumulative average 51774.0 best score: 59150 epsilon 0.10 steps 126994
# Episode: 659 Total Revenue: 49900  Cumulative average 51771.2 best score: 59150 epsilon 0.10 steps 127187
# Episode: 660 Total Revenue: 51300  Cumulative average 51770.5 best score: 59150 epsilon 0.10 steps 127380
# Episode: 661 Total Revenue: 50150  Cumulative average 51768.0 best score: 59150 epsilon 0.10 steps 127573
# Episode: 662 Total Revenue: 52050  Cumulative average 51768.4 best score: 59150 epsilon 0.10 steps 127766
# Episode: 663 Total Revenue: 51300  Cumulative average 51767.7 best score: 59150 epsilon 0.10 steps 127959
# Episode: 664 Total Revenue: 50550  Cumulative average 51765.9 best score: 59150 epsilon 0.10 steps 128152
# Episode: 665 Total Revenue: 50500  Cumulative average 51764.0 best score: 59150 epsilon 0.10 steps 128345
# Episode: 666 Total Revenue: 51350  Cumulative average 51763.4 best score: 59150 epsilon 0.10 steps 128538
# Episode: 667 Total Revenue: 53300  Cumulative average 51765.7 best score: 59150 epsilon 0.10 steps 128731
# Episode: 668 Total Revenue: 51900  Cumulative average 51765.9 best score: 59150 epsilon 0.10 steps 128924
# Episode: 669 Total Revenue: 50150  Cumulative average 51763.5 best score: 59150 epsilon 0.10 steps 129117
# Episode: 670 Total Revenue: 50100  Cumulative average 51761.0 best score: 59150 epsilon 0.10 steps 129310
# Episode: 671 Total Revenue: 52250  Cumulative average 51761.7 best score: 59150 epsilon 0.10 steps 129503
# Episode: 672 Total Revenue: 52150  Cumulative average 51762.3 best score: 59150 epsilon 0.10 steps 129696
# Episode: 673 Total Revenue: 53800  Cumulative average 51765.3 best score: 59150 epsilon 0.10 steps 129889
# Episode: 674 Total Revenue: 52450  Cumulative average 51766.3 best score: 59150 epsilon 0.10 steps 130082
# Episode: 675 Total Revenue: 49800  Cumulative average 51763.4 best score: 59150 epsilon 0.10 steps 130275
# Episode: 676 Total Revenue: 50650  Cumulative average 51761.8 best score: 59150 epsilon 0.10 steps 130468
# Episode: 677 Total Revenue: 52150  Cumulative average 51762.3 best score: 59150 epsilon 0.10 steps 130661
# Episode: 678 Total Revenue: 50550  Cumulative average 51760.5 best score: 59150 epsilon 0.10 steps 130854
# Episode: 679 Total Revenue: 53650  Cumulative average 51763.3 best score: 59150 epsilon 0.10 steps 131047
# Episode: 680 Total Revenue: 51850  Cumulative average 51763.5 best score: 59150 epsilon 0.10 steps 131240
# Episode: 681 Total Revenue: 50650  Cumulative average 51761.8 best score: 59150 epsilon 0.10 steps 131433
# Episode: 682 Total Revenue: 52550  Cumulative average 51763.0 best score: 59150 epsilon 0.10 steps 131626
# Episode: 683 Total Revenue: 50950  Cumulative average 51761.8 best score: 59150 epsilon 0.10 steps 131819
# Episode: 684 Total Revenue: 49900  Cumulative average 51759.1 best score: 59150 epsilon 0.10 steps 132012
# Episode: 685 Total Revenue: 51350  Cumulative average 51758.5 best score: 59150 epsilon 0.10 steps 132205
# Episode: 686 Total Revenue: 51900  Cumulative average 51758.7 best score: 59150 epsilon 0.10 steps 132398
# Episode: 687 Total Revenue: 49400  Cumulative average 51755.2 best score: 59150 epsilon 0.10 steps 132591
# Episode: 688 Total Revenue: 49950  Cumulative average 51752.6 best score: 59150 epsilon 0.10 steps 132784
# Episode: 689 Total Revenue: 53650  Cumulative average 51755.4 best score: 59150 epsilon 0.10 steps 132977
# Episode: 690 Total Revenue: 51850  Cumulative average 51755.5 best score: 59150 epsilon 0.10 steps 133170
# Episode: 691 Total Revenue: 50100  Cumulative average 51753.1 best score: 59150 epsilon 0.10 steps 133363
# Episode: 692 Total Revenue: 51550  Cumulative average 51752.8 best score: 59150 epsilon 0.10 steps 133556
# Episode: 693 Total Revenue: 52900  Cumulative average 51754.5 best score: 59150 epsilon 0.10 steps 133749
# Episode: 694 Total Revenue: 49650  Cumulative average 51751.4 best score: 59150 epsilon 0.10 steps 133942
# Episode: 695 Total Revenue: 51900  Cumulative average 51751.7 best score: 59150 epsilon 0.10 steps 134135
# Episode: 696 Total Revenue: 50800  Cumulative average 51750.3 best score: 59150 epsilon 0.10 steps 134328
# Episode: 697 Total Revenue: 50900  Cumulative average 51749.1 best score: 59150 epsilon 0.10 steps 134521
# Episode: 698 Total Revenue: 51850  Cumulative average 51749.2 best score: 59150 epsilon 0.10 steps 134714
# Episode: 699 Total Revenue: 50800  Cumulative average 51747.9 best score: 59150 epsilon 0.10 steps 134907
# Episode: 700 Total Revenue: 49750  Cumulative average 51745.0 best score: 59150 epsilon 0.10 steps 135100
# Episode: 701 Total Revenue: 50600  Cumulative average 51743.4 best score: 59150 epsilon 0.10 steps 135293
# Episode: 702 Total Revenue: 48900  Cumulative average 51739.3 best score: 59150 epsilon 0.10 steps 135486
# Episode: 703 Total Revenue: 49050  Cumulative average 51735.5 best score: 59150 epsilon 0.10 steps 135679
# Episode: 704 Total Revenue: 51450  Cumulative average 51735.1 best score: 59150 epsilon 0.10 steps 135872
# Episode: 705 Total Revenue: 49700  Cumulative average 51732.2 best score: 59150 epsilon 0.10 steps 136065
# Episode: 706 Total Revenue: 51500  Cumulative average 51731.9 best score: 59150 epsilon 0.10 steps 136258
# Episode: 707 Total Revenue: 51750  Cumulative average 51731.9 best score: 59150 epsilon 0.10 steps 136451
# Episode: 708 Total Revenue: 52250  Cumulative average 51732.6 best score: 59150 epsilon 0.10 steps 136644
# Episode: 709 Total Revenue: 52600  Cumulative average 51733.9 best score: 59150 epsilon 0.10 steps 136837
# Episode: 710 Total Revenue: 49500  Cumulative average 51730.7 best score: 59150 epsilon 0.10 steps 137030
# Episode: 711 Total Revenue: 52000  Cumulative average 51731.1 best score: 59150 epsilon 0.10 steps 137223
# Episode: 712 Total Revenue: 52900  Cumulative average 51732.7 best score: 59150 epsilon 0.10 steps 137416
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 40
#      38 # agent memorize transition
#      39 agent.store_transition(observation, action, reward, observation_, departure)
# ---> 40 agent.learn()
#      42 # Move on to the next state
#      43 observation = observation_
#
# Cell In[12], line 67, in DQNAgent.learn(self)
#      63 self.q_eval.optimizer.zero_grad() # diminish previous gradient
#      65 self.replace_target_network()
# ---> 67 states, actions, rewards, states_, dones = self.sample_memory()
#      68 indices = np.arange(self.batch_size)
#      70 q_pred = self.q_eval.forward(states)[indices, actions]
#
# Cell In[12], line 44, in DQNAgent.sample_memory(self)
#      42 dones = T.tensor(done).to(self.q_eval.device)
#      43 actions = T.tensor(action).to(self.q_eval.device)
# ---> 44 states_ = T.tensor(new_state).to(self.q_eval.device)
#      45 return states, actions, rewards, states_, dones
#
# KeyboardInterrupt:

# %%
# Plot results
plt.figure(figsize=(10, 6))  
plt.plot(range(num_episodes), DQN_total_revenues, label='DQN each episode', alpha=0.5, color='b')
plt.plot(range(num_episodes), DQN_per_50_avg, label='DQN per 50 episode', alpha=0.5, color='green')
plt.plot(range(num_episodes), DQN_cumulative_average, label='DQN Cumulative')
plt.axhline(y=dp, color='r', label='DP')
plt.axhline(y=fcfs, color='orange', label='FCFS')
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('Total Reward per Episode')
plt.legend()  
plt.grid(True)
plt.show()
